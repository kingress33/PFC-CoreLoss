# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# 讀取 CSV 檔案
file_path = ".\Data\CH467160.csv"
data = pd.read_csv(file_path)

# 確認資料格式
B1 = data['B1']  #N=20
H1 = data['H1']

B2 = data['B2']  #N=10
H2 = data['H2']

#參數
freq = 100e-3
Ve = 0.0000213726

# %% [markdown]
# ![DMR96A_S_100kHz_100mT-10_Norm..jpg](attachment:DMR96A_S_100kHz_100mT-10_Norm..jpg)

# %%
# # 使用 trapz 計算面積
# area = np.trapz(H, B)
# Pcv = freq * np.trapz(H, B) * 1000
# print(f"BH 曲線的面積為: {abs(Pcv):.6f}kW/m^3")

# 繪製 BH 曲線
plt.figure(figsize=(8, 6))
plt.plot(H1, B1, label='B-H Curve')
plt.plot(H2, B2, label='B-H Curve')
plt.title("CH467160 @Hdc=1000A/m,deltaB=40mT B-H Curve Compare ")
plt.xlabel("H (A/m)")
plt.ylabel("B (T)")
plt.grid(True)
plt.legend(["N=20", "N=10"])
plt.show()
