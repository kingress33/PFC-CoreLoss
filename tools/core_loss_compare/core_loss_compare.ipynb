# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# 讀取 CSV 檔案的數據
file1 = './Data/CH229160_waveform.csv'

data1 = pd.read_csv(file1)

print(data1)

# IWATSU_Hdc = data1['Hdc_IWATSU']
# IWATSU_Pcv = data1['Pcv_IWATSU']
# Meas_Hdc = data1['Hdc_Meas']
# Meas_Pcv = data1['Pcv_Meas']

IWATSU_Hdc = data1['B_IWATSU']
IWATSU_Pcv = data1['Pcv_IWATSU']
Meas_Hdc = data1['B_Meas']
Meas_Pcv = data1['Pcv_Meas']
# Out:
#     B_IWATSU  Pcv_IWATSU    B_Meas  Pcv_Meas
# 0   0.019989      24.846  0.019936    20.680
# 1   0.025020      40.022  0.024996    35.454
# 2   0.029603      57.374  0.030010    51.917
# 3   0.034924      82.053  0.034867    72.154
# 4   0.040083     110.740  0.039862    96.806
# 5   0.045138     144.420  0.044858   125.800
# 6   0.050046     180.200  0.050106   159.590
# 7   0.055072     224.520  0.055041   197.340
# 8   0.060326     271.430  0.060084   239.410
# 9   0.065241     327.470  0.065127   285.690
# 10  0.069860     386.070  0.070228   347.040
# 11  0.073915     437.790  0.075235   402.200
# 12  0.080268     524.660  0.080255   461.430
# 13  0.085205     601.540  0.085248   524.690
# 14  0.090419     682.010  0.090268   598.100
# 15  0.095386     766.800  0.095255   670.090
# 16  0.100300     854.490  0.100100   744.140
# 17  0.125400    1397.300  0.125300  1210.600
# 18  0.148000    1997.900  0.149700  1764.500
# 19  0.174800    2838.100  0.174600  2412.500
# ...

# %%
# # 繪圖
# plt.figure(figsize=(8, 6))

# # IWATSU 曲線
# plt.plot(IWATSU_Hdc,
#          IWATSU_Pcv,
#          'o--',
#          label="IWATSU",
#          linewidth=2,
#          markersize=6)

# # 測量數據
# plt.plot(Meas_Hdc, Meas_Pcv, 'x', label="Meas-Test1", markersize=8)

# # 設定對數尺度
# plt.xscale("log")
# plt.yscale("log")
# plt.ylim(1, 100)

# # 標籤和標題
# plt.xlabel(r"$H_{dc}$ (A/m)", fontsize=12)
# plt.ylabel(r"$P_{core}$ (kW/m³)", fontsize=12)
# plt.title(r"CH229060 100kHz $\Delta B$=50mT Core Loss Compare (Log)",
#           fontsize=14)
# plt.legend(fontsize=10)

# # 格線和顯示
# plt.grid(which="both", linestyle="--", linewidth=0.5)
# plt.tight_layout()
# plt.show()

# =============================================== B ==============================================

# 繪圖
plt.figure(figsize=(8, 6))

# IWATSU 曲線
plt.plot(IWATSU_Hdc, IWATSU_Pcv, 'o--', label="SIN", linewidth=2, markersize=6)

# IWATSU 曲線
plt.plot(Meas_Hdc, Meas_Pcv, 'o--', label="TRI", linewidth=2, markersize=6)
# 設定對數尺度
plt.xscale("log")
plt.yscale("log")
# plt.ylim(1, 100)

# 標籤和標題
plt.xlabel(r"$B_{m}$ (mT)", fontsize=12)
plt.ylabel(r"$P_{core}$ (kW/m³)", fontsize=12)
plt.title(r"CH229160 100kHz Core Loss Compare (Log)", fontsize=14)
plt.legend(fontsize=10)

# 格線和顯示
plt.grid(which="both", linestyle="--", linewidth=0.5)
plt.tight_layout()
plt.show()
