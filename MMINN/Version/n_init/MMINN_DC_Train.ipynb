# %% [markdown]
# # Part 1: Network Training

# %% [markdown]
# ## Step0: Import Package & Hyperparameter Configuration

# %%
"""
2025/02/03: 1.新增normDict計算 #!注意normDict是有先經過資料前處理計算的
            2.資料集中任意取n筆去訓練(n:自填數) 
            
2025/03/17: 1.修改增加Hdc,N輸入參數
            2.Mdoel修正兩個子迴路接考慮Hdc與N            
            
"""
# Out:
# '\n2025/02/03: 1.新增normDict計算 #!注意normDict是有先經過資料前處理計算的\n            2.資料集中任意取n筆去訓練(n:自填數) \n            \n2025/03/17: 1.修改增加Hdc,N輸入參數\n            2.Mdoel修正兩個子迴路接考慮Hdc與N            \n            \n'

# %%
# %reset -f  # 清空所有變數

import gc
gc.collect()  # 強制 Python 回收記憶體
# Out:
# Don't know how to reset  #, please run `%reset?` for details
# Don't know how to reset  清空所有變數, please run `%reset?` for details
# 0

# %% [markdown]
# ### Package

# %%
import os
import torch
import numpy as np
import random
import torch.nn as nn
from torch.autograd import Variable
from torch.utils.data import DataLoader, TensorDataset
import matplotlib.pyplot as plt
from tqdm import tqdm

# %% [markdown]
# ### Hyperparameter Config

# %%
# %%
# Unified Hyperparameter Configuration
class Config:
    SEED = 1
    NUM_EPOCHS = 3000
    BATCH_SIZE = 128
    LEARNING_RATE = 0.002  #論文提供
    LR_SCHEDULER_GAMMA = 0.99  #論文提供
    DECAY_EPOCH = 200
    DECAY_RATIO = 0.5
    EARLY_STOPPING_PATIENCE = 500
    HIDDEN_SIZE = 30
    OPERATOR_SIZE = 30


# Reproducibility
random.seed(Config.SEED)
np.random.seed(Config.SEED)
torch.manual_seed(Config.SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %% [markdown]
# ### Material & Number of Data

# %%
material = "CH467160"
down_sample_way = "range"
downsample = 128

# 訓練情況況
plot_interval = 300
train_show_sample = 1

# 定義保存模型的路徑
model_save_dir = f"./Model/{down_sample_way}/{downsample}/"
os.makedirs(model_save_dir, exist_ok=True)  # 如果路徑不存在，創建路徑
model_save_path = os.path.join(model_save_dir, f"{material}.pt")  # 定義模型保存檔名

figure_save_base_path = f"./figure/{down_sample_way}/{downsample}/"
os.makedirs(figure_save_base_path, exist_ok=True)  # 如果路徑不存在，創建路徑

# Select device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Step1: Data processing and data loader generate

# %%
# %% Preprocess data into a data loader
def get_dataloader(data_B,
                   data_F,
                   data_T,
                   data_H,
                   data_N,
                   data_Hdc,
                   data_Pcv,
                   n_init=16):
    """ #*(Date:250105)
    Process data and return DataLoader for training, validation, and testing.

    Parameters
    ----------
    data_B : np.array
        Magnetic flux density data.
    data_F : np.array
        Frequency data.
    data_T : np.array
        Temperature data.
    data_N : np.array
        Turns data.
    data_Hdc : np.array
        DC Magnetic field strength data.
    data_H : np.array
        AC Magnetic field strength data.
    data_Pcv : np.array
        Core loss data.
    norm : list
        Normalization parameters for the features.
    n_init : int
        Number of initial data points for magnetization.

    Returns
    -------
        train_loader, valid_loader : DataLoader
        Dataloaders for training, validation
        norm
    """

    # Data pre-process

    # 1. Down-sample to 128 points
    seq_length = downsample
    #range(start, stop, step) #*  Add  Down-sample: 8192 to 128 points (Date:241213)
    # cols = range(0, 8192, int(8192 / seq_length))
    cols = np.linspace(0, 8191, seq_length, dtype=int)
    data_B = data_B[:, cols]
    data_H = data_H[:, cols]  #*  Add H Down-sample to 128 points (Date:241213)

    # data_B = data_B - np.mean(data_B, axis=1,
    #                           keepdims=True)  #*  移除降階影響 (Date:250325)
    # data_H = data_H - np.mean(data_H, axis=1, keepdims=True)

    # 2. Add extra points for initial magnetization calculation
    #*(Date:241216) MMINN output似乎是128點
    #*(Date:250130) 原始MMINN H有包含n_init
    data_length = seq_length + n_init
    data_B = np.hstack((data_B, data_B[:, :n_init]))
    data_H = np.hstack((data_H, data_H[:, :n_init]))

    # 3. Format data into tensors  #*(Date:241216) seq_length=128, data_length=144
    B = torch.from_numpy(data_B).view(-1, data_length, 1).float()
    H = torch.from_numpy(data_H).view(-1, data_length, 1).float()
    F = torch.log10(torch.from_numpy(data_F).view(-1, 1).float())
    T = torch.from_numpy(data_T).view(-1, 1).float()
    Hdc = torch.from_numpy(data_Hdc).view(-1, 1).float()
    N = torch.from_numpy(data_N).view(-1, 1).float()
    Pcv = torch.log10(torch.from_numpy(data_Pcv).view(-1, 1).float())

    # 原本在6. 因要先計算標準化故移至這
    dB = torch.diff(B, dim=1)
    dB = torch.cat((dB[:, 0:1], dB), dim=1)
    dB_dt = dB * (seq_length * F.view(-1, 1, 1))

    # # 4. Compute normalization parameters (均值 & 標準差)**
    # norm = [
    #     [torch.mean(B).item(), torch.std(B).item()],  # B
    #     [torch.mean(H).item(), torch.std(H).item()],  # H
    #     [torch.mean(F).item(), torch.std(F).item()],  # F
    #     [torch.mean(T).item(), torch.std(T).item()],  # T
    #     [torch.mean(Hdc).item(), torch.std(Hdc).item()],  # Hdc #*(250317新加入)
    #     [torch.mean(N).item(), torch.std(N).item()],  # N #*(250317新加入)
    #     [torch.mean(Pcv).item(), torch.std(Pcv).item()],  # Pv
    # ]

    #  4. Compute normalization parameters (均值 & 標準差)**
    # ! 溫度頻率不變加入微小的 epsilon
    norm = [
        safe_mean_std(B),  # 0: B
        safe_mean_std(H),  # 1: H
        safe_mean_std(F),  # 2: F
        safe_mean_std(T),  # 3: T
        safe_mean_std(dB_dt),  # 4: dB/dt
        safe_mean_std(Pcv),  # 5: Pcv
        safe_mean_std(Hdc),  # 6: Hdc
        safe_mean_std(N)  # 7: N
    ]

    # 用來做test固定標準化參數的
    material_name = f"{material}"
    print(f'"{material_name}": [')
    for param in norm:
        print(f"    {param},")
    print("]")

    # 5. Data Normalization
    in_B = (B - norm[0][0]) / norm[0][1]  # B
    out_H = (H - norm[1][0]) / norm[1][1]  # H
    in_F = (F - norm[2][0]) / norm[2][1]  # F
    in_T = (T - norm[3][0]) / norm[3][1]  # T

    in_Pcv = (Pcv - norm[5][0]) / norm[5][1]  # Pcv
    in_Hdc = (Hdc - norm[6][0]) / norm[6][1]  # Hdc
    in_N = (N - norm[7][0]) / norm[7][1]  # N

    # 6. Extra features

    in_dB = torch.diff(B, dim=1)
    in_dB = torch.cat((in_dB[:, 0:1], in_dB), dim=1)

    in_dB_dt = (dB_dt - norm[4][0]) / norm[4][1]

    max_B, _ = torch.max(in_B, dim=1)
    min_B, _ = torch.min(in_B, dim=1)

    s0 = get_operator_init(in_B[:, 0] - in_dB[:, 0], in_dB, max_B, min_B)

    # 7. Create dataloader to speed up data processing
    full_dataset = torch.utils.data.TensorDataset(
        torch.cat((in_B, in_dB, in_dB_dt), dim=2),  # B 部分（144 點）
        torch.cat((in_F, in_T, in_Hdc, in_N, in_Pcv), dim=1),  # 輔助變量
        s0,  # 初始狀態
        out_H)

    # Split dataset into train, validation, and test sets (60:20:20)
    train_size = int(0.8 * len(full_dataset))
    valid_size = len(full_dataset) - train_size

    train_dataset, valid_dataset = torch.utils.data.random_split(
        full_dataset, [train_size, valid_size],
        generator=torch.Generator().manual_seed(Config.SEED))

    train_loader = torch.utils.data.DataLoader(train_dataset,
                                               batch_size=Config.BATCH_SIZE,
                                               shuffle=True,
                                               num_workers=0,
                                               collate_fn=filter_input)

    valid_loader = torch.utils.data.DataLoader(valid_dataset,
                                               batch_size=Config.BATCH_SIZE,
                                               shuffle=False,
                                               num_workers=0,
                                               collate_fn=filter_input)

    return train_loader, valid_loader, norm


# %% Predict the operator state at t0
def get_operator_init(B1,
                      dB,
                      Bmax,
                      Bmin,
                      max_out_H=5,
                      operator_size=Config.OPERATOR_SIZE):
    """Compute the initial state of hysteresis operators"""
    s0 = torch.zeros((dB.shape[0], operator_size))
    operator_thre = torch.from_numpy(
        np.linspace(max_out_H / operator_size, max_out_H,
                    operator_size)).view(1, -1)

    for i in range(dB.shape[0]):
        for j in range(operator_size):
            r = operator_thre[0, j]
            if (Bmax[i] >= r) or (Bmin[i] <= -r):
                if dB[i, 0] >= 0:
                    if B1[i] > Bmin[i] + 2 * r:
                        s0[i, j] = r
                    else:
                        s0[i, j] = B1[i] - (r + Bmin[i])
                else:
                    if B1[i] < Bmax[i] - 2 * r:
                        s0[i, j] = -r
                    else:
                        s0[i, j] = B1[i] + (r - Bmax[i])
    return s0


def filter_input(batch):
    inputs, features, s0, target_H = zip(*batch)

    # 如果 inputs 是 tuple，先堆疊成張量
    inputs = torch.stack(inputs)  # B 的所有輸入部分（144 點）

    # 保留 in_B, in_dB, in_dB_dt 作為模型輸入
    inputs = inputs[:, :, :3]

    # 保留 features（包括 in_F 和 in_T）
    features = torch.stack(
        features
    )[:, :4]  #!(250317)保留 in_F, in_T, in_Hdc, in_N (排除 in_Pcv，in_Pcv要放在最面)

    # 保留目標值 H
    target_H = torch.stack(
        target_H)[:, -downsample:, :]  # ?只取最後 128 點 (改1024看狀況有無變好)

    s0 = torch.stack(s0)  # 初始狀態

    return inputs, features, s0, target_H


# ! 溫度頻率不變加入微小的 epsilon
def safe_mean_std(tensor, eps=1e-8):
    m_tensor = torch.mean(tensor)  # 還是 Tensor
    s_tensor = torch.std(tensor)  # 還是 Tensor

    m_val = m_tensor.item()  # 第一次轉成 float
    s_val = s_tensor.item()
    if s_val < eps:
        s_val = 1.0

    return [m_val, s_val]  # 直接回傳 float

# %% [markdown]
# ## Step2: Define Network Structure

# %%
# %% Magnetization mechansim-determined neural network
"""
    Parameters:
    - hidden_size: number of eddy current slices (RNN neuron)
    - operator_size: number of operators
    - input_size: number of inputs (1.B 2.dB 3.dB/dt)
# ! - var_size: number of supplenmentary variables (1.F 2.T 3.Hdc 4.N)        
    - output_size: number of outputs (1.H)
"""


class MMINet(nn.Module):
    def __init__(
            self,
            norm,  #*這裡改成從外部傳入 norm(250203)
            hidden_size=Config.HIDDEN_SIZE,
            operator_size=Config.OPERATOR_SIZE,
            input_size=3,
            var_size=4,
            output_size=1):
        super().__init__()
        self.input_size = input_size
        self.var_size = var_size
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.operator_size = operator_size
        self.norm = norm  #*這裡改成從外部傳入 norm(250203)

        self.rnn1 = StopOperatorCell(self.operator_size)
        self.dnn1 = nn.Linear(self.operator_size + 4,
                              1)  #!250317更新：operator_size + 4
        self.rnn2 = EddyCell(
            6, self.hidden_size,
            output_size)  #!250317更新：4 (F, T, B, dB/dt ) + 2 (Hdc, N)
        self.dnn2 = nn.Linear(self.hidden_size, 1)

        self.rnn2_hx = None

    def forward(self, x, var, s0, n_init=16):
        """
         Parameters: 
          - x(batch,seq,input_size): Input features (1.B, 2.dB, 3.dB/dt)  
# !       - var(batch,var_size): Supplementary inputs (1.F 2.T 3.Hdc 4.N) 
          - s0(batch,1): Operator inital states
        """
        batch_size = x.size(0)  # Batch size
        seq_size = x.size(1)  # Ser
        self.rnn1_hx = s0

        # Initialize DNN2 input (1.B 2.dB/dt)
        x2 = torch.cat((x[:, :, 0:1], x[:, :, 2:3]), dim=2)

        for t in range(seq_size):
            # RNN1 input (dB,state)
            self.rnn1_hx = self.rnn1(x[:, t, 1:2], self.rnn1_hx)

            # DNN1 input (rnn1_hx,F,T,Hdc,N)
            dnn1_in = torch.cat((self.rnn1_hx, var), dim=1)

            # H hysteresis prediction
            H_hyst_pred = self.dnn1(dnn1_in)

            # DNN2 input (B,dB/dt,T,F)
            rnn2_in = torch.cat((x2[:, t, :], var), dim=1)

            # Initialize second rnn state
            if t == 0:
                H_eddy_init = x[:, t, 0:1] - H_hyst_pred
                buffer = x.new_ones(x.size(0), self.hidden_size)
                self.rnn2_hx = Variable(
                    (buffer / torch.sum(self.dnn2.weight, dim=1)) *
                    H_eddy_init)

            #rnn2_in = torch.cat((rnn2_in,H_hyst_pred),dim=1)
            self.rnn2_hx = self.rnn2(rnn2_in, self.rnn2_hx)

            # H eddy prediction
            H_eddy = self.dnn2(self.rnn2_hx)

            # H total
            H_total = (H_hyst_pred + H_eddy).view(batch_size, 1,
                                                  self.output_size)
            if t == 0:
                output = H_total
            else:
                output = torch.cat((output, H_total), dim=1)

        H = (output[:, n_init:, :])

        return H


class StopOperatorCell():
    def __init__(self, operator_size):
        self.operator_thre = torch.from_numpy(
            np.linspace(5 / operator_size, 5, operator_size)).view(1, -1)

    def sslu(self, X):
        a = torch.ones_like(X)
        return torch.max(-a, torch.min(a, X))

    def __call__(self, dB, state):
        r = self.operator_thre.to(dB.device)
        output = self.sslu((dB + state) / r) * r
        return output.float()


class EddyCell(nn.Module):
    def __init__(self, input_size, hidden_size, output_size=1):
        super().__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.output_size = output_size

        self.x2h = nn.Linear(input_size, hidden_size, bias=False)
        self.h2h = nn.Linear(hidden_size, hidden_size, bias=False)

    def forward(self, x, hidden=None):
        hidden = self.x2h(x) + self.h2h(hidden)
        hidden = torch.sigmoid(hidden)
        return hidden

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# ## Step3: Training the Model

# %% [markdown]
# ### Load Dataset

# %%
# %%
def load_dataset(material, base_path="./Data/"):

    in_file1 = f"{base_path}{material}/train/B_Field.csv"
    in_file2 = f"{base_path}{material}/train/Frequency.csv"
    in_file3 = f"{base_path}{material}/train/Temperature.csv"
    in_file4 = f"{base_path}{material}/train/H_Field.csv"
    in_file5 = f"{base_path}{material}/train/Volumetric_Loss.csv"
    in_file6 = f"{base_path}{material}/train/Hdc.csv"  # *250317新增：直流偏置磁場
    in_file7 = f"{base_path}{material}/train/Turns.csv"  # *250317新增：匝數

    data_B = np.genfromtxt(in_file1, delimiter=',')  # N x 1024
    data_F = np.genfromtxt(in_file2, delimiter=',')  # N x 1
    data_T = np.genfromtxt(in_file3, delimiter=',')  # N x 1
    data_H = np.genfromtxt(in_file4, delimiter=',')  # N x 1024  # *250317新增
    data_Pcv = np.genfromtxt(in_file5, delimiter=',')  # N x 1
    data_Hdc = np.genfromtxt(in_file6, delimiter=',')  # N x 1  # *250317新增
    data_N = np.genfromtxt(in_file7, delimiter=',')  # N x 1

    return data_B, data_F, data_T, data_H, data_Pcv, data_Hdc, data_N

# %% [markdown]
# ### Train Code

# %%
# %%
def train_model(norm, train_loader, valid_loader):

    model = MMINet(norm=norm).to(device)
    print("Number of parameters: ", count_parameters(model))
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=Config.LEARNING_RATE)

    best_val_loss = float('inf')
    patience_counter = 0

    # **新增 Loss 記錄**
    train_losses = []
    val_losses = []
    fixed_idx = None

    for epoch in range(Config.NUM_EPOCHS):
        model.train()
        train_loss = 0

        for inputs, features, s0, target_H in train_loader:
            inputs, features, s0, target_H = inputs.to(device), features.to(
                device), s0.to(device), target_H.to(device)

            optimizer.zero_grad()
            outputs = model(inputs, features, s0)  # 模型的輸出
            loss = criterion(outputs, target_H)  # 使用真實的 H(t) 計算損失
            loss.backward()
            optimizer.step()
            train_loss += loss.item()

        train_loss /= len(train_loader)
        train_losses.append(train_loss)  # **記錄 Train Loss**

        model.eval()
        val_loss = 0

        with torch.no_grad():
            for inputs, features, s0, target_H in valid_loader:
                inputs, features, s0, target_H = inputs.to(
                    device), features.to(device), s0.to(device), target_H.to(
                        device)
                outputs = model(inputs, features, s0)
                loss = criterion(outputs, target_H)
                val_loss += loss.item()

        val_loss /= len(valid_loader)
        val_losses.append(val_loss)  # **記錄 Validation Loss**

        print(
            f"Epoch {epoch+1}, Train Loss: {train_loss:.6f}, Validation Loss: {val_loss:.6f}"
        )

        # ======================================================繪製訓練情況======================================================

        if (epoch + 1) % plot_interval == 0:

            # 第一次產生固定的隨機索引
            if fixed_idx is None:
                batch_size_fix = 3
                fixed_idx = torch.randperm(batch_size_fix)[:train_show_sample]

            # # -------------------------設定圖表H(t)比較---------------------------------------

            # outputs = [fixed_idx, :downsample,
            #  0].detach().cpu().numpy()
            # targets_np = target_H[fixed_idx, :downsample,
            #                       0].detach().cpu().numpy()

            # plt.figure(figsize=(12, 6))

            # for i in range(outputs.shape[0]):  # 每一批數據繪製一個圖表
            #     plt.plot(outputs[i, :, 0],
            #              label=f"Pred: Sample {i+1}",
            #              linestyle='--',
            #              marker='o')
            #     plt.plot(targets[i, :, 0],
            #              label=f"Target: Sample {i+1}",
            #              linestyle='-',
            #              marker='x')

            # # 添加標題和標籤
            # plt.title(f"Compare - Epoch {epoch + 1}", fontsize=16)
            # plt.xlabel("Index", fontsize=14)
            # plt.ylabel("Value", fontsize=14)
            # plt.legend(loc="upper right", fontsize=12)
            # plt.grid(alpha=0.5)

            # # 顯示圖表
            # plt.show()
            # # -------------------------設定圖表H(t)比較 結束---------------------------------------

            # # -------------------------設定圖表B-H比較---------------------------------------
            # 取對應 sample
            outputs_np = outputs[fixed_idx, -downsample:,
                                 0].detach().cpu().numpy()
            targets_np = target_H[fixed_idx, -downsample:,
                                  0].detach().cpu().numpy()
            B_seq_np = inputs[fixed_idx, -downsample:,
                              0].detach().cpu().numpy()

            # 設定圖表
            plt.figure()

            for i in range(train_show_sample):  # 每一批數據繪製一個圖表
                plt.plot(outputs_np[i],
                         B_seq_np[i],
                         label=f"Pred: Sample {i+1}",
                         markersize=1)

                plt.plot(targets_np[i],
                         B_seq_np[i],
                         label=f"Target: Sample {i+1}",
                         alpha=0.5)

            # 添加標題和標籤
            plt.title(f"Compare - Epoch {epoch + 1}")
            plt.xlabel("Index")
            plt.ylabel("Value")
            plt.grid(alpha=0.5)
            plt.legend()
            figure_save_path1 = os.path.join(
                figure_save_base_path,
                f"Compare_Epoch {epoch + 1}.svg")  # 定義模型保存檔名
            plt.savefig(figure_save_path1)
            # 顯示圖表
            plt.show()
            # # -------------------------設定圖表B-H比較 END---------------------------------------
        # ======================================================繪製訓練情況  END ======================================================

        # ======================================================Early stop======================================================
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            torch.save(model.state_dict(), model_save_path)  # 保存最佳模型
            print(
                f"Saving model at epoch {epoch+1} with validation loss {val_loss:.6f}..."
            )
            patience_counter = 0
        else:
            patience_counter += 1

        if patience_counter >= Config.EARLY_STOPPING_PATIENCE:
            print("Early stopping triggered.")
            break

        # ======================================================Early stop======================================================

    print(f"Training complete. Best model saved at {model_save_path}.")

    # ==============================繪製 Train Loss 與 Validation Loss 圖==============================
    plt.figure(figsize=(10, 5))
    plt.plot(
        range(1,
              len(train_losses) + 1),
        train_losses,
        label="Train Loss",
    )
    plt.plot(range(1,
                   len(val_losses) + 1),
             val_losses,
             label="Validation Loss")

    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.title("Training & Validation Loss Curve")
    plt.legend()
    plt.grid(alpha=0.5)
    figure_save_path2 = os.path.join(figure_save_base_path,
                                     "Training_Loss_Curve.svg")  # 定義模型保存檔名
    plt.savefig(figure_save_path2)
    plt.show()
    # ==============================繪製 Train Loss 與 Validation Loss 圖 END==============================

    # ===================================使用最佳模型來產生驗證結果=============================
    model.load_state_dict(torch.load(model_save_path))  # 載入最佳模型
    model.eval()

    with torch.no_grad():
        for inputs, features, s0, target_H in valid_loader:
            inputs, features, s0, target_H = inputs.to(device), features.to(
                device), s0.to(device), target_H.to(device)

            outputs = model(inputs, features, s0)  # 使用最佳模型產生預測值
            break  # 只使用一批驗證數據進行可視化

    # 選取對應資料（index tensor 要先轉 list 才能 index numpy）
    outputs_np = outputs[fixed_idx, -downsample:, 0].detach().cpu().numpy()
    targets_np = target_H[fixed_idx, -downsample:, 0].detach().cpu().numpy()
    B_seq_np = inputs[fixed_idx, -downsample:, 0].detach().cpu().numpy()

    # 設定圖表
    plt.figure()

    for i in range(train_show_sample):  # 每一批數據繪製一個圖表
        plt.plot(outputs_np[i], B_seq_np[i], label=f"Pred: Sample {i+1}")

        plt.plot(targets_np[i],
                 B_seq_np[i],
                 label=f"Target: Sample {i+1}",
                 alpha=0.7)

    # 添加標題和標籤
    plt.title(f"Best Model - Predicted vs Target")
    plt.xlabel("Index")
    plt.ylabel("Value")
    plt.grid(alpha=0.5)
    plt.legend()
    figure_save_path3 = os.path.join(
        figure_save_base_path,
        "Best Model_Predicted vs Target.svg")  # 定義模型保存檔名
    plt.savefig(figure_save_path3)

    # ===================================使用最佳模型來產生驗證結果 END=============================

# %% [markdown]
# ### Start Train!!!

# %%
if __name__ == "__main__":

    data_B, data_F, data_T, data_H, data_Pcv, data_Hdc, data_N = load_dataset(
        material)

    train_loader, valid_loader, norm = get_dataloader(data_B, data_F, data_T,
                                                      data_H, data_N, data_Hdc,
                                                      data_Pcv)

    train_model(norm, train_loader, valid_loader)
# Out:
# "CH467160": [
#     [0.001179709448479116, 0.028274253010749817],
#     [7.182668685913086, 155.9204559326172],
#     [2.0, 1.0],
#     [25.0, 1.0],
#     [0.04307248815894127, 0.44447946548461914],
#     [1.8067814111709595, 0.715567409992218],
#     [1250.265380859375, 701.6740112304688],
#     [12.159845352172852, 3.296860456466675],
# ]
# Number of parameters:  1146
# Epoch 1, Train Loss: 1.078258, Validation Loss: 0.980916
# Saving model at epoch 1 with validation loss 0.980916...
# Epoch 2, Train Loss: 0.919698, Validation Loss: 0.825614
# Saving model at epoch 2 with validation loss 0.825614...
# Epoch 3, Train Loss: 0.755719, Validation Loss: 0.660021
# Saving model at epoch 3 with validation loss 0.660021...
# Epoch 4, Train Loss: 0.583705, Validation Loss: 0.466071
# Saving model at epoch 4 with validation loss 0.466071...
# Epoch 5, Train Loss: 0.372503, Validation Loss: 0.244088
# Saving model at epoch 5 with validation loss 0.244088...
# Epoch 6, Train Loss: 0.161920, Validation Loss: 0.074581
# Saving model at epoch 6 with validation loss 0.074581...
# Epoch 7, Train Loss: 0.069495, Validation Loss: 0.065281
# Saving model at epoch 7 with validation loss 0.065281...
# Epoch 8, Train Loss: 0.062216, Validation Loss: 0.046329
# Saving model at epoch 8 with validation loss 0.046329...
# Epoch 9, Train Loss: 0.047890, Validation Loss: 0.040189
# Saving model at epoch 9 with validation loss 0.040189...
# Epoch 10, Train Loss: 0.039773, Validation Loss: 0.034193
# Saving model at epoch 10 with validation loss 0.034193...
# Epoch 11, Train Loss: 0.035072, Validation Loss: 0.030258
# Saving model at epoch 11 with validation loss 0.030258...
# Epoch 12, Train Loss: 0.030933, Validation Loss: 0.026192
# Saving model at epoch 12 with validation loss 0.026192...
# Epoch 13, Train Loss: 0.027090, Validation Loss: 0.023065
# Saving model at epoch 13 with validation loss 0.023065...
# Epoch 14, Train Loss: 0.025038, Validation Loss: 0.020394
# Saving model at epoch 14 with validation loss 0.020394...
# Epoch 15, Train Loss: 0.021028, Validation Loss: 0.018041
# Saving model at epoch 15 with validation loss 0.018041...
# Epoch 16, Train Loss: 0.019048, Validation Loss: 0.016155
# Saving model at epoch 16 with validation loss 0.016155...
# Epoch 17, Train Loss: 0.017017, Validation Loss: 0.014456
# Saving model at epoch 17 with validation loss 0.014456...
# Epoch 18, Train Loss: 0.015036, Validation Loss: 0.012968
# Saving model at epoch 18 with validation loss 0.012968...
# Epoch 19, Train Loss: 0.013608, Validation Loss: 0.011794
# Saving model at epoch 19 with validation loss 0.011794...
# Epoch 20, Train Loss: 0.012192, Validation Loss: 0.010573
# Saving model at epoch 20 with validation loss 0.010573...
# Epoch 21, Train Loss: 0.011199, Validation Loss: 0.009676
# Saving model at epoch 21 with validation loss 0.009676...
# Epoch 22, Train Loss: 0.010372, Validation Loss: 0.008769
# Saving model at epoch 22 with validation loss 0.008769...
# Epoch 23, Train Loss: 0.009323, Validation Loss: 0.008055
# Saving model at epoch 23 with validation loss 0.008055...
# Epoch 24, Train Loss: 0.008533, Validation Loss: 0.007327
# Saving model at epoch 24 with validation loss 0.007327...
# Epoch 25, Train Loss: 0.007845, Validation Loss: 0.006738
# Saving model at epoch 25 with validation loss 0.006738...
# Epoch 26, Train Loss: 0.007306, Validation Loss: 0.006155
# Saving model at epoch 26 with validation loss 0.006155...
# Epoch 27, Train Loss: 0.006898, Validation Loss: 0.005691
# Saving model at epoch 27 with validation loss 0.005691...
# Epoch 28, Train Loss: 0.006168, Validation Loss: 0.005197
# Saving model at epoch 28 with validation loss 0.005197...
# Epoch 29, Train Loss: 0.005724, Validation Loss: 0.004730
# Saving model at epoch 29 with validation loss 0.004730...
# Epoch 30, Train Loss: 0.005341, Validation Loss: 0.004371
# Saving model at epoch 30 with validation loss 0.004371...
# Epoch 31, Train Loss: 0.004804, Validation Loss: 0.004071
# Saving model at epoch 31 with validation loss 0.004071...
# Epoch 32, Train Loss: 0.004382, Validation Loss: 0.003703
# Saving model at epoch 32 with validation loss 0.003703...
# Epoch 33, Train Loss: 0.004065, Validation Loss: 0.003423
# Saving model at epoch 33 with validation loss 0.003423...
# Epoch 34, Train Loss: 0.003795, Validation Loss: 0.003224
# Saving model at epoch 34 with validation loss 0.003224...
# Epoch 35, Train Loss: 0.003474, Validation Loss: 0.002973
# Saving model at epoch 35 with validation loss 0.002973...
# Epoch 36, Train Loss: 0.003316, Validation Loss: 0.002777
# Saving model at epoch 36 with validation loss 0.002777...
# Epoch 37, Train Loss: 0.003108, Validation Loss: 0.002609
# Saving model at epoch 37 with validation loss 0.002609...
# Epoch 38, Train Loss: 0.002937, Validation Loss: 0.002515
# Saving model at epoch 38 with validation loss 0.002515...
# Epoch 39, Train Loss: 0.002774, Validation Loss: 0.002319
# Saving model at epoch 39 with validation loss 0.002319...
# Epoch 40, Train Loss: 0.002637, Validation Loss: 0.002200
# Saving model at epoch 40 with validation loss 0.002200...
# Epoch 41, Train Loss: 0.002533, Validation Loss: 0.002208
# Epoch 42, Train Loss: 0.002508, Validation Loss: 0.002063
# Saving model at epoch 42 with validation loss 0.002063...
# Epoch 43, Train Loss: 0.002452, Validation Loss: 0.001972
# Saving model at epoch 43 with validation loss 0.001972...
# Epoch 44, Train Loss: 0.002224, Validation Loss: 0.001975
# Epoch 45, Train Loss: 0.002258, Validation Loss: 0.001887
# Saving model at epoch 45 with validation loss 0.001887...
# Epoch 46, Train Loss: 0.002213, Validation Loss: 0.001905
# Epoch 47, Train Loss: 0.002140, Validation Loss: 0.001805
# Saving model at epoch 47 with validation loss 0.001805...
# Epoch 48, Train Loss: 0.002113, Validation Loss: 0.001902
# Epoch 49, Train Loss: 0.002074, Validation Loss: 0.001732
# Saving model at epoch 49 with validation loss 0.001732...
# Epoch 50, Train Loss: 0.002004, Validation Loss: 0.001691
# Saving model at epoch 50 with validation loss 0.001691...
# Epoch 51, Train Loss: 0.001921, Validation Loss: 0.001681
# Saving model at epoch 51 with validation loss 0.001681...
# Epoch 52, Train Loss: 0.001942, Validation Loss: 0.001620
# Saving model at epoch 52 with validation loss 0.001620...
# Epoch 53, Train Loss: 0.001886, Validation Loss: 0.001648
# Epoch 54, Train Loss: 0.001874, Validation Loss: 0.001588
# Saving model at epoch 54 with validation loss 0.001588...
# Epoch 55, Train Loss: 0.001803, Validation Loss: 0.001542
# Saving model at epoch 55 with validation loss 0.001542...
# Epoch 56, Train Loss: 0.001741, Validation Loss: 0.001524
# Saving model at epoch 56 with validation loss 0.001524...
# Epoch 57, Train Loss: 0.001754, Validation Loss: 0.001558
# Epoch 58, Train Loss: 0.001727, Validation Loss: 0.001470
# Saving model at epoch 58 with validation loss 0.001470...
# Epoch 59, Train Loss: 0.001659, Validation Loss: 0.001446
# Saving model at epoch 59 with validation loss 0.001446...
# Epoch 60, Train Loss: 0.001627, Validation Loss: 0.001421
# Saving model at epoch 60 with validation loss 0.001421...
# Epoch 61, Train Loss: 0.001630, Validation Loss: 0.001475
# Epoch 62, Train Loss: 0.001730, Validation Loss: 0.001431
# Epoch 63, Train Loss: 0.001599, Validation Loss: 0.001360
# Saving model at epoch 63 with validation loss 0.001360...
# Epoch 64, Train Loss: 0.001563, Validation Loss: 0.001352
# Saving model at epoch 64 with validation loss 0.001352...
# Epoch 65, Train Loss: 0.001568, Validation Loss: 0.001338
# Saving model at epoch 65 with validation loss 0.001338...
# Epoch 66, Train Loss: 0.001530, Validation Loss: 0.001338
# Saving model at epoch 66 with validation loss 0.001338...
# Epoch 67, Train Loss: 0.001513, Validation Loss: 0.001295
# Saving model at epoch 67 with validation loss 0.001295...
# Epoch 68, Train Loss: 0.001510, Validation Loss: 0.001294
# Saving model at epoch 68 with validation loss 0.001294...
# Epoch 69, Train Loss: 0.001511, Validation Loss: 0.001401
# Epoch 70, Train Loss: 0.001510, Validation Loss: 0.001350
# Epoch 71, Train Loss: 0.001504, Validation Loss: 0.001235
# Saving model at epoch 71 with validation loss 0.001235...
# Epoch 72, Train Loss: 0.001488, Validation Loss: 0.001273
# Epoch 73, Train Loss: 0.001430, Validation Loss: 0.001205
# Saving model at epoch 73 with validation loss 0.001205...
# Epoch 74, Train Loss: 0.001387, Validation Loss: 0.001189
# Saving model at epoch 74 with validation loss 0.001189...
# Epoch 75, Train Loss: 0.001335, Validation Loss: 0.001177
# Saving model at epoch 75 with validation loss 0.001177...
# Epoch 76, Train Loss: 0.001342, Validation Loss: 0.001165
# Saving model at epoch 76 with validation loss 0.001165...
# Epoch 77, Train Loss: 0.001318, Validation Loss: 0.001174
# Epoch 78, Train Loss: 0.001356, Validation Loss: 0.001140
# Saving model at epoch 78 with validation loss 0.001140...
# Epoch 79, Train Loss: 0.001327, Validation Loss: 0.001135
# Saving model at epoch 79 with validation loss 0.001135...
# Epoch 80, Train Loss: 0.001290, Validation Loss: 0.001122
# Saving model at epoch 80 with validation loss 0.001122...
# Epoch 81, Train Loss: 0.001280, Validation Loss: 0.001118
# Saving model at epoch 81 with validation loss 0.001118...
# Epoch 82, Train Loss: 0.001270, Validation Loss: 0.001098
# Saving model at epoch 82 with validation loss 0.001098...
# Epoch 83, Train Loss: 0.001264, Validation Loss: 0.001091
# Saving model at epoch 83 with validation loss 0.001091...
# Epoch 84, Train Loss: 0.001226, Validation Loss: 0.001080
# Saving model at epoch 84 with validation loss 0.001080...
# Epoch 85, Train Loss: 0.001249, Validation Loss: 0.001162
# Epoch 86, Train Loss: 0.001270, Validation Loss: 0.001082
# Epoch 87, Train Loss: 0.001223, Validation Loss: 0.001098
# Epoch 88, Train Loss: 0.001200, Validation Loss: 0.001081
# Epoch 89, Train Loss: 0.001198, Validation Loss: 0.001040
# Saving model at epoch 89 with validation loss 0.001040...
# Epoch 90, Train Loss: 0.001219, Validation Loss: 0.001057
# Epoch 91, Train Loss: 0.001187, Validation Loss: 0.001031
# Saving model at epoch 91 with validation loss 0.001031...
# Epoch 92, Train Loss: 0.001161, Validation Loss: 0.001008
# Saving model at epoch 92 with validation loss 0.001008...
# Epoch 93, Train Loss: 0.001151, Validation Loss: 0.001016
# Epoch 94, Train Loss: 0.001124, Validation Loss: 0.001002
# Saving model at epoch 94 with validation loss 0.001002...
# Epoch 95, Train Loss: 0.001116, Validation Loss: 0.001009
# Epoch 96, Train Loss: 0.001110, Validation Loss: 0.001036
# Epoch 97, Train Loss: 0.001134, Validation Loss: 0.000980
# Saving model at epoch 97 with validation loss 0.000980...
# Epoch 98, Train Loss: 0.001098, Validation Loss: 0.000971
# Saving model at epoch 98 with validation loss 0.000971...
# Epoch 99, Train Loss: 0.001106, Validation Loss: 0.001000
# Epoch 100, Train Loss: 0.001127, Validation Loss: 0.000953
# Saving model at epoch 100 with validation loss 0.000953...
# Epoch 101, Train Loss: 0.001076, Validation Loss: 0.000995
# Epoch 102, Train Loss: 0.001062, Validation Loss: 0.000956
# Epoch 103, Train Loss: 0.001075, Validation Loss: 0.000945
# Saving model at epoch 103 with validation loss 0.000945...
# Epoch 104, Train Loss: 0.001064, Validation Loss: 0.001002
# Epoch 105, Train Loss: 0.001058, Validation Loss: 0.000930
# Saving model at epoch 105 with validation loss 0.000930...
# Epoch 106, Train Loss: 0.001063, Validation Loss: 0.000937
# Epoch 107, Train Loss: 0.001059, Validation Loss: 0.000925
# Saving model at epoch 107 with validation loss 0.000925...
# Epoch 108, Train Loss: 0.001053, Validation Loss: 0.000927
# Epoch 109, Train Loss: 0.001042, Validation Loss: 0.000922
# Saving model at epoch 109 with validation loss 0.000922...
# Epoch 110, Train Loss: 0.001015, Validation Loss: 0.000906
# Saving model at epoch 110 with validation loss 0.000906...
# Epoch 111, Train Loss: 0.001042, Validation Loss: 0.000947
# Epoch 112, Train Loss: 0.001038, Validation Loss: 0.000895
# Saving model at epoch 112 with validation loss 0.000895...
# Epoch 113, Train Loss: 0.000998, Validation Loss: 0.000886
# Saving model at epoch 113 with validation loss 0.000886...
# Epoch 114, Train Loss: 0.000981, Validation Loss: 0.000892
# Epoch 115, Train Loss: 0.000977, Validation Loss: 0.000883
# Saving model at epoch 115 with validation loss 0.000883...
# Epoch 116, Train Loss: 0.000984, Validation Loss: 0.000907
# Epoch 117, Train Loss: 0.000985, Validation Loss: 0.001004
# Epoch 118, Train Loss: 0.001002, Validation Loss: 0.000923
# Epoch 119, Train Loss: 0.000998, Validation Loss: 0.000895
# Epoch 120, Train Loss: 0.000973, Validation Loss: 0.000859
# Saving model at epoch 120 with validation loss 0.000859...
# Epoch 121, Train Loss: 0.000965, Validation Loss: 0.000873
# Epoch 122, Train Loss: 0.000946, Validation Loss: 0.000864
# Epoch 123, Train Loss: 0.000976, Validation Loss: 0.000882
# Epoch 124, Train Loss: 0.000949, Validation Loss: 0.000945
# Epoch 125, Train Loss: 0.001028, Validation Loss: 0.000844
# Saving model at epoch 125 with validation loss 0.000844...
# Epoch 126, Train Loss: 0.000961, Validation Loss: 0.000858
# Epoch 127, Train Loss: 0.000934, Validation Loss: 0.000898
# Epoch 128, Train Loss: 0.000932, Validation Loss: 0.000853
# Epoch 129, Train Loss: 0.000952, Validation Loss: 0.000845
# Epoch 130, Train Loss: 0.000927, Validation Loss: 0.000869
# Epoch 131, Train Loss: 0.000931, Validation Loss: 0.000830
# Saving model at epoch 131 with validation loss 0.000830...
# Epoch 132, Train Loss: 0.000910, Validation Loss: 0.000823
# Saving model at epoch 132 with validation loss 0.000823...
# Epoch 133, Train Loss: 0.000912, Validation Loss: 0.000852
# Epoch 134, Train Loss: 0.000938, Validation Loss: 0.000818
# Saving model at epoch 134 with validation loss 0.000818...
# Epoch 135, Train Loss: 0.000919, Validation Loss: 0.000849
# Epoch 136, Train Loss: 0.000927, Validation Loss: 0.000881
# Epoch 137, Train Loss: 0.000953, Validation Loss: 0.000851
# Epoch 138, Train Loss: 0.000977, Validation Loss: 0.000887
# Epoch 139, Train Loss: 0.000912, Validation Loss: 0.000829
# Epoch 140, Train Loss: 0.000916, Validation Loss: 0.000828
# Epoch 141, Train Loss: 0.000920, Validation Loss: 0.000804
# Saving model at epoch 141 with validation loss 0.000804...
# Epoch 142, Train Loss: 0.000903, Validation Loss: 0.000905
# Epoch 143, Train Loss: 0.000940, Validation Loss: 0.000855
# Epoch 144, Train Loss: 0.000894, Validation Loss: 0.000803
# Saving model at epoch 144 with validation loss 0.000803...
# Epoch 145, Train Loss: 0.000891, Validation Loss: 0.000807
# Epoch 146, Train Loss: 0.000866, Validation Loss: 0.000789
# Saving model at epoch 146 with validation loss 0.000789...
# Epoch 147, Train Loss: 0.000863, Validation Loss: 0.000781
# Saving model at epoch 147 with validation loss 0.000781...
# Epoch 148, Train Loss: 0.000849, Validation Loss: 0.000784
# Epoch 149, Train Loss: 0.000867, Validation Loss: 0.000787
# Epoch 150, Train Loss: 0.000869, Validation Loss: 0.000790
# Epoch 151, Train Loss: 0.000855, Validation Loss: 0.000784
# Epoch 152, Train Loss: 0.000857, Validation Loss: 0.000775
# Saving model at epoch 152 with validation loss 0.000775...
# Epoch 153, Train Loss: 0.000851, Validation Loss: 0.000775
# Saving model at epoch 153 with validation loss 0.000775...
# Epoch 154, Train Loss: 0.000846, Validation Loss: 0.000795
# Epoch 155, Train Loss: 0.000851, Validation Loss: 0.000769
# Saving model at epoch 155 with validation loss 0.000769...
# Epoch 156, Train Loss: 0.000832, Validation Loss: 0.000772
# Epoch 157, Train Loss: 0.000836, Validation Loss: 0.000805
# Epoch 158, Train Loss: 0.000863, Validation Loss: 0.000782
# Epoch 159, Train Loss: 0.000843, Validation Loss: 0.000766
# Saving model at epoch 159 with validation loss 0.000766...
# Epoch 160, Train Loss: 0.000829, Validation Loss: 0.000760
# Saving model at epoch 160 with validation loss 0.000760...
# Epoch 161, Train Loss: 0.000839, Validation Loss: 0.000765
# Epoch 162, Train Loss: 0.000848, Validation Loss: 0.000831
# Epoch 163, Train Loss: 0.000863, Validation Loss: 0.000759
# Saving model at epoch 163 with validation loss 0.000759...
# Epoch 164, Train Loss: 0.000842, Validation Loss: 0.000777
# Epoch 165, Train Loss: 0.000848, Validation Loss: 0.000977
# Epoch 166, Train Loss: 0.000883, Validation Loss: 0.000775
# Epoch 167, Train Loss: 0.000830, Validation Loss: 0.000791
# Epoch 168, Train Loss: 0.000835, Validation Loss: 0.000750
# Saving model at epoch 168 with validation loss 0.000750...
# Epoch 169, Train Loss: 0.000839, Validation Loss: 0.000763
# Epoch 170, Train Loss: 0.000831, Validation Loss: 0.000744
# Saving model at epoch 170 with validation loss 0.000744...
# Epoch 171, Train Loss: 0.000815, Validation Loss: 0.000752
# Epoch 172, Train Loss: 0.000811, Validation Loss: 0.000752
# Epoch 173, Train Loss: 0.000810, Validation Loss: 0.000742
# Saving model at epoch 173 with validation loss 0.000742...
# Epoch 174, Train Loss: 0.000808, Validation Loss: 0.000738
# Saving model at epoch 174 with validation loss 0.000738...
# Epoch 175, Train Loss: 0.000804, Validation Loss: 0.000744
# Epoch 176, Train Loss: 0.000795, Validation Loss: 0.000747
# Epoch 177, Train Loss: 0.000794, Validation Loss: 0.000745
# Epoch 178, Train Loss: 0.000812, Validation Loss: 0.000751
# Epoch 179, Train Loss: 0.000813, Validation Loss: 0.000730
# Saving model at epoch 179 with validation loss 0.000730...
# Epoch 180, Train Loss: 0.000811, Validation Loss: 0.000763
# Epoch 181, Train Loss: 0.000805, Validation Loss: 0.000739
# Epoch 182, Train Loss: 0.000795, Validation Loss: 0.000756
# Epoch 183, Train Loss: 0.000796, Validation Loss: 0.000747
# Epoch 184, Train Loss: 0.000807, Validation Loss: 0.000857
# Epoch 185, Train Loss: 0.000848, Validation Loss: 0.000877
# Epoch 186, Train Loss: 0.000892, Validation Loss: 0.000790
# Epoch 187, Train Loss: 0.000806, Validation Loss: 0.000755
# Epoch 188, Train Loss: 0.000774, Validation Loss: 0.000717
# Saving model at epoch 188 with validation loss 0.000717...
# Epoch 189, Train Loss: 0.000775, Validation Loss: 0.000729
# Epoch 190, Train Loss: 0.000784, Validation Loss: 0.000789
# Epoch 191, Train Loss: 0.000799, Validation Loss: 0.000769
# Epoch 192, Train Loss: 0.000784, Validation Loss: 0.000722
# Epoch 193, Train Loss: 0.000771, Validation Loss: 0.000751
# Epoch 194, Train Loss: 0.000771, Validation Loss: 0.000781
# Epoch 195, Train Loss: 0.000779, Validation Loss: 0.000818
# Epoch 196, Train Loss: 0.000791, Validation Loss: 0.000773
# Epoch 197, Train Loss: 0.000783, Validation Loss: 0.000793
# Epoch 198, Train Loss: 0.000818, Validation Loss: 0.000709
# Saving model at epoch 198 with validation loss 0.000709...
# Epoch 199, Train Loss: 0.000788, Validation Loss: 0.000712
# Epoch 200, Train Loss: 0.000775, Validation Loss: 0.000731
# Epoch 201, Train Loss: 0.000760, Validation Loss: 0.000701
# Saving model at epoch 201 with validation loss 0.000701...
# Epoch 202, Train Loss: 0.000760, Validation Loss: 0.000705
# Epoch 203, Train Loss: 0.000748, Validation Loss: 0.000707
# Epoch 204, Train Loss: 0.000767, Validation Loss: 0.000703
# Epoch 205, Train Loss: 0.000748, Validation Loss: 0.000702
# Epoch 206, Train Loss: 0.000744, Validation Loss: 0.000707
# Epoch 207, Train Loss: 0.000763, Validation Loss: 0.000720
# Epoch 208, Train Loss: 0.000755, Validation Loss: 0.000698
# Saving model at epoch 208 with validation loss 0.000698...
# Epoch 209, Train Loss: 0.000754, Validation Loss: 0.000716
# Epoch 210, Train Loss: 0.000738, Validation Loss: 0.000703
# Epoch 211, Train Loss: 0.000744, Validation Loss: 0.000780
# Epoch 212, Train Loss: 0.000800, Validation Loss: 0.000752
# Epoch 213, Train Loss: 0.000796, Validation Loss: 0.000776
# Epoch 214, Train Loss: 0.000793, Validation Loss: 0.000699
# Epoch 215, Train Loss: 0.000776, Validation Loss: 0.000727
# Epoch 216, Train Loss: 0.000735, Validation Loss: 0.000693
# Saving model at epoch 216 with validation loss 0.000693...
# Epoch 217, Train Loss: 0.000741, Validation Loss: 0.000697
# Epoch 218, Train Loss: 0.000749, Validation Loss: 0.000705
# Epoch 219, Train Loss: 0.000774, Validation Loss: 0.000699
# Epoch 220, Train Loss: 0.000752, Validation Loss: 0.000706
# Epoch 221, Train Loss: 0.000734, Validation Loss: 0.000689
# Saving model at epoch 221 with validation loss 0.000689...
# Epoch 222, Train Loss: 0.000734, Validation Loss: 0.000758
# Epoch 223, Train Loss: 0.000735, Validation Loss: 0.000725
# Epoch 224, Train Loss: 0.000748, Validation Loss: 0.000687
# Saving model at epoch 224 with validation loss 0.000687...
# Epoch 225, Train Loss: 0.000720, Validation Loss: 0.000710
# Epoch 226, Train Loss: 0.000730, Validation Loss: 0.000679
# Saving model at epoch 226 with validation loss 0.000679...
# Epoch 227, Train Loss: 0.000725, Validation Loss: 0.000683
# Epoch 228, Train Loss: 0.000717, Validation Loss: 0.000674
# Saving model at epoch 228 with validation loss 0.000674...
# Epoch 229, Train Loss: 0.000720, Validation Loss: 0.000674
# Epoch 230, Train Loss: 0.000737, Validation Loss: 0.000728
# Epoch 231, Train Loss: 0.000720, Validation Loss: 0.000693
# Epoch 232, Train Loss: 0.000715, Validation Loss: 0.000677
# Epoch 233, Train Loss: 0.000724, Validation Loss: 0.000727
# Epoch 234, Train Loss: 0.000730, Validation Loss: 0.000688
# Epoch 235, Train Loss: 0.000738, Validation Loss: 0.000671
# Saving model at epoch 235 with validation loss 0.000671...
# Epoch 236, Train Loss: 0.000703, Validation Loss: 0.000716
# Epoch 237, Train Loss: 0.000719, Validation Loss: 0.000680
# Epoch 238, Train Loss: 0.000727, Validation Loss: 0.000672
# Epoch 239, Train Loss: 0.000711, Validation Loss: 0.000667
# Saving model at epoch 239 with validation loss 0.000667...
# Epoch 240, Train Loss: 0.000705, Validation Loss: 0.000681
# Epoch 241, Train Loss: 0.000708, Validation Loss: 0.000680
# Epoch 242, Train Loss: 0.000721, Validation Loss: 0.000698
# Epoch 243, Train Loss: 0.000719, Validation Loss: 0.000664
# Saving model at epoch 243 with validation loss 0.000664...
# Epoch 244, Train Loss: 0.000712, Validation Loss: 0.000732
# Epoch 245, Train Loss: 0.000741, Validation Loss: 0.000748
# Epoch 246, Train Loss: 0.000739, Validation Loss: 0.000748
# Epoch 247, Train Loss: 0.000792, Validation Loss: 0.000799
# Epoch 248, Train Loss: 0.000732, Validation Loss: 0.000665
# Epoch 249, Train Loss: 0.000709, Validation Loss: 0.000670
# Epoch 250, Train Loss: 0.000711, Validation Loss: 0.000701
# Epoch 251, Train Loss: 0.000744, Validation Loss: 0.000755
# Epoch 252, Train Loss: 0.000759, Validation Loss: 0.000664
# Saving model at epoch 252 with validation loss 0.000664...
# Epoch 253, Train Loss: 0.000711, Validation Loss: 0.000664
# Epoch 254, Train Loss: 0.000698, Validation Loss: 0.000676
# Epoch 255, Train Loss: 0.000696, Validation Loss: 0.000659
# Saving model at epoch 255 with validation loss 0.000659...
# Epoch 256, Train Loss: 0.000713, Validation Loss: 0.000656
# Saving model at epoch 256 with validation loss 0.000656...
# Epoch 257, Train Loss: 0.000700, Validation Loss: 0.000671
# Epoch 258, Train Loss: 0.000698, Validation Loss: 0.000733
# Epoch 259, Train Loss: 0.000739, Validation Loss: 0.000681
# Epoch 260, Train Loss: 0.000699, Validation Loss: 0.000659
# Epoch 261, Train Loss: 0.000691, Validation Loss: 0.000657
# Epoch 262, Train Loss: 0.000693, Validation Loss: 0.000667
# Epoch 263, Train Loss: 0.000686, Validation Loss: 0.000657
# Epoch 264, Train Loss: 0.000709, Validation Loss: 0.000735
# Epoch 265, Train Loss: 0.000722, Validation Loss: 0.000656
# Saving model at epoch 265 with validation loss 0.000656...
# Epoch 266, Train Loss: 0.000694, Validation Loss: 0.000673
# Epoch 267, Train Loss: 0.000694, Validation Loss: 0.000696
# Epoch 268, Train Loss: 0.000729, Validation Loss: 0.000757
# Epoch 269, Train Loss: 0.000697, Validation Loss: 0.000660
# Epoch 270, Train Loss: 0.000694, Validation Loss: 0.000714
# Epoch 271, Train Loss: 0.000713, Validation Loss: 0.000702
# Epoch 272, Train Loss: 0.000703, Validation Loss: 0.000778
# Epoch 273, Train Loss: 0.000731, Validation Loss: 0.000666
# Epoch 274, Train Loss: 0.000676, Validation Loss: 0.000649
# Saving model at epoch 274 with validation loss 0.000649...
# Epoch 275, Train Loss: 0.000686, Validation Loss: 0.000653
# Epoch 276, Train Loss: 0.000680, Validation Loss: 0.000648
# Saving model at epoch 276 with validation loss 0.000648...
# Epoch 277, Train Loss: 0.000684, Validation Loss: 0.000649
# Epoch 278, Train Loss: 0.000711, Validation Loss: 0.000665
# Epoch 279, Train Loss: 0.000714, Validation Loss: 0.000663
# Epoch 280, Train Loss: 0.000699, Validation Loss: 0.000662
# Epoch 281, Train Loss: 0.000724, Validation Loss: 0.000656
# Epoch 282, Train Loss: 0.000687, Validation Loss: 0.000655
# Epoch 283, Train Loss: 0.000695, Validation Loss: 0.000690
# Epoch 284, Train Loss: 0.000688, Validation Loss: 0.000656
# Epoch 285, Train Loss: 0.000677, Validation Loss: 0.000655
# Epoch 286, Train Loss: 0.000683, Validation Loss: 0.000668
# Epoch 287, Train Loss: 0.000674, Validation Loss: 0.000649
# Epoch 288, Train Loss: 0.000685, Validation Loss: 0.000670
# Epoch 289, Train Loss: 0.000680, Validation Loss: 0.000643
# Saving model at epoch 289 with validation loss 0.000643...
# Epoch 290, Train Loss: 0.000678, Validation Loss: 0.000646
# Epoch 291, Train Loss: 0.000669, Validation Loss: 0.000639
# Saving model at epoch 291 with validation loss 0.000639...
# Epoch 292, Train Loss: 0.000675, Validation Loss: 0.000679
# Epoch 293, Train Loss: 0.000681, Validation Loss: 0.000691
# Epoch 294, Train Loss: 0.000683, Validation Loss: 0.000643
# Epoch 295, Train Loss: 0.000666, Validation Loss: 0.000643
# Epoch 296, Train Loss: 0.000673, Validation Loss: 0.000677
# Epoch 297, Train Loss: 0.000697, Validation Loss: 0.000726
# Epoch 298, Train Loss: 0.000739, Validation Loss: 0.000652
# Epoch 299, Train Loss: 0.000692, Validation Loss: 0.000641
# Epoch 300, Train Loss: 0.000692, Validation Loss: 0.000740
# Epoch 301, Train Loss: 0.000734, Validation Loss: 0.000677
# Epoch 302, Train Loss: 0.000714, Validation Loss: 0.000639
# Epoch 303, Train Loss: 0.000672, Validation Loss: 0.000665
# Epoch 304, Train Loss: 0.000688, Validation Loss: 0.000670
# Epoch 305, Train Loss: 0.000679, Validation Loss: 0.000637
# Saving model at epoch 305 with validation loss 0.000637...
# Epoch 306, Train Loss: 0.000665, Validation Loss: 0.000644
# Epoch 307, Train Loss: 0.000666, Validation Loss: 0.000637
# Epoch 308, Train Loss: 0.000670, Validation Loss: 0.000663
# Epoch 309, Train Loss: 0.000680, Validation Loss: 0.000704
# Epoch 310, Train Loss: 0.000685, Validation Loss: 0.000634
# Saving model at epoch 310 with validation loss 0.000634...
# Epoch 311, Train Loss: 0.000666, Validation Loss: 0.000639
# Epoch 312, Train Loss: 0.000667, Validation Loss: 0.000645
# Epoch 313, Train Loss: 0.000691, Validation Loss: 0.000634
# Epoch 314, Train Loss: 0.000666, Validation Loss: 0.000640
# Epoch 315, Train Loss: 0.000710, Validation Loss: 0.000790
# Epoch 316, Train Loss: 0.000691, Validation Loss: 0.000645
# Epoch 317, Train Loss: 0.000661, Validation Loss: 0.000637
# Epoch 318, Train Loss: 0.000666, Validation Loss: 0.000645
# Epoch 319, Train Loss: 0.000662, Validation Loss: 0.000629
# Saving model at epoch 319 with validation loss 0.000629...
# Epoch 320, Train Loss: 0.000668, Validation Loss: 0.000635
# Epoch 321, Train Loss: 0.000670, Validation Loss: 0.000633
# Epoch 322, Train Loss: 0.000661, Validation Loss: 0.000647
# Epoch 323, Train Loss: 0.000680, Validation Loss: 0.000686
# Epoch 324, Train Loss: 0.000712, Validation Loss: 0.000657
# Epoch 325, Train Loss: 0.000693, Validation Loss: 0.000654
# Epoch 326, Train Loss: 0.000662, Validation Loss: 0.000637
# Epoch 327, Train Loss: 0.000655, Validation Loss: 0.000635
# Epoch 328, Train Loss: 0.000672, Validation Loss: 0.000778
# Epoch 329, Train Loss: 0.000723, Validation Loss: 0.000653
# Epoch 330, Train Loss: 0.000673, Validation Loss: 0.000706
# Epoch 331, Train Loss: 0.000700, Validation Loss: 0.000669
# Epoch 332, Train Loss: 0.000671, Validation Loss: 0.000708
# Epoch 333, Train Loss: 0.000669, Validation Loss: 0.000655
# Epoch 334, Train Loss: 0.000648, Validation Loss: 0.000626
# Saving model at epoch 334 with validation loss 0.000626...
# Epoch 335, Train Loss: 0.000645, Validation Loss: 0.000637
# Epoch 336, Train Loss: 0.000661, Validation Loss: 0.000692
# Epoch 337, Train Loss: 0.000682, Validation Loss: 0.000626
# Saving model at epoch 337 with validation loss 0.000626...
# Epoch 338, Train Loss: 0.000656, Validation Loss: 0.000628
# Epoch 339, Train Loss: 0.000651, Validation Loss: 0.000640
# Epoch 340, Train Loss: 0.000667, Validation Loss: 0.000643
# Epoch 341, Train Loss: 0.000656, Validation Loss: 0.000632
# Epoch 342, Train Loss: 0.000648, Validation Loss: 0.000680
# Epoch 343, Train Loss: 0.000680, Validation Loss: 0.000727
# Epoch 344, Train Loss: 0.000698, Validation Loss: 0.000629
# Epoch 345, Train Loss: 0.000658, Validation Loss: 0.000621
# Saving model at epoch 345 with validation loss 0.000621...
# Epoch 346, Train Loss: 0.000657, Validation Loss: 0.000625
# Epoch 347, Train Loss: 0.000656, Validation Loss: 0.000630
# Epoch 348, Train Loss: 0.000647, Validation Loss: 0.000637
# Epoch 349, Train Loss: 0.000671, Validation Loss: 0.000623
# Epoch 350, Train Loss: 0.000670, Validation Loss: 0.000620
# Saving model at epoch 350 with validation loss 0.000620...
# Epoch 351, Train Loss: 0.000673, Validation Loss: 0.000769
# Epoch 352, Train Loss: 0.000697, Validation Loss: 0.000625
# Epoch 353, Train Loss: 0.000658, Validation Loss: 0.000640
# Epoch 354, Train Loss: 0.000680, Validation Loss: 0.000637
# Epoch 355, Train Loss: 0.000673, Validation Loss: 0.000641
# Epoch 356, Train Loss: 0.000654, Validation Loss: 0.000618
# Saving model at epoch 356 with validation loss 0.000618...
# Epoch 357, Train Loss: 0.000645, Validation Loss: 0.000710
# Epoch 358, Train Loss: 0.000705, Validation Loss: 0.000625
# Epoch 359, Train Loss: 0.000660, Validation Loss: 0.000620
# Epoch 360, Train Loss: 0.000642, Validation Loss: 0.000642
# Epoch 361, Train Loss: 0.000654, Validation Loss: 0.000661
# Epoch 362, Train Loss: 0.000670, Validation Loss: 0.000615
# Saving model at epoch 362 with validation loss 0.000615...
# Epoch 363, Train Loss: 0.000648, Validation Loss: 0.000635
# Epoch 364, Train Loss: 0.000673, Validation Loss: 0.000650
# Epoch 365, Train Loss: 0.000675, Validation Loss: 0.000621
# Epoch 366, Train Loss: 0.000664, Validation Loss: 0.000615
# Saving model at epoch 366 with validation loss 0.000615...
# Epoch 367, Train Loss: 0.000681, Validation Loss: 0.000654
# Epoch 368, Train Loss: 0.000651, Validation Loss: 0.000629
# Epoch 369, Train Loss: 0.000634, Validation Loss: 0.000635
# Epoch 370, Train Loss: 0.000640, Validation Loss: 0.000634
# Epoch 371, Train Loss: 0.000627, Validation Loss: 0.000609
# Saving model at epoch 371 with validation loss 0.000609...
# Epoch 372, Train Loss: 0.000629, Validation Loss: 0.000616
# Epoch 373, Train Loss: 0.000632, Validation Loss: 0.000609
# Epoch 374, Train Loss: 0.000637, Validation Loss: 0.000608
# Saving model at epoch 374 with validation loss 0.000608...
# Epoch 375, Train Loss: 0.000638, Validation Loss: 0.000620
# Epoch 376, Train Loss: 0.000662, Validation Loss: 0.000614
# Epoch 377, Train Loss: 0.000635, Validation Loss: 0.000645
# Epoch 378, Train Loss: 0.000648, Validation Loss: 0.000631
# Epoch 379, Train Loss: 0.000644, Validation Loss: 0.000606
# Saving model at epoch 379 with validation loss 0.000606...
# Epoch 380, Train Loss: 0.000642, Validation Loss: 0.000659
# Epoch 381, Train Loss: 0.000635, Validation Loss: 0.000625
# Epoch 382, Train Loss: 0.000631, Validation Loss: 0.000614
# Epoch 383, Train Loss: 0.000630, Validation Loss: 0.000602
# Saving model at epoch 383 with validation loss 0.000602...
# Epoch 384, Train Loss: 0.000645, Validation Loss: 0.000626
# Epoch 385, Train Loss: 0.000640, Validation Loss: 0.000663
# Epoch 386, Train Loss: 0.000655, Validation Loss: 0.000630
# Epoch 387, Train Loss: 0.000647, Validation Loss: 0.000605
# Epoch 388, Train Loss: 0.000623, Validation Loss: 0.000611
# Epoch 389, Train Loss: 0.000619, Validation Loss: 0.000604
# Epoch 390, Train Loss: 0.000621, Validation Loss: 0.000605
# Epoch 391, Train Loss: 0.000614, Validation Loss: 0.000606
# Epoch 392, Train Loss: 0.000650, Validation Loss: 0.000606
# Epoch 393, Train Loss: 0.000625, Validation Loss: 0.000653
# Epoch 394, Train Loss: 0.000630, Validation Loss: 0.000607
# Epoch 395, Train Loss: 0.000633, Validation Loss: 0.000603
# Epoch 396, Train Loss: 0.000638, Validation Loss: 0.000633
# Epoch 397, Train Loss: 0.000643, Validation Loss: 0.000650
# Epoch 398, Train Loss: 0.000662, Validation Loss: 0.000610
# Epoch 399, Train Loss: 0.000626, Validation Loss: 0.000604
# Epoch 400, Train Loss: 0.000622, Validation Loss: 0.000604
# Epoch 401, Train Loss: 0.000635, Validation Loss: 0.000611
# Epoch 402, Train Loss: 0.000625, Validation Loss: 0.000629
# Epoch 403, Train Loss: 0.000626, Validation Loss: 0.000595
# Saving model at epoch 403 with validation loss 0.000595...
# Epoch 404, Train Loss: 0.000626, Validation Loss: 0.000604
# Epoch 405, Train Loss: 0.000609, Validation Loss: 0.000593
# Saving model at epoch 405 with validation loss 0.000593...
# Epoch 406, Train Loss: 0.000633, Validation Loss: 0.000600
# Epoch 407, Train Loss: 0.000613, Validation Loss: 0.000609
# Epoch 408, Train Loss: 0.000635, Validation Loss: 0.000619
# Epoch 409, Train Loss: 0.000619, Validation Loss: 0.000621
# Epoch 410, Train Loss: 0.000629, Validation Loss: 0.000612
# Epoch 411, Train Loss: 0.000624, Validation Loss: 0.000598
# Epoch 412, Train Loss: 0.000618, Validation Loss: 0.000657
# Epoch 413, Train Loss: 0.000622, Validation Loss: 0.000591
# Saving model at epoch 413 with validation loss 0.000591...
# Epoch 414, Train Loss: 0.000614, Validation Loss: 0.000590
# Saving model at epoch 414 with validation loss 0.000590...
# Epoch 415, Train Loss: 0.000627, Validation Loss: 0.000609
# Epoch 416, Train Loss: 0.000632, Validation Loss: 0.000598
# Epoch 417, Train Loss: 0.000632, Validation Loss: 0.000600
# Epoch 418, Train Loss: 0.000625, Validation Loss: 0.000639
# Epoch 419, Train Loss: 0.000654, Validation Loss: 0.000707
# Epoch 420, Train Loss: 0.000646, Validation Loss: 0.000646
# Epoch 421, Train Loss: 0.000628, Validation Loss: 0.000591
# Epoch 422, Train Loss: 0.000615, Validation Loss: 0.000609
# Epoch 423, Train Loss: 0.000618, Validation Loss: 0.000586
# Saving model at epoch 423 with validation loss 0.000586...
# Epoch 424, Train Loss: 0.000603, Validation Loss: 0.000588
# Epoch 425, Train Loss: 0.000617, Validation Loss: 0.000590
# Epoch 426, Train Loss: 0.000613, Validation Loss: 0.000586
# Saving model at epoch 426 with validation loss 0.000586...
# Epoch 427, Train Loss: 0.000609, Validation Loss: 0.000591
# Epoch 428, Train Loss: 0.000619, Validation Loss: 0.000634
# Epoch 429, Train Loss: 0.000627, Validation Loss: 0.000615
# Epoch 430, Train Loss: 0.000615, Validation Loss: 0.000606
# Epoch 431, Train Loss: 0.000615, Validation Loss: 0.000603
# Epoch 432, Train Loss: 0.000608, Validation Loss: 0.000590
# Epoch 433, Train Loss: 0.000602, Validation Loss: 0.000585
# Saving model at epoch 433 with validation loss 0.000585...
# Epoch 434, Train Loss: 0.000613, Validation Loss: 0.000638
# Epoch 435, Train Loss: 0.000619, Validation Loss: 0.000590
# Epoch 436, Train Loss: 0.000620, Validation Loss: 0.000600
# Epoch 437, Train Loss: 0.000612, Validation Loss: 0.000631
# Epoch 438, Train Loss: 0.000633, Validation Loss: 0.000701
# Epoch 439, Train Loss: 0.000632, Validation Loss: 0.000617
# Epoch 440, Train Loss: 0.000622, Validation Loss: 0.000656
# Epoch 441, Train Loss: 0.000624, Validation Loss: 0.000616
# Epoch 442, Train Loss: 0.000610, Validation Loss: 0.000588
# Epoch 443, Train Loss: 0.000598, Validation Loss: 0.000623
# Epoch 444, Train Loss: 0.000616, Validation Loss: 0.000578
# Saving model at epoch 444 with validation loss 0.000578...
# Epoch 445, Train Loss: 0.000619, Validation Loss: 0.000589
# Epoch 446, Train Loss: 0.000602, Validation Loss: 0.000611
# Epoch 447, Train Loss: 0.000627, Validation Loss: 0.000614
# Epoch 448, Train Loss: 0.000614, Validation Loss: 0.000594
# Epoch 449, Train Loss: 0.000596, Validation Loss: 0.000577
# Saving model at epoch 449 with validation loss 0.000577...
# Epoch 450, Train Loss: 0.000597, Validation Loss: 0.000577
# Epoch 451, Train Loss: 0.000597, Validation Loss: 0.000582
# Epoch 452, Train Loss: 0.000594, Validation Loss: 0.000574
# Saving model at epoch 452 with validation loss 0.000574...
# Epoch 453, Train Loss: 0.000598, Validation Loss: 0.000572
# Saving model at epoch 453 with validation loss 0.000572...
# Epoch 454, Train Loss: 0.000605, Validation Loss: 0.000604
# Epoch 455, Train Loss: 0.000603, Validation Loss: 0.000588
# Epoch 456, Train Loss: 0.000598, Validation Loss: 0.000584
# Epoch 457, Train Loss: 0.000615, Validation Loss: 0.000619
# Epoch 458, Train Loss: 0.000613, Validation Loss: 0.000578
# Epoch 459, Train Loss: 0.000609, Validation Loss: 0.000595
# Epoch 460, Train Loss: 0.000612, Validation Loss: 0.000578
# Epoch 461, Train Loss: 0.000592, Validation Loss: 0.000581
# Epoch 462, Train Loss: 0.000606, Validation Loss: 0.000579
# Epoch 463, Train Loss: 0.000588, Validation Loss: 0.000572
# Saving model at epoch 463 with validation loss 0.000572...
# Epoch 464, Train Loss: 0.000585, Validation Loss: 0.000574
# Epoch 465, Train Loss: 0.000589, Validation Loss: 0.000567
# Saving model at epoch 465 with validation loss 0.000567...
# Epoch 466, Train Loss: 0.000600, Validation Loss: 0.000636
# Epoch 467, Train Loss: 0.000609, Validation Loss: 0.000573
# Epoch 468, Train Loss: 0.000606, Validation Loss: 0.000588
# Epoch 469, Train Loss: 0.000606, Validation Loss: 0.000599
# Epoch 470, Train Loss: 0.000600, Validation Loss: 0.000572
# Epoch 471, Train Loss: 0.000622, Validation Loss: 0.000666
# Epoch 472, Train Loss: 0.000627, Validation Loss: 0.000640
# Epoch 473, Train Loss: 0.000639, Validation Loss: 0.000565
# Saving model at epoch 473 with validation loss 0.000565...
# Epoch 474, Train Loss: 0.000592, Validation Loss: 0.000579
# Epoch 475, Train Loss: 0.000590, Validation Loss: 0.000573
# Epoch 476, Train Loss: 0.000582, Validation Loss: 0.000591
# Epoch 477, Train Loss: 0.000590, Validation Loss: 0.000579
# Epoch 478, Train Loss: 0.000603, Validation Loss: 0.000570
# Epoch 479, Train Loss: 0.000586, Validation Loss: 0.000565
# Saving model at epoch 479 with validation loss 0.000565...
# Epoch 480, Train Loss: 0.000577, Validation Loss: 0.000574
# Epoch 481, Train Loss: 0.000590, Validation Loss: 0.000564
# Saving model at epoch 481 with validation loss 0.000564...
# Epoch 482, Train Loss: 0.000597, Validation Loss: 0.000606
# Epoch 483, Train Loss: 0.000601, Validation Loss: 0.000560
# Saving model at epoch 483 with validation loss 0.000560...
# Epoch 484, Train Loss: 0.000598, Validation Loss: 0.000573
# Epoch 485, Train Loss: 0.000597, Validation Loss: 0.000565
# Epoch 486, Train Loss: 0.000588, Validation Loss: 0.000563
# Epoch 487, Train Loss: 0.000589, Validation Loss: 0.000573
# Epoch 488, Train Loss: 0.000595, Validation Loss: 0.000572
# Epoch 489, Train Loss: 0.000586, Validation Loss: 0.000566
# Epoch 490, Train Loss: 0.000581, Validation Loss: 0.000556
# Saving model at epoch 490 with validation loss 0.000556...
# Epoch 491, Train Loss: 0.000587, Validation Loss: 0.000631
# Epoch 492, Train Loss: 0.000597, Validation Loss: 0.000571
# Epoch 493, Train Loss: 0.000605, Validation Loss: 0.000558
# Epoch 494, Train Loss: 0.000599, Validation Loss: 0.000660
# Epoch 495, Train Loss: 0.000657, Validation Loss: 0.000635
# Epoch 496, Train Loss: 0.000610, Validation Loss: 0.000559
# Epoch 497, Train Loss: 0.000599, Validation Loss: 0.000558
# Epoch 498, Train Loss: 0.000589, Validation Loss: 0.000556
# Saving model at epoch 498 with validation loss 0.000556...
# Epoch 499, Train Loss: 0.000580, Validation Loss: 0.000575
# Epoch 500, Train Loss: 0.000589, Validation Loss: 0.000557
# Epoch 501, Train Loss: 0.000576, Validation Loss: 0.000561
# Epoch 502, Train Loss: 0.000596, Validation Loss: 0.000612
# Epoch 503, Train Loss: 0.000617, Validation Loss: 0.000606
# Epoch 504, Train Loss: 0.000618, Validation Loss: 0.000554
# Saving model at epoch 504 with validation loss 0.000554...
# Epoch 505, Train Loss: 0.000575, Validation Loss: 0.000568
# Epoch 506, Train Loss: 0.000587, Validation Loss: 0.000551
# Saving model at epoch 506 with validation loss 0.000551...
# Epoch 507, Train Loss: 0.000586, Validation Loss: 0.000550
# Saving model at epoch 507 with validation loss 0.000550...
# Epoch 508, Train Loss: 0.000583, Validation Loss: 0.000558
# Epoch 509, Train Loss: 0.000579, Validation Loss: 0.000557
# Epoch 510, Train Loss: 0.000565, Validation Loss: 0.000563
# Epoch 511, Train Loss: 0.000584, Validation Loss: 0.000564
# Epoch 512, Train Loss: 0.000599, Validation Loss: 0.000569
# Epoch 513, Train Loss: 0.000576, Validation Loss: 0.000557
# Epoch 514, Train Loss: 0.000612, Validation Loss: 0.000623
# Epoch 515, Train Loss: 0.000605, Validation Loss: 0.000583
# Epoch 516, Train Loss: 0.000598, Validation Loss: 0.000552
# Epoch 517, Train Loss: 0.000582, Validation Loss: 0.000550
# Saving model at epoch 517 with validation loss 0.000550...
# Epoch 518, Train Loss: 0.000602, Validation Loss: 0.000568
# Epoch 519, Train Loss: 0.000565, Validation Loss: 0.000549
# Saving model at epoch 519 with validation loss 0.000549...
# Epoch 520, Train Loss: 0.000591, Validation Loss: 0.000554
# Epoch 521, Train Loss: 0.000572, Validation Loss: 0.000549
# Epoch 522, Train Loss: 0.000561, Validation Loss: 0.000555
# Epoch 523, Train Loss: 0.000571, Validation Loss: 0.000571
# Epoch 524, Train Loss: 0.000584, Validation Loss: 0.000560
# Epoch 525, Train Loss: 0.000592, Validation Loss: 0.000549
# Saving model at epoch 525 with validation loss 0.000549...
# Epoch 526, Train Loss: 0.000592, Validation Loss: 0.000569
# Epoch 527, Train Loss: 0.000587, Validation Loss: 0.000606
# Epoch 528, Train Loss: 0.000574, Validation Loss: 0.000549
# Epoch 529, Train Loss: 0.000564, Validation Loss: 0.000542
# Saving model at epoch 529 with validation loss 0.000542...
# Epoch 530, Train Loss: 0.000570, Validation Loss: 0.000545
# Epoch 531, Train Loss: 0.000554, Validation Loss: 0.000547
# Epoch 532, Train Loss: 0.000570, Validation Loss: 0.000550
# Epoch 533, Train Loss: 0.000572, Validation Loss: 0.000561
# Epoch 534, Train Loss: 0.000587, Validation Loss: 0.000583
# Epoch 535, Train Loss: 0.000589, Validation Loss: 0.000553
# Epoch 536, Train Loss: 0.000573, Validation Loss: 0.000562
# Epoch 537, Train Loss: 0.000569, Validation Loss: 0.000547
# Epoch 538, Train Loss: 0.000556, Validation Loss: 0.000546
# Epoch 539, Train Loss: 0.000560, Validation Loss: 0.000569
# Epoch 540, Train Loss: 0.000577, Validation Loss: 0.000582
# Epoch 541, Train Loss: 0.000575, Validation Loss: 0.000550
# Epoch 542, Train Loss: 0.000558, Validation Loss: 0.000540
# Saving model at epoch 542 with validation loss 0.000540...
# Epoch 543, Train Loss: 0.000557, Validation Loss: 0.000541
# Epoch 544, Train Loss: 0.000565, Validation Loss: 0.000540
# Epoch 545, Train Loss: 0.000568, Validation Loss: 0.000564
# Epoch 546, Train Loss: 0.000571, Validation Loss: 0.000592
# Epoch 547, Train Loss: 0.000573, Validation Loss: 0.000606
# Epoch 548, Train Loss: 0.000563, Validation Loss: 0.000604
# Epoch 549, Train Loss: 0.000567, Validation Loss: 0.000537
# Saving model at epoch 549 with validation loss 0.000537...
# Epoch 550, Train Loss: 0.000557, Validation Loss: 0.000572
# Epoch 551, Train Loss: 0.000579, Validation Loss: 0.000570
# Epoch 552, Train Loss: 0.000562, Validation Loss: 0.000550
# Epoch 553, Train Loss: 0.000557, Validation Loss: 0.000549
# Epoch 554, Train Loss: 0.000574, Validation Loss: 0.000540
# Epoch 555, Train Loss: 0.000586, Validation Loss: 0.000535
# Saving model at epoch 555 with validation loss 0.000535...
# Epoch 556, Train Loss: 0.000568, Validation Loss: 0.000564
# Epoch 557, Train Loss: 0.000679, Validation Loss: 0.000674
# Epoch 558, Train Loss: 0.000651, Validation Loss: 0.000673
# Epoch 559, Train Loss: 0.000578, Validation Loss: 0.000542
# Epoch 560, Train Loss: 0.000562, Validation Loss: 0.000536
# Epoch 561, Train Loss: 0.000552, Validation Loss: 0.000541
# Epoch 562, Train Loss: 0.000554, Validation Loss: 0.000539
# Epoch 563, Train Loss: 0.000558, Validation Loss: 0.000532
# Saving model at epoch 563 with validation loss 0.000532...
# Epoch 564, Train Loss: 0.000547, Validation Loss: 0.000533
# Epoch 565, Train Loss: 0.000550, Validation Loss: 0.000538
# Epoch 566, Train Loss: 0.000553, Validation Loss: 0.000533
# Epoch 567, Train Loss: 0.000559, Validation Loss: 0.000534
# Epoch 568, Train Loss: 0.000550, Validation Loss: 0.000536
# Epoch 569, Train Loss: 0.000558, Validation Loss: 0.000534
# Epoch 570, Train Loss: 0.000556, Validation Loss: 0.000531
# Saving model at epoch 570 with validation loss 0.000531...
# Epoch 571, Train Loss: 0.000560, Validation Loss: 0.000562
# Epoch 572, Train Loss: 0.000553, Validation Loss: 0.000531
# Saving model at epoch 572 with validation loss 0.000531...
# Epoch 573, Train Loss: 0.000561, Validation Loss: 0.000570
# Epoch 574, Train Loss: 0.000554, Validation Loss: 0.000531
# Epoch 575, Train Loss: 0.000543, Validation Loss: 0.000538
# Epoch 576, Train Loss: 0.000551, Validation Loss: 0.000529
# Saving model at epoch 576 with validation loss 0.000529...
# Epoch 577, Train Loss: 0.000544, Validation Loss: 0.000525
# Saving model at epoch 577 with validation loss 0.000525...
# Epoch 578, Train Loss: 0.000547, Validation Loss: 0.000533
# Epoch 579, Train Loss: 0.000552, Validation Loss: 0.000532
# Epoch 580, Train Loss: 0.000543, Validation Loss: 0.000576
# Epoch 581, Train Loss: 0.000571, Validation Loss: 0.000532
# Epoch 582, Train Loss: 0.000551, Validation Loss: 0.000603
# Epoch 583, Train Loss: 0.000564, Validation Loss: 0.000532
# Epoch 584, Train Loss: 0.000555, Validation Loss: 0.000550
# Epoch 585, Train Loss: 0.000555, Validation Loss: 0.000527
# Epoch 586, Train Loss: 0.000544, Validation Loss: 0.000534
# Epoch 587, Train Loss: 0.000542, Validation Loss: 0.000527
# Epoch 588, Train Loss: 0.000539, Validation Loss: 0.000522
# Saving model at epoch 588 with validation loss 0.000522...
# Epoch 589, Train Loss: 0.000544, Validation Loss: 0.000558
# Epoch 590, Train Loss: 0.000550, Validation Loss: 0.000522
# Saving model at epoch 590 with validation loss 0.000522...
# Epoch 591, Train Loss: 0.000542, Validation Loss: 0.000547
# Epoch 592, Train Loss: 0.000550, Validation Loss: 0.000571
# Epoch 593, Train Loss: 0.000565, Validation Loss: 0.000574
# Epoch 594, Train Loss: 0.000548, Validation Loss: 0.000520
# Saving model at epoch 594 with validation loss 0.000520...
# Epoch 595, Train Loss: 0.000533, Validation Loss: 0.000524
# Epoch 596, Train Loss: 0.000545, Validation Loss: 0.000521
# Epoch 597, Train Loss: 0.000539, Validation Loss: 0.000519
# Saving model at epoch 597 with validation loss 0.000519...
# Epoch 598, Train Loss: 0.000546, Validation Loss: 0.000552
# Epoch 599, Train Loss: 0.000557, Validation Loss: 0.000620
# Epoch 600, Train Loss: 0.000566, Validation Loss: 0.000528
# Epoch 601, Train Loss: 0.000551, Validation Loss: 0.000522
# Epoch 602, Train Loss: 0.000528, Validation Loss: 0.000521
# Epoch 603, Train Loss: 0.000530, Validation Loss: 0.000519
# Saving model at epoch 603 with validation loss 0.000519...
# Epoch 604, Train Loss: 0.000557, Validation Loss: 0.000565
# Epoch 605, Train Loss: 0.000559, Validation Loss: 0.000566
# Epoch 606, Train Loss: 0.000549, Validation Loss: 0.000545
# Epoch 607, Train Loss: 0.000570, Validation Loss: 0.000536
# Epoch 608, Train Loss: 0.000540, Validation Loss: 0.000560
# Epoch 609, Train Loss: 0.000575, Validation Loss: 0.000669
# Epoch 610, Train Loss: 0.000578, Validation Loss: 0.000536
# Epoch 611, Train Loss: 0.000534, Validation Loss: 0.000516
# Saving model at epoch 611 with validation loss 0.000516...
# Epoch 612, Train Loss: 0.000537, Validation Loss: 0.000529
# Epoch 613, Train Loss: 0.000532, Validation Loss: 0.000520
# Epoch 614, Train Loss: 0.000546, Validation Loss: 0.000528
# Epoch 615, Train Loss: 0.000533, Validation Loss: 0.000513
# Saving model at epoch 615 with validation loss 0.000513...
# Epoch 616, Train Loss: 0.000526, Validation Loss: 0.000514
# Epoch 617, Train Loss: 0.000532, Validation Loss: 0.000521
# Epoch 618, Train Loss: 0.000535, Validation Loss: 0.000519
# Epoch 619, Train Loss: 0.000535, Validation Loss: 0.000519
# Epoch 620, Train Loss: 0.000525, Validation Loss: 0.000529
# Epoch 621, Train Loss: 0.000527, Validation Loss: 0.000513
# Saving model at epoch 621 with validation loss 0.000513...
# Epoch 622, Train Loss: 0.000548, Validation Loss: 0.000531
# Epoch 623, Train Loss: 0.000559, Validation Loss: 0.000525
# Epoch 624, Train Loss: 0.000573, Validation Loss: 0.000580
# Epoch 625, Train Loss: 0.000563, Validation Loss: 0.000515
# Epoch 626, Train Loss: 0.000526, Validation Loss: 0.000512
# Saving model at epoch 626 with validation loss 0.000512...
# ...
# Epoch 2774, Train Loss: 0.000335, Validation Loss: 0.000371
# Epoch 2775, Train Loss: 0.000332, Validation Loss: 0.000319
# Epoch 2776, Train Loss: 0.000322, Validation Loss: 0.000319
# Epoch 2777, Train Loss: 0.000319, Validation Loss: 0.000319
# Epoch 2778, Train Loss: 0.000325, Validation Loss: 0.000317
# Saving model at epoch 2778 with validation loss 0.000317...
# Epoch 2779, Train Loss: 0.000320, Validation Loss: 0.000318
# Epoch 2780, Train Loss: 0.000322, Validation Loss: 0.000324
# Epoch 2781, Train Loss: 0.000322, Validation Loss: 0.000326
# Epoch 2782, Train Loss: 0.000318, Validation Loss: 0.000332
# Epoch 2783, Train Loss: 0.000337, Validation Loss: 0.000331
# Epoch 2784, Train Loss: 0.000335, Validation Loss: 0.000330
# Epoch 2785, Train Loss: 0.000328, Validation Loss: 0.000320
# Epoch 2786, Train Loss: 0.000322, Validation Loss: 0.000324
# Epoch 2787, Train Loss: 0.000330, Validation Loss: 0.000325
# Epoch 2788, Train Loss: 0.000327, Validation Loss: 0.000347
# Epoch 2789, Train Loss: 0.000335, Validation Loss: 0.000321
# Epoch 2790, Train Loss: 0.000318, Validation Loss: 0.000318
# Epoch 2791, Train Loss: 0.000331, Validation Loss: 0.000320
# Epoch 2792, Train Loss: 0.000322, Validation Loss: 0.000321
# Epoch 2793, Train Loss: 0.000323, Validation Loss: 0.000325
# Epoch 2794, Train Loss: 0.000320, Validation Loss: 0.000322
# Epoch 2795, Train Loss: 0.000322, Validation Loss: 0.000330
# Epoch 2796, Train Loss: 0.000327, Validation Loss: 0.000324
# Epoch 2797, Train Loss: 0.000346, Validation Loss: 0.000391
# Epoch 2798, Train Loss: 0.000365, Validation Loss: 0.000343
# Epoch 2799, Train Loss: 0.000334, Validation Loss: 0.000328
# Epoch 2800, Train Loss: 0.000332, Validation Loss: 0.000408
# Epoch 2801, Train Loss: 0.000367, Validation Loss: 0.000372
# Epoch 2802, Train Loss: 0.000341, Validation Loss: 0.000343
# Epoch 2803, Train Loss: 0.000329, Validation Loss: 0.000317
# Epoch 2804, Train Loss: 0.000326, Validation Loss: 0.000316
# Saving model at epoch 2804 with validation loss 0.000316...
# Epoch 2805, Train Loss: 0.000325, Validation Loss: 0.000318
# Epoch 2806, Train Loss: 0.000312, Validation Loss: 0.000317
# Epoch 2807, Train Loss: 0.000317, Validation Loss: 0.000316
# Saving model at epoch 2807 with validation loss 0.000316...
# Epoch 2808, Train Loss: 0.000330, Validation Loss: 0.000325
# Epoch 2809, Train Loss: 0.000320, Validation Loss: 0.000324
# Epoch 2810, Train Loss: 0.000316, Validation Loss: 0.000329
# Epoch 2811, Train Loss: 0.000329, Validation Loss: 0.000354
# Epoch 2812, Train Loss: 0.000359, Validation Loss: 0.000413
# Epoch 2813, Train Loss: 0.000421, Validation Loss: 0.000326
# Epoch 2814, Train Loss: 0.000341, Validation Loss: 0.000318
# Epoch 2815, Train Loss: 0.000325, Validation Loss: 0.000368
# Epoch 2816, Train Loss: 0.000337, Validation Loss: 0.000343
# Epoch 2817, Train Loss: 0.000339, Validation Loss: 0.000379
# Epoch 2818, Train Loss: 0.000350, Validation Loss: 0.000343
# Epoch 2819, Train Loss: 0.000325, Validation Loss: 0.000325
# Epoch 2820, Train Loss: 0.000311, Validation Loss: 0.000329
# Epoch 2821, Train Loss: 0.000326, Validation Loss: 0.000320
# Epoch 2822, Train Loss: 0.000317, Validation Loss: 0.000316
# Epoch 2823, Train Loss: 0.000314, Validation Loss: 0.000317
# Epoch 2824, Train Loss: 0.000318, Validation Loss: 0.000328
# Epoch 2825, Train Loss: 0.000321, Validation Loss: 0.000313
# Saving model at epoch 2825 with validation loss 0.000313...
# Epoch 2826, Train Loss: 0.000323, Validation Loss: 0.000328
# Epoch 2827, Train Loss: 0.000310, Validation Loss: 0.000317
# Epoch 2828, Train Loss: 0.000315, Validation Loss: 0.000313
# Saving model at epoch 2828 with validation loss 0.000313...
# Epoch 2829, Train Loss: 0.000312, Validation Loss: 0.000315
# Epoch 2830, Train Loss: 0.000318, Validation Loss: 0.000316
# Epoch 2831, Train Loss: 0.000313, Validation Loss: 0.000315
# Epoch 2832, Train Loss: 0.000314, Validation Loss: 0.000315
# Epoch 2833, Train Loss: 0.000320, Validation Loss: 0.000319
# Epoch 2834, Train Loss: 0.000315, Validation Loss: 0.000324
# Epoch 2835, Train Loss: 0.000316, Validation Loss: 0.000317
# Epoch 2836, Train Loss: 0.000324, Validation Loss: 0.000314
# Epoch 2837, Train Loss: 0.000319, Validation Loss: 0.000313
# Epoch 2838, Train Loss: 0.000320, Validation Loss: 0.000346
# Epoch 2839, Train Loss: 0.000338, Validation Loss: 0.000441
# Epoch 2840, Train Loss: 0.000376, Validation Loss: 0.000341
# Epoch 2841, Train Loss: 0.000342, Validation Loss: 0.000323
# Epoch 2842, Train Loss: 0.000330, Validation Loss: 0.000360
# Epoch 2843, Train Loss: 0.000323, Validation Loss: 0.000316
# Epoch 2844, Train Loss: 0.000331, Validation Loss: 0.000338
# Epoch 2845, Train Loss: 0.000327, Validation Loss: 0.000330
# Epoch 2846, Train Loss: 0.000322, Validation Loss: 0.000329
# Epoch 2847, Train Loss: 0.000313, Validation Loss: 0.000327
# Epoch 2848, Train Loss: 0.000318, Validation Loss: 0.000330
# Epoch 2849, Train Loss: 0.000331, Validation Loss: 0.000338
# Epoch 2850, Train Loss: 0.000320, Validation Loss: 0.000316
# Epoch 2851, Train Loss: 0.000318, Validation Loss: 0.000313
# Epoch 2852, Train Loss: 0.000319, Validation Loss: 0.000330
# Epoch 2853, Train Loss: 0.000318, Validation Loss: 0.000311
# Saving model at epoch 2853 with validation loss 0.000311...
# Epoch 2854, Train Loss: 0.000315, Validation Loss: 0.000312
# Epoch 2855, Train Loss: 0.000313, Validation Loss: 0.000313
# Epoch 2856, Train Loss: 0.000307, Validation Loss: 0.000315
# Epoch 2857, Train Loss: 0.000320, Validation Loss: 0.000317
# Epoch 2858, Train Loss: 0.000323, Validation Loss: 0.000328
# Epoch 2859, Train Loss: 0.000314, Validation Loss: 0.000319
# Epoch 2860, Train Loss: 0.000328, Validation Loss: 0.000382
# Epoch 2861, Train Loss: 0.000327, Validation Loss: 0.000314
# Epoch 2862, Train Loss: 0.000315, Validation Loss: 0.000325
# Epoch 2863, Train Loss: 0.000330, Validation Loss: 0.000324
# Epoch 2864, Train Loss: 0.000313, Validation Loss: 0.000311
# Saving model at epoch 2864 with validation loss 0.000311...
# Epoch 2865, Train Loss: 0.000310, Validation Loss: 0.000311
# Epoch 2866, Train Loss: 0.000314, Validation Loss: 0.000316
# Epoch 2867, Train Loss: 0.000313, Validation Loss: 0.000311
# Epoch 2868, Train Loss: 0.000308, Validation Loss: 0.000315
# Epoch 2869, Train Loss: 0.000310, Validation Loss: 0.000314
# Epoch 2870, Train Loss: 0.000314, Validation Loss: 0.000316
# Epoch 2871, Train Loss: 0.000312, Validation Loss: 0.000319
# Epoch 2872, Train Loss: 0.000316, Validation Loss: 0.000313
# Epoch 2873, Train Loss: 0.000318, Validation Loss: 0.000326
# Epoch 2874, Train Loss: 0.000322, Validation Loss: 0.000336
# Epoch 2875, Train Loss: 0.000328, Validation Loss: 0.000332
# Epoch 2876, Train Loss: 0.000342, Validation Loss: 0.000322
# Epoch 2877, Train Loss: 0.000311, Validation Loss: 0.000316
# Epoch 2878, Train Loss: 0.000318, Validation Loss: 0.000326
# Epoch 2879, Train Loss: 0.000331, Validation Loss: 0.000357
# Epoch 2880, Train Loss: 0.000336, Validation Loss: 0.000317
# Epoch 2881, Train Loss: 0.000316, Validation Loss: 0.000310
# Saving model at epoch 2881 with validation loss 0.000310...
# Epoch 2882, Train Loss: 0.000315, Validation Loss: 0.000326
# Epoch 2883, Train Loss: 0.000320, Validation Loss: 0.000338
# Epoch 2884, Train Loss: 0.000318, Validation Loss: 0.000365
# Epoch 2885, Train Loss: 0.000332, Validation Loss: 0.000336
# Epoch 2886, Train Loss: 0.000314, Validation Loss: 0.000326
# Epoch 2887, Train Loss: 0.000319, Validation Loss: 0.000352
# Epoch 2888, Train Loss: 0.000335, Validation Loss: 0.000324
# Epoch 2889, Train Loss: 0.000361, Validation Loss: 0.000342
# Epoch 2890, Train Loss: 0.000366, Validation Loss: 0.000379
# Epoch 2891, Train Loss: 0.000349, Validation Loss: 0.000322
# Epoch 2892, Train Loss: 0.000331, Validation Loss: 0.000311
# Epoch 2893, Train Loss: 0.000314, Validation Loss: 0.000326
# Epoch 2894, Train Loss: 0.000324, Validation Loss: 0.000314
# Epoch 2895, Train Loss: 0.000309, Validation Loss: 0.000312
# Epoch 2896, Train Loss: 0.000308, Validation Loss: 0.000338
# Epoch 2897, Train Loss: 0.000314, Validation Loss: 0.000366
# Epoch 2898, Train Loss: 0.000327, Validation Loss: 0.000317
# Epoch 2899, Train Loss: 0.000312, Validation Loss: 0.000318
# Epoch 2900, Train Loss: 0.000309, Validation Loss: 0.000324
# Epoch 2901, Train Loss: 0.000315, Validation Loss: 0.000311
# Epoch 2902, Train Loss: 0.000317, Validation Loss: 0.000315
# Epoch 2903, Train Loss: 0.000309, Validation Loss: 0.000308
# Saving model at epoch 2903 with validation loss 0.000308...
# Epoch 2904, Train Loss: 0.000309, Validation Loss: 0.000311
# Epoch 2905, Train Loss: 0.000311, Validation Loss: 0.000315
# Epoch 2906, Train Loss: 0.000308, Validation Loss: 0.000311
# Epoch 2907, Train Loss: 0.000322, Validation Loss: 0.000317
# Epoch 2908, Train Loss: 0.000316, Validation Loss: 0.000329
# Epoch 2909, Train Loss: 0.000319, Validation Loss: 0.000315
# Epoch 2910, Train Loss: 0.000327, Validation Loss: 0.000308
# Saving model at epoch 2910 with validation loss 0.000308...
# Epoch 2911, Train Loss: 0.000309, Validation Loss: 0.000311
# Epoch 2912, Train Loss: 0.000311, Validation Loss: 0.000337
# Epoch 2913, Train Loss: 0.000321, Validation Loss: 0.000320
# Epoch 2914, Train Loss: 0.000324, Validation Loss: 0.000318
# Epoch 2915, Train Loss: 0.000319, Validation Loss: 0.000309
# Epoch 2916, Train Loss: 0.000311, Validation Loss: 0.000317
# Epoch 2917, Train Loss: 0.000311, Validation Loss: 0.000308
# Saving model at epoch 2917 with validation loss 0.000308...
# Epoch 2918, Train Loss: 0.000320, Validation Loss: 0.000323
# Epoch 2919, Train Loss: 0.000314, Validation Loss: 0.000309
# Epoch 2920, Train Loss: 0.000319, Validation Loss: 0.000308
# Epoch 2921, Train Loss: 0.000310, Validation Loss: 0.000314
# Epoch 2922, Train Loss: 0.000307, Validation Loss: 0.000333
# Epoch 2923, Train Loss: 0.000354, Validation Loss: 0.000328
# Epoch 2924, Train Loss: 0.000314, Validation Loss: 0.000312
# Epoch 2925, Train Loss: 0.000319, Validation Loss: 0.000308
# Epoch 2926, Train Loss: 0.000306, Validation Loss: 0.000332
# Epoch 2927, Train Loss: 0.000322, Validation Loss: 0.000322
# Epoch 2928, Train Loss: 0.000308, Validation Loss: 0.000319
# Epoch 2929, Train Loss: 0.000315, Validation Loss: 0.000330
# Epoch 2930, Train Loss: 0.000308, Validation Loss: 0.000309
# Epoch 2931, Train Loss: 0.000308, Validation Loss: 0.000309
# Epoch 2932, Train Loss: 0.000309, Validation Loss: 0.000325
# Epoch 2933, Train Loss: 0.000314, Validation Loss: 0.000313
# Epoch 2934, Train Loss: 0.000316, Validation Loss: 0.000317
# Epoch 2935, Train Loss: 0.000309, Validation Loss: 0.000309
# Epoch 2936, Train Loss: 0.000309, Validation Loss: 0.000341
# Epoch 2937, Train Loss: 0.000325, Validation Loss: 0.000332
# Epoch 2938, Train Loss: 0.000324, Validation Loss: 0.000305
# Saving model at epoch 2938 with validation loss 0.000305...
# Epoch 2939, Train Loss: 0.000310, Validation Loss: 0.000337
# Epoch 2940, Train Loss: 0.000359, Validation Loss: 0.000329
# Epoch 2941, Train Loss: 0.000320, Validation Loss: 0.000316
# Epoch 2942, Train Loss: 0.000340, Validation Loss: 0.000308
# Epoch 2943, Train Loss: 0.000310, Validation Loss: 0.000324
# Epoch 2944, Train Loss: 0.000307, Validation Loss: 0.000306
# Epoch 2945, Train Loss: 0.000325, Validation Loss: 0.000308
# Epoch 2946, Train Loss: 0.000325, Validation Loss: 0.000308
# Epoch 2947, Train Loss: 0.000316, Validation Loss: 0.000307
# Epoch 2948, Train Loss: 0.000323, Validation Loss: 0.000337
# Epoch 2949, Train Loss: 0.000328, Validation Loss: 0.000316
# Epoch 2950, Train Loss: 0.000311, Validation Loss: 0.000305
# Saving model at epoch 2950 with validation loss 0.000305...
# Epoch 2951, Train Loss: 0.000314, Validation Loss: 0.000342
# Epoch 2952, Train Loss: 0.000319, Validation Loss: 0.000308
# Epoch 2953, Train Loss: 0.000317, Validation Loss: 0.000326
# Epoch 2954, Train Loss: 0.000312, Validation Loss: 0.000317
# Epoch 2955, Train Loss: 0.000314, Validation Loss: 0.000304
# Saving model at epoch 2955 with validation loss 0.000304...
# Epoch 2956, Train Loss: 0.000312, Validation Loss: 0.000304
# Saving model at epoch 2956 with validation loss 0.000304...
# Epoch 2957, Train Loss: 0.000327, Validation Loss: 0.000362
# Epoch 2958, Train Loss: 0.000315, Validation Loss: 0.000308
# Epoch 2959, Train Loss: 0.000319, Validation Loss: 0.000311
# Epoch 2960, Train Loss: 0.000305, Validation Loss: 0.000311
# Epoch 2961, Train Loss: 0.000332, Validation Loss: 0.000328
# Epoch 2962, Train Loss: 0.000327, Validation Loss: 0.000332
# Epoch 2963, Train Loss: 0.000325, Validation Loss: 0.000332
# Epoch 2964, Train Loss: 0.000308, Validation Loss: 0.000311
# Epoch 2965, Train Loss: 0.000311, Validation Loss: 0.000328
# Epoch 2966, Train Loss: 0.000306, Validation Loss: 0.000303
# Saving model at epoch 2966 with validation loss 0.000303...
# Epoch 2967, Train Loss: 0.000311, Validation Loss: 0.000306
# Epoch 2968, Train Loss: 0.000349, Validation Loss: 0.000310
# Epoch 2969, Train Loss: 0.000308, Validation Loss: 0.000328
# Epoch 2970, Train Loss: 0.000320, Validation Loss: 0.000311
# Epoch 2971, Train Loss: 0.000325, Validation Loss: 0.000308
# Epoch 2972, Train Loss: 0.000315, Validation Loss: 0.000319
# Epoch 2973, Train Loss: 0.000307, Validation Loss: 0.000312
# Epoch 2974, Train Loss: 0.000310, Validation Loss: 0.000306
# Epoch 2975, Train Loss: 0.000301, Validation Loss: 0.000303
# Saving model at epoch 2975 with validation loss 0.000303...
# Epoch 2976, Train Loss: 0.000305, Validation Loss: 0.000303
# Saving model at epoch 2976 with validation loss 0.000303...
# Epoch 2977, Train Loss: 0.000302, Validation Loss: 0.000313
# Epoch 2978, Train Loss: 0.000306, Validation Loss: 0.000310
# Epoch 2979, Train Loss: 0.000321, Validation Loss: 0.000364
# Epoch 2980, Train Loss: 0.000326, Validation Loss: 0.000306
# Epoch 2981, Train Loss: 0.000307, Validation Loss: 0.000313
# Epoch 2982, Train Loss: 0.000310, Validation Loss: 0.000303
# Epoch 2983, Train Loss: 0.000300, Validation Loss: 0.000307
# Epoch 2984, Train Loss: 0.000301, Validation Loss: 0.000304
# Epoch 2985, Train Loss: 0.000319, Validation Loss: 0.000307
# Epoch 2986, Train Loss: 0.000317, Validation Loss: 0.000303
# Epoch 2987, Train Loss: 0.000310, Validation Loss: 0.000308
# Epoch 2988, Train Loss: 0.000322, Validation Loss: 0.000304
# Epoch 2989, Train Loss: 0.000312, Validation Loss: 0.000306
# Epoch 2990, Train Loss: 0.000348, Validation Loss: 0.000308
# Epoch 2991, Train Loss: 0.000309, Validation Loss: 0.000333
# Epoch 2992, Train Loss: 0.000310, Validation Loss: 0.000304
# Epoch 2993, Train Loss: 0.000316, Validation Loss: 0.000302
# Saving model at epoch 2993 with validation loss 0.000302...
# Epoch 2994, Train Loss: 0.000321, Validation Loss: 0.000303
# Epoch 2995, Train Loss: 0.000315, Validation Loss: 0.000325
# Epoch 2996, Train Loss: 0.000324, Validation Loss: 0.000321
# Epoch 2997, Train Loss: 0.000304, Validation Loss: 0.000309
# Epoch 2998, Train Loss: 0.000300, Validation Loss: 0.000304
# Epoch 2999, Train Loss: 0.000302, Validation Loss: 0.000302
# Saving model at epoch 2999 with validation loss 0.000302...
# Epoch 3000, Train Loss: 0.000304, Validation Loss: 0.000301
# Saving model at epoch 3000 with validation loss 0.000301...
# Training complete. Best model saved at ./Model/range/128/CH467160.pt.
# C:\Users\USER\AppData\Local\Temp\ipykernel_42872\3145885345.py:174: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_save_path))  # 載入最佳模型
