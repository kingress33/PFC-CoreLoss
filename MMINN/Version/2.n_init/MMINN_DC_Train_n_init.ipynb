# %% [markdown]
# # Part 1: Network Training

# %% [markdown]
# ## Step0: Import Package & Hyperparameter Configuration

# %%
"""
2025/02/03: 1.新增normDict計算 #!注意normDict是有先經過資料前處理計算的
            2.資料集中任意取n筆去訓練(n:自填數) 
            
2025/03/17: 1.修改增加Hdc,N輸入參數
            2.Mdoel修正兩個子迴路接考慮Hdc與N            
            
"""
# Out:
# '\n2025/02/03: 1.新增normDict計算 #!注意normDict是有先經過資料前處理計算的\n            2.資料集中任意取n筆去訓練(n:自填數) \n            \n2025/03/17: 1.修改增加Hdc,N輸入參數\n            2.Mdoel修正兩個子迴路接考慮Hdc與N            \n            \n'

# %%
# %reset -f  # 清空所有變數

import gc
gc.collect()  # 強制 Python 回收記憶體
# Out:
# Don't know how to reset  #, please run `%reset?` for details
# Don't know how to reset  清空所有變數, please run `%reset?` for details
# 0

# %% [markdown]
# ### Package

# %%
import os
import torch
import numpy as np
import random
import torch.nn as nn
from torch.autograd import Variable
from torch.utils.data import DataLoader, TensorDataset
import matplotlib.pyplot as plt
from tqdm import tqdm

# %% [markdown]
# ### Hyperparameter Config

# %%
# %%
# Unified Hyperparameter Configuration
class Config:
    SEED = 1
    NUM_EPOCHS = 3000
    BATCH_SIZE = 128
    LEARNING_RATE = 0.002  #論文提供
    LR_SCHEDULER_GAMMA = 0.99  #論文提供
    DECAY_EPOCH = 200
    DECAY_RATIO = 0.5
    EARLY_STOPPING_PATIENCE = 500
    HIDDEN_SIZE = 30
    OPERATOR_SIZE = 30


# Reproducibility
random.seed(Config.SEED)
np.random.seed(Config.SEED)
torch.manual_seed(Config.SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %% [markdown]
# ### Material & Number of Data

# %%
material = "CH467160"
down_sample_way = "linspace_n_init1"  #range
downsample = 1024

# 訓練情況況
plot_interval = 300
train_show_sample = 1

# 定義保存模型的路徑
model_save_dir = f"./Model/{down_sample_way}/{downsample}/"
os.makedirs(model_save_dir, exist_ok=True)  # 如果路徑不存在，創建路徑

model_save_path = os.path.join(model_save_dir,
                               f"{material}_n_init1.pt")  # 定義模型保存檔名

figure_save_base_path = f"./figure/{down_sample_way}/{downsample}/"
os.makedirs(figure_save_base_path, exist_ok=True)  # 如果路徑不存在，創建路徑

# Select device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Step1: Data processing and data loader generate

# %%
# %% Preprocess data into a data loader
def get_dataloader(data_B,
                   data_F,
                   data_T,
                   data_H,
                   data_N,
                   data_Hdc,
                   data_Pcv,
                   n_init=16):
    """ #*(Date:250105)
    Process data and return DataLoader for training, validation, and testing.

    Parameters
    ----------
    data_B : np.array
        Magnetic flux density data.
    data_F : np.array
        Frequency data.
    data_T : np.array
        Temperature data.
    data_N : np.array
        Turns data.
    data_Hdc : np.array
        DC Magnetic field strength data.
    data_H : np.array
        AC Magnetic field strength data.
    data_Pcv : np.array
        Core loss data.
    norm : list
        Normalization parameters for the features.
    n_init : int
        Number of initial data points for magnetization.

    Returns
    -------
        train_loader, valid_loader : DataLoader
        Dataloaders for training, validation
        norm
    """

    # Data pre-process

    # 1. Down-sample to 128 points
    #*  Add  Down-sample: 8192 to 128 points (Date:241213)
    #*  Add H Down-sample to 128 points (Date:241213)
    seq_length = downsample
    #range(start, stop, step)
    # cols = range(0, 8192, int(8192 / seq_length))
    cols = np.linspace(0, 8191, seq_length, dtype=int)
    data_B = data_B[:, cols]
    data_H = data_H[:, cols]

    # data_B = data_B - np.mean(data_B, axis=1,
    #                           keepdims=True)  #*  移除降階影響 (Date:250325)
    # data_H = data_H - np.mean(data_H, axis=1, keepdims=True)

    # 2. Add extra points for initial magnetization calculation
    #*(Date:241216) MMINN output似乎是128點
    #*(Date:250130) 原始MMINN H有包含n_init
    data_length = seq_length + n_init
    data_B = np.hstack((data_B, data_B[:, :n_init]))
    data_H = np.hstack((data_H, data_H[:, :n_init]))

    # 3. Format data into tensors  #*(Date:241216) seq_length=128, data_length=144
    B = torch.from_numpy(data_B).view(-1, data_length, 1).float()
    H = torch.from_numpy(data_H).view(-1, data_length, 1).float()
    F = torch.log10(torch.from_numpy(data_F).view(-1, 1).float())
    T = torch.from_numpy(data_T).view(-1, 1).float()
    Hdc = torch.from_numpy(data_Hdc).view(-1, 1).float()
    N = torch.from_numpy(data_N).view(-1, 1).float()
    Pcv = torch.log10(torch.from_numpy(data_Pcv).view(-1, 1).float())

    # 原本在6. 因要先計算標準化故移至這
    dB = torch.diff(B, dim=1)
    dB = torch.cat((dB[:, 0:1], dB), dim=1)
    dB_dt = dB * (seq_length * F.view(-1, 1, 1))

    # # 4. Compute normalization parameters (均值 & 標準差)**
    # norm = [
    #     [torch.mean(B).item(), torch.std(B).item()],  # B
    #     [torch.mean(H).item(), torch.std(H).item()],  # H
    #     [torch.mean(F).item(), torch.std(F).item()],  # F
    #     [torch.mean(T).item(), torch.std(T).item()],  # T
    #     [torch.mean(Hdc).item(), torch.std(Hdc).item()],  # Hdc #*(250317新加入)
    #     [torch.mean(N).item(), torch.std(N).item()],  # N #*(250317新加入)
    #     [torch.mean(Pcv).item(), torch.std(Pcv).item()],  # Pv
    # ]

    #  4. Compute normalization parameters (均值 & 標準差)**
    # ! 溫度頻率不變加入微小的 epsilon
    norm = [
        safe_mean_std(B),  # 0: B
        safe_mean_std(H),  # 1: H
        safe_mean_std(F),  # 2: F
        safe_mean_std(T),  # 3: T
        safe_mean_std(dB_dt),  # 4: dB/dt
        safe_mean_std(Pcv),  # 5: Pcv
        safe_mean_std(Hdc),  # 6: Hdc
        safe_mean_std(N)  # 7: N
    ]

    # 用來做test固定標準化參數的
    material_name = f"{material}"
    print(f'"{material_name}": [')
    for param in norm:
        print(f"    {param},")
    print("]")

    # 5. Data Normalization
    in_B = (B - norm[0][0]) / norm[0][1]  # B
    out_H = (H - norm[1][0]) / norm[1][1]  # H
    in_F = (F - norm[2][0]) / norm[2][1]  # F
    in_T = (T - norm[3][0]) / norm[3][1]  # T

    in_Pcv = (Pcv - norm[5][0]) / norm[5][1]  # Pcv
    in_Hdc = (Hdc - norm[6][0]) / norm[6][1]  # Hdc
    in_N = (N - norm[7][0]) / norm[7][1]  # N

    # 6. Extra features

    in_dB = torch.diff(B, dim=1)
    in_dB = torch.cat((in_dB[:, 0:1], in_dB), dim=1)

    in_dB_dt = (dB_dt - norm[4][0]) / norm[4][1]

    max_B, _ = torch.max(in_B, dim=1)
    min_B, _ = torch.min(in_B, dim=1)

    s0 = get_operator_init(in_B[:, 0] - in_dB[:, 0], in_dB, max_B, min_B)

    # 7. Create dataloader to speed up data processing
    full_dataset = torch.utils.data.TensorDataset(
        torch.cat((in_B, in_dB, in_dB_dt), dim=2),  # B 部分（144 點）
        torch.cat((in_F, in_T, in_Hdc, in_N, in_Pcv), dim=1),  # 輔助變量
        s0,  # 初始狀態
        out_H)

    # Split dataset into train, validation, and test sets (60:20:20)
    train_size = int(0.8 * len(full_dataset))
    valid_size = len(full_dataset) - train_size

    train_dataset, valid_dataset = torch.utils.data.random_split(
        full_dataset, [train_size, valid_size],
        generator=torch.Generator().manual_seed(Config.SEED))

    train_loader = torch.utils.data.DataLoader(train_dataset,
                                               batch_size=Config.BATCH_SIZE,
                                               shuffle=True,
                                               num_workers=0,
                                               collate_fn=filter_input)

    valid_loader = torch.utils.data.DataLoader(valid_dataset,
                                               batch_size=Config.BATCH_SIZE,
                                               shuffle=False,
                                               num_workers=0,
                                               collate_fn=filter_input)

    return train_loader, valid_loader, norm


# %% Predict the operator state at t0
def get_operator_init(B1,
                      dB,
                      Bmax,
                      Bmin,
                      max_out_H=5,
                      operator_size=Config.OPERATOR_SIZE):
    """Compute the initial state of hysteresis operators"""
    s0 = torch.zeros((dB.shape[0], operator_size))
    operator_thre = torch.from_numpy(
        np.linspace(max_out_H / operator_size, max_out_H,
                    operator_size)).view(1, -1)

    for i in range(dB.shape[0]):
        for j in range(operator_size):
            r = operator_thre[0, j]
            if (Bmax[i] >= r) or (Bmin[i] <= -r):
                if dB[i, 0] >= 0:
                    if B1[i] > Bmin[i] + 2 * r:
                        s0[i, j] = r
                    else:
                        s0[i, j] = B1[i] - (r + Bmin[i])
                else:
                    if B1[i] < Bmax[i] - 2 * r:
                        s0[i, j] = -r
                    else:
                        s0[i, j] = B1[i] + (r - Bmax[i])
    return s0


def filter_input(batch):
    inputs, features, s0, target_H = zip(*batch)

    # 如果 inputs 是 tuple，先堆疊成張量
    inputs = torch.stack(inputs)  # B 的所有輸入部分（144 點）

    # 保留 in_B, in_dB, in_dB_dt 作為模型輸入
    inputs = inputs[:, :, :3]

    # 保留 features（包括 in_F 和 in_T）
    features = torch.stack(
        features
    )[:, :4]  #!(250317)保留 in_F, in_T, in_Hdc, in_N (排除 in_Pcv，in_Pcv要放在最面)

    # 保留目標值 H
    target_H = torch.stack(
        target_H)[:, :downsample, :]  # ?只取最後 128 點 (改1024看狀況有無變好)

    s0 = torch.stack(s0)  # 初始狀態

    return inputs, features, s0, target_H


# ! 溫度頻率不變加入微小的 epsilon
def safe_mean_std(tensor, eps=1e-8):
    m_tensor = torch.mean(tensor)  # 還是 Tensor
    s_tensor = torch.std(tensor)  # 還是 Tensor

    m_val = m_tensor.item()  # 第一次轉成 float
    s_val = s_tensor.item()
    if s_val < eps:
        s_val = 1.0

    return [m_val, s_val]  # 直接回傳 float

# %% [markdown]
# ## Step2: Define Network Structure

# %%
# %% Magnetization mechansim-determined neural network
"""
    Parameters:
    - hidden_size: number of eddy current slices (RNN neuron)
    - operator_size: number of operators
    - input_size: number of inputs (1.B 2.dB 3.dB/dt)
# ! - var_size: number of supplenmentary variables (1.F 2.T 3.Hdc 4.N)        
    - output_size: number of outputs (1.H)
"""


class MMINet(nn.Module):
    def __init__(
            self,
            norm,  #*這裡改成從外部傳入 norm(250203)
            hidden_size=Config.HIDDEN_SIZE,
            operator_size=Config.OPERATOR_SIZE,
            input_size=3,
            var_size=4,
            output_size=1):
        super().__init__()
        self.input_size = input_size
        self.var_size = var_size
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.operator_size = operator_size
        self.norm = norm  #*這裡改成從外部傳入 norm(250203)

        self.rnn1 = StopOperatorCell(self.operator_size)
        self.dnn1 = nn.Linear(self.operator_size + 4,
                              1)  #!250317更新：operator_size + 4
        self.rnn2 = EddyCell(
            6, self.hidden_size,
            output_size)  #!250317更新：4 (F, T, B, dB/dt ) + 2 (Hdc, N)
        self.dnn2 = nn.Linear(self.hidden_size, 1)

        self.rnn2_hx = None

    def forward(self, x, var, s0, n_init=16):
        """
         Parameters: 
          - x(batch,seq,input_size): Input features (1.B, 2.dB, 3.dB/dt)  
# !       - var(batch,var_size): Supplementary inputs (1.F 2.T 3.Hdc 4.N) 
          - s0(batch,1): Operator inital states
        """
        batch_size = x.size(0)  # Batch size
        seq_size = x.size(1)  # Ser
        self.rnn1_hx = s0

        # Initialize DNN2 input (1.B 2.dB/dt)
        x2 = torch.cat((x[:, :, 0:1], x[:, :, 2:3]), dim=2)

        for t in range(seq_size):
            # RNN1 input (dB,state)
            self.rnn1_hx = self.rnn1(x[:, t, 1:2], self.rnn1_hx)

            # DNN1 input (rnn1_hx,F,T,Hdc,N)
            dnn1_in = torch.cat((self.rnn1_hx, var), dim=1)

            # H hysteresis prediction
            H_hyst_pred = self.dnn1(dnn1_in)

            # DNN2 input (B,dB/dt,T,F)
            rnn2_in = torch.cat((x2[:, t, :], var), dim=1)

            # Initialize second rnn state
            if t == 0:
                H_eddy_init = x[:, t, 0:1] - H_hyst_pred
                buffer = x.new_ones(x.size(0), self.hidden_size)
                self.rnn2_hx = Variable(
                    (buffer / torch.sum(self.dnn2.weight, dim=1)) *
                    H_eddy_init)

            #rnn2_in = torch.cat((rnn2_in,H_hyst_pred),dim=1)
            self.rnn2_hx = self.rnn2(rnn2_in, self.rnn2_hx)

            # H eddy prediction
            H_eddy = self.dnn2(self.rnn2_hx)

            # H total
            H_total = (H_hyst_pred + H_eddy).view(batch_size, 1,
                                                  self.output_size)
            if t == 0:
                output = H_total
            else:
                output = torch.cat((output, H_total), dim=1)

        H = (output[:, :-n_init, :])

        return H


class StopOperatorCell():
    def __init__(self, operator_size):
        self.operator_thre = torch.from_numpy(
            np.linspace(5 / operator_size, 5, operator_size)).view(1, -1)

    def sslu(self, X):
        a = torch.ones_like(X)
        return torch.max(-a, torch.min(a, X))

    def __call__(self, dB, state):
        r = self.operator_thre.to(dB.device)
        output = self.sslu((dB + state) / r) * r
        return output.float()


class EddyCell(nn.Module):
    def __init__(self, input_size, hidden_size, output_size=1):
        super().__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.output_size = output_size

        self.x2h = nn.Linear(input_size, hidden_size, bias=False)
        self.h2h = nn.Linear(hidden_size, hidden_size, bias=False)

    def forward(self, x, hidden=None):
        hidden = self.x2h(x) + self.h2h(hidden)
        hidden = torch.sigmoid(hidden)
        return hidden

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# ## Step3: Training the Model

# %% [markdown]
# ### Load Dataset

# %%
# %%
def load_dataset(material, base_path="./Data/"):

    in_file1 = f"{base_path}{material}/train/B_Field.csv"
    in_file2 = f"{base_path}{material}/train/Frequency.csv"
    in_file3 = f"{base_path}{material}/train/Temperature.csv"
    in_file4 = f"{base_path}{material}/train/H_Field.csv"
    in_file5 = f"{base_path}{material}/train/Volumetric_Loss.csv"
    in_file6 = f"{base_path}{material}/train/Hdc.csv"  # *250317新增：直流偏置磁場
    in_file7 = f"{base_path}{material}/train/Turns.csv"  # *250317新增：匝數

    data_B = np.genfromtxt(in_file1, delimiter=',')  # N x 1024
    data_F = np.genfromtxt(in_file2, delimiter=',')  # N x 1
    data_T = np.genfromtxt(in_file3, delimiter=',')  # N x 1
    data_H = np.genfromtxt(in_file4, delimiter=',')  # N x 1024  # *250317新增
    data_Pcv = np.genfromtxt(in_file5, delimiter=',')  # N x 1
    data_Hdc = np.genfromtxt(in_file6, delimiter=',')  # N x 1  # *250317新增
    data_N = np.genfromtxt(in_file7, delimiter=',')  # N x 1

    return data_B, data_F, data_T, data_H, data_Pcv, data_Hdc, data_N

# %% [markdown]
# ### Train Code

# %%
# %%
def train_model(norm, train_loader, valid_loader):

    model = MMINet(norm=norm).to(device)
    print("Number of parameters: ", count_parameters(model))
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=Config.LEARNING_RATE)

    best_val_loss = float('inf')
    patience_counter = 0

    # **新增 Loss 記錄**
    train_losses = []
    val_losses = []
    fixed_idx = None

    for epoch in range(Config.NUM_EPOCHS):
        model.train()
        train_loss = 0

        for inputs, features, s0, target_H in train_loader:
            inputs, features, s0, target_H = inputs.to(device), features.to(
                device), s0.to(device), target_H.to(device)

            optimizer.zero_grad()
            outputs = model(inputs, features, s0)  # 模型的輸出
            loss = criterion(outputs, target_H)  # 使用真實的 H(t) 計算損失
            loss.backward()
            optimizer.step()
            train_loss += loss.item()

        train_loss /= len(train_loader)
        train_losses.append(train_loss)  # **記錄 Train Loss**

        model.eval()
        val_loss = 0

        with torch.no_grad():
            for inputs, features, s0, target_H in valid_loader:
                inputs, features, s0, target_H = inputs.to(
                    device), features.to(device), s0.to(device), target_H.to(
                        device)
                outputs = model(inputs, features, s0)
                loss = criterion(outputs, target_H)
                val_loss += loss.item()

        val_loss /= len(valid_loader)
        val_losses.append(val_loss)  # **記錄 Validation Loss**

        print(
            f"Epoch {epoch+1}, Train Loss: {train_loss:.6f}, Validation Loss: {val_loss:.6f}"
        )

        # ======================================================繪製訓練情況======================================================

        if (epoch + 1) % plot_interval == 0:

            # 第一次產生固定的隨機索引
            if fixed_idx is None:
                batch_size_fix = 3
                fixed_idx = torch.randperm(batch_size_fix)[:train_show_sample]

            # # -------------------------設定圖表H(t)比較---------------------------------------

            # outputs = [fixed_idx, :downsample,
            #  0].detach().cpu().numpy()
            # targets_np = target_H[fixed_idx, :downsample,
            #                       0].detach().cpu().numpy()

            # plt.figure(figsize=(12, 6))

            # for i in range(outputs.shape[0]):  # 每一批數據繪製一個圖表
            #     plt.plot(outputs[i, :, 0],
            #              label=f"Pred: Sample {i+1}",
            #              linestyle='--',
            #              marker='o')
            #     plt.plot(targets[i, :, 0],
            #              label=f"Target: Sample {i+1}",
            #              linestyle='-',
            #              marker='x')

            # # 添加標題和標籤
            # plt.title(f"Compare - Epoch {epoch + 1}", fontsize=16)
            # plt.xlabel("Index", fontsize=14)
            # plt.ylabel("Value", fontsize=14)
            # plt.legend(loc="upper right", fontsize=12)
            # plt.grid(alpha=0.5)

            # # 顯示圖表
            # plt.show()
            # # -------------------------設定圖表H(t)比較 結束---------------------------------------

            # # -------------------------設定圖表B-H比較---------------------------------------
            # 取對應 sample
            outputs_np = outputs[fixed_idx, :downsample,
                                 0].detach().cpu().numpy()
            targets_np = target_H[fixed_idx, :downsample,
                                  0].detach().cpu().numpy()
            B_seq_np = inputs[fixed_idx, :downsample, 0].detach().cpu().numpy()

            # 設定圖表
            plt.figure()

            for i in range(train_show_sample):  # 每一批數據繪製一個圖表
                plt.plot(outputs_np[i],
                         B_seq_np[i],
                         label=f"Pred: Sample {i+1}",
                         markersize=1)

                plt.plot(targets_np[i],
                         B_seq_np[i],
                         label=f"Target: Sample {i+1}",
                         alpha=0.5)

            # 添加標題和標籤
            plt.title(f"Compare - Epoch {epoch + 1}")
            plt.xlabel("Index")
            plt.ylabel("Value")
            plt.grid(alpha=0.5)
            plt.legend()
            figure_save_path1 = os.path.join(
                figure_save_base_path,
                f"Compare_Epoch {epoch + 1}.svg")  # 定義模型保存檔名

            plt.savefig(figure_save_path1)
            # 顯示圖表
            plt.show()
            # # -------------------------設定圖表B-H比較 END---------------------------------------
        # ======================================================繪製訓練情況  END ======================================================

        # ======================================================Early stop======================================================
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            torch.save(model.state_dict(), model_save_path)  # 保存最佳模型
            print(
                f"Saving model at epoch {epoch+1} with validation loss {val_loss:.6f}..."
            )
            patience_counter = 0
        else:
            patience_counter += 1

        if patience_counter >= Config.EARLY_STOPPING_PATIENCE:
            print("Early stopping triggered.")
            break

        # ======================================================Early stop======================================================

    print(f"Training complete. Best model saved at {model_save_path}.")

    # ==============================繪製 Train Loss 與 Validation Loss 圖==============================
    plt.figure(figsize=(10, 5))
    plt.plot(
        range(1,
              len(train_losses) + 1),
        train_losses,
        label="Train Loss",
    )
    plt.plot(range(1,
                   len(val_losses) + 1),
             val_losses,
             label="Validation Loss")

    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.title("Training & Validation Loss Curve")
    plt.legend()
    plt.grid(alpha=0.5)
    figure_save_path2 = os.path.join(figure_save_base_path,
                                     "Training_Loss_Curve.svg")  # 定義模型保存檔名
    plt.savefig(figure_save_path2)
    plt.show()
    # ==============================繪製 Train Loss 與 Validation Loss 圖 END==============================

    # ===================================使用最佳模型來產生驗證結果=============================
    model.load_state_dict(torch.load(model_save_path))  # 載入最佳模型
    model.eval()

    with torch.no_grad():
        for inputs, features, s0, target_H in valid_loader:
            inputs, features, s0, target_H = inputs.to(device), features.to(
                device), s0.to(device), target_H.to(device)

            outputs = model(inputs, features, s0)  # 使用最佳模型產生預測值
            break  # 只使用一批驗證數據進行可視化

    # 選取對應資料（index tensor 要先轉 list 才能 index numpy）
    outputs_np = outputs[fixed_idx, :downsample, 0].detach().cpu().numpy()
    targets_np = target_H[fixed_idx, :downsample, 0].detach().cpu().numpy()
    B_seq_np = inputs[fixed_idx, :downsample, 0].detach().cpu().numpy()

    # 設定圖表
    plt.figure()

    for i in range(train_show_sample):  # 每一批數據繪製一個圖表
        plt.plot(outputs_np[i], B_seq_np[i], label=f"Pred: Sample {i+1}")

        plt.plot(targets_np[i],
                 B_seq_np[i],
                 label=f"Target: Sample {i+1}",
                 alpha=0.7)

    # 添加標題和標籤
    plt.title(f"Best Model - Predicted vs Target")
    plt.xlabel("Index")
    plt.ylabel("Value")
    plt.grid(alpha=0.5)
    plt.legend()
    figure_save_path3 = os.path.join(
        figure_save_base_path,
        "Best Model_Predicted vs Target.svg")  # 定義模型保存檔名
    plt.savefig(figure_save_path3)

    # ===================================使用最佳模型來產生驗證結果 END=============================

# %% [markdown]
# ### Start Train!!!

# %%
if __name__ == "__main__":

    data_B, data_F, data_T, data_H, data_Pcv, data_Hdc, data_N = load_dataset(
        material)

    train_loader, valid_loader, norm = get_dataloader(data_B, data_F, data_T,
                                                      data_H, data_N, data_Hdc,
                                                      data_Pcv)

    train_model(norm, train_loader, valid_loader)
# Out:
# "CH467160": [
#     [5.061452611698769e-06, 0.029233083128929138],
#     [0.13549742102622986, 160.82618713378906],
#     [2.0, 1.0],
#     [25.0, 1.0],
#     [0.00640619033947587, 0.44422411918640137],
#     [1.8067814111709595, 0.715567409992218],
#     [1250.265380859375, 701.6740112304688],
#     [12.159845352172852, 3.296860456466675],
# ]
# Number of parameters:  1146
# Epoch 1, Train Loss: 1.004081, Validation Loss: 0.909126
# Saving model at epoch 1 with validation loss 0.909126...
# Epoch 2, Train Loss: 0.848484, Validation Loss: 0.756789
# Saving model at epoch 2 with validation loss 0.756789...
# Epoch 3, Train Loss: 0.687380, Validation Loss: 0.593498
# Saving model at epoch 3 with validation loss 0.593498...
# Epoch 4, Train Loss: 0.517331, Validation Loss: 0.402090
# Saving model at epoch 4 with validation loss 0.402090...
# Epoch 5, Train Loss: 0.310142, Validation Loss: 0.186720
# Saving model at epoch 5 with validation loss 0.186720...
# Epoch 6, Train Loss: 0.116432, Validation Loss: 0.053866
# Saving model at epoch 6 with validation loss 0.053866...
# Epoch 7, Train Loss: 0.060530, Validation Loss: 0.054813
# Epoch 8, Train Loss: 0.049987, Validation Loss: 0.038685
# Saving model at epoch 8 with validation loss 0.038685...
# Epoch 9, Train Loss: 0.040381, Validation Loss: 0.033545
# Saving model at epoch 9 with validation loss 0.033545...
# Epoch 10, Train Loss: 0.033160, Validation Loss: 0.028863
# Saving model at epoch 10 with validation loss 0.028863...
# Epoch 11, Train Loss: 0.029371, Validation Loss: 0.025283
# Saving model at epoch 11 with validation loss 0.025283...
# Epoch 12, Train Loss: 0.025872, Validation Loss: 0.021990
# Saving model at epoch 12 with validation loss 0.021990...
# Epoch 13, Train Loss: 0.022682, Validation Loss: 0.019412
# Saving model at epoch 13 with validation loss 0.019412...
# Epoch 14, Train Loss: 0.021024, Validation Loss: 0.017186
# Saving model at epoch 14 with validation loss 0.017186...
# Epoch 15, Train Loss: 0.017679, Validation Loss: 0.015224
# Saving model at epoch 15 with validation loss 0.015224...
# Epoch 16, Train Loss: 0.016013, Validation Loss: 0.013644
# Saving model at epoch 16 with validation loss 0.013644...
# Epoch 17, Train Loss: 0.014328, Validation Loss: 0.012227
# Saving model at epoch 17 with validation loss 0.012227...
# Epoch 18, Train Loss: 0.012701, Validation Loss: 0.011051
# Saving model at epoch 18 with validation loss 0.011051...
# Epoch 19, Train Loss: 0.011517, Validation Loss: 0.009998
# Saving model at epoch 19 with validation loss 0.009998...
# Epoch 20, Train Loss: 0.010315, Validation Loss: 0.009005
# Saving model at epoch 20 with validation loss 0.009005...
# Epoch 21, Train Loss: 0.009515, Validation Loss: 0.008277
# Saving model at epoch 21 with validation loss 0.008277...
# Epoch 22, Train Loss: 0.008806, Validation Loss: 0.007503
# Saving model at epoch 22 with validation loss 0.007503...
# Epoch 23, Train Loss: 0.007947, Validation Loss: 0.006915
# Saving model at epoch 23 with validation loss 0.006915...
# Epoch 24, Train Loss: 0.007295, Validation Loss: 0.006317
# Saving model at epoch 24 with validation loss 0.006317...
# Epoch 25, Train Loss: 0.006728, Validation Loss: 0.005817
# Saving model at epoch 25 with validation loss 0.005817...
# Epoch 26, Train Loss: 0.006282, Validation Loss: 0.005346
# Saving model at epoch 26 with validation loss 0.005346...
# Epoch 27, Train Loss: 0.005953, Validation Loss: 0.004983
# Saving model at epoch 27 with validation loss 0.004983...
# Epoch 28, Train Loss: 0.005357, Validation Loss: 0.004580
# Saving model at epoch 28 with validation loss 0.004580...
# Epoch 29, Train Loss: 0.005022, Validation Loss: 0.004208
# Saving model at epoch 29 with validation loss 0.004208...
# Epoch 30, Train Loss: 0.004691, Validation Loss: 0.003968
# Saving model at epoch 30 with validation loss 0.003968...
# Epoch 31, Train Loss: 0.004304, Validation Loss: 0.003727
# Saving model at epoch 31 with validation loss 0.003727...
# Epoch 32, Train Loss: 0.003939, Validation Loss: 0.003375
# Saving model at epoch 32 with validation loss 0.003375...
# Epoch 33, Train Loss: 0.003682, Validation Loss: 0.003154
# Saving model at epoch 33 with validation loss 0.003154...
# Epoch 34, Train Loss: 0.003449, Validation Loss: 0.002980
# Saving model at epoch 34 with validation loss 0.002980...
# Epoch 35, Train Loss: 0.003163, Validation Loss: 0.002750
# Saving model at epoch 35 with validation loss 0.002750...
# Epoch 36, Train Loss: 0.003016, Validation Loss: 0.002567
# Saving model at epoch 36 with validation loss 0.002567...
# Epoch 37, Train Loss: 0.002812, Validation Loss: 0.002397
# Saving model at epoch 37 with validation loss 0.002397...
# Epoch 38, Train Loss: 0.002667, Validation Loss: 0.002302
# Saving model at epoch 38 with validation loss 0.002302...
# Epoch 39, Train Loss: 0.002487, Validation Loss: 0.002114
# Saving model at epoch 39 with validation loss 0.002114...
# Epoch 40, Train Loss: 0.002319, Validation Loss: 0.001972
# Saving model at epoch 40 with validation loss 0.001972...
# Epoch 41, Train Loss: 0.002206, Validation Loss: 0.001933
# Saving model at epoch 41 with validation loss 0.001933...
# Epoch 42, Train Loss: 0.002156, Validation Loss: 0.001776
# Saving model at epoch 42 with validation loss 0.001776...
# Epoch 43, Train Loss: 0.002092, Validation Loss: 0.001669
# Saving model at epoch 43 with validation loss 0.001669...
# Epoch 44, Train Loss: 0.001848, Validation Loss: 0.001642
# Saving model at epoch 44 with validation loss 0.001642...
# Epoch 45, Train Loss: 0.001838, Validation Loss: 0.001552
# Saving model at epoch 45 with validation loss 0.001552...
# Epoch 46, Train Loss: 0.001771, Validation Loss: 0.001508
# Saving model at epoch 46 with validation loss 0.001508...
# Epoch 47, Train Loss: 0.001685, Validation Loss: 0.001400
# Saving model at epoch 47 with validation loss 0.001400...
# Epoch 48, Train Loss: 0.001621, Validation Loss: 0.001570
# Epoch 49, Train Loss: 0.001611, Validation Loss: 0.001343
# Saving model at epoch 49 with validation loss 0.001343...
# Epoch 50, Train Loss: 0.001515, Validation Loss: 0.001275
# Saving model at epoch 50 with validation loss 0.001275...
# Epoch 51, Train Loss: 0.001434, Validation Loss: 0.001245
# Saving model at epoch 51 with validation loss 0.001245...
# Epoch 52, Train Loss: 0.001427, Validation Loss: 0.001203
# Saving model at epoch 52 with validation loss 0.001203...
# Epoch 53, Train Loss: 0.001386, Validation Loss: 0.001192
# Saving model at epoch 53 with validation loss 0.001192...
# Epoch 54, Train Loss: 0.001369, Validation Loss: 0.001158
# Saving model at epoch 54 with validation loss 0.001158...
# Epoch 55, Train Loss: 0.001316, Validation Loss: 0.001128
# Saving model at epoch 55 with validation loss 0.001128...
# Epoch 56, Train Loss: 0.001268, Validation Loss: 0.001109
# Saving model at epoch 56 with validation loss 0.001109...
# Epoch 57, Train Loss: 0.001275, Validation Loss: 0.001098
# Saving model at epoch 57 with validation loss 0.001098...
# Epoch 58, Train Loss: 0.001249, Validation Loss: 0.001063
# Saving model at epoch 58 with validation loss 0.001063...
# Epoch 59, Train Loss: 0.001200, Validation Loss: 0.001043
# Saving model at epoch 59 with validation loss 0.001043...
# Epoch 60, Train Loss: 0.001172, Validation Loss: 0.001028
# Saving model at epoch 60 with validation loss 0.001028...
# Epoch 61, Train Loss: 0.001173, Validation Loss: 0.001075
# Epoch 62, Train Loss: 0.001252, Validation Loss: 0.001053
# Epoch 63, Train Loss: 0.001144, Validation Loss: 0.000996
# Saving model at epoch 63 with validation loss 0.000996...
# Epoch 64, Train Loss: 0.001124, Validation Loss: 0.000967
# Saving model at epoch 64 with validation loss 0.000967...
# Epoch 65, Train Loss: 0.001117, Validation Loss: 0.000956
# Saving model at epoch 65 with validation loss 0.000956...
# Epoch 66, Train Loss: 0.001096, Validation Loss: 0.000944
# Saving model at epoch 66 with validation loss 0.000944...
# Epoch 67, Train Loss: 0.001085, Validation Loss: 0.000929
# Saving model at epoch 67 with validation loss 0.000929...
# Epoch 68, Train Loss: 0.001086, Validation Loss: 0.000929
# Saving model at epoch 68 with validation loss 0.000929...
# Epoch 69, Train Loss: 0.001087, Validation Loss: 0.001002
# Epoch 70, Train Loss: 0.001083, Validation Loss: 0.000944
# Epoch 71, Train Loss: 0.001090, Validation Loss: 0.000884
# Saving model at epoch 71 with validation loss 0.000884...
# Epoch 72, Train Loss: 0.001068, Validation Loss: 0.000950
# Epoch 73, Train Loss: 0.001046, Validation Loss: 0.000876
# Saving model at epoch 73 with validation loss 0.000876...
# Epoch 74, Train Loss: 0.001016, Validation Loss: 0.000874
# Saving model at epoch 74 with validation loss 0.000874...
# Epoch 75, Train Loss: 0.000965, Validation Loss: 0.000850
# Saving model at epoch 75 with validation loss 0.000850...
# Epoch 76, Train Loss: 0.000971, Validation Loss: 0.000838
# Saving model at epoch 76 with validation loss 0.000838...
# Epoch 77, Train Loss: 0.000952, Validation Loss: 0.000835
# Saving model at epoch 77 with validation loss 0.000835...
# Epoch 78, Train Loss: 0.000972, Validation Loss: 0.000821
# Saving model at epoch 78 with validation loss 0.000821...
# Epoch 79, Train Loss: 0.000957, Validation Loss: 0.000819
# Saving model at epoch 79 with validation loss 0.000819...
# Epoch 80, Train Loss: 0.000928, Validation Loss: 0.000803
# Saving model at epoch 80 with validation loss 0.000803...
# Epoch 81, Train Loss: 0.000923, Validation Loss: 0.000803
# Epoch 82, Train Loss: 0.000916, Validation Loss: 0.000792
# Saving model at epoch 82 with validation loss 0.000792...
# Epoch 83, Train Loss: 0.000917, Validation Loss: 0.000802
# Epoch 84, Train Loss: 0.000887, Validation Loss: 0.000776
# Saving model at epoch 84 with validation loss 0.000776...
# Epoch 85, Train Loss: 0.000899, Validation Loss: 0.000842
# Epoch 86, Train Loss: 0.000919, Validation Loss: 0.000760
# Saving model at epoch 86 with validation loss 0.000760...
# Epoch 87, Train Loss: 0.000885, Validation Loss: 0.000817
# Epoch 88, Train Loss: 0.000871, Validation Loss: 0.000766
# Epoch 89, Train Loss: 0.000859, Validation Loss: 0.000735
# Saving model at epoch 89 with validation loss 0.000735...
# Epoch 90, Train Loss: 0.000871, Validation Loss: 0.000751
# Epoch 91, Train Loss: 0.000849, Validation Loss: 0.000720
# Saving model at epoch 91 with validation loss 0.000720...
# Epoch 92, Train Loss: 0.000828, Validation Loss: 0.000709
# Saving model at epoch 92 with validation loss 0.000709...
# Epoch 93, Train Loss: 0.000818, Validation Loss: 0.000717
# Epoch 94, Train Loss: 0.000804, Validation Loss: 0.000709
# Epoch 95, Train Loss: 0.000794, Validation Loss: 0.000710
# Epoch 96, Train Loss: 0.000792, Validation Loss: 0.000749
# Epoch 97, Train Loss: 0.000825, Validation Loss: 0.000683
# Saving model at epoch 97 with validation loss 0.000683...
# Epoch 98, Train Loss: 0.000776, Validation Loss: 0.000695
# Epoch 99, Train Loss: 0.000796, Validation Loss: 0.000713
# Epoch 100, Train Loss: 0.000816, Validation Loss: 0.000671
# Saving model at epoch 100 with validation loss 0.000671...
# Epoch 101, Train Loss: 0.000758, Validation Loss: 0.000694
# Epoch 102, Train Loss: 0.000752, Validation Loss: 0.000670
# Saving model at epoch 102 with validation loss 0.000670...
# Epoch 103, Train Loss: 0.000762, Validation Loss: 0.000673
# Epoch 104, Train Loss: 0.000754, Validation Loss: 0.000720
# Epoch 105, Train Loss: 0.000752, Validation Loss: 0.000667
# Saving model at epoch 105 with validation loss 0.000667...
# Epoch 106, Train Loss: 0.000749, Validation Loss: 0.000644
# Saving model at epoch 106 with validation loss 0.000644...
# Epoch 107, Train Loss: 0.000752, Validation Loss: 0.000638
# Saving model at epoch 107 with validation loss 0.000638...
# Epoch 108, Train Loss: 0.000746, Validation Loss: 0.000628
# Saving model at epoch 108 with validation loss 0.000628...
# Epoch 109, Train Loss: 0.000731, Validation Loss: 0.000631
# Epoch 110, Train Loss: 0.000710, Validation Loss: 0.000634
# Epoch 111, Train Loss: 0.000732, Validation Loss: 0.000649
# Epoch 112, Train Loss: 0.000731, Validation Loss: 0.000615
# Saving model at epoch 112 with validation loss 0.000615...
# Epoch 113, Train Loss: 0.000698, Validation Loss: 0.000612
# Saving model at epoch 113 with validation loss 0.000612...
# Epoch 114, Train Loss: 0.000684, Validation Loss: 0.000601
# Saving model at epoch 114 with validation loss 0.000601...
# Epoch 115, Train Loss: 0.000679, Validation Loss: 0.000596
# Saving model at epoch 115 with validation loss 0.000596...
# Epoch 116, Train Loss: 0.000683, Validation Loss: 0.000617
# Epoch 117, Train Loss: 0.000681, Validation Loss: 0.000659
# Epoch 118, Train Loss: 0.000688, Validation Loss: 0.000612
# Epoch 119, Train Loss: 0.000692, Validation Loss: 0.000613
# Epoch 120, Train Loss: 0.000683, Validation Loss: 0.000582
# Saving model at epoch 120 with validation loss 0.000582...
# Epoch 121, Train Loss: 0.000669, Validation Loss: 0.000587
# Epoch 122, Train Loss: 0.000654, Validation Loss: 0.000585
# Epoch 123, Train Loss: 0.000656, Validation Loss: 0.000570
# Saving model at epoch 123 with validation loss 0.000570...
# Epoch 124, Train Loss: 0.000643, Validation Loss: 0.000646
# Epoch 125, Train Loss: 0.000692, Validation Loss: 0.000562
# Saving model at epoch 125 with validation loss 0.000562...
# Epoch 126, Train Loss: 0.000653, Validation Loss: 0.000573
# Epoch 127, Train Loss: 0.000644, Validation Loss: 0.000600
# Epoch 128, Train Loss: 0.000630, Validation Loss: 0.000555
# Saving model at epoch 128 with validation loss 0.000555...
# Epoch 129, Train Loss: 0.000648, Validation Loss: 0.000556
# Epoch 130, Train Loss: 0.000628, Validation Loss: 0.000582
# Epoch 131, Train Loss: 0.000636, Validation Loss: 0.000576
# Epoch 132, Train Loss: 0.000618, Validation Loss: 0.000537
# Saving model at epoch 132 with validation loss 0.000537...
# Epoch 133, Train Loss: 0.000630, Validation Loss: 0.000620
# Epoch 134, Train Loss: 0.000659, Validation Loss: 0.000535
# Saving model at epoch 134 with validation loss 0.000535...
# Epoch 135, Train Loss: 0.000623, Validation Loss: 0.000568
# Epoch 136, Train Loss: 0.000630, Validation Loss: 0.000593
# Epoch 137, Train Loss: 0.000653, Validation Loss: 0.000574
# Epoch 138, Train Loss: 0.000684, Validation Loss: 0.000619
# Epoch 139, Train Loss: 0.000632, Validation Loss: 0.000534
# Saving model at epoch 139 with validation loss 0.000534...
# Epoch 140, Train Loss: 0.000615, Validation Loss: 0.000540
# Epoch 141, Train Loss: 0.000612, Validation Loss: 0.000522
# Saving model at epoch 141 with validation loss 0.000522...
# Epoch 142, Train Loss: 0.000608, Validation Loss: 0.000593
# Epoch 143, Train Loss: 0.000624, Validation Loss: 0.000562
# Epoch 144, Train Loss: 0.000583, Validation Loss: 0.000518
# Saving model at epoch 144 with validation loss 0.000518...
# Epoch 145, Train Loss: 0.000593, Validation Loss: 0.000517
# Saving model at epoch 145 with validation loss 0.000517...
# Epoch 146, Train Loss: 0.000566, Validation Loss: 0.000505
# Saving model at epoch 146 with validation loss 0.000505...
# Epoch 147, Train Loss: 0.000563, Validation Loss: 0.000500
# Saving model at epoch 147 with validation loss 0.000500...
# Epoch 148, Train Loss: 0.000554, Validation Loss: 0.000514
# Epoch 149, Train Loss: 0.000566, Validation Loss: 0.000514
# Epoch 150, Train Loss: 0.000577, Validation Loss: 0.000526
# Epoch 151, Train Loss: 0.000566, Validation Loss: 0.000496
# Saving model at epoch 151 with validation loss 0.000496...
# Epoch 152, Train Loss: 0.000557, Validation Loss: 0.000498
# Epoch 153, Train Loss: 0.000554, Validation Loss: 0.000489
# Saving model at epoch 153 with validation loss 0.000489...
# Epoch 154, Train Loss: 0.000550, Validation Loss: 0.000525
# Epoch 155, Train Loss: 0.000557, Validation Loss: 0.000493
# Epoch 156, Train Loss: 0.000535, Validation Loss: 0.000483
# Saving model at epoch 156 with validation loss 0.000483...
# Epoch 157, Train Loss: 0.000535, Validation Loss: 0.000528
# Epoch 158, Train Loss: 0.000563, Validation Loss: 0.000490
# Epoch 159, Train Loss: 0.000533, Validation Loss: 0.000475
# Saving model at epoch 159 with validation loss 0.000475...
# Epoch 160, Train Loss: 0.000533, Validation Loss: 0.000488
# Epoch 161, Train Loss: 0.000540, Validation Loss: 0.000495
# Epoch 162, Train Loss: 0.000551, Validation Loss: 0.000554
# Epoch 163, Train Loss: 0.000574, Validation Loss: 0.000481
# Epoch 164, Train Loss: 0.000545, Validation Loss: 0.000493
# Epoch 165, Train Loss: 0.000550, Validation Loss: 0.000646
# Epoch 166, Train Loss: 0.000596, Validation Loss: 0.000475
# Epoch 167, Train Loss: 0.000535, Validation Loss: 0.000548
# Epoch 168, Train Loss: 0.000535, Validation Loss: 0.000457
# Saving model at epoch 168 with validation loss 0.000457...
# Epoch 169, Train Loss: 0.000524, Validation Loss: 0.000497
# Epoch 170, Train Loss: 0.000542, Validation Loss: 0.000457
# Epoch 171, Train Loss: 0.000512, Validation Loss: 0.000487
# Epoch 172, Train Loss: 0.000518, Validation Loss: 0.000461
# Epoch 173, Train Loss: 0.000512, Validation Loss: 0.000470
# Epoch 174, Train Loss: 0.000515, Validation Loss: 0.000462
# Epoch 175, Train Loss: 0.000505, Validation Loss: 0.000449
# Saving model at epoch 175 with validation loss 0.000449...
# Epoch 176, Train Loss: 0.000509, Validation Loss: 0.000487
# Epoch 177, Train Loss: 0.000502, Validation Loss: 0.000464
# Epoch 178, Train Loss: 0.000502, Validation Loss: 0.000466
# Epoch 179, Train Loss: 0.000514, Validation Loss: 0.000535
# Epoch 180, Train Loss: 0.000533, Validation Loss: 0.000447
# Saving model at epoch 180 with validation loss 0.000447...
# Epoch 181, Train Loss: 0.000496, Validation Loss: 0.000455
# Epoch 182, Train Loss: 0.000502, Validation Loss: 0.000478
# Epoch 183, Train Loss: 0.000498, Validation Loss: 0.000467
# Epoch 184, Train Loss: 0.000508, Validation Loss: 0.000563
# Epoch 185, Train Loss: 0.000538, Validation Loss: 0.000550
# Epoch 186, Train Loss: 0.000569, Validation Loss: 0.000524
# Epoch 187, Train Loss: 0.000511, Validation Loss: 0.000434
# Saving model at epoch 187 with validation loss 0.000434...
# Epoch 188, Train Loss: 0.000477, Validation Loss: 0.000439
# Epoch 189, Train Loss: 0.000475, Validation Loss: 0.000448
# Epoch 190, Train Loss: 0.000486, Validation Loss: 0.000526
# Epoch 191, Train Loss: 0.000510, Validation Loss: 0.000451
# Epoch 192, Train Loss: 0.000479, Validation Loss: 0.000430
# Saving model at epoch 192 with validation loss 0.000430...
# Epoch 193, Train Loss: 0.000462, Validation Loss: 0.000425
# Saving model at epoch 193 with validation loss 0.000425...
# Epoch 194, Train Loss: 0.000464, Validation Loss: 0.000428
# Epoch 195, Train Loss: 0.000456, Validation Loss: 0.000485
# Epoch 196, Train Loss: 0.000481, Validation Loss: 0.000451
# Epoch 197, Train Loss: 0.000469, Validation Loss: 0.000481
# Epoch 198, Train Loss: 0.000475, Validation Loss: 0.000460
# Epoch 199, Train Loss: 0.000477, Validation Loss: 0.000431
# Epoch 200, Train Loss: 0.000467, Validation Loss: 0.000429
# Epoch 201, Train Loss: 0.000458, Validation Loss: 0.000413
# Saving model at epoch 201 with validation loss 0.000413...
# Epoch 202, Train Loss: 0.000455, Validation Loss: 0.000418
# Epoch 203, Train Loss: 0.000450, Validation Loss: 0.000411
# Saving model at epoch 203 with validation loss 0.000411...
# Epoch 204, Train Loss: 0.000457, Validation Loss: 0.000412
# Epoch 205, Train Loss: 0.000452, Validation Loss: 0.000408
# Saving model at epoch 205 with validation loss 0.000408...
# Epoch 206, Train Loss: 0.000442, Validation Loss: 0.000408
# Saving model at epoch 206 with validation loss 0.000408...
# Epoch 207, Train Loss: 0.000454, Validation Loss: 0.000405
# Saving model at epoch 207 with validation loss 0.000405...
# Epoch 208, Train Loss: 0.000453, Validation Loss: 0.000413
# Epoch 209, Train Loss: 0.000456, Validation Loss: 0.000431
# Epoch 210, Train Loss: 0.000445, Validation Loss: 0.000416
# Epoch 211, Train Loss: 0.000446, Validation Loss: 0.000474
# Epoch 212, Train Loss: 0.000481, Validation Loss: 0.000407
# Epoch 213, Train Loss: 0.000448, Validation Loss: 0.000447
# Epoch 214, Train Loss: 0.000460, Validation Loss: 0.000395
# Saving model at epoch 214 with validation loss 0.000395...
# Epoch 215, Train Loss: 0.000453, Validation Loss: 0.000403
# Epoch 216, Train Loss: 0.000429, Validation Loss: 0.000394
# Saving model at epoch 216 with validation loss 0.000394...
# Epoch 217, Train Loss: 0.000437, Validation Loss: 0.000396
# Epoch 218, Train Loss: 0.000442, Validation Loss: 0.000406
# Epoch 219, Train Loss: 0.000453, Validation Loss: 0.000397
# Epoch 220, Train Loss: 0.000445, Validation Loss: 0.000416
# Epoch 221, Train Loss: 0.000428, Validation Loss: 0.000399
# Epoch 222, Train Loss: 0.000438, Validation Loss: 0.000456
# Epoch 223, Train Loss: 0.000430, Validation Loss: 0.000423
# Epoch 224, Train Loss: 0.000453, Validation Loss: 0.000402
# Epoch 225, Train Loss: 0.000420, Validation Loss: 0.000411
# Epoch 226, Train Loss: 0.000420, Validation Loss: 0.000385
# Saving model at epoch 226 with validation loss 0.000385...
# Epoch 227, Train Loss: 0.000421, Validation Loss: 0.000396
# Epoch 228, Train Loss: 0.000415, Validation Loss: 0.000393
# Epoch 229, Train Loss: 0.000425, Validation Loss: 0.000386
# Epoch 230, Train Loss: 0.000444, Validation Loss: 0.000474
# Epoch 231, Train Loss: 0.000435, Validation Loss: 0.000418
# Epoch 232, Train Loss: 0.000412, Validation Loss: 0.000377
# Saving model at epoch 232 with validation loss 0.000377...
# Epoch 233, Train Loss: 0.000411, Validation Loss: 0.000394
# Epoch 234, Train Loss: 0.000415, Validation Loss: 0.000396
# Epoch 235, Train Loss: 0.000424, Validation Loss: 0.000376
# Saving model at epoch 235 with validation loss 0.000376...
# Epoch 236, Train Loss: 0.000408, Validation Loss: 0.000429
# Epoch 237, Train Loss: 0.000414, Validation Loss: 0.000377
# Epoch 238, Train Loss: 0.000420, Validation Loss: 0.000392
# Epoch 239, Train Loss: 0.000402, Validation Loss: 0.000374
# Saving model at epoch 239 with validation loss 0.000374...
# Epoch 240, Train Loss: 0.000394, Validation Loss: 0.000381
# Epoch 241, Train Loss: 0.000398, Validation Loss: 0.000373
# Saving model at epoch 241 with validation loss 0.000373...
# Epoch 242, Train Loss: 0.000407, Validation Loss: 0.000401
# Epoch 243, Train Loss: 0.000422, Validation Loss: 0.000365
# Saving model at epoch 243 with validation loss 0.000365...
# Epoch 244, Train Loss: 0.000417, Validation Loss: 0.000449
# Epoch 245, Train Loss: 0.000465, Validation Loss: 0.000436
# Epoch 246, Train Loss: 0.000444, Validation Loss: 0.000370
# Epoch 247, Train Loss: 0.000431, Validation Loss: 0.000372
# Epoch 248, Train Loss: 0.000394, Validation Loss: 0.000365
# Saving model at epoch 248 with validation loss 0.000365...
# Epoch 249, Train Loss: 0.000394, Validation Loss: 0.000369
# Epoch 250, Train Loss: 0.000395, Validation Loss: 0.000435
# Epoch 251, Train Loss: 0.000438, Validation Loss: 0.000424
# Epoch 252, Train Loss: 0.000431, Validation Loss: 0.000400
# Epoch 253, Train Loss: 0.000414, Validation Loss: 0.000390
# Epoch 254, Train Loss: 0.000406, Validation Loss: 0.000410
# Epoch 255, Train Loss: 0.000397, Validation Loss: 0.000364
# Saving model at epoch 255 with validation loss 0.000364...
# Epoch 256, Train Loss: 0.000398, Validation Loss: 0.000378
# Epoch 257, Train Loss: 0.000405, Validation Loss: 0.000366
# Epoch 258, Train Loss: 0.000387, Validation Loss: 0.000381
# Epoch 259, Train Loss: 0.000406, Validation Loss: 0.000353
# Saving model at epoch 259 with validation loss 0.000353...
# Epoch 260, Train Loss: 0.000381, Validation Loss: 0.000361
# Epoch 261, Train Loss: 0.000381, Validation Loss: 0.000356
# Epoch 262, Train Loss: 0.000378, Validation Loss: 0.000366
# Epoch 263, Train Loss: 0.000371, Validation Loss: 0.000355
# Epoch 264, Train Loss: 0.000380, Validation Loss: 0.000365
# Epoch 265, Train Loss: 0.000380, Validation Loss: 0.000350
# Saving model at epoch 265 with validation loss 0.000350...
# Epoch 266, Train Loss: 0.000383, Validation Loss: 0.000384
# Epoch 267, Train Loss: 0.000389, Validation Loss: 0.000366
# Epoch 268, Train Loss: 0.000395, Validation Loss: 0.000424
# Epoch 269, Train Loss: 0.000381, Validation Loss: 0.000345
# Saving model at epoch 269 with validation loss 0.000345...
# Epoch 270, Train Loss: 0.000377, Validation Loss: 0.000394
# Epoch 271, Train Loss: 0.000397, Validation Loss: 0.000376
# Epoch 272, Train Loss: 0.000384, Validation Loss: 0.000394
# Epoch 273, Train Loss: 0.000381, Validation Loss: 0.000346
# Epoch 274, Train Loss: 0.000361, Validation Loss: 0.000342
# Saving model at epoch 274 with validation loss 0.000342...
# Epoch 275, Train Loss: 0.000364, Validation Loss: 0.000350
# Epoch 276, Train Loss: 0.000364, Validation Loss: 0.000339
# Saving model at epoch 276 with validation loss 0.000339...
# Epoch 277, Train Loss: 0.000371, Validation Loss: 0.000346
# Epoch 278, Train Loss: 0.000370, Validation Loss: 0.000342
# Epoch 279, Train Loss: 0.000366, Validation Loss: 0.000340
# Epoch 280, Train Loss: 0.000375, Validation Loss: 0.000343
# Epoch 281, Train Loss: 0.000395, Validation Loss: 0.000351
# Epoch 282, Train Loss: 0.000367, Validation Loss: 0.000339
# Saving model at epoch 282 with validation loss 0.000339...
# Epoch 283, Train Loss: 0.000362, Validation Loss: 0.000345
# Epoch 284, Train Loss: 0.000362, Validation Loss: 0.000340
# Epoch 285, Train Loss: 0.000357, Validation Loss: 0.000341
# Epoch 286, Train Loss: 0.000364, Validation Loss: 0.000409
# Epoch 287, Train Loss: 0.000376, Validation Loss: 0.000341
# Epoch 288, Train Loss: 0.000359, Validation Loss: 0.000332
# Saving model at epoch 288 with validation loss 0.000332...
# Epoch 289, Train Loss: 0.000355, Validation Loss: 0.000335
# Epoch 290, Train Loss: 0.000356, Validation Loss: 0.000342
# Epoch 291, Train Loss: 0.000366, Validation Loss: 0.000329
# Saving model at epoch 291 with validation loss 0.000329...
# Epoch 292, Train Loss: 0.000352, Validation Loss: 0.000328
# Saving model at epoch 292 with validation loss 0.000328...
# Epoch 293, Train Loss: 0.000358, Validation Loss: 0.000356
# Epoch 294, Train Loss: 0.000355, Validation Loss: 0.000329
# Epoch 295, Train Loss: 0.000352, Validation Loss: 0.000337
# Epoch 296, Train Loss: 0.000364, Validation Loss: 0.000374
# Epoch 297, Train Loss: 0.000376, Validation Loss: 0.000435
# Epoch 298, Train Loss: 0.000425, Validation Loss: 0.000370
# Epoch 299, Train Loss: 0.000397, Validation Loss: 0.000327
# Saving model at epoch 299 with validation loss 0.000327...
# Epoch 300, Train Loss: 0.000375, Validation Loss: 0.000348
# Epoch 301, Train Loss: 0.000378, Validation Loss: 0.000352
# Epoch 302, Train Loss: 0.000360, Validation Loss: 0.000330
# Epoch 303, Train Loss: 0.000343, Validation Loss: 0.000328
# Epoch 304, Train Loss: 0.000347, Validation Loss: 0.000328
# Epoch 305, Train Loss: 0.000345, Validation Loss: 0.000320
# Saving model at epoch 305 with validation loss 0.000320...
# Epoch 306, Train Loss: 0.000344, Validation Loss: 0.000328
# Epoch 307, Train Loss: 0.000346, Validation Loss: 0.000325
# Epoch 308, Train Loss: 0.000346, Validation Loss: 0.000330
# Epoch 309, Train Loss: 0.000352, Validation Loss: 0.000349
# Epoch 310, Train Loss: 0.000346, Validation Loss: 0.000326
# Epoch 311, Train Loss: 0.000342, Validation Loss: 0.000329
# Epoch 312, Train Loss: 0.000348, Validation Loss: 0.000339
# Epoch 313, Train Loss: 0.000370, Validation Loss: 0.000343
# Epoch 314, Train Loss: 0.000354, Validation Loss: 0.000326
# Epoch 315, Train Loss: 0.000362, Validation Loss: 0.000399
# Epoch 316, Train Loss: 0.000351, Validation Loss: 0.000327
# Epoch 317, Train Loss: 0.000337, Validation Loss: 0.000312
# Saving model at epoch 317 with validation loss 0.000312...
# Epoch 318, Train Loss: 0.000335, Validation Loss: 0.000321
# Epoch 319, Train Loss: 0.000331, Validation Loss: 0.000309
# Saving model at epoch 319 with validation loss 0.000309...
# Epoch 320, Train Loss: 0.000339, Validation Loss: 0.000332
# Epoch 321, Train Loss: 0.000343, Validation Loss: 0.000310
# Epoch 322, Train Loss: 0.000331, Validation Loss: 0.000311
# Epoch 323, Train Loss: 0.000343, Validation Loss: 0.000362
# Epoch 324, Train Loss: 0.000371, Validation Loss: 0.000318
# Epoch 325, Train Loss: 0.000351, Validation Loss: 0.000344
# Epoch 326, Train Loss: 0.000346, Validation Loss: 0.000321
# Epoch 327, Train Loss: 0.000334, Validation Loss: 0.000311
# Epoch 328, Train Loss: 0.000346, Validation Loss: 0.000414
# Epoch 329, Train Loss: 0.000368, Validation Loss: 0.000326
# Epoch 330, Train Loss: 0.000334, Validation Loss: 0.000379
# Epoch 331, Train Loss: 0.000350, Validation Loss: 0.000328
# Epoch 332, Train Loss: 0.000356, Validation Loss: 0.000393
# Epoch 333, Train Loss: 0.000342, Validation Loss: 0.000304
# Saving model at epoch 333 with validation loss 0.000304...
# Epoch 334, Train Loss: 0.000318, Validation Loss: 0.000301
# Saving model at epoch 334 with validation loss 0.000301...
# Epoch 335, Train Loss: 0.000326, Validation Loss: 0.000304
# Epoch 336, Train Loss: 0.000326, Validation Loss: 0.000342
# Epoch 337, Train Loss: 0.000346, Validation Loss: 0.000318
# Epoch 338, Train Loss: 0.000327, Validation Loss: 0.000306
# Epoch 339, Train Loss: 0.000322, Validation Loss: 0.000302
# Epoch 340, Train Loss: 0.000329, Validation Loss: 0.000316
# Epoch 341, Train Loss: 0.000325, Validation Loss: 0.000302
# Epoch 342, Train Loss: 0.000318, Validation Loss: 0.000333
# Epoch 343, Train Loss: 0.000349, Validation Loss: 0.000403
# Epoch 344, Train Loss: 0.000369, Validation Loss: 0.000320
# Epoch 345, Train Loss: 0.000342, Validation Loss: 0.000319
# Epoch 346, Train Loss: 0.000333, Validation Loss: 0.000296
# Saving model at epoch 346 with validation loss 0.000296...
# Epoch 347, Train Loss: 0.000333, Validation Loss: 0.000313
# Epoch 348, Train Loss: 0.000319, Validation Loss: 0.000297
# Epoch 349, Train Loss: 0.000325, Validation Loss: 0.000301
# Epoch 350, Train Loss: 0.000320, Validation Loss: 0.000297
# Epoch 351, Train Loss: 0.000329, Validation Loss: 0.000426
# Epoch 352, Train Loss: 0.000355, Validation Loss: 0.000300
# Epoch 353, Train Loss: 0.000324, Validation Loss: 0.000316
# Epoch 354, Train Loss: 0.000333, Validation Loss: 0.000329
# Epoch 355, Train Loss: 0.000335, Validation Loss: 0.000332
# Epoch 356, Train Loss: 0.000331, Validation Loss: 0.000306
# Epoch 357, Train Loss: 0.000314, Validation Loss: 0.000332
# Epoch 358, Train Loss: 0.000342, Validation Loss: 0.000356
# Epoch 359, Train Loss: 0.000343, Validation Loss: 0.000296
# Epoch 360, Train Loss: 0.000310, Validation Loss: 0.000297
# Epoch 361, Train Loss: 0.000314, Validation Loss: 0.000296
# Epoch 362, Train Loss: 0.000327, Validation Loss: 0.000305
# Epoch 363, Train Loss: 0.000315, Validation Loss: 0.000315
# Epoch 364, Train Loss: 0.000320, Validation Loss: 0.000290
# Saving model at epoch 364 with validation loss 0.000290...
# Epoch 365, Train Loss: 0.000315, Validation Loss: 0.000294
# Epoch 366, Train Loss: 0.000319, Validation Loss: 0.000318
# Epoch 367, Train Loss: 0.000340, Validation Loss: 0.000345
# Epoch 368, Train Loss: 0.000317, Validation Loss: 0.000289
# Saving model at epoch 368 with validation loss 0.000289...
# Epoch 369, Train Loss: 0.000301, Validation Loss: 0.000316
# Epoch 370, Train Loss: 0.000305, Validation Loss: 0.000303
# Epoch 371, Train Loss: 0.000297, Validation Loss: 0.000284
# Saving model at epoch 371 with validation loss 0.000284...
# Epoch 372, Train Loss: 0.000295, Validation Loss: 0.000290
# Epoch 373, Train Loss: 0.000296, Validation Loss: 0.000286
# Epoch 374, Train Loss: 0.000301, Validation Loss: 0.000289
# Epoch 375, Train Loss: 0.000302, Validation Loss: 0.000284
# Saving model at epoch 375 with validation loss 0.000284...
# Epoch 376, Train Loss: 0.000319, Validation Loss: 0.000290
# Epoch 377, Train Loss: 0.000297, Validation Loss: 0.000293
# Epoch 378, Train Loss: 0.000303, Validation Loss: 0.000308
# Epoch 379, Train Loss: 0.000312, Validation Loss: 0.000293
# Epoch 380, Train Loss: 0.000307, Validation Loss: 0.000290
# Epoch 381, Train Loss: 0.000302, Validation Loss: 0.000286
# Epoch 382, Train Loss: 0.000294, Validation Loss: 0.000282
# Saving model at epoch 382 with validation loss 0.000282...
# Epoch 383, Train Loss: 0.000305, Validation Loss: 0.000285
# Epoch 384, Train Loss: 0.000315, Validation Loss: 0.000281
# Saving model at epoch 384 with validation loss 0.000281...
# Epoch 385, Train Loss: 0.000306, Validation Loss: 0.000311
# Epoch 386, Train Loss: 0.000300, Validation Loss: 0.000286
# Epoch 387, Train Loss: 0.000293, Validation Loss: 0.000300
# Epoch 388, Train Loss: 0.000294, Validation Loss: 0.000278
# Saving model at epoch 388 with validation loss 0.000278...
# Epoch 389, Train Loss: 0.000292, Validation Loss: 0.000280
# Epoch 390, Train Loss: 0.000296, Validation Loss: 0.000301
# Epoch 391, Train Loss: 0.000291, Validation Loss: 0.000277
# Saving model at epoch 391 with validation loss 0.000277...
# Epoch 392, Train Loss: 0.000310, Validation Loss: 0.000286
# Epoch 393, Train Loss: 0.000299, Validation Loss: 0.000298
# Epoch 394, Train Loss: 0.000307, Validation Loss: 0.000281
# Epoch 395, Train Loss: 0.000309, Validation Loss: 0.000287
# Epoch 396, Train Loss: 0.000318, Validation Loss: 0.000290
# Epoch 397, Train Loss: 0.000311, Validation Loss: 0.000398
# Epoch 398, Train Loss: 0.000349, Validation Loss: 0.000425
# Epoch 399, Train Loss: 0.000320, Validation Loss: 0.000281
# Epoch 400, Train Loss: 0.000292, Validation Loss: 0.000280
# Epoch 401, Train Loss: 0.000330, Validation Loss: 0.000311
# Epoch 402, Train Loss: 0.000325, Validation Loss: 0.000353
# Epoch 403, Train Loss: 0.000303, Validation Loss: 0.000285
# Epoch 404, Train Loss: 0.000300, Validation Loss: 0.000274
# Saving model at epoch 404 with validation loss 0.000274...
# Epoch 405, Train Loss: 0.000285, Validation Loss: 0.000275
# Epoch 406, Train Loss: 0.000289, Validation Loss: 0.000273
# Saving model at epoch 406 with validation loss 0.000273...
# Epoch 407, Train Loss: 0.000282, Validation Loss: 0.000273
# Epoch 408, Train Loss: 0.000286, Validation Loss: 0.000276
# Epoch 409, Train Loss: 0.000279, Validation Loss: 0.000276
# Epoch 410, Train Loss: 0.000285, Validation Loss: 0.000284
# Epoch 411, Train Loss: 0.000290, Validation Loss: 0.000280
# Epoch 412, Train Loss: 0.000286, Validation Loss: 0.000319
# Epoch 413, Train Loss: 0.000290, Validation Loss: 0.000278
# Epoch 414, Train Loss: 0.000290, Validation Loss: 0.000276
# Epoch 415, Train Loss: 0.000301, Validation Loss: 0.000292
# Epoch 416, Train Loss: 0.000294, Validation Loss: 0.000272
# Saving model at epoch 416 with validation loss 0.000272...
# Epoch 417, Train Loss: 0.000303, Validation Loss: 0.000298
# Epoch 418, Train Loss: 0.000300, Validation Loss: 0.000329
# Epoch 419, Train Loss: 0.000314, Validation Loss: 0.000364
# Epoch 420, Train Loss: 0.000304, Validation Loss: 0.000305
# Epoch 421, Train Loss: 0.000296, Validation Loss: 0.000273
# Epoch 422, Train Loss: 0.000281, Validation Loss: 0.000274
# Epoch 423, Train Loss: 0.000284, Validation Loss: 0.000273
# Epoch 424, Train Loss: 0.000279, Validation Loss: 0.000266
# Saving model at epoch 424 with validation loss 0.000266...
# Epoch 425, Train Loss: 0.000291, Validation Loss: 0.000271
# Epoch 426, Train Loss: 0.000289, Validation Loss: 0.000292
# Epoch 427, Train Loss: 0.000288, Validation Loss: 0.000321
# Epoch 428, Train Loss: 0.000311, Validation Loss: 0.000365
# Epoch 429, Train Loss: 0.000324, Validation Loss: 0.000317
# Epoch 430, Train Loss: 0.000304, Validation Loss: 0.000336
# Epoch 431, Train Loss: 0.000304, Validation Loss: 0.000290
# Epoch 432, Train Loss: 0.000281, Validation Loss: 0.000266
# Epoch 433, Train Loss: 0.000278, Validation Loss: 0.000264
# Saving model at epoch 433 with validation loss 0.000264...
# Epoch 434, Train Loss: 0.000272, Validation Loss: 0.000268
# Epoch 435, Train Loss: 0.000278, Validation Loss: 0.000291
# Epoch 436, Train Loss: 0.000287, Validation Loss: 0.000266
# Epoch 437, Train Loss: 0.000279, Validation Loss: 0.000271
# Epoch 438, Train Loss: 0.000280, Validation Loss: 0.000280
# Epoch 439, Train Loss: 0.000278, Validation Loss: 0.000277
# Epoch 440, Train Loss: 0.000280, Validation Loss: 0.000276
# Epoch 441, Train Loss: 0.000288, Validation Loss: 0.000268
# Epoch 442, Train Loss: 0.000290, Validation Loss: 0.000288
# Epoch 443, Train Loss: 0.000287, Validation Loss: 0.000268
# Epoch 444, Train Loss: 0.000293, Validation Loss: 0.000298
# Epoch 445, Train Loss: 0.000288, Validation Loss: 0.000287
# Epoch 446, Train Loss: 0.000278, Validation Loss: 0.000292
# Epoch 447, Train Loss: 0.000283, Validation Loss: 0.000267
# Epoch 448, Train Loss: 0.000284, Validation Loss: 0.000285
# Epoch 449, Train Loss: 0.000277, Validation Loss: 0.000264
# Saving model at epoch 449 with validation loss 0.000264...
# Epoch 450, Train Loss: 0.000282, Validation Loss: 0.000274
# Epoch 451, Train Loss: 0.000276, Validation Loss: 0.000283
# Epoch 452, Train Loss: 0.000272, Validation Loss: 0.000259
# Saving model at epoch 452 with validation loss 0.000259...
# Epoch 453, Train Loss: 0.000269, Validation Loss: 0.000258
# Saving model at epoch 453 with validation loss 0.000258...
# Epoch 454, Train Loss: 0.000271, Validation Loss: 0.000272
# Epoch 455, Train Loss: 0.000270, Validation Loss: 0.000273
# Epoch 456, Train Loss: 0.000280, Validation Loss: 0.000260
# Epoch 457, Train Loss: 0.000299, Validation Loss: 0.000370
# Epoch 458, Train Loss: 0.000310, Validation Loss: 0.000268
# Epoch 459, Train Loss: 0.000319, Validation Loss: 0.000320
# Epoch 460, Train Loss: 0.000313, Validation Loss: 0.000273
# Epoch 461, Train Loss: 0.000276, Validation Loss: 0.000262
# Epoch 462, Train Loss: 0.000285, Validation Loss: 0.000304
# Epoch 463, Train Loss: 0.000280, Validation Loss: 0.000283
# Epoch 464, Train Loss: 0.000270, Validation Loss: 0.000265
# Epoch 465, Train Loss: 0.000264, Validation Loss: 0.000275
# Epoch 466, Train Loss: 0.000279, Validation Loss: 0.000323
# Epoch 467, Train Loss: 0.000293, Validation Loss: 0.000282
# Epoch 468, Train Loss: 0.000278, Validation Loss: 0.000261
# Epoch 469, Train Loss: 0.000272, Validation Loss: 0.000261
# Epoch 470, Train Loss: 0.000265, Validation Loss: 0.000256
# Saving model at epoch 470 with validation loss 0.000256...
# Epoch 471, Train Loss: 0.000277, Validation Loss: 0.000285
# Epoch 472, Train Loss: 0.000285, Validation Loss: 0.000296
# Epoch 473, Train Loss: 0.000280, Validation Loss: 0.000257
# Epoch 474, Train Loss: 0.000267, Validation Loss: 0.000256
# Epoch 475, Train Loss: 0.000276, Validation Loss: 0.000284
# Epoch 476, Train Loss: 0.000270, Validation Loss: 0.000300
# Epoch 477, Train Loss: 0.000276, Validation Loss: 0.000270
# Epoch 478, Train Loss: 0.000278, Validation Loss: 0.000261
# Epoch 479, Train Loss: 0.000271, Validation Loss: 0.000254
# Saving model at epoch 479 with validation loss 0.000254...
# Epoch 480, Train Loss: 0.000259, Validation Loss: 0.000255
# Epoch 481, Train Loss: 0.000269, Validation Loss: 0.000264
# Epoch 482, Train Loss: 0.000275, Validation Loss: 0.000266
# Epoch 483, Train Loss: 0.000269, Validation Loss: 0.000253
# Saving model at epoch 483 with validation loss 0.000253...
# Epoch 484, Train Loss: 0.000266, Validation Loss: 0.000255
# Epoch 485, Train Loss: 0.000265, Validation Loss: 0.000257
# Epoch 486, Train Loss: 0.000264, Validation Loss: 0.000257
# Epoch 487, Train Loss: 0.000263, Validation Loss: 0.000253
# Saving model at epoch 487 with validation loss 0.000253...
# Epoch 488, Train Loss: 0.000263, Validation Loss: 0.000251
# Saving model at epoch 488 with validation loss 0.000251...
# Epoch 489, Train Loss: 0.000265, Validation Loss: 0.000278
# Epoch 490, Train Loss: 0.000278, Validation Loss: 0.000315
# Epoch 491, Train Loss: 0.000314, Validation Loss: 0.000261
# Epoch 492, Train Loss: 0.000267, Validation Loss: 0.000267
# Epoch 493, Train Loss: 0.000267, Validation Loss: 0.000254
# Epoch 494, Train Loss: 0.000277, Validation Loss: 0.000295
# Epoch 495, Train Loss: 0.000313, Validation Loss: 0.000379
# Epoch 496, Train Loss: 0.000281, Validation Loss: 0.000256
# Epoch 497, Train Loss: 0.000264, Validation Loss: 0.000252
# Epoch 498, Train Loss: 0.000258, Validation Loss: 0.000258
# Epoch 499, Train Loss: 0.000261, Validation Loss: 0.000258
# Epoch 500, Train Loss: 0.000265, Validation Loss: 0.000256
# Epoch 501, Train Loss: 0.000254, Validation Loss: 0.000261
# Epoch 502, Train Loss: 0.000271, Validation Loss: 0.000311
# Epoch 503, Train Loss: 0.000284, Validation Loss: 0.000252
# Epoch 504, Train Loss: 0.000270, Validation Loss: 0.000282
# Epoch 505, Train Loss: 0.000270, Validation Loss: 0.000260
# Epoch 506, Train Loss: 0.000269, Validation Loss: 0.000252
# Epoch 507, Train Loss: 0.000263, Validation Loss: 0.000254
# Epoch 508, Train Loss: 0.000265, Validation Loss: 0.000264
# Epoch 509, Train Loss: 0.000261, Validation Loss: 0.000251
# Epoch 510, Train Loss: 0.000254, Validation Loss: 0.000250
# Saving model at epoch 510 with validation loss 0.000250...
# Epoch 511, Train Loss: 0.000260, Validation Loss: 0.000249
# Saving model at epoch 511 with validation loss 0.000249...
# Epoch 512, Train Loss: 0.000262, Validation Loss: 0.000263
# Epoch 513, Train Loss: 0.000259, Validation Loss: 0.000247
# Saving model at epoch 513 with validation loss 0.000247...
# Epoch 514, Train Loss: 0.000261, Validation Loss: 0.000255
# Epoch 515, Train Loss: 0.000283, Validation Loss: 0.000259
# Epoch 516, Train Loss: 0.000271, Validation Loss: 0.000252
# Epoch 517, Train Loss: 0.000257, Validation Loss: 0.000254
# Epoch 518, Train Loss: 0.000264, Validation Loss: 0.000270
# Epoch 519, Train Loss: 0.000267, Validation Loss: 0.000272
# Epoch 520, Train Loss: 0.000276, Validation Loss: 0.000299
# Epoch 521, Train Loss: 0.000270, Validation Loss: 0.000247
# Saving model at epoch 521 with validation loss 0.000247...
# Epoch 522, Train Loss: 0.000259, Validation Loss: 0.000262
# Epoch 523, Train Loss: 0.000270, Validation Loss: 0.000288
# Epoch 524, Train Loss: 0.000271, Validation Loss: 0.000256
# Epoch 525, Train Loss: 0.000268, Validation Loss: 0.000252
# Epoch 526, Train Loss: 0.000258, Validation Loss: 0.000252
# Epoch 527, Train Loss: 0.000254, Validation Loss: 0.000245
# Saving model at epoch 527 with validation loss 0.000245...
# Epoch 528, Train Loss: 0.000253, Validation Loss: 0.000282
# Epoch 529, Train Loss: 0.000262, Validation Loss: 0.000260
# Epoch 530, Train Loss: 0.000266, Validation Loss: 0.000247
# Epoch 531, Train Loss: 0.000252, Validation Loss: 0.000251
# Epoch 532, Train Loss: 0.000267, Validation Loss: 0.000330
# Epoch 533, Train Loss: 0.000303, Validation Loss: 0.000296
# Epoch 534, Train Loss: 0.000294, Validation Loss: 0.000247
# Epoch 535, Train Loss: 0.000286, Validation Loss: 0.000283
# Epoch 536, Train Loss: 0.000282, Validation Loss: 0.000307
# Epoch 537, Train Loss: 0.000299, Validation Loss: 0.000250
# Epoch 538, Train Loss: 0.000254, Validation Loss: 0.000249
# Epoch 539, Train Loss: 0.000254, Validation Loss: 0.000279
# Epoch 540, Train Loss: 0.000264, Validation Loss: 0.000257
# Epoch 541, Train Loss: 0.000257, Validation Loss: 0.000247
# Epoch 542, Train Loss: 0.000248, Validation Loss: 0.000245
# Saving model at epoch 542 with validation loss 0.000245...
# Epoch 543, Train Loss: 0.000248, Validation Loss: 0.000242
# Saving model at epoch 543 with validation loss 0.000242...
# Epoch 544, Train Loss: 0.000249, Validation Loss: 0.000244
# Epoch 545, Train Loss: 0.000251, Validation Loss: 0.000252
# Epoch 546, Train Loss: 0.000251, Validation Loss: 0.000265
# Epoch 547, Train Loss: 0.000256, Validation Loss: 0.000277
# Epoch 548, Train Loss: 0.000254, Validation Loss: 0.000310
# Epoch 549, Train Loss: 0.000282, Validation Loss: 0.000258
# Epoch 550, Train Loss: 0.000250, Validation Loss: 0.000264
# Epoch 551, Train Loss: 0.000265, Validation Loss: 0.000339
# Epoch 552, Train Loss: 0.000269, Validation Loss: 0.000245
# Epoch 553, Train Loss: 0.000247, Validation Loss: 0.000241
# Saving model at epoch 553 with validation loss 0.000241...
# Epoch 554, Train Loss: 0.000259, Validation Loss: 0.000254
# Epoch 555, Train Loss: 0.000259, Validation Loss: 0.000257
# Epoch 556, Train Loss: 0.000253, Validation Loss: 0.000246
# Epoch 557, Train Loss: 0.000266, Validation Loss: 0.000290
# Epoch 558, Train Loss: 0.000264, Validation Loss: 0.000239
# Saving model at epoch 558 with validation loss 0.000239...
# Epoch 559, Train Loss: 0.000262, Validation Loss: 0.000280
# Epoch 560, Train Loss: 0.000276, Validation Loss: 0.000268
# Epoch 561, Train Loss: 0.000263, Validation Loss: 0.000243
# Epoch 562, Train Loss: 0.000263, Validation Loss: 0.000240
# Epoch 563, Train Loss: 0.000265, Validation Loss: 0.000294
# Epoch 564, Train Loss: 0.000269, Validation Loss: 0.000258
# Epoch 565, Train Loss: 0.000265, Validation Loss: 0.000250
# Epoch 566, Train Loss: 0.000277, Validation Loss: 0.000262
# Epoch 567, Train Loss: 0.000264, Validation Loss: 0.000238
# Saving model at epoch 567 with validation loss 0.000238...
# Epoch 568, Train Loss: 0.000244, Validation Loss: 0.000241
# Epoch 569, Train Loss: 0.000244, Validation Loss: 0.000240
# Epoch 570, Train Loss: 0.000247, Validation Loss: 0.000240
# Epoch 571, Train Loss: 0.000252, Validation Loss: 0.000249
# Epoch 572, Train Loss: 0.000252, Validation Loss: 0.000250
# Epoch 573, Train Loss: 0.000249, Validation Loss: 0.000279
# Epoch 574, Train Loss: 0.000290, Validation Loss: 0.000293
# Epoch 575, Train Loss: 0.000263, Validation Loss: 0.000245
# Epoch 576, Train Loss: 0.000257, Validation Loss: 0.000244
# Epoch 577, Train Loss: 0.000251, Validation Loss: 0.000237
# Saving model at epoch 577 with validation loss 0.000237...
# Epoch 578, Train Loss: 0.000242, Validation Loss: 0.000247
# Epoch 579, Train Loss: 0.000251, Validation Loss: 0.000240
# Epoch 580, Train Loss: 0.000245, Validation Loss: 0.000258
# Epoch 581, Train Loss: 0.000262, Validation Loss: 0.000261
# Epoch 582, Train Loss: 0.000247, Validation Loss: 0.000237
# Epoch 583, Train Loss: 0.000244, Validation Loss: 0.000237
# Epoch 584, Train Loss: 0.000247, Validation Loss: 0.000255
# Epoch 585, Train Loss: 0.000271, Validation Loss: 0.000246
# Epoch 586, Train Loss: 0.000247, Validation Loss: 0.000237
# Saving model at epoch 586 with validation loss 0.000237...
# Epoch 587, Train Loss: 0.000244, Validation Loss: 0.000256
# Epoch 588, Train Loss: 0.000255, Validation Loss: 0.000242
# Epoch 589, Train Loss: 0.000244, Validation Loss: 0.000243
# Epoch 590, Train Loss: 0.000251, Validation Loss: 0.000235
# Saving model at epoch 590 with validation loss 0.000235...
# Epoch 591, Train Loss: 0.000253, Validation Loss: 0.000249
# Epoch 592, Train Loss: 0.000252, Validation Loss: 0.000249
# Epoch 593, Train Loss: 0.000246, Validation Loss: 0.000238
# Epoch 594, Train Loss: 0.000240, Validation Loss: 0.000239
# Epoch 595, Train Loss: 0.000241, Validation Loss: 0.000234
# Saving model at epoch 595 with validation loss 0.000234...
# Epoch 596, Train Loss: 0.000240, Validation Loss: 0.000234
# Saving model at epoch 596 with validation loss 0.000234...
# Epoch 597, Train Loss: 0.000243, Validation Loss: 0.000238
# Epoch 598, Train Loss: 0.000253, Validation Loss: 0.000302
# Epoch 599, Train Loss: 0.000261, Validation Loss: 0.000301
# Epoch 600, Train Loss: 0.000263, Validation Loss: 0.000235
# Epoch 601, Train Loss: 0.000241, Validation Loss: 0.000240
# Epoch 602, Train Loss: 0.000240, Validation Loss: 0.000247
# Epoch 603, Train Loss: 0.000250, Validation Loss: 0.000235
# Epoch 604, Train Loss: 0.000271, Validation Loss: 0.000258
# Epoch 605, Train Loss: 0.000264, Validation Loss: 0.000238
# Epoch 606, Train Loss: 0.000251, Validation Loss: 0.000240
# Epoch 607, Train Loss: 0.000294, Validation Loss: 0.000243
# Epoch 608, Train Loss: 0.000254, Validation Loss: 0.000303
# Epoch 609, Train Loss: 0.000287, Validation Loss: 0.000251
# Epoch 610, Train Loss: 0.000254, Validation Loss: 0.000277
# Epoch 611, Train Loss: 0.000266, Validation Loss: 0.000244
# Epoch 612, Train Loss: 0.000259, Validation Loss: 0.000254
# Epoch 613, Train Loss: 0.000245, Validation Loss: 0.000233
# Saving model at epoch 613 with validation loss 0.000233...
# Epoch 614, Train Loss: 0.000250, Validation Loss: 0.000244
# Epoch 615, Train Loss: 0.000237, Validation Loss: 0.000233
# Epoch 616, Train Loss: 0.000235, Validation Loss: 0.000230
# Saving model at epoch 616 with validation loss 0.000230...
# Epoch 617, Train Loss: 0.000236, Validation Loss: 0.000234
# Epoch 618, Train Loss: 0.000238, Validation Loss: 0.000235
# Epoch 619, Train Loss: 0.000241, Validation Loss: 0.000282
# Epoch 620, Train Loss: 0.000240, Validation Loss: 0.000247
# Epoch 621, Train Loss: 0.000234, Validation Loss: 0.000232
# Epoch 622, Train Loss: 0.000241, Validation Loss: 0.000234
# Epoch 623, Train Loss: 0.000244, Validation Loss: 0.000305
# Epoch 624, Train Loss: 0.000259, Validation Loss: 0.000233
# Epoch 625, Train Loss: 0.000243, Validation Loss: 0.000242
# Epoch 626, Train Loss: 0.000237, Validation Loss: 0.000239
# Epoch 627, Train Loss: 0.000235, Validation Loss: 0.000246
# Epoch 628, Train Loss: 0.000247, Validation Loss: 0.000240
# Epoch 629, Train Loss: 0.000249, Validation Loss: 0.000232
# ...
# Epoch 2755, Train Loss: 0.000141, Validation Loss: 0.000147
# Epoch 2756, Train Loss: 0.000145, Validation Loss: 0.000145
# Epoch 2757, Train Loss: 0.000143, Validation Loss: 0.000167
# Epoch 2758, Train Loss: 0.000170, Validation Loss: 0.000205
# Epoch 2759, Train Loss: 0.000192, Validation Loss: 0.000232
# Epoch 2760, Train Loss: 0.000173, Validation Loss: 0.000164
# Epoch 2761, Train Loss: 0.000174, Validation Loss: 0.000147
# Epoch 2762, Train Loss: 0.000148, Validation Loss: 0.000145
# Epoch 2763, Train Loss: 0.000156, Validation Loss: 0.000152
# Epoch 2764, Train Loss: 0.000146, Validation Loss: 0.000143
# Epoch 2765, Train Loss: 0.000146, Validation Loss: 0.000196
# Epoch 2766, Train Loss: 0.000170, Validation Loss: 0.000147
# Epoch 2767, Train Loss: 0.000152, Validation Loss: 0.000157
# Epoch 2768, Train Loss: 0.000150, Validation Loss: 0.000152
# Epoch 2769, Train Loss: 0.000148, Validation Loss: 0.000155
# Epoch 2770, Train Loss: 0.000140, Validation Loss: 0.000142
# Epoch 2771, Train Loss: 0.000137, Validation Loss: 0.000148
# Epoch 2772, Train Loss: 0.000147, Validation Loss: 0.000153
# Epoch 2773, Train Loss: 0.000148, Validation Loss: 0.000165
# Epoch 2774, Train Loss: 0.000170, Validation Loss: 0.000204
# Epoch 2775, Train Loss: 0.000162, Validation Loss: 0.000151
# Epoch 2776, Train Loss: 0.000147, Validation Loss: 0.000156
# Epoch 2777, Train Loss: 0.000146, Validation Loss: 0.000157
# Epoch 2778, Train Loss: 0.000152, Validation Loss: 0.000148
# Epoch 2779, Train Loss: 0.000147, Validation Loss: 0.000145
# Epoch 2780, Train Loss: 0.000145, Validation Loss: 0.000154
# Epoch 2781, Train Loss: 0.000141, Validation Loss: 0.000145
# Epoch 2782, Train Loss: 0.000146, Validation Loss: 0.000148
# Epoch 2783, Train Loss: 0.000144, Validation Loss: 0.000151
# Epoch 2784, Train Loss: 0.000145, Validation Loss: 0.000142
# Saving model at epoch 2784 with validation loss 0.000142...
# Epoch 2785, Train Loss: 0.000140, Validation Loss: 0.000152
# Epoch 2786, Train Loss: 0.000147, Validation Loss: 0.000149
# Epoch 2787, Train Loss: 0.000144, Validation Loss: 0.000150
# Epoch 2788, Train Loss: 0.000144, Validation Loss: 0.000146
# Epoch 2789, Train Loss: 0.000138, Validation Loss: 0.000147
# Epoch 2790, Train Loss: 0.000139, Validation Loss: 0.000147
# Epoch 2791, Train Loss: 0.000154, Validation Loss: 0.000144
# Epoch 2792, Train Loss: 0.000145, Validation Loss: 0.000147
# Epoch 2793, Train Loss: 0.000143, Validation Loss: 0.000147
# Epoch 2794, Train Loss: 0.000138, Validation Loss: 0.000145
# Epoch 2795, Train Loss: 0.000147, Validation Loss: 0.000172
# Epoch 2796, Train Loss: 0.000148, Validation Loss: 0.000147
# Epoch 2797, Train Loss: 0.000151, Validation Loss: 0.000160
# Epoch 2798, Train Loss: 0.000166, Validation Loss: 0.000173
# Epoch 2799, Train Loss: 0.000174, Validation Loss: 0.000204
# Epoch 2800, Train Loss: 0.000179, Validation Loss: 0.000266
# Epoch 2801, Train Loss: 0.000194, Validation Loss: 0.000173
# Epoch 2802, Train Loss: 0.000183, Validation Loss: 0.000170
# Epoch 2803, Train Loss: 0.000163, Validation Loss: 0.000179
# Epoch 2804, Train Loss: 0.000152, Validation Loss: 0.000156
# Epoch 2805, Train Loss: 0.000157, Validation Loss: 0.000151
# Epoch 2806, Train Loss: 0.000148, Validation Loss: 0.000148
# Epoch 2807, Train Loss: 0.000145, Validation Loss: 0.000143
# Epoch 2808, Train Loss: 0.000141, Validation Loss: 0.000149
# Epoch 2809, Train Loss: 0.000147, Validation Loss: 0.000147
# Epoch 2810, Train Loss: 0.000147, Validation Loss: 0.000178
# Epoch 2811, Train Loss: 0.000152, Validation Loss: 0.000149
# Epoch 2812, Train Loss: 0.000158, Validation Loss: 0.000222
# Epoch 2813, Train Loss: 0.000183, Validation Loss: 0.000156
# Epoch 2814, Train Loss: 0.000159, Validation Loss: 0.000153
# Epoch 2815, Train Loss: 0.000149, Validation Loss: 0.000202
# Epoch 2816, Train Loss: 0.000165, Validation Loss: 0.000178
# Epoch 2817, Train Loss: 0.000172, Validation Loss: 0.000210
# Epoch 2818, Train Loss: 0.000173, Validation Loss: 0.000182
# Epoch 2819, Train Loss: 0.000157, Validation Loss: 0.000154
# Epoch 2820, Train Loss: 0.000143, Validation Loss: 0.000162
# Epoch 2821, Train Loss: 0.000147, Validation Loss: 0.000146
# Epoch 2822, Train Loss: 0.000140, Validation Loss: 0.000143
# Epoch 2823, Train Loss: 0.000138, Validation Loss: 0.000142
# Epoch 2824, Train Loss: 0.000144, Validation Loss: 0.000150
# Epoch 2825, Train Loss: 0.000141, Validation Loss: 0.000144
# Epoch 2826, Train Loss: 0.000140, Validation Loss: 0.000144
# Epoch 2827, Train Loss: 0.000137, Validation Loss: 0.000144
# Epoch 2828, Train Loss: 0.000139, Validation Loss: 0.000141
# Saving model at epoch 2828 with validation loss 0.000141...
# Epoch 2829, Train Loss: 0.000139, Validation Loss: 0.000142
# Epoch 2830, Train Loss: 0.000138, Validation Loss: 0.000143
# Epoch 2831, Train Loss: 0.000140, Validation Loss: 0.000165
# Epoch 2832, Train Loss: 0.000149, Validation Loss: 0.000147
# Epoch 2833, Train Loss: 0.000144, Validation Loss: 0.000141
# Epoch 2834, Train Loss: 0.000140, Validation Loss: 0.000148
# Epoch 2835, Train Loss: 0.000137, Validation Loss: 0.000147
# Epoch 2836, Train Loss: 0.000141, Validation Loss: 0.000144
# Epoch 2837, Train Loss: 0.000140, Validation Loss: 0.000142
# Epoch 2838, Train Loss: 0.000139, Validation Loss: 0.000168
# Epoch 2839, Train Loss: 0.000152, Validation Loss: 0.000220
# Epoch 2840, Train Loss: 0.000186, Validation Loss: 0.000172
# Epoch 2841, Train Loss: 0.000159, Validation Loss: 0.000147
# Epoch 2842, Train Loss: 0.000161, Validation Loss: 0.000193
# Epoch 2843, Train Loss: 0.000159, Validation Loss: 0.000166
# Epoch 2844, Train Loss: 0.000175, Validation Loss: 0.000153
# Epoch 2845, Train Loss: 0.000143, Validation Loss: 0.000144
# Epoch 2846, Train Loss: 0.000140, Validation Loss: 0.000143
# Epoch 2847, Train Loss: 0.000144, Validation Loss: 0.000159
# Epoch 2848, Train Loss: 0.000142, Validation Loss: 0.000154
# Epoch 2849, Train Loss: 0.000147, Validation Loss: 0.000147
# Epoch 2850, Train Loss: 0.000141, Validation Loss: 0.000146
# Epoch 2851, Train Loss: 0.000151, Validation Loss: 0.000142
# Epoch 2852, Train Loss: 0.000155, Validation Loss: 0.000162
# Epoch 2853, Train Loss: 0.000149, Validation Loss: 0.000141
# Epoch 2854, Train Loss: 0.000140, Validation Loss: 0.000146
# Epoch 2855, Train Loss: 0.000143, Validation Loss: 0.000145
# Epoch 2856, Train Loss: 0.000142, Validation Loss: 0.000151
# Epoch 2857, Train Loss: 0.000148, Validation Loss: 0.000148
# Epoch 2858, Train Loss: 0.000150, Validation Loss: 0.000162
# Epoch 2859, Train Loss: 0.000139, Validation Loss: 0.000146
# Epoch 2860, Train Loss: 0.000140, Validation Loss: 0.000150
# Epoch 2861, Train Loss: 0.000151, Validation Loss: 0.000143
# Epoch 2862, Train Loss: 0.000145, Validation Loss: 0.000152
# Epoch 2863, Train Loss: 0.000156, Validation Loss: 0.000146
# Epoch 2864, Train Loss: 0.000140, Validation Loss: 0.000145
# Epoch 2865, Train Loss: 0.000148, Validation Loss: 0.000143
# Epoch 2866, Train Loss: 0.000153, Validation Loss: 0.000155
# Epoch 2867, Train Loss: 0.000146, Validation Loss: 0.000160
# Epoch 2868, Train Loss: 0.000144, Validation Loss: 0.000142
# Epoch 2869, Train Loss: 0.000139, Validation Loss: 0.000154
# Epoch 2870, Train Loss: 0.000145, Validation Loss: 0.000151
# Epoch 2871, Train Loss: 0.000142, Validation Loss: 0.000143
# Epoch 2872, Train Loss: 0.000144, Validation Loss: 0.000148
# Epoch 2873, Train Loss: 0.000146, Validation Loss: 0.000143
# Epoch 2874, Train Loss: 0.000141, Validation Loss: 0.000142
# Epoch 2875, Train Loss: 0.000146, Validation Loss: 0.000150
# Epoch 2876, Train Loss: 0.000143, Validation Loss: 0.000179
# Epoch 2877, Train Loss: 0.000151, Validation Loss: 0.000144
# Epoch 2878, Train Loss: 0.000139, Validation Loss: 0.000141
# Epoch 2879, Train Loss: 0.000146, Validation Loss: 0.000169
# Epoch 2880, Train Loss: 0.000148, Validation Loss: 0.000143
# Epoch 2881, Train Loss: 0.000153, Validation Loss: 0.000155
# Epoch 2882, Train Loss: 0.000141, Validation Loss: 0.000142
# Epoch 2883, Train Loss: 0.000151, Validation Loss: 0.000166
# Epoch 2884, Train Loss: 0.000153, Validation Loss: 0.000205
# Epoch 2885, Train Loss: 0.000178, Validation Loss: 0.000168
# Epoch 2886, Train Loss: 0.000151, Validation Loss: 0.000149
# Epoch 2887, Train Loss: 0.000143, Validation Loss: 0.000162
# Epoch 2888, Train Loss: 0.000168, Validation Loss: 0.000175
# Epoch 2889, Train Loss: 0.000193, Validation Loss: 0.000202
# Epoch 2890, Train Loss: 0.000212, Validation Loss: 0.000164
# Epoch 2891, Train Loss: 0.000163, Validation Loss: 0.000158
# Epoch 2892, Train Loss: 0.000151, Validation Loss: 0.000147
# Epoch 2893, Train Loss: 0.000143, Validation Loss: 0.000176
# Epoch 2894, Train Loss: 0.000162, Validation Loss: 0.000146
# Epoch 2895, Train Loss: 0.000141, Validation Loss: 0.000155
# Epoch 2896, Train Loss: 0.000141, Validation Loss: 0.000154
# Epoch 2897, Train Loss: 0.000150, Validation Loss: 0.000232
# Epoch 2898, Train Loss: 0.000165, Validation Loss: 0.000151
# Epoch 2899, Train Loss: 0.000142, Validation Loss: 0.000143
# Epoch 2900, Train Loss: 0.000139, Validation Loss: 0.000171
# Epoch 2901, Train Loss: 0.000145, Validation Loss: 0.000146
# Epoch 2902, Train Loss: 0.000146, Validation Loss: 0.000154
# Epoch 2903, Train Loss: 0.000144, Validation Loss: 0.000147
# Epoch 2904, Train Loss: 0.000142, Validation Loss: 0.000143
# Epoch 2905, Train Loss: 0.000149, Validation Loss: 0.000156
# Epoch 2906, Train Loss: 0.000145, Validation Loss: 0.000166
# Epoch 2907, Train Loss: 0.000154, Validation Loss: 0.000145
# Epoch 2908, Train Loss: 0.000139, Validation Loss: 0.000157
# Epoch 2909, Train Loss: 0.000146, Validation Loss: 0.000150
# Epoch 2910, Train Loss: 0.000152, Validation Loss: 0.000144
# Epoch 2911, Train Loss: 0.000142, Validation Loss: 0.000152
# Epoch 2912, Train Loss: 0.000155, Validation Loss: 0.000163
# Epoch 2913, Train Loss: 0.000148, Validation Loss: 0.000154
# Epoch 2914, Train Loss: 0.000147, Validation Loss: 0.000143
# Epoch 2915, Train Loss: 0.000138, Validation Loss: 0.000143
# Epoch 2916, Train Loss: 0.000144, Validation Loss: 0.000141
# Epoch 2917, Train Loss: 0.000159, Validation Loss: 0.000156
# Epoch 2918, Train Loss: 0.000156, Validation Loss: 0.000149
# Epoch 2919, Train Loss: 0.000143, Validation Loss: 0.000161
# Epoch 2920, Train Loss: 0.000163, Validation Loss: 0.000183
# Epoch 2921, Train Loss: 0.000157, Validation Loss: 0.000143
# Epoch 2922, Train Loss: 0.000148, Validation Loss: 0.000145
# Epoch 2923, Train Loss: 0.000139, Validation Loss: 0.000143
# Epoch 2924, Train Loss: 0.000138, Validation Loss: 0.000171
# Epoch 2925, Train Loss: 0.000155, Validation Loss: 0.000155
# Epoch 2926, Train Loss: 0.000144, Validation Loss: 0.000150
# Epoch 2927, Train Loss: 0.000145, Validation Loss: 0.000142
# Epoch 2928, Train Loss: 0.000145, Validation Loss: 0.000158
# Epoch 2929, Train Loss: 0.000151, Validation Loss: 0.000152
# Epoch 2930, Train Loss: 0.000148, Validation Loss: 0.000146
# Epoch 2931, Train Loss: 0.000141, Validation Loss: 0.000153
# Epoch 2932, Train Loss: 0.000146, Validation Loss: 0.000144
# Epoch 2933, Train Loss: 0.000138, Validation Loss: 0.000143
# Epoch 2934, Train Loss: 0.000141, Validation Loss: 0.000149
# Epoch 2935, Train Loss: 0.000141, Validation Loss: 0.000143
# Epoch 2936, Train Loss: 0.000139, Validation Loss: 0.000156
# Epoch 2937, Train Loss: 0.000146, Validation Loss: 0.000142
# Epoch 2938, Train Loss: 0.000142, Validation Loss: 0.000145
# Epoch 2939, Train Loss: 0.000145, Validation Loss: 0.000170
# Epoch 2940, Train Loss: 0.000169, Validation Loss: 0.000149
# Epoch 2941, Train Loss: 0.000144, Validation Loss: 0.000150
# Epoch 2942, Train Loss: 0.000143, Validation Loss: 0.000143
# Epoch 2943, Train Loss: 0.000143, Validation Loss: 0.000145
# Epoch 2944, Train Loss: 0.000139, Validation Loss: 0.000142
# Epoch 2945, Train Loss: 0.000140, Validation Loss: 0.000146
# Epoch 2946, Train Loss: 0.000154, Validation Loss: 0.000153
# Epoch 2947, Train Loss: 0.000153, Validation Loss: 0.000161
# Epoch 2948, Train Loss: 0.000146, Validation Loss: 0.000147
# Epoch 2949, Train Loss: 0.000142, Validation Loss: 0.000151
# Epoch 2950, Train Loss: 0.000150, Validation Loss: 0.000226
# Epoch 2951, Train Loss: 0.000188, Validation Loss: 0.000247
# Epoch 2952, Train Loss: 0.000166, Validation Loss: 0.000164
# Epoch 2953, Train Loss: 0.000144, Validation Loss: 0.000142
# Epoch 2954, Train Loss: 0.000143, Validation Loss: 0.000151
# Epoch 2955, Train Loss: 0.000140, Validation Loss: 0.000145
# Epoch 2956, Train Loss: 0.000148, Validation Loss: 0.000148
# Epoch 2957, Train Loss: 0.000153, Validation Loss: 0.000205
# Epoch 2958, Train Loss: 0.000157, Validation Loss: 0.000145
# Epoch 2959, Train Loss: 0.000148, Validation Loss: 0.000173
# Epoch 2960, Train Loss: 0.000159, Validation Loss: 0.000174
# Epoch 2961, Train Loss: 0.000173, Validation Loss: 0.000148
# Epoch 2962, Train Loss: 0.000141, Validation Loss: 0.000144
# Epoch 2963, Train Loss: 0.000150, Validation Loss: 0.000163
# Epoch 2964, Train Loss: 0.000141, Validation Loss: 0.000151
# Epoch 2965, Train Loss: 0.000140, Validation Loss: 0.000145
# Epoch 2966, Train Loss: 0.000149, Validation Loss: 0.000141
# Epoch 2967, Train Loss: 0.000155, Validation Loss: 0.000145
# Epoch 2968, Train Loss: 0.000186, Validation Loss: 0.000143
# Epoch 2969, Train Loss: 0.000146, Validation Loss: 0.000146
# Epoch 2970, Train Loss: 0.000149, Validation Loss: 0.000155
# Epoch 2971, Train Loss: 0.000148, Validation Loss: 0.000154
# Epoch 2972, Train Loss: 0.000140, Validation Loss: 0.000146
# Epoch 2973, Train Loss: 0.000138, Validation Loss: 0.000146
# Epoch 2974, Train Loss: 0.000142, Validation Loss: 0.000142
# Epoch 2975, Train Loss: 0.000140, Validation Loss: 0.000145
# Epoch 2976, Train Loss: 0.000139, Validation Loss: 0.000144
# Epoch 2977, Train Loss: 0.000139, Validation Loss: 0.000141
# Epoch 2978, Train Loss: 0.000136, Validation Loss: 0.000146
# Epoch 2979, Train Loss: 0.000151, Validation Loss: 0.000165
# Epoch 2980, Train Loss: 0.000147, Validation Loss: 0.000143
# Epoch 2981, Train Loss: 0.000146, Validation Loss: 0.000147
# Epoch 2982, Train Loss: 0.000142, Validation Loss: 0.000142
# Epoch 2983, Train Loss: 0.000139, Validation Loss: 0.000142
# Epoch 2984, Train Loss: 0.000152, Validation Loss: 0.000170
# Epoch 2985, Train Loss: 0.000160, Validation Loss: 0.000159
# Epoch 2986, Train Loss: 0.000163, Validation Loss: 0.000159
# Epoch 2987, Train Loss: 0.000172, Validation Loss: 0.000187
# Epoch 2988, Train Loss: 0.000193, Validation Loss: 0.000148
# Epoch 2989, Train Loss: 0.000164, Validation Loss: 0.000206
# Epoch 2990, Train Loss: 0.000194, Validation Loss: 0.000159
# Epoch 2991, Train Loss: 0.000194, Validation Loss: 0.000151
# Epoch 2992, Train Loss: 0.000152, Validation Loss: 0.000146
# Epoch 2993, Train Loss: 0.000149, Validation Loss: 0.000144
# Epoch 2994, Train Loss: 0.000145, Validation Loss: 0.000143
# Epoch 2995, Train Loss: 0.000146, Validation Loss: 0.000153
# Epoch 2996, Train Loss: 0.000154, Validation Loss: 0.000145
# Epoch 2997, Train Loss: 0.000146, Validation Loss: 0.000175
# Epoch 2998, Train Loss: 0.000151, Validation Loss: 0.000166
# Epoch 2999, Train Loss: 0.000147, Validation Loss: 0.000159
# Epoch 3000, Train Loss: 0.000146, Validation Loss: 0.000152
# Training complete. Best model saved at ./Model/linspace_n_init1/1024/CH467160_n_init1.pt.
# C:\Users\USER\AppData\Local\Temp\ipykernel_39868\219871016.py:175: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_save_path))  # 載入最佳模型
