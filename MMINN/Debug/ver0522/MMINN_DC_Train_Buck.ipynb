# %% [markdown]
# # Part 1: Network Training

# %% [markdown]
# ## Step0: Import Package & Hyperparameter Configuration

# %%
# 清空所有變數
# %reset -f  
# 強制 Python 回收記憶體
import gc
gc.collect()
# Out:
# 0

# %% [markdown]
# ### Package

# %%
import os
import torch
import numpy as np
import random
import torch.nn as nn
from torch.autograd import Variable
from torch.utils.data import DataLoader, TensorDataset
import matplotlib.pyplot as plt
from tqdm import tqdm

# %% [markdown]
# ### Hyperparameter Config

# %%
# %%
# Unified Hyperparameter Configuration
class Config:
    SEED = 1
    NUM_EPOCHS = 3000
    BATCH_SIZE = 128
    LEARNING_RATE = 0.002  #論文提供
    LR_SCHEDULER_GAMMA = 0.99  #論文提供
    DECAY_EPOCH = 200
    DECAY_RATIO = 0.5
    EARLY_STOPPING_PATIENCE = 500
    HIDDEN_SIZE = 30
    OPERATOR_SIZE = 30


# Reproducibility
random.seed(Config.SEED)
np.random.seed(Config.SEED)
torch.manual_seed(Config.SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %% [markdown]
# ### Material & Number of Data

# %%
material = "CH467160_Buck"
down_sample_way = "linspace_n_init2"
downsample = 128

# 訓練情況況
plot_interval = 300
train_show_sample = 1

# 定義保存模型的路徑
model_save_dir = f"./Model/{down_sample_way}/{downsample}/"
os.makedirs(model_save_dir, exist_ok=True)  # 如果路徑不存在，創建路徑
model_save_path = os.path.join(model_save_dir,
                               f"{material}_n_init2.pt")  # 定義模型保存檔名

figure_save_base_path = f"./figure/{down_sample_way}/{downsample}/"
os.makedirs(figure_save_base_path, exist_ok=True)  # 如果路徑不存在，創建路徑

# Select device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Step1: Data processing and data loader generate

# %%
# %% Preprocess data into a data loader
def get_dataloader(data_B,
                   data_F,
                   data_T,
                   data_H,
                   data_N,
                   data_Hdc,
                   data_Pcv,
                   n_init=16):
    """ #*(Date:250105)
    Process data and return DataLoader for training, validation, and testing.

    Parameters
    ----------
    data_B : np.array
        Magnetic flux density data.
    data_F : np.array
        Frequency data.
    data_T : np.array
        Temperature data.
    data_N : np.array
        Turns data.
    data_Hdc : np.array
        DC Magnetic field strength data.
    data_H : np.array
        AC Magnetic field strength data.
    data_Pcv : np.array
        Core loss data.
    norm : list
        Normalization parameters for the features.
    n_init : int
        Number of initial data points for magnetization.

    Returns
    -------
        train_loader, valid_loader : DataLoader
        Dataloaders for training, validation
        norm
    """

    # Data pre-process

    # 1. Down-sample to 128 points
    seq_length = downsample
    #range(start, stop, step)
    # cols = range(0, 8192, int(8192 / seq_length))
    cols = np.linspace(0, 1023, seq_length, dtype=int)
    data_B = data_B[:, cols]
    data_H = data_H[:, cols]

    # 2. Add extra points for initial magnetization calculation
    data_length = seq_length + n_init
    data_B = np.hstack((data_B[:, -n_init:], data_B))
    data_H = np.hstack((data_H[:, -n_init:], data_H))

    # 3. Format data into tensors  #*(Date:241216) seq_length=128, data_length=144
    B = torch.from_numpy(data_B).view(-1, data_length, 1).float()
    H = torch.from_numpy(data_H).view(-1, data_length, 1).float()
    F = torch.log10(torch.from_numpy(data_F).view(-1, 1).float())
    T = torch.from_numpy(data_T).view(-1, 1).float()
    Hdc = torch.from_numpy(data_Hdc).view(-1, 1).float()
    N = torch.from_numpy(data_N).view(-1, 1).float()
    Pcv = torch.log10(torch.from_numpy(data_Pcv).view(-1, 1).float())

    # 原本在6. 因要先計算標準化故移至這

    dB = torch.diff(B, dim=1)
    dB = torch.cat((dB[:, 0:1], dB), dim=1)
    dB_dt = dB * (seq_length * F.view(-1, 1, 1))

    in_dB = torch.diff(B, dim=1)
    in_dB = torch.cat((in_dB[:, 0:1], in_dB), dim=1)

    d2B = torch.diff(dB, dim=1)  # *二階導數(version:250520)
    d2B = torch.cat((d2B[:, 0:1], d2B), dim=1)  # *填充首點(version:250520)
    d2B_dt = d2B * (seq_length * F.view(-1, 1, 1))

    #  4. Compute normalization parameters (均值 & 標準差)**
    # ! 溫度頻率不變加入微小的 epsilon
    norm = [
        safe_mean_std(B),  # 0: B
        safe_mean_std(H),  # 1: H
        safe_mean_std(F),  # 2: F
        safe_mean_std(T),  # 3: T
        safe_mean_std(d2B_dt),  # 4: dB/dt
        safe_mean_std(Pcv),  # 5: Pcv
        safe_mean_std(Hdc),  # 6: Hdc
        safe_mean_std(N),  # 7: N
        safe_mean_std(d2B)  # *8: d2B/dt2(version:250520)
    ]

    # 用來做test固定標準化參數的
    material_name = f"{material}"
    print(f'"{material_name}": [')
    for param in norm:
        print(f"    {param},")
    print("]")

    # 5. Data Normalization
    in_B = (B - norm[0][0]) / norm[0][1]  # B
    out_H = (H - norm[1][0]) / norm[1][1]  # H
    in_F = (F - norm[2][0]) / norm[2][1]  # F
    in_T = (T - norm[3][0]) / norm[3][1]  # T

    in_Pcv = (Pcv - norm[5][0]) / norm[5][1]  # Pcv
    in_Hdc = (Hdc - norm[6][0]) / norm[6][1]  # Hdc
    in_N = (N - norm[7][0]) / norm[7][1]  # N
    in_d2B = (d2B_dt - norm[8][0]) / norm[8][1]  # *d2B/dt2(version:250520)
    in_dB_dt = (dB_dt - norm[4][0]) / norm[4][1]

    # 6. Extra features
    max_B, _ = torch.max(in_B, dim=1)
    min_B, _ = torch.min(in_B, dim=1)
    s0 = get_operator_init(in_B[:, 0] - in_dB[:, 0], in_dB, max_B, min_B)

    # 7. Create dataloader to speed up data processing
    full_dataset = torch.utils.data.TensorDataset(
        torch.cat((in_B, in_dB, in_dB_dt, in_d2B),
                  dim=2),  # B 部分（144 點） # !Add d2B
        torch.cat((in_F, in_T, in_Hdc, in_N, in_Pcv), dim=1),  # 輔助變量
        s0,  # 初始狀態
        out_H)

    # Split dataset into train, validation, and test sets (60:20:20)
    train_size = int(0.8 * len(full_dataset))
    valid_size = len(full_dataset) - train_size

    train_dataset, valid_dataset = torch.utils.data.random_split(
        full_dataset, [train_size, valid_size],
        generator=torch.Generator().manual_seed(Config.SEED))

    train_loader = torch.utils.data.DataLoader(train_dataset,
                                               batch_size=Config.BATCH_SIZE,
                                               shuffle=True,
                                               num_workers=0,
                                               collate_fn=filter_input)

    valid_loader = torch.utils.data.DataLoader(valid_dataset,
                                               batch_size=Config.BATCH_SIZE,
                                               shuffle=False,
                                               num_workers=0,
                                               collate_fn=filter_input)

    return train_loader, valid_loader, norm


# %% Predict the operator state at t0
def get_operator_init(B1,
                      dB,
                      Bmax,
                      Bmin,
                      max_out_H=5,
                      operator_size=Config.OPERATOR_SIZE):
    """Compute the initial state of hysteresis operators"""
    s0 = torch.zeros((dB.shape[0], operator_size))
    operator_thre = torch.from_numpy(
        np.linspace(max_out_H / operator_size, max_out_H,
                    operator_size)).view(1, -1)

    for i in range(dB.shape[0]):
        for j in range(operator_size):
            r = operator_thre[0, j]
            if (Bmax[i] >= r) or (Bmin[i] <= -r):
                if dB[i, 0] >= 0:
                    if B1[i] > Bmin[i] + 2 * r:
                        s0[i, j] = r
                    else:
                        s0[i, j] = B1[i] - (r + Bmin[i])
                else:
                    if B1[i] < Bmax[i] - 2 * r:
                        s0[i, j] = -r
                    else:
                        s0[i, j] = B1[i] + (r - Bmax[i])
    return s0


def filter_input(batch):
    inputs, features, s0, target_H = zip(*batch)

    # 如果 inputs 是 tuple，先堆疊成張量
    inputs = torch.stack(inputs)  # B 的所有輸入部分（144 點）

    # 保留 in_B, in_dB, in_dB_dt, in_d2B_dt 作為模型輸入
    inputs = inputs[:, :, :4]

    # 保留 in_F, in_T, in_Hdc, in_N (排除 in_Pcv，in_Pcv要放在最面)
    features = torch.stack(features)[:, :4]

    # 保留目標值 H
    target_H = torch.stack(
        target_H)[:, -downsample:, :]  # ?只取最後 128 點 (改1024看狀況有無變好)

    s0 = torch.stack(s0)  # 初始狀態

    return inputs, features, s0, target_H


# ! 溫度頻率不變加入微小的 epsilon
def safe_mean_std(tensor, eps=1e-8):
    m_tensor = torch.mean(tensor)  # 還是 Tensor
    s_tensor = torch.std(tensor)  # 還是 Tensor

    m_val = m_tensor.item()  # 第一次轉成 float
    s_val = s_tensor.item()
    if s_val < eps:
        s_val = 1.0

    return [m_val, s_val]  # 直接回傳 float

# %% [markdown]
# ## Step2: Define Network Structure

# %%
# %% Magnetization mechansim-determined neural network
"""
    Parameters:
    - hidden_size: number of eddy current slices (RNN neuron)
    - operator_size: number of operators
# !  - input_size: number of inputs (1.B 2.dB 3.dB/dt 4.d2B/dt)
# ! - var_size: number of supplenmentary variables (1.F 2.T 3.Hdc 4.N)        
    - output_size: number of outputs (1.H)
    
    只先把d2B/dt考量在EddyCell裡面
"""


class MMINet(nn.Module):
    def __init__(
            self,
            norm,
            hidden_size=Config.HIDDEN_SIZE,
            operator_size=Config.OPERATOR_SIZE,
            input_size=4,  #!新增d2B(250203)
            var_size=4,
            output_size=1):
        super().__init__()
        self.input_size = input_size
        self.var_size = var_size
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.operator_size = operator_size
        self.norm = norm  #*這裡改成從外部傳入 norm(250203)

        self.rnn1 = StopOperatorCell(self.operator_size)
        self.dnn1 = nn.Linear(self.operator_size + self.var_size, 1)
        self.rnn2 = EddyCell(
            7, self.hidden_size,
            output_size)  #!250520更新：5 (F, T, B, dB/dt, d2B/dt ) + 2 (Hdc, N)
        self.dnn2 = nn.Linear(self.hidden_size, 1)

        self.rnn2_hx = None

    def forward(self, x, var, s0, n_init=16):
        """
         Parameters: 
          - x(batch,seq,input_size): Input features (1.B, 2.dB, 3.dB/dt)  
# !       - var(batch,var_size): Supplementary inputs (1.F 2.T 3.Hdc 4.N) 
          - s0(batch,1): Operator inital states
        """
        batch_size = x.size(0)  # Batch size
        seq_size = x.size(1)  # Ser
        self.rnn1_hx = s0

        # !Initialize DNN2 input (1.B 2.dB/dt 3.d2B)
        # x2 = torch.cat((x[:, :, 0:1], x[:, :, 2:3]), dim=2)
        x2 = torch.cat((x[:, :, 0:1], x[:, :, 2:4]),
                       dim=2)  # !選取 B, dB/dt, d2B

        for t in range(seq_size):
            # RNN1 input (dB,state)
            self.rnn1_hx = self.rnn1(x[:, t, 1:2], self.rnn1_hx)

            # DNN1 input (rnn1_hx,F,T,Hdc,N)
            dnn1_in = torch.cat((self.rnn1_hx, var), dim=1)

            # H hysteresis prediction
            H_hyst_pred = self.dnn1(dnn1_in)

            # DNN2 input (B,dB/dt,T,F)
            rnn2_in = torch.cat((x2[:, t, :], var), dim=1)

            # Initialize second rnn state
            if t == 0:
                H_eddy_init = x[:, t, 0:1] - H_hyst_pred
                buffer = x.new_ones(x.size(0), self.hidden_size)
                self.rnn2_hx = Variable(
                    (buffer / torch.sum(self.dnn2.weight, dim=1)) *
                    H_eddy_init)

            #rnn2_in = torch.cat((rnn2_in,H_hyst_pred),dim=1)
            self.rnn2_hx = self.rnn2(rnn2_in, self.rnn2_hx)

            # H eddy prediction
            H_eddy = self.dnn2(self.rnn2_hx)

            # H total
            H_total = (H_hyst_pred + H_eddy).view(batch_size, 1,
                                                  self.output_size)
            if t == 0:
                output = H_total
            else:
                output = torch.cat((output, H_total), dim=1)

        H = (output[:, n_init:, :])

        return H


class StopOperatorCell():
    def __init__(self, operator_size):
        self.operator_thre = torch.from_numpy(
            np.linspace(5 / operator_size, 5, operator_size)).view(1, -1)

    def sslu(self, X):
        a = torch.ones_like(X)
        return torch.max(-a, torch.min(a, X))

    def __call__(self, dB, state):
        r = self.operator_thre.to(dB.device)
        output = self.sslu((dB + state) / r) * r
        return output.float()


class EddyCell(nn.Module):
    def __init__(self, input_size, hidden_size, output_size=1):
        super().__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.output_size = output_size

        self.x2h = nn.Linear(input_size, hidden_size, bias=False)
        self.h2h = nn.Linear(hidden_size, hidden_size, bias=False)

    def forward(self, x, hidden=None):
        hidden = self.x2h(x) + self.h2h(hidden)
        hidden = torch.sigmoid(hidden)
        return hidden

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# ## Step3: Training the Model

# %% [markdown]
# ### Load Dataset

# %%
# %%
def load_dataset(material, base_path="./Data/"):

    in_file1 = f"{base_path}{material}/train/B_Field.csv"
    in_file2 = f"{base_path}{material}/train/Frequency.csv"
    in_file3 = f"{base_path}{material}/train/Temperature.csv"
    in_file4 = f"{base_path}{material}/train/H_Field.csv"
    in_file5 = f"{base_path}{material}/train/Volumetric_Loss.csv"
    in_file6 = f"{base_path}{material}/train/Hdc.csv"  # *250317新增：直流偏置磁場
    in_file7 = f"{base_path}{material}/train/Turns.csv"  # *250317新增：匝數

    data_B = np.genfromtxt(in_file1, delimiter=',')  # N x 1024
    data_F = np.genfromtxt(in_file2, delimiter=',')  # N x 1
    data_T = np.genfromtxt(in_file3, delimiter=',')  # N x 1
    data_H = np.genfromtxt(in_file4, delimiter=',')  # N x 1024  # *250317新增
    data_Pcv = np.genfromtxt(in_file5, delimiter=',')  # N x 1
    data_Hdc = np.genfromtxt(in_file6, delimiter=',')  # N x 1  # *250317新增
    data_N = np.genfromtxt(in_file7, delimiter=',')  # N x 1

    return data_B, data_F, data_T, data_H, data_Pcv, data_Hdc, data_N

# %% [markdown]
# ### Train Code

# %%
# %%
def train_model(norm, train_loader, valid_loader):

    model = MMINet(norm=norm).to(device)
    print("Number of parameters: ", count_parameters(model))
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=Config.LEARNING_RATE)

    best_val_loss = float('inf')
    patience_counter = 0

    # **新增 Loss 記錄**
    train_losses = []
    val_losses = []
    fixed_idx = None

    for epoch in range(Config.NUM_EPOCHS):
        model.train()
        train_loss = 0

        for inputs, features, s0, target_H in train_loader:
            inputs, features, s0, target_H = inputs.to(device), features.to(
                device), s0.to(device), target_H.to(device)

            optimizer.zero_grad()
            outputs = model(inputs, features, s0)  # 模型的輸出
            loss = criterion(outputs, target_H)  # 使用真實的 H(t) 計算損失
            loss.backward()
            optimizer.step()
            train_loss += loss.item()

        train_loss /= len(train_loader)
        train_losses.append(train_loss)  # **記錄 Train Loss**

        model.eval()
        val_loss = 0

        with torch.no_grad():
            for inputs, features, s0, target_H in valid_loader:
                inputs, features, s0, target_H = inputs.to(
                    device), features.to(device), s0.to(device), target_H.to(
                        device)
                outputs = model(inputs, features, s0)
                loss = criterion(outputs, target_H)
                val_loss += loss.item()

        val_loss /= len(valid_loader)
        val_losses.append(val_loss)  # **記錄 Validation Loss**

        print(
            f"Epoch {epoch+1}, Train Loss: {train_loss:.6f}, Validation Loss: {val_loss:.6f}"
        )

        # ======================================================繪製訓練情況======================================================

        if (epoch + 1) % plot_interval == 0:

            # 第一次產生固定的隨機索引
            if fixed_idx is None:
                batch_size_fix = 3
                fixed_idx = torch.randperm(batch_size_fix)[:train_show_sample]

            # # -------------------------設定圖表H(t)比較---------------------------------------

            # outputs = [fixed_idx, :downsample,
            #  0].detach().cpu().numpy()
            # targets_np = target_H[fixed_idx, :downsample,
            #                       0].detach().cpu().numpy()

            # plt.figure(figsize=(12, 6))

            # for i in range(outputs.shape[0]):  # 每一批數據繪製一個圖表
            #     plt.plot(outputs[i, :, 0],
            #              label=f"Pred: Sample {i+1}",
            #              linestyle='--',
            #              marker='o')
            #     plt.plot(targets[i, :, 0],
            #              label=f"Target: Sample {i+1}",
            #              linestyle='-',
            #              marker='x')

            # # 添加標題和標籤
            # plt.title(f"Compare - Epoch {epoch + 1}", fontsize=16)
            # plt.xlabel("Index", fontsize=14)
            # plt.ylabel("Value", fontsize=14)
            # plt.legend(loc="upper right", fontsize=12)
            # plt.grid(alpha=0.5)

            # # 顯示圖表
            # plt.show()
            # # -------------------------設定圖表H(t)比較 結束---------------------------------------

            # # -------------------------設定圖表B-H比較---------------------------------------
            # 取對應 sample
            outputs_np = outputs[fixed_idx, -downsample:,
                                 0].detach().cpu().numpy()
            targets_np = target_H[fixed_idx, -downsample:,
                                  0].detach().cpu().numpy()
            B_seq_np = inputs[fixed_idx, -downsample:,
                              0].detach().cpu().numpy()

            # 設定圖表
            plt.figure()

            for i in range(train_show_sample):  # 每一批數據繪製一個圖表
                plt.plot(outputs_np[i],
                         B_seq_np[i],
                         label=f"Pred: Sample {i+1}",
                         markersize=1)

                plt.plot(targets_np[i],
                         B_seq_np[i],
                         label=f"Target: Sample {i+1}",
                         alpha=0.5)

            # 添加標題和標籤
            plt.title(f"Compare - Epoch {epoch + 1}")
            plt.xlabel("Index")
            plt.ylabel("Value")
            plt.grid(alpha=0.5)
            plt.legend()
            figure_save_path1 = os.path.join(
                figure_save_base_path,
                f"Compare_Epoch {epoch + 1}.svg")  # 定義模型保存檔名

            plt.savefig(figure_save_path1)
            # 顯示圖表
            plt.show()
            # # -------------------------設定圖表B-H比較 END---------------------------------------
        # ======================================================繪製訓練情況  END ======================================================

        # ======================================================Early stop======================================================
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            torch.save(model.state_dict(), model_save_path)  # 保存最佳模型
            print(
                f"Saving model at epoch {epoch+1} with validation loss {val_loss:.6f}..."
            )
            patience_counter = 0
        else:
            patience_counter += 1

        if patience_counter >= Config.EARLY_STOPPING_PATIENCE:
            print("Early stopping triggered.")
            break

        # ======================================================Early stop======================================================

    print(f"Training complete. Best model saved at {model_save_path}.")

    # ==============================繪製 Train Loss 與 Validation Loss 圖==============================
    plt.figure(figsize=(10, 5))
    plt.plot(
        range(1,
              len(train_losses) + 1),
        train_losses,
        label="Train Loss",
    )
    plt.plot(range(1,
                   len(val_losses) + 1),
             val_losses,
             label="Validation Loss")

    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.title("Training & Validation Loss Curve")
    plt.legend()
    plt.grid(alpha=0.5)
    figure_save_path2 = os.path.join(figure_save_base_path,
                                     "Training_Loss_Curve.svg")  # 定義模型保存檔名
    plt.savefig(figure_save_path2)
    plt.show()
    # ==============================繪製 Train Loss 與 Validation Loss 圖 END==============================

    # ===================================使用最佳模型來產生驗證結果=============================
    model.load_state_dict(torch.load(model_save_path))  # 載入最佳模型
    model.eval()

    with torch.no_grad():
        for inputs, features, s0, target_H in valid_loader:
            inputs, features, s0, target_H = inputs.to(device), features.to(
                device), s0.to(device), target_H.to(device)

            outputs = model(inputs, features, s0)  # 使用最佳模型產生預測值
            break  # 只使用一批驗證數據進行可視化

    # 選取對應資料（index tensor 要先轉 list 才能 index numpy）
    outputs_np = outputs[fixed_idx, -downsample:, 0].detach().cpu().numpy()
    targets_np = target_H[fixed_idx, -downsample:, 0].detach().cpu().numpy()
    B_seq_np = inputs[fixed_idx, -downsample:, 0].detach().cpu().numpy()

    # 設定圖表
    plt.figure()

    for i in range(train_show_sample):  # 每一批數據繪製一個圖表
        plt.plot(outputs_np[i], B_seq_np[i], label=f"Pred: Sample {i+1}")

        plt.plot(targets_np[i],
                 B_seq_np[i],
                 label=f"Target: Sample {i+1}",
                 alpha=0.7)

    # 添加標題和標籤
    plt.title(f"Best Model - Predicted vs Target")
    plt.xlabel("Index")
    plt.ylabel("Value")
    plt.grid(alpha=0.5)
    plt.legend()
    figure_save_path3 = os.path.join(
        figure_save_base_path,
        "Best Model_Predicted vs Target.svg")  # 定義模型保存檔名
    plt.savefig(figure_save_path3)

    # ===================================使用最佳模型來產生驗證結果 END=============================

# %% [markdown]
# ### Start Train!!!

# %%
if __name__ == "__main__":

    data_B, data_F, data_T, data_H, data_Pcv, data_Hdc, data_N = load_dataset(
        material)

    train_loader, valid_loader, norm = get_dataloader(data_B, data_F, data_T,
                                                      data_H, data_N, data_Hdc,
                                                      data_Pcv)

    train_model(norm, train_loader, valid_loader)
# Out:
# "CH467160_Buck": [
#     [-0.0015205632662400603, 0.028872927650809288],
#     [-7.60919189453125, 158.39918518066406],
#     [2.0, 1.0],
#     [25.0, 1.0],
#     [0.0012219095369800925, 0.12914611399173737],
#     [1.8336955308914185, 0.7193894982337952],
#     [1239.43505859375, 699.09326171875],
#     [11.327028274536133, 2.208418846130371],
#     [4.7730841288284864e-06, 0.0005044770077802241],
# ]
# Number of parameters:  1176
# Epoch 1, Train Loss: 1.585582, Validation Loss: 1.286139
# Saving model at epoch 1 with validation loss 1.286139...
# Epoch 2, Train Loss: 1.038112, Validation Loss: 1.025437
# Saving model at epoch 2 with validation loss 1.025437...
# Epoch 3, Train Loss: 0.904105, Validation Loss: 0.957856
# Saving model at epoch 3 with validation loss 0.957856...
# Epoch 4, Train Loss: 0.836578, Validation Loss: 0.878850
# Saving model at epoch 4 with validation loss 0.878850...
# Epoch 5, Train Loss: 0.762849, Validation Loss: 0.820000
# Saving model at epoch 5 with validation loss 0.820000...
# Epoch 6, Train Loss: 0.742862, Validation Loss: 0.770801
# Saving model at epoch 6 with validation loss 0.770801...
# Epoch 7, Train Loss: 0.686390, Validation Loss: 0.720834
# Saving model at epoch 7 with validation loss 0.720834...
# Epoch 8, Train Loss: 0.646248, Validation Loss: 0.668364
# Saving model at epoch 8 with validation loss 0.668364...
# Epoch 9, Train Loss: 0.597099, Validation Loss: 0.613897
# Saving model at epoch 9 with validation loss 0.613897...
# Epoch 10, Train Loss: 0.548830, Validation Loss: 0.565944
# Saving model at epoch 10 with validation loss 0.565944...
# Epoch 11, Train Loss: 0.497677, Validation Loss: 0.515800
# Saving model at epoch 11 with validation loss 0.515800...
# Epoch 12, Train Loss: 0.443305, Validation Loss: 0.462932
# Saving model at epoch 12 with validation loss 0.462932...
# Epoch 13, Train Loss: 0.394654, Validation Loss: 0.403151
# Saving model at epoch 13 with validation loss 0.403151...
# Epoch 14, Train Loss: 0.323574, Validation Loss: 0.328091
# Saving model at epoch 14 with validation loss 0.328091...
# Epoch 15, Train Loss: 0.272681, Validation Loss: 0.271459
# Saving model at epoch 15 with validation loss 0.271459...
# Epoch 16, Train Loss: 0.218692, Validation Loss: 0.225988
# Saving model at epoch 16 with validation loss 0.225988...
# Epoch 17, Train Loss: 0.188701, Validation Loss: 0.188629
# Saving model at epoch 17 with validation loss 0.188629...
# Epoch 18, Train Loss: 0.157383, Validation Loss: 0.167252
# Saving model at epoch 18 with validation loss 0.167252...
# Epoch 19, Train Loss: 0.143104, Validation Loss: 0.145716
# Saving model at epoch 19 with validation loss 0.145716...
# Epoch 20, Train Loss: 0.120804, Validation Loss: 0.125234
# Saving model at epoch 20 with validation loss 0.125234...
# Epoch 21, Train Loss: 0.104459, Validation Loss: 0.112682
# Saving model at epoch 21 with validation loss 0.112682...
# Epoch 22, Train Loss: 0.093968, Validation Loss: 0.101449
# Saving model at epoch 22 with validation loss 0.101449...
# Epoch 23, Train Loss: 0.084369, Validation Loss: 0.091745
# Saving model at epoch 23 with validation loss 0.091745...
# Epoch 24, Train Loss: 0.075244, Validation Loss: 0.080714
# Saving model at epoch 24 with validation loss 0.080714...
# Epoch 25, Train Loss: 0.067007, Validation Loss: 0.070710
# Saving model at epoch 25 with validation loss 0.070710...
# Epoch 26, Train Loss: 0.058015, Validation Loss: 0.065220
# Saving model at epoch 26 with validation loss 0.065220...
# Epoch 27, Train Loss: 0.054533, Validation Loss: 0.060234
# Saving model at epoch 27 with validation loss 0.060234...
# Epoch 28, Train Loss: 0.048053, Validation Loss: 0.055460
# Saving model at epoch 28 with validation loss 0.055460...
# Epoch 29, Train Loss: 0.045350, Validation Loss: 0.051896
# Saving model at epoch 29 with validation loss 0.051896...
# Epoch 30, Train Loss: 0.041903, Validation Loss: 0.048402
# Saving model at epoch 30 with validation loss 0.048402...
# Epoch 31, Train Loss: 0.039284, Validation Loss: 0.045343
# Saving model at epoch 31 with validation loss 0.045343...
# Epoch 32, Train Loss: 0.036615, Validation Loss: 0.042460
# Saving model at epoch 32 with validation loss 0.042460...
# Epoch 33, Train Loss: 0.036494, Validation Loss: 0.039926
# Saving model at epoch 33 with validation loss 0.039926...
# Epoch 34, Train Loss: 0.032776, Validation Loss: 0.037749
# Saving model at epoch 34 with validation loss 0.037749...
# Epoch 35, Train Loss: 0.031172, Validation Loss: 0.035628
# Saving model at epoch 35 with validation loss 0.035628...
# Epoch 36, Train Loss: 0.028933, Validation Loss: 0.033355
# Saving model at epoch 36 with validation loss 0.033355...
# Epoch 37, Train Loss: 0.026842, Validation Loss: 0.031541
# Saving model at epoch 37 with validation loss 0.031541...
# Epoch 38, Train Loss: 0.025158, Validation Loss: 0.030267
# Saving model at epoch 38 with validation loss 0.030267...
# Epoch 39, Train Loss: 0.024484, Validation Loss: 0.028407
# Saving model at epoch 39 with validation loss 0.028407...
# Epoch 40, Train Loss: 0.024972, Validation Loss: 0.026735
# Saving model at epoch 40 with validation loss 0.026735...
# Epoch 41, Train Loss: 0.025800, Validation Loss: 0.025440
# Saving model at epoch 41 with validation loss 0.025440...
# Epoch 42, Train Loss: 0.022339, Validation Loss: 0.024915
# Saving model at epoch 42 with validation loss 0.024915...
# Epoch 43, Train Loss: 0.020143, Validation Loss: 0.023057
# Saving model at epoch 43 with validation loss 0.023057...
# Epoch 44, Train Loss: 0.018971, Validation Loss: 0.022335
# Saving model at epoch 44 with validation loss 0.022335...
# Epoch 45, Train Loss: 0.017822, Validation Loss: 0.020220
# Saving model at epoch 45 with validation loss 0.020220...
# Epoch 46, Train Loss: 0.016363, Validation Loss: 0.019017
# Saving model at epoch 46 with validation loss 0.019017...
# Epoch 47, Train Loss: 0.016591, Validation Loss: 0.018558
# Saving model at epoch 47 with validation loss 0.018558...
# Epoch 48, Train Loss: 0.014410, Validation Loss: 0.017039
# Saving model at epoch 48 with validation loss 0.017039...
# Epoch 49, Train Loss: 0.013622, Validation Loss: 0.016212
# Saving model at epoch 49 with validation loss 0.016212...
# Epoch 50, Train Loss: 0.012792, Validation Loss: 0.015298
# Saving model at epoch 50 with validation loss 0.015298...
# Epoch 51, Train Loss: 0.012224, Validation Loss: 0.014274
# Saving model at epoch 51 with validation loss 0.014274...
# Epoch 52, Train Loss: 0.011206, Validation Loss: 0.014470
# Epoch 53, Train Loss: 0.011131, Validation Loss: 0.012686
# Saving model at epoch 53 with validation loss 0.012686...
# Epoch 54, Train Loss: 0.010288, Validation Loss: 0.013881
# Epoch 55, Train Loss: 0.009873, Validation Loss: 0.012283
# Saving model at epoch 55 with validation loss 0.012283...
# Epoch 56, Train Loss: 0.010021, Validation Loss: 0.011131
# Saving model at epoch 56 with validation loss 0.011131...
# Epoch 57, Train Loss: 0.008549, Validation Loss: 0.010582
# Saving model at epoch 57 with validation loss 0.010582...
# Epoch 58, Train Loss: 0.008402, Validation Loss: 0.009951
# Saving model at epoch 58 with validation loss 0.009951...
# Epoch 59, Train Loss: 0.007892, Validation Loss: 0.009899
# Saving model at epoch 59 with validation loss 0.009899...
# Epoch 60, Train Loss: 0.007527, Validation Loss: 0.009317
# Saving model at epoch 60 with validation loss 0.009317...
# Epoch 61, Train Loss: 0.007067, Validation Loss: 0.008908
# Saving model at epoch 61 with validation loss 0.008908...
# Epoch 62, Train Loss: 0.006968, Validation Loss: 0.008458
# Saving model at epoch 62 with validation loss 0.008458...
# Epoch 63, Train Loss: 0.006901, Validation Loss: 0.008297
# Saving model at epoch 63 with validation loss 0.008297...
# Epoch 64, Train Loss: 0.006756, Validation Loss: 0.008258
# Saving model at epoch 64 with validation loss 0.008258...
# Epoch 65, Train Loss: 0.006085, Validation Loss: 0.007508
# Saving model at epoch 65 with validation loss 0.007508...
# Epoch 66, Train Loss: 0.006044, Validation Loss: 0.007320
# Saving model at epoch 66 with validation loss 0.007320...
# Epoch 67, Train Loss: 0.005959, Validation Loss: 0.007725
# Epoch 68, Train Loss: 0.005822, Validation Loss: 0.007049
# Saving model at epoch 68 with validation loss 0.007049...
# Epoch 69, Train Loss: 0.005266, Validation Loss: 0.006636
# Saving model at epoch 69 with validation loss 0.006636...
# Epoch 70, Train Loss: 0.005069, Validation Loss: 0.006499
# Saving model at epoch 70 with validation loss 0.006499...
# Epoch 71, Train Loss: 0.005095, Validation Loss: 0.006181
# Saving model at epoch 71 with validation loss 0.006181...
# Epoch 72, Train Loss: 0.004838, Validation Loss: 0.006072
# Saving model at epoch 72 with validation loss 0.006072...
# Epoch 73, Train Loss: 0.004531, Validation Loss: 0.005816
# Saving model at epoch 73 with validation loss 0.005816...
# Epoch 74, Train Loss: 0.004490, Validation Loss: 0.005698
# Saving model at epoch 74 with validation loss 0.005698...
# Epoch 75, Train Loss: 0.004597, Validation Loss: 0.005539
# Saving model at epoch 75 with validation loss 0.005539...
# Epoch 76, Train Loss: 0.004425, Validation Loss: 0.005340
# Saving model at epoch 76 with validation loss 0.005340...
# Epoch 77, Train Loss: 0.004437, Validation Loss: 0.005158
# Saving model at epoch 77 with validation loss 0.005158...
# Epoch 78, Train Loss: 0.003964, Validation Loss: 0.005050
# Saving model at epoch 78 with validation loss 0.005050...
# Epoch 79, Train Loss: 0.003918, Validation Loss: 0.005055
# Epoch 80, Train Loss: 0.003710, Validation Loss: 0.004916
# Saving model at epoch 80 with validation loss 0.004916...
# Epoch 81, Train Loss: 0.003909, Validation Loss: 0.004598
# Saving model at epoch 81 with validation loss 0.004598...
# Epoch 82, Train Loss: 0.003482, Validation Loss: 0.004594
# Saving model at epoch 82 with validation loss 0.004594...
# Epoch 83, Train Loss: 0.003546, Validation Loss: 0.004322
# Saving model at epoch 83 with validation loss 0.004322...
# Epoch 84, Train Loss: 0.003279, Validation Loss: 0.004235
# Saving model at epoch 84 with validation loss 0.004235...
# Epoch 85, Train Loss: 0.003221, Validation Loss: 0.004096
# Saving model at epoch 85 with validation loss 0.004096...
# Epoch 86, Train Loss: 0.003315, Validation Loss: 0.004067
# Saving model at epoch 86 with validation loss 0.004067...
# Epoch 87, Train Loss: 0.003339, Validation Loss: 0.003939
# Saving model at epoch 87 with validation loss 0.003939...
# Epoch 88, Train Loss: 0.003162, Validation Loss: 0.003974
# Epoch 89, Train Loss: 0.003232, Validation Loss: 0.003895
# Saving model at epoch 89 with validation loss 0.003895...
# Epoch 90, Train Loss: 0.003020, Validation Loss: 0.003770
# Saving model at epoch 90 with validation loss 0.003770...
# Epoch 91, Train Loss: 0.003107, Validation Loss: 0.003574
# Saving model at epoch 91 with validation loss 0.003574...
# Epoch 92, Train Loss: 0.002752, Validation Loss: 0.003977
# Epoch 93, Train Loss: 0.003082, Validation Loss: 0.003522
# Saving model at epoch 93 with validation loss 0.003522...
# Epoch 94, Train Loss: 0.003748, Validation Loss: 0.004278
# Epoch 95, Train Loss: 0.003365, Validation Loss: 0.003611
# Epoch 96, Train Loss: 0.002796, Validation Loss: 0.003315
# Saving model at epoch 96 with validation loss 0.003315...
# Epoch 97, Train Loss: 0.002680, Validation Loss: 0.003403
# Epoch 98, Train Loss: 0.002628, Validation Loss: 0.003138
# Saving model at epoch 98 with validation loss 0.003138...
# Epoch 99, Train Loss: 0.002488, Validation Loss: 0.003719
# Epoch 100, Train Loss: 0.002735, Validation Loss: 0.003549
# Epoch 101, Train Loss: 0.002592, Validation Loss: 0.002996
# Saving model at epoch 101 with validation loss 0.002996...
# Epoch 102, Train Loss: 0.002427, Validation Loss: 0.002982
# Saving model at epoch 102 with validation loss 0.002982...
# Epoch 103, Train Loss: 0.002323, Validation Loss: 0.002959
# Saving model at epoch 103 with validation loss 0.002959...
# Epoch 104, Train Loss: 0.002287, Validation Loss: 0.002814
# Saving model at epoch 104 with validation loss 0.002814...
# Epoch 105, Train Loss: 0.002250, Validation Loss: 0.002759
# Saving model at epoch 105 with validation loss 0.002759...
# Epoch 106, Train Loss: 0.002152, Validation Loss: 0.002739
# Saving model at epoch 106 with validation loss 0.002739...
# Epoch 107, Train Loss: 0.002139, Validation Loss: 0.002681
# Saving model at epoch 107 with validation loss 0.002681...
# Epoch 108, Train Loss: 0.002332, Validation Loss: 0.002919
# Epoch 109, Train Loss: 0.002427, Validation Loss: 0.003332
# Epoch 110, Train Loss: 0.002464, Validation Loss: 0.002578
# Saving model at epoch 110 with validation loss 0.002578...
# Epoch 111, Train Loss: 0.002099, Validation Loss: 0.002798
# Epoch 112, Train Loss: 0.002163, Validation Loss: 0.002541
# Saving model at epoch 112 with validation loss 0.002541...
# Epoch 113, Train Loss: 0.002024, Validation Loss: 0.002472
# Saving model at epoch 113 with validation loss 0.002472...
# Epoch 114, Train Loss: 0.001972, Validation Loss: 0.002428
# Saving model at epoch 114 with validation loss 0.002428...
# Epoch 115, Train Loss: 0.001966, Validation Loss: 0.002441
# Epoch 116, Train Loss: 0.001930, Validation Loss: 0.002429
# Epoch 117, Train Loss: 0.002044, Validation Loss: 0.002334
# Saving model at epoch 117 with validation loss 0.002334...
# Epoch 118, Train Loss: 0.001928, Validation Loss: 0.002479
# Epoch 119, Train Loss: 0.002023, Validation Loss: 0.002815
# Epoch 120, Train Loss: 0.002079, Validation Loss: 0.002385
# Epoch 121, Train Loss: 0.001945, Validation Loss: 0.002477
# Epoch 122, Train Loss: 0.001930, Validation Loss: 0.002585
# Epoch 123, Train Loss: 0.001951, Validation Loss: 0.002292
# Saving model at epoch 123 with validation loss 0.002292...
# Epoch 124, Train Loss: 0.001851, Validation Loss: 0.002171
# Saving model at epoch 124 with validation loss 0.002171...
# Epoch 125, Train Loss: 0.001751, Validation Loss: 0.002248
# Epoch 126, Train Loss: 0.001907, Validation Loss: 0.002136
# Saving model at epoch 126 with validation loss 0.002136...
# Epoch 127, Train Loss: 0.001736, Validation Loss: 0.002171
# Epoch 128, Train Loss: 0.001768, Validation Loss: 0.002173
# Epoch 129, Train Loss: 0.001724, Validation Loss: 0.002097
# Saving model at epoch 129 with validation loss 0.002097...
# Epoch 130, Train Loss: 0.001872, Validation Loss: 0.002176
# Epoch 131, Train Loss: 0.001804, Validation Loss: 0.002152
# Epoch 132, Train Loss: 0.001780, Validation Loss: 0.002342
# Epoch 133, Train Loss: 0.001945, Validation Loss: 0.002139
# Epoch 134, Train Loss: 0.001753, Validation Loss: 0.002028
# Saving model at epoch 134 with validation loss 0.002028...
# Epoch 135, Train Loss: 0.001603, Validation Loss: 0.001967
# Saving model at epoch 135 with validation loss 0.001967...
# Epoch 136, Train Loss: 0.001595, Validation Loss: 0.001983
# Epoch 137, Train Loss: 0.001630, Validation Loss: 0.001923
# Saving model at epoch 137 with validation loss 0.001923...
# Epoch 138, Train Loss: 0.001670, Validation Loss: 0.002114
# Epoch 139, Train Loss: 0.001735, Validation Loss: 0.001880
# Saving model at epoch 139 with validation loss 0.001880...
# Epoch 140, Train Loss: 0.001642, Validation Loss: 0.001897
# Epoch 141, Train Loss: 0.001510, Validation Loss: 0.001895
# Epoch 142, Train Loss: 0.001588, Validation Loss: 0.002235
# Epoch 143, Train Loss: 0.001656, Validation Loss: 0.001858
# Saving model at epoch 143 with validation loss 0.001858...
# Epoch 144, Train Loss: 0.001548, Validation Loss: 0.001813
# Saving model at epoch 144 with validation loss 0.001813...
# Epoch 145, Train Loss: 0.001502, Validation Loss: 0.001920
# Epoch 146, Train Loss: 0.001497, Validation Loss: 0.001775
# Saving model at epoch 146 with validation loss 0.001775...
# Epoch 147, Train Loss: 0.001502, Validation Loss: 0.001812
# Epoch 148, Train Loss: 0.001488, Validation Loss: 0.001779
# Epoch 149, Train Loss: 0.001593, Validation Loss: 0.002107
# Epoch 150, Train Loss: 0.001668, Validation Loss: 0.001752
# Saving model at epoch 150 with validation loss 0.001752...
# Epoch 151, Train Loss: 0.001670, Validation Loss: 0.001765
# Epoch 152, Train Loss: 0.001511, Validation Loss: 0.001857
# Epoch 153, Train Loss: 0.001484, Validation Loss: 0.001738
# Saving model at epoch 153 with validation loss 0.001738...
# Epoch 154, Train Loss: 0.001439, Validation Loss: 0.001744
# Epoch 155, Train Loss: 0.001475, Validation Loss: 0.001837
# Epoch 156, Train Loss: 0.001658, Validation Loss: 0.001734
# Saving model at epoch 156 with validation loss 0.001734...
# Epoch 157, Train Loss: 0.001418, Validation Loss: 0.001661
# Saving model at epoch 157 with validation loss 0.001661...
# Epoch 158, Train Loss: 0.001434, Validation Loss: 0.001657
# Saving model at epoch 158 with validation loss 0.001657...
# Epoch 159, Train Loss: 0.001534, Validation Loss: 0.001754
# Epoch 160, Train Loss: 0.001774, Validation Loss: 0.001687
# Epoch 161, Train Loss: 0.001597, Validation Loss: 0.001993
# Epoch 162, Train Loss: 0.001457, Validation Loss: 0.001614
# Saving model at epoch 162 with validation loss 0.001614...
# Epoch 163, Train Loss: 0.001443, Validation Loss: 0.001669
# Epoch 164, Train Loss: 0.001557, Validation Loss: 0.001708
# Epoch 165, Train Loss: 0.001358, Validation Loss: 0.001597
# Saving model at epoch 165 with validation loss 0.001597...
# Epoch 166, Train Loss: 0.001371, Validation Loss: 0.001599
# Epoch 167, Train Loss: 0.001383, Validation Loss: 0.001546
# Saving model at epoch 167 with validation loss 0.001546...
# Epoch 168, Train Loss: 0.001313, Validation Loss: 0.001581
# Epoch 169, Train Loss: 0.001421, Validation Loss: 0.002354
# Epoch 170, Train Loss: 0.002319, Validation Loss: 0.001991
# Epoch 171, Train Loss: 0.001904, Validation Loss: 0.002113
# Epoch 172, Train Loss: 0.001410, Validation Loss: 0.001576
# Epoch 173, Train Loss: 0.001335, Validation Loss: 0.001535
# Saving model at epoch 173 with validation loss 0.001535...
# Epoch 174, Train Loss: 0.001331, Validation Loss: 0.001609
# Epoch 175, Train Loss: 0.001312, Validation Loss: 0.001509
# Saving model at epoch 175 with validation loss 0.001509...
# Epoch 176, Train Loss: 0.001341, Validation Loss: 0.001746
# Epoch 177, Train Loss: 0.001413, Validation Loss: 0.001483
# Saving model at epoch 177 with validation loss 0.001483...
# Epoch 178, Train Loss: 0.001309, Validation Loss: 0.002103
# Epoch 179, Train Loss: 0.001548, Validation Loss: 0.001730
# Epoch 180, Train Loss: 0.001490, Validation Loss: 0.001464
# Saving model at epoch 180 with validation loss 0.001464...
# Epoch 181, Train Loss: 0.001430, Validation Loss: 0.001458
# Saving model at epoch 181 with validation loss 0.001458...
# Epoch 182, Train Loss: 0.001239, Validation Loss: 0.001452
# Saving model at epoch 182 with validation loss 0.001452...
# Epoch 183, Train Loss: 0.001247, Validation Loss: 0.001603
# Epoch 184, Train Loss: 0.001378, Validation Loss: 0.001736
# Epoch 185, Train Loss: 0.001351, Validation Loss: 0.001518
# Epoch 186, Train Loss: 0.001305, Validation Loss: 0.001478
# Epoch 187, Train Loss: 0.001296, Validation Loss: 0.001892
# Epoch 188, Train Loss: 0.001472, Validation Loss: 0.001422
# Saving model at epoch 188 with validation loss 0.001422...
# Epoch 189, Train Loss: 0.001329, Validation Loss: 0.001470
# Epoch 190, Train Loss: 0.001258, Validation Loss: 0.001410
# Saving model at epoch 190 with validation loss 0.001410...
# Epoch 191, Train Loss: 0.001175, Validation Loss: 0.001415
# Epoch 192, Train Loss: 0.001206, Validation Loss: 0.001521
# Epoch 193, Train Loss: 0.001299, Validation Loss: 0.001418
# Epoch 194, Train Loss: 0.001270, Validation Loss: 0.001356
# Saving model at epoch 194 with validation loss 0.001356...
# Epoch 195, Train Loss: 0.001191, Validation Loss: 0.001471
# Epoch 196, Train Loss: 0.001241, Validation Loss: 0.001360
# Epoch 197, Train Loss: 0.001283, Validation Loss: 0.001569
# Epoch 198, Train Loss: 0.001367, Validation Loss: 0.001701
# Epoch 199, Train Loss: 0.001306, Validation Loss: 0.001488
# Epoch 200, Train Loss: 0.001208, Validation Loss: 0.001346
# Saving model at epoch 200 with validation loss 0.001346...
# Epoch 201, Train Loss: 0.001124, Validation Loss: 0.001318
# Saving model at epoch 201 with validation loss 0.001318...
# Epoch 202, Train Loss: 0.001142, Validation Loss: 0.001288
# Saving model at epoch 202 with validation loss 0.001288...
# Epoch 203, Train Loss: 0.001192, Validation Loss: 0.001569
# Epoch 204, Train Loss: 0.001217, Validation Loss: 0.001263
# Saving model at epoch 204 with validation loss 0.001263...
# Epoch 205, Train Loss: 0.001189, Validation Loss: 0.001322
# Epoch 206, Train Loss: 0.001179, Validation Loss: 0.001257
# Saving model at epoch 206 with validation loss 0.001257...
# Epoch 207, Train Loss: 0.001099, Validation Loss: 0.001250
# Saving model at epoch 207 with validation loss 0.001250...
# Epoch 208, Train Loss: 0.001142, Validation Loss: 0.001302
# Epoch 209, Train Loss: 0.001087, Validation Loss: 0.001580
# Epoch 210, Train Loss: 0.001380, Validation Loss: 0.001634
# Epoch 211, Train Loss: 0.001294, Validation Loss: 0.001736
# Epoch 212, Train Loss: 0.001360, Validation Loss: 0.001407
# Epoch 213, Train Loss: 0.001146, Validation Loss: 0.001280
# Epoch 214, Train Loss: 0.001113, Validation Loss: 0.001257
# Epoch 215, Train Loss: 0.001087, Validation Loss: 0.001269
# Epoch 216, Train Loss: 0.001163, Validation Loss: 0.001200
# Saving model at epoch 216 with validation loss 0.001200...
# Epoch 217, Train Loss: 0.001166, Validation Loss: 0.001260
# Epoch 218, Train Loss: 0.001124, Validation Loss: 0.001259
# Epoch 219, Train Loss: 0.001136, Validation Loss: 0.001363
# Epoch 220, Train Loss: 0.001217, Validation Loss: 0.001520
# Epoch 221, Train Loss: 0.001225, Validation Loss: 0.001408
# Epoch 222, Train Loss: 0.001098, Validation Loss: 0.001190
# Saving model at epoch 222 with validation loss 0.001190...
# Epoch 223, Train Loss: 0.001063, Validation Loss: 0.001196
# Epoch 224, Train Loss: 0.001080, Validation Loss: 0.001394
# Epoch 225, Train Loss: 0.001183, Validation Loss: 0.001421
# Epoch 226, Train Loss: 0.001351, Validation Loss: 0.001329
# Epoch 227, Train Loss: 0.001088, Validation Loss: 0.001260
# Epoch 228, Train Loss: 0.001341, Validation Loss: 0.001880
# Epoch 229, Train Loss: 0.001274, Validation Loss: 0.001241
# Epoch 230, Train Loss: 0.001074, Validation Loss: 0.001317
# Epoch 231, Train Loss: 0.001081, Validation Loss: 0.001247
# Epoch 232, Train Loss: 0.001076, Validation Loss: 0.001165
# Saving model at epoch 232 with validation loss 0.001165...
# Epoch 233, Train Loss: 0.001010, Validation Loss: 0.001120
# Saving model at epoch 233 with validation loss 0.001120...
# Epoch 234, Train Loss: 0.001095, Validation Loss: 0.001252
# Epoch 235, Train Loss: 0.001350, Validation Loss: 0.003391
# Epoch 236, Train Loss: 0.001833, Validation Loss: 0.002129
# Epoch 237, Train Loss: 0.001314, Validation Loss: 0.001163
# Epoch 238, Train Loss: 0.001040, Validation Loss: 0.001207
# Epoch 239, Train Loss: 0.000994, Validation Loss: 0.001106
# Saving model at epoch 239 with validation loss 0.001106...
# Epoch 240, Train Loss: 0.001018, Validation Loss: 0.001101
# Saving model at epoch 240 with validation loss 0.001101...
# Epoch 241, Train Loss: 0.000961, Validation Loss: 0.001122
# Epoch 242, Train Loss: 0.001054, Validation Loss: 0.002211
# Epoch 243, Train Loss: 0.001748, Validation Loss: 0.001255
# Epoch 244, Train Loss: 0.001032, Validation Loss: 0.001118
# Epoch 245, Train Loss: 0.000970, Validation Loss: 0.001078
# Saving model at epoch 245 with validation loss 0.001078...
# Epoch 246, Train Loss: 0.000937, Validation Loss: 0.001074
# Saving model at epoch 246 with validation loss 0.001074...
# Epoch 247, Train Loss: 0.000949, Validation Loss: 0.001119
# Epoch 248, Train Loss: 0.000991, Validation Loss: 0.001077
# Epoch 249, Train Loss: 0.000942, Validation Loss: 0.001117
# Epoch 250, Train Loss: 0.000944, Validation Loss: 0.001078
# Epoch 251, Train Loss: 0.001002, Validation Loss: 0.001175
# Epoch 252, Train Loss: 0.000971, Validation Loss: 0.001043
# Saving model at epoch 252 with validation loss 0.001043...
# Epoch 253, Train Loss: 0.000917, Validation Loss: 0.001055
# Epoch 254, Train Loss: 0.000979, Validation Loss: 0.001063
# Epoch 255, Train Loss: 0.000921, Validation Loss: 0.001071
# Epoch 256, Train Loss: 0.000906, Validation Loss: 0.001061
# Epoch 257, Train Loss: 0.000936, Validation Loss: 0.001064
# Epoch 258, Train Loss: 0.000937, Validation Loss: 0.001104
# Epoch 259, Train Loss: 0.000952, Validation Loss: 0.001208
# Epoch 260, Train Loss: 0.000990, Validation Loss: 0.001169
# Epoch 261, Train Loss: 0.000965, Validation Loss: 0.001359
# Epoch 262, Train Loss: 0.001045, Validation Loss: 0.001575
# Epoch 263, Train Loss: 0.001322, Validation Loss: 0.001323
# Epoch 264, Train Loss: 0.000977, Validation Loss: 0.001144
# Epoch 265, Train Loss: 0.000949, Validation Loss: 0.001060
# Epoch 266, Train Loss: 0.000915, Validation Loss: 0.001237
# Epoch 267, Train Loss: 0.001169, Validation Loss: 0.001219
# Epoch 268, Train Loss: 0.000977, Validation Loss: 0.001112
# Epoch 269, Train Loss: 0.000990, Validation Loss: 0.001285
# Epoch 270, Train Loss: 0.000986, Validation Loss: 0.000967
# Saving model at epoch 270 with validation loss 0.000967...
# Epoch 271, Train Loss: 0.000866, Validation Loss: 0.000997
# Epoch 272, Train Loss: 0.001126, Validation Loss: 0.001616
# Epoch 273, Train Loss: 0.001251, Validation Loss: 0.001368
# Epoch 274, Train Loss: 0.001084, Validation Loss: 0.001007
# Epoch 275, Train Loss: 0.000915, Validation Loss: 0.000948
# Saving model at epoch 275 with validation loss 0.000948...
# Epoch 276, Train Loss: 0.000914, Validation Loss: 0.001296
# Epoch 277, Train Loss: 0.000979, Validation Loss: 0.001095
# Epoch 278, Train Loss: 0.000905, Validation Loss: 0.000945
# Saving model at epoch 278 with validation loss 0.000945...
# Epoch 279, Train Loss: 0.000828, Validation Loss: 0.001082
# Epoch 280, Train Loss: 0.000935, Validation Loss: 0.001277
# Epoch 281, Train Loss: 0.000924, Validation Loss: 0.000972
# Epoch 282, Train Loss: 0.000831, Validation Loss: 0.000944
# Saving model at epoch 282 with validation loss 0.000944...
# Epoch 283, Train Loss: 0.000821, Validation Loss: 0.000956
# Epoch 284, Train Loss: 0.000807, Validation Loss: 0.000916
# Saving model at epoch 284 with validation loss 0.000916...
# Epoch 285, Train Loss: 0.000799, Validation Loss: 0.001030
# Epoch 286, Train Loss: 0.000854, Validation Loss: 0.000916
# Saving model at epoch 286 with validation loss 0.000916...
# Epoch 287, Train Loss: 0.000814, Validation Loss: 0.001082
# Epoch 288, Train Loss: 0.001086, Validation Loss: 0.001599
# Epoch 289, Train Loss: 0.000937, Validation Loss: 0.000918
# Epoch 290, Train Loss: 0.000827, Validation Loss: 0.000900
# Saving model at epoch 290 with validation loss 0.000900...
# Epoch 291, Train Loss: 0.000811, Validation Loss: 0.001005
# Epoch 292, Train Loss: 0.000787, Validation Loss: 0.000897
# Saving model at epoch 292 with validation loss 0.000897...
# Epoch 293, Train Loss: 0.000794, Validation Loss: 0.001002
# Epoch 294, Train Loss: 0.000878, Validation Loss: 0.001022
# Epoch 295, Train Loss: 0.000843, Validation Loss: 0.000919
# Epoch 296, Train Loss: 0.000870, Validation Loss: 0.001030
# Epoch 297, Train Loss: 0.000872, Validation Loss: 0.000959
# Epoch 298, Train Loss: 0.000911, Validation Loss: 0.000899
# Epoch 299, Train Loss: 0.000786, Validation Loss: 0.000857
# Saving model at epoch 299 with validation loss 0.000857...
# Epoch 300, Train Loss: 0.000799, Validation Loss: 0.001138
# Epoch 301, Train Loss: 0.001169, Validation Loss: 0.001736
# Epoch 302, Train Loss: 0.001384, Validation Loss: 0.000981
# Epoch 303, Train Loss: 0.001053, Validation Loss: 0.000980
# Epoch 304, Train Loss: 0.000805, Validation Loss: 0.000912
# Epoch 305, Train Loss: 0.000799, Validation Loss: 0.001029
# Epoch 306, Train Loss: 0.000801, Validation Loss: 0.000952
# Epoch 307, Train Loss: 0.000830, Validation Loss: 0.000892
# Epoch 308, Train Loss: 0.000800, Validation Loss: 0.001111
# Epoch 309, Train Loss: 0.000813, Validation Loss: 0.000872
# Epoch 310, Train Loss: 0.001109, Validation Loss: 0.001368
# Epoch 311, Train Loss: 0.001027, Validation Loss: 0.000995
# Epoch 312, Train Loss: 0.000856, Validation Loss: 0.000834
# Saving model at epoch 312 with validation loss 0.000834...
# Epoch 313, Train Loss: 0.000792, Validation Loss: 0.000980
# Epoch 314, Train Loss: 0.000944, Validation Loss: 0.000999
# Epoch 315, Train Loss: 0.000791, Validation Loss: 0.000895
# Epoch 316, Train Loss: 0.000731, Validation Loss: 0.000817
# Saving model at epoch 316 with validation loss 0.000817...
# Epoch 317, Train Loss: 0.000756, Validation Loss: 0.000838
# Epoch 318, Train Loss: 0.000719, Validation Loss: 0.000820
# Epoch 319, Train Loss: 0.000703, Validation Loss: 0.000806
# Saving model at epoch 319 with validation loss 0.000806...
# Epoch 320, Train Loss: 0.000705, Validation Loss: 0.000786
# Saving model at epoch 320 with validation loss 0.000786...
# Epoch 321, Train Loss: 0.000684, Validation Loss: 0.000801
# Epoch 322, Train Loss: 0.000684, Validation Loss: 0.000775
# Saving model at epoch 322 with validation loss 0.000775...
# Epoch 323, Train Loss: 0.000684, Validation Loss: 0.000785
# Epoch 324, Train Loss: 0.000741, Validation Loss: 0.001081
# Epoch 325, Train Loss: 0.000770, Validation Loss: 0.000877
# Epoch 326, Train Loss: 0.000686, Validation Loss: 0.000770
# Saving model at epoch 326 with validation loss 0.000770...
# Epoch 327, Train Loss: 0.000654, Validation Loss: 0.000844
# Epoch 328, Train Loss: 0.000825, Validation Loss: 0.000787
# Epoch 329, Train Loss: 0.000663, Validation Loss: 0.000766
# Saving model at epoch 329 with validation loss 0.000766...
# Epoch 330, Train Loss: 0.000684, Validation Loss: 0.000792
# Epoch 331, Train Loss: 0.000675, Validation Loss: 0.000764
# Saving model at epoch 331 with validation loss 0.000764...
# Epoch 332, Train Loss: 0.000701, Validation Loss: 0.000758
# Saving model at epoch 332 with validation loss 0.000758...
# Epoch 333, Train Loss: 0.000683, Validation Loss: 0.000734
# Saving model at epoch 333 with validation loss 0.000734...
# Epoch 334, Train Loss: 0.000636, Validation Loss: 0.000839
# Epoch 335, Train Loss: 0.000661, Validation Loss: 0.000748
# Epoch 336, Train Loss: 0.000714, Validation Loss: 0.001082
# Epoch 337, Train Loss: 0.000747, Validation Loss: 0.000817
# Epoch 338, Train Loss: 0.000947, Validation Loss: 0.000853
# Epoch 339, Train Loss: 0.000904, Validation Loss: 0.000760
# Epoch 340, Train Loss: 0.000743, Validation Loss: 0.000747
# Epoch 341, Train Loss: 0.000891, Validation Loss: 0.000965
# Epoch 342, Train Loss: 0.000686, Validation Loss: 0.001238
# Epoch 343, Train Loss: 0.001654, Validation Loss: 0.000994
# Epoch 344, Train Loss: 0.001065, Validation Loss: 0.001324
# Epoch 345, Train Loss: 0.001105, Validation Loss: 0.000805
# Epoch 346, Train Loss: 0.000740, Validation Loss: 0.000881
# Epoch 347, Train Loss: 0.000781, Validation Loss: 0.000714
# Saving model at epoch 347 with validation loss 0.000714...
# Epoch 348, Train Loss: 0.000680, Validation Loss: 0.001053
# Epoch 349, Train Loss: 0.000769, Validation Loss: 0.000734
# Epoch 350, Train Loss: 0.000697, Validation Loss: 0.000728
# Epoch 351, Train Loss: 0.000680, Validation Loss: 0.000857
# Epoch 352, Train Loss: 0.000638, Validation Loss: 0.000724
# Epoch 353, Train Loss: 0.000606, Validation Loss: 0.000708
# Saving model at epoch 353 with validation loss 0.000708...
# Epoch 354, Train Loss: 0.000648, Validation Loss: 0.000808
# Epoch 355, Train Loss: 0.000674, Validation Loss: 0.000826
# Epoch 356, Train Loss: 0.001061, Validation Loss: 0.000902
# Epoch 357, Train Loss: 0.001096, Validation Loss: 0.000955
# Epoch 358, Train Loss: 0.000641, Validation Loss: 0.000743
# Epoch 359, Train Loss: 0.000610, Validation Loss: 0.000737
# Epoch 360, Train Loss: 0.000585, Validation Loss: 0.000715
# Epoch 361, Train Loss: 0.000627, Validation Loss: 0.000741
# Epoch 362, Train Loss: 0.000625, Validation Loss: 0.000779
# Epoch 363, Train Loss: 0.000654, Validation Loss: 0.000699
# Saving model at epoch 363 with validation loss 0.000699...
# Epoch 364, Train Loss: 0.000720, Validation Loss: 0.000876
# Epoch 365, Train Loss: 0.000783, Validation Loss: 0.000707
# Epoch 366, Train Loss: 0.000718, Validation Loss: 0.000727
# Epoch 367, Train Loss: 0.000580, Validation Loss: 0.000739
# Epoch 368, Train Loss: 0.000619, Validation Loss: 0.000689
# Saving model at epoch 368 with validation loss 0.000689...
# Epoch 369, Train Loss: 0.000577, Validation Loss: 0.000686
# Saving model at epoch 369 with validation loss 0.000686...
# Epoch 370, Train Loss: 0.000602, Validation Loss: 0.000689
# Epoch 371, Train Loss: 0.000595, Validation Loss: 0.000669
# Saving model at epoch 371 with validation loss 0.000669...
# Epoch 372, Train Loss: 0.000572, Validation Loss: 0.000671
# Epoch 373, Train Loss: 0.000567, Validation Loss: 0.000656
# Saving model at epoch 373 with validation loss 0.000656...
# Epoch 374, Train Loss: 0.000550, Validation Loss: 0.000671
# Epoch 375, Train Loss: 0.000560, Validation Loss: 0.000641
# Saving model at epoch 375 with validation loss 0.000641...
# Epoch 376, Train Loss: 0.000552, Validation Loss: 0.000691
# Epoch 377, Train Loss: 0.000607, Validation Loss: 0.001178
# Epoch 378, Train Loss: 0.000773, Validation Loss: 0.000664
# Epoch 379, Train Loss: 0.000693, Validation Loss: 0.000665
# Epoch 380, Train Loss: 0.000562, Validation Loss: 0.000998
# Epoch 381, Train Loss: 0.000836, Validation Loss: 0.000636
# Saving model at epoch 381 with validation loss 0.000636...
# Epoch 382, Train Loss: 0.000775, Validation Loss: 0.001025
# Epoch 383, Train Loss: 0.000769, Validation Loss: 0.000840
# Epoch 384, Train Loss: 0.000596, Validation Loss: 0.000625
# Saving model at epoch 384 with validation loss 0.000625...
# Epoch 385, Train Loss: 0.000557, Validation Loss: 0.000723
# Epoch 386, Train Loss: 0.000613, Validation Loss: 0.000698
# Epoch 387, Train Loss: 0.000565, Validation Loss: 0.000695
# Epoch 388, Train Loss: 0.000581, Validation Loss: 0.000706
# Epoch 389, Train Loss: 0.000603, Validation Loss: 0.001377
# Epoch 390, Train Loss: 0.000825, Validation Loss: 0.000620
# Saving model at epoch 390 with validation loss 0.000620...
# Epoch 391, Train Loss: 0.000628, Validation Loss: 0.000653
# Epoch 392, Train Loss: 0.000576, Validation Loss: 0.000683
# Epoch 393, Train Loss: 0.000551, Validation Loss: 0.000695
# Epoch 394, Train Loss: 0.000572, Validation Loss: 0.000633
# Epoch 395, Train Loss: 0.000512, Validation Loss: 0.000625
# Epoch 396, Train Loss: 0.000505, Validation Loss: 0.000623
# Epoch 397, Train Loss: 0.000540, Validation Loss: 0.000666
# Epoch 398, Train Loss: 0.000535, Validation Loss: 0.000636
# Epoch 399, Train Loss: 0.000537, Validation Loss: 0.000599
# Saving model at epoch 399 with validation loss 0.000599...
# Epoch 400, Train Loss: 0.000532, Validation Loss: 0.000602
# Epoch 401, Train Loss: 0.000686, Validation Loss: 0.000609
# Epoch 402, Train Loss: 0.000626, Validation Loss: 0.000663
# Epoch 403, Train Loss: 0.000687, Validation Loss: 0.000624
# Epoch 404, Train Loss: 0.000521, Validation Loss: 0.000618
# Epoch 405, Train Loss: 0.000881, Validation Loss: 0.001050
# Epoch 406, Train Loss: 0.000871, Validation Loss: 0.000649
# Epoch 407, Train Loss: 0.000768, Validation Loss: 0.000678
# Epoch 408, Train Loss: 0.000578, Validation Loss: 0.000676
# Epoch 409, Train Loss: 0.000538, Validation Loss: 0.000753
# Epoch 410, Train Loss: 0.000578, Validation Loss: 0.000842
# Epoch 411, Train Loss: 0.000680, Validation Loss: 0.000845
# Epoch 412, Train Loss: 0.000580, Validation Loss: 0.000793
# Epoch 413, Train Loss: 0.000550, Validation Loss: 0.000565
# Saving model at epoch 413 with validation loss 0.000565...
# Epoch 414, Train Loss: 0.000529, Validation Loss: 0.000572
# Epoch 415, Train Loss: 0.000749, Validation Loss: 0.000678
# Epoch 416, Train Loss: 0.000534, Validation Loss: 0.000573
# Epoch 417, Train Loss: 0.000487, Validation Loss: 0.000637
# Epoch 418, Train Loss: 0.000506, Validation Loss: 0.000620
# Epoch 419, Train Loss: 0.000536, Validation Loss: 0.000586
# Epoch 420, Train Loss: 0.000465, Validation Loss: 0.000559
# Saving model at epoch 420 with validation loss 0.000559...
# Epoch 421, Train Loss: 0.000480, Validation Loss: 0.000590
# Epoch 422, Train Loss: 0.000478, Validation Loss: 0.000594
# Epoch 423, Train Loss: 0.000477, Validation Loss: 0.000560
# Epoch 424, Train Loss: 0.000471, Validation Loss: 0.000562
# Epoch 425, Train Loss: 0.000485, Validation Loss: 0.000672
# Epoch 426, Train Loss: 0.000593, Validation Loss: 0.001162
# Epoch 427, Train Loss: 0.000839, Validation Loss: 0.000792
# Epoch 428, Train Loss: 0.000534, Validation Loss: 0.000676
# Epoch 429, Train Loss: 0.000532, Validation Loss: 0.000806
# Epoch 430, Train Loss: 0.000553, Validation Loss: 0.000743
# Epoch 431, Train Loss: 0.000583, Validation Loss: 0.000535
# Saving model at epoch 431 with validation loss 0.000535...
# Epoch 432, Train Loss: 0.000559, Validation Loss: 0.000590
# Epoch 433, Train Loss: 0.000469, Validation Loss: 0.000545
# Epoch 434, Train Loss: 0.000488, Validation Loss: 0.000818
# Epoch 435, Train Loss: 0.000725, Validation Loss: 0.002061
# Epoch 436, Train Loss: 0.002159, Validation Loss: 0.004310
# Epoch 437, Train Loss: 0.001784, Validation Loss: 0.001016
# Epoch 438, Train Loss: 0.001068, Validation Loss: 0.001239
# Epoch 439, Train Loss: 0.000916, Validation Loss: 0.001606
# Epoch 440, Train Loss: 0.000822, Validation Loss: 0.000862
# Epoch 441, Train Loss: 0.000583, Validation Loss: 0.000530
# Saving model at epoch 441 with validation loss 0.000530...
# Epoch 442, Train Loss: 0.000502, Validation Loss: 0.000602
# Epoch 443, Train Loss: 0.000494, Validation Loss: 0.000539
# Epoch 444, Train Loss: 0.000451, Validation Loss: 0.000516
# Saving model at epoch 444 with validation loss 0.000516...
# Epoch 445, Train Loss: 0.000432, Validation Loss: 0.000553
# Epoch 446, Train Loss: 0.000437, Validation Loss: 0.000504
# Saving model at epoch 446 with validation loss 0.000504...
# Epoch 447, Train Loss: 0.000422, Validation Loss: 0.000557
# Epoch 448, Train Loss: 0.000465, Validation Loss: 0.000647
# Epoch 449, Train Loss: 0.000461, Validation Loss: 0.000511
# Epoch 450, Train Loss: 0.000410, Validation Loss: 0.000512
# Epoch 451, Train Loss: 0.000418, Validation Loss: 0.000498
# Saving model at epoch 451 with validation loss 0.000498...
# Epoch 452, Train Loss: 0.000422, Validation Loss: 0.000505
# Epoch 453, Train Loss: 0.000429, Validation Loss: 0.000568
# Epoch 454, Train Loss: 0.000444, Validation Loss: 0.000562
# Epoch 455, Train Loss: 0.000433, Validation Loss: 0.000491
# Saving model at epoch 455 with validation loss 0.000491...
# Epoch 456, Train Loss: 0.000404, Validation Loss: 0.000547
# Epoch 457, Train Loss: 0.000509, Validation Loss: 0.000615
# Epoch 458, Train Loss: 0.000542, Validation Loss: 0.000546
# Epoch 459, Train Loss: 0.000505, Validation Loss: 0.000481
# Saving model at epoch 459 with validation loss 0.000481...
# Epoch 460, Train Loss: 0.000423, Validation Loss: 0.000528
# Epoch 461, Train Loss: 0.000420, Validation Loss: 0.000576
# Epoch 462, Train Loss: 0.000430, Validation Loss: 0.000510
# Epoch 463, Train Loss: 0.000420, Validation Loss: 0.000484
# Epoch 464, Train Loss: 0.000435, Validation Loss: 0.000589
# Epoch 465, Train Loss: 0.000452, Validation Loss: 0.000575
# Epoch 466, Train Loss: 0.000518, Validation Loss: 0.000597
# Epoch 467, Train Loss: 0.000454, Validation Loss: 0.000568
# Epoch 468, Train Loss: 0.000433, Validation Loss: 0.000477
# Saving model at epoch 468 with validation loss 0.000477...
# Epoch 469, Train Loss: 0.000421, Validation Loss: 0.000576
# Epoch 470, Train Loss: 0.000445, Validation Loss: 0.000484
# Epoch 471, Train Loss: 0.000451, Validation Loss: 0.000598
# Epoch 472, Train Loss: 0.000492, Validation Loss: 0.000576
# Epoch 473, Train Loss: 0.000413, Validation Loss: 0.000459
# Saving model at epoch 473 with validation loss 0.000459...
# Epoch 474, Train Loss: 0.000401, Validation Loss: 0.000457
# Saving model at epoch 474 with validation loss 0.000457...
# Epoch 475, Train Loss: 0.000390, Validation Loss: 0.000503
# Epoch 476, Train Loss: 0.000407, Validation Loss: 0.000541
# Epoch 477, Train Loss: 0.000429, Validation Loss: 0.000758
# Epoch 478, Train Loss: 0.000905, Validation Loss: 0.000647
# Epoch 479, Train Loss: 0.000599, Validation Loss: 0.000507
# Epoch 480, Train Loss: 0.000462, Validation Loss: 0.000508
# Epoch 481, Train Loss: 0.000467, Validation Loss: 0.000565
# Epoch 482, Train Loss: 0.000524, Validation Loss: 0.000516
# Epoch 483, Train Loss: 0.000402, Validation Loss: 0.000453
# Saving model at epoch 483 with validation loss 0.000453...
# Epoch 484, Train Loss: 0.000376, Validation Loss: 0.000514
# Epoch 485, Train Loss: 0.000435, Validation Loss: 0.000499
# Epoch 486, Train Loss: 0.000400, Validation Loss: 0.000442
# Saving model at epoch 486 with validation loss 0.000442...
# Epoch 487, Train Loss: 0.000367, Validation Loss: 0.000494
# Epoch 488, Train Loss: 0.000405, Validation Loss: 0.000483
# Epoch 489, Train Loss: 0.000396, Validation Loss: 0.000488
# Epoch 490, Train Loss: 0.000398, Validation Loss: 0.000453
# Epoch 491, Train Loss: 0.000385, Validation Loss: 0.000469
# Epoch 492, Train Loss: 0.000402, Validation Loss: 0.000498
# Epoch 493, Train Loss: 0.000411, Validation Loss: 0.000463
# Epoch 494, Train Loss: 0.000407, Validation Loss: 0.000527
# Epoch 495, Train Loss: 0.000397, Validation Loss: 0.000439
# Saving model at epoch 495 with validation loss 0.000439...
# Epoch 496, Train Loss: 0.000383, Validation Loss: 0.000440
# Epoch 497, Train Loss: 0.000388, Validation Loss: 0.000517
# Epoch 498, Train Loss: 0.000419, Validation Loss: 0.000547
# Epoch 499, Train Loss: 0.000419, Validation Loss: 0.000697
# Epoch 500, Train Loss: 0.000653, Validation Loss: 0.000674
# Epoch 501, Train Loss: 0.000906, Validation Loss: 0.000793
# Epoch 502, Train Loss: 0.000471, Validation Loss: 0.000442
# Epoch 503, Train Loss: 0.000421, Validation Loss: 0.000610
# Epoch 504, Train Loss: 0.000416, Validation Loss: 0.000442
# Epoch 505, Train Loss: 0.000362, Validation Loss: 0.000440
# Epoch 506, Train Loss: 0.000362, Validation Loss: 0.000431
# Saving model at epoch 506 with validation loss 0.000431...
# Epoch 507, Train Loss: 0.000371, Validation Loss: 0.000451
# Epoch 508, Train Loss: 0.000458, Validation Loss: 0.000870
# Epoch 509, Train Loss: 0.000654, Validation Loss: 0.001423
# Epoch 510, Train Loss: 0.000786, Validation Loss: 0.000517
# Epoch 511, Train Loss: 0.000486, Validation Loss: 0.000560
# Epoch 512, Train Loss: 0.000486, Validation Loss: 0.000524
# Epoch 513, Train Loss: 0.000636, Validation Loss: 0.001620
# Epoch 514, Train Loss: 0.001015, Validation Loss: 0.000736
# Epoch 515, Train Loss: 0.000526, Validation Loss: 0.000512
# Epoch 516, Train Loss: 0.000400, Validation Loss: 0.000420
# Saving model at epoch 516 with validation loss 0.000420...
# Epoch 517, Train Loss: 0.000351, Validation Loss: 0.000539
# Epoch 518, Train Loss: 0.000374, Validation Loss: 0.000466
# Epoch 519, Train Loss: 0.000355, Validation Loss: 0.000490
# Epoch 520, Train Loss: 0.000367, Validation Loss: 0.000426
# Epoch 521, Train Loss: 0.000403, Validation Loss: 0.000421
# Epoch 522, Train Loss: 0.000401, Validation Loss: 0.000419
# Saving model at epoch 522 with validation loss 0.000419...
# Epoch 523, Train Loss: 0.000407, Validation Loss: 0.000471
# Epoch 524, Train Loss: 0.000487, Validation Loss: 0.000499
# Epoch 525, Train Loss: 0.000406, Validation Loss: 0.000456
# Epoch 526, Train Loss: 0.000380, Validation Loss: 0.000406
# Saving model at epoch 526 with validation loss 0.000406...
# Epoch 527, Train Loss: 0.000409, Validation Loss: 0.000405
# Saving model at epoch 527 with validation loss 0.000405...
# Epoch 528, Train Loss: 0.000395, Validation Loss: 0.000503
# Epoch 529, Train Loss: 0.000406, Validation Loss: 0.000525
# Epoch 530, Train Loss: 0.000363, Validation Loss: 0.000408
# Epoch 531, Train Loss: 0.000345, Validation Loss: 0.000420
# Epoch 532, Train Loss: 0.000335, Validation Loss: 0.000413
# Epoch 533, Train Loss: 0.000376, Validation Loss: 0.000395
# Saving model at epoch 533 with validation loss 0.000395...
# Epoch 534, Train Loss: 0.000350, Validation Loss: 0.000400
# Epoch 535, Train Loss: 0.000452, Validation Loss: 0.001030
# Epoch 536, Train Loss: 0.000756, Validation Loss: 0.001835
# Epoch 537, Train Loss: 0.001291, Validation Loss: 0.000977
# Epoch 538, Train Loss: 0.000885, Validation Loss: 0.000533
# Epoch 539, Train Loss: 0.000626, Validation Loss: 0.000492
# Epoch 540, Train Loss: 0.000538, Validation Loss: 0.000433
# Epoch 541, Train Loss: 0.000490, Validation Loss: 0.000455
# Epoch 542, Train Loss: 0.000377, Validation Loss: 0.000442
# Epoch 543, Train Loss: 0.000366, Validation Loss: 0.000491
# Epoch 544, Train Loss: 0.000384, Validation Loss: 0.000482
# Epoch 545, Train Loss: 0.000346, Validation Loss: 0.000412
# Epoch 546, Train Loss: 0.000357, Validation Loss: 0.000398
# Epoch 547, Train Loss: 0.000328, Validation Loss: 0.000407
# Epoch 548, Train Loss: 0.000345, Validation Loss: 0.000417
# Epoch 549, Train Loss: 0.000458, Validation Loss: 0.001073
# Epoch 550, Train Loss: 0.000547, Validation Loss: 0.000493
# Epoch 551, Train Loss: 0.000394, Validation Loss: 0.000445
# Epoch 552, Train Loss: 0.000363, Validation Loss: 0.000425
# Epoch 553, Train Loss: 0.000453, Validation Loss: 0.000487
# Epoch 554, Train Loss: 0.000362, Validation Loss: 0.000405
# Epoch 555, Train Loss: 0.000339, Validation Loss: 0.000423
# Epoch 556, Train Loss: 0.000406, Validation Loss: 0.000396
# Epoch 557, Train Loss: 0.000382, Validation Loss: 0.000680
# Epoch 558, Train Loss: 0.000458, Validation Loss: 0.000408
# Epoch 559, Train Loss: 0.000700, Validation Loss: 0.001202
# Epoch 560, Train Loss: 0.000697, Validation Loss: 0.001187
# Epoch 561, Train Loss: 0.000761, Validation Loss: 0.000574
# Epoch 562, Train Loss: 0.000580, Validation Loss: 0.000399
# Epoch 563, Train Loss: 0.000507, Validation Loss: 0.000576
# Epoch 564, Train Loss: 0.000432, Validation Loss: 0.000464
# Epoch 565, Train Loss: 0.000359, Validation Loss: 0.000381
# Saving model at epoch 565 with validation loss 0.000381...
# Epoch 566, Train Loss: 0.000363, Validation Loss: 0.000381
# Saving model at epoch 566 with validation loss 0.000381...
# Epoch 567, Train Loss: 0.000320, Validation Loss: 0.000403
# Epoch 568, Train Loss: 0.000359, Validation Loss: 0.000468
# Epoch 569, Train Loss: 0.000339, Validation Loss: 0.000412
# Epoch 570, Train Loss: 0.000359, Validation Loss: 0.000376
# Saving model at epoch 570 with validation loss 0.000376...
# Epoch 571, Train Loss: 0.000347, Validation Loss: 0.000382
# Epoch 572, Train Loss: 0.000330, Validation Loss: 0.000487
# Epoch 573, Train Loss: 0.000342, Validation Loss: 0.000416
# Epoch 574, Train Loss: 0.000405, Validation Loss: 0.000384
# Epoch 575, Train Loss: 0.000551, Validation Loss: 0.000463
# Epoch 576, Train Loss: 0.000383, Validation Loss: 0.000405
# Epoch 577, Train Loss: 0.000338, Validation Loss: 0.000417
# Epoch 578, Train Loss: 0.000350, Validation Loss: 0.000380
# Epoch 579, Train Loss: 0.000359, Validation Loss: 0.000511
# Epoch 580, Train Loss: 0.000478, Validation Loss: 0.000849
# Epoch 581, Train Loss: 0.000524, Validation Loss: 0.000388
# Epoch 582, Train Loss: 0.000382, Validation Loss: 0.000451
# Epoch 583, Train Loss: 0.000357, Validation Loss: 0.000439
# Epoch 584, Train Loss: 0.000364, Validation Loss: 0.000392
# Epoch 585, Train Loss: 0.000347, Validation Loss: 0.000424
# Epoch 586, Train Loss: 0.000411, Validation Loss: 0.000489
# Epoch 587, Train Loss: 0.000317, Validation Loss: 0.000383
# Epoch 588, Train Loss: 0.000307, Validation Loss: 0.000362
# Saving model at epoch 588 with validation loss 0.000362...
# Epoch 589, Train Loss: 0.000320, Validation Loss: 0.000376
# Epoch 590, Train Loss: 0.000341, Validation Loss: 0.000382
# Epoch 591, Train Loss: 0.000419, Validation Loss: 0.000373
# Epoch 592, Train Loss: 0.000344, Validation Loss: 0.000511
# Epoch 593, Train Loss: 0.000370, Validation Loss: 0.000368
# Epoch 594, Train Loss: 0.000426, Validation Loss: 0.000370
# Epoch 595, Train Loss: 0.000361, Validation Loss: 0.000395
# Epoch 596, Train Loss: 0.000368, Validation Loss: 0.000417
# Epoch 597, Train Loss: 0.000384, Validation Loss: 0.000390
# Epoch 598, Train Loss: 0.000322, Validation Loss: 0.000368
# Epoch 599, Train Loss: 0.000305, Validation Loss: 0.000402
# Epoch 600, Train Loss: 0.000320, Validation Loss: 0.000375
# Epoch 601, Train Loss: 0.000353, Validation Loss: 0.000376
# Epoch 602, Train Loss: 0.000343, Validation Loss: 0.000352
# Saving model at epoch 602 with validation loss 0.000352...
# Epoch 603, Train Loss: 0.000321, Validation Loss: 0.000383
# Epoch 604, Train Loss: 0.000311, Validation Loss: 0.000450
# Epoch 605, Train Loss: 0.000854, Validation Loss: 0.001005
# Epoch 606, Train Loss: 0.000536, Validation Loss: 0.000525
# Epoch 607, Train Loss: 0.000337, Validation Loss: 0.000356
# Epoch 608, Train Loss: 0.000301, Validation Loss: 0.000364
# Epoch 609, Train Loss: 0.000323, Validation Loss: 0.000386
# ...
# Epoch 2753, Train Loss: 0.000185, Validation Loss: 0.000187
# Epoch 2754, Train Loss: 0.000179, Validation Loss: 0.000209
# Epoch 2755, Train Loss: 0.000193, Validation Loss: 0.000203
# Epoch 2756, Train Loss: 0.000235, Validation Loss: 0.000320
# Epoch 2757, Train Loss: 0.000240, Validation Loss: 0.000240
# Epoch 2758, Train Loss: 0.000260, Validation Loss: 0.000389
# Epoch 2759, Train Loss: 0.000281, Validation Loss: 0.000339
# Epoch 2760, Train Loss: 0.000295, Validation Loss: 0.000274
# Epoch 2761, Train Loss: 0.000296, Validation Loss: 0.000440
# Epoch 2762, Train Loss: 0.000527, Validation Loss: 0.000691
# Epoch 2763, Train Loss: 0.000452, Validation Loss: 0.000431
# Epoch 2764, Train Loss: 0.000278, Validation Loss: 0.000268
# Epoch 2765, Train Loss: 0.000226, Validation Loss: 0.000206
# Epoch 2766, Train Loss: 0.000258, Validation Loss: 0.000247
# Epoch 2767, Train Loss: 0.000282, Validation Loss: 0.000236
# Epoch 2768, Train Loss: 0.000187, Validation Loss: 0.000222
# Epoch 2769, Train Loss: 0.000201, Validation Loss: 0.000187
# Epoch 2770, Train Loss: 0.000184, Validation Loss: 0.000203
# Epoch 2771, Train Loss: 0.000186, Validation Loss: 0.000215
# Epoch 2772, Train Loss: 0.000229, Validation Loss: 0.000201
# Epoch 2773, Train Loss: 0.000200, Validation Loss: 0.000191
# Epoch 2774, Train Loss: 0.000173, Validation Loss: 0.000181
# Epoch 2775, Train Loss: 0.000178, Validation Loss: 0.000325
# Epoch 2776, Train Loss: 0.000221, Validation Loss: 0.000196
# Epoch 2777, Train Loss: 0.000192, Validation Loss: 0.000186
# Epoch 2778, Train Loss: 0.000204, Validation Loss: 0.000232
# Epoch 2779, Train Loss: 0.000194, Validation Loss: 0.000201
# Epoch 2780, Train Loss: 0.000224, Validation Loss: 0.000417
# Epoch 2781, Train Loss: 0.000293, Validation Loss: 0.000369
# Epoch 2782, Train Loss: 0.000267, Validation Loss: 0.000271
# Epoch 2783, Train Loss: 0.000254, Validation Loss: 0.000224
# Epoch 2784, Train Loss: 0.000229, Validation Loss: 0.000213
# Epoch 2785, Train Loss: 0.000176, Validation Loss: 0.000200
# Epoch 2786, Train Loss: 0.000189, Validation Loss: 0.000306
# Epoch 2787, Train Loss: 0.000209, Validation Loss: 0.000193
# Epoch 2788, Train Loss: 0.000188, Validation Loss: 0.000269
# Epoch 2789, Train Loss: 0.000335, Validation Loss: 0.000551
# Epoch 2790, Train Loss: 0.000296, Validation Loss: 0.000614
# Epoch 2791, Train Loss: 0.000303, Validation Loss: 0.000453
# Epoch 2792, Train Loss: 0.000292, Validation Loss: 0.000267
# Epoch 2793, Train Loss: 0.000206, Validation Loss: 0.000214
# Epoch 2794, Train Loss: 0.000191, Validation Loss: 0.000203
# Epoch 2795, Train Loss: 0.000181, Validation Loss: 0.000186
# Epoch 2796, Train Loss: 0.000180, Validation Loss: 0.000195
# Epoch 2797, Train Loss: 0.000178, Validation Loss: 0.000194
# Epoch 2798, Train Loss: 0.000167, Validation Loss: 0.000189
# Epoch 2799, Train Loss: 0.000192, Validation Loss: 0.000220
# Epoch 2800, Train Loss: 0.000180, Validation Loss: 0.000206
# Epoch 2801, Train Loss: 0.000222, Validation Loss: 0.000466
# Epoch 2802, Train Loss: 0.000299, Validation Loss: 0.000199
# Epoch 2803, Train Loss: 0.000202, Validation Loss: 0.000256
# Epoch 2804, Train Loss: 0.000207, Validation Loss: 0.000330
# Epoch 2805, Train Loss: 0.000239, Validation Loss: 0.000210
# Epoch 2806, Train Loss: 0.000201, Validation Loss: 0.000251
# Epoch 2807, Train Loss: 0.000251, Validation Loss: 0.000235
# Epoch 2808, Train Loss: 0.000205, Validation Loss: 0.000280
# Epoch 2809, Train Loss: 0.000229, Validation Loss: 0.000197
# Epoch 2810, Train Loss: 0.000218, Validation Loss: 0.000206
# Epoch 2811, Train Loss: 0.000226, Validation Loss: 0.000230
# Epoch 2812, Train Loss: 0.000211, Validation Loss: 0.000209
# Epoch 2813, Train Loss: 0.000186, Validation Loss: 0.000198
# Epoch 2814, Train Loss: 0.000186, Validation Loss: 0.000188
# Epoch 2815, Train Loss: 0.000176, Validation Loss: 0.000228
# Epoch 2816, Train Loss: 0.000245, Validation Loss: 0.000400
# Epoch 2817, Train Loss: 0.000235, Validation Loss: 0.000236
# Epoch 2818, Train Loss: 0.000202, Validation Loss: 0.000207
# Epoch 2819, Train Loss: 0.000202, Validation Loss: 0.000285
# Epoch 2820, Train Loss: 0.000312, Validation Loss: 0.000255
# Epoch 2821, Train Loss: 0.000456, Validation Loss: 0.000288
# Epoch 2822, Train Loss: 0.000409, Validation Loss: 0.000493
# Epoch 2823, Train Loss: 0.000474, Validation Loss: 0.000358
# Epoch 2824, Train Loss: 0.000230, Validation Loss: 0.000215
# Epoch 2825, Train Loss: 0.000215, Validation Loss: 0.000219
# Epoch 2826, Train Loss: 0.000608, Validation Loss: 0.000613
# Epoch 2827, Train Loss: 0.000398, Validation Loss: 0.000306
# Epoch 2828, Train Loss: 0.000295, Validation Loss: 0.000270
# Epoch 2829, Train Loss: 0.000505, Validation Loss: 0.000224
# Epoch 2830, Train Loss: 0.000232, Validation Loss: 0.000184
# Epoch 2831, Train Loss: 0.000166, Validation Loss: 0.000191
# Epoch 2832, Train Loss: 0.000173, Validation Loss: 0.000183
# Epoch 2833, Train Loss: 0.000166, Validation Loss: 0.000198
# Epoch 2834, Train Loss: 0.000173, Validation Loss: 0.000205
# Epoch 2835, Train Loss: 0.000180, Validation Loss: 0.000186
# Epoch 2836, Train Loss: 0.000167, Validation Loss: 0.000188
# Epoch 2837, Train Loss: 0.000171, Validation Loss: 0.000195
# Epoch 2838, Train Loss: 0.000183, Validation Loss: 0.000250
# Epoch 2839, Train Loss: 0.000214, Validation Loss: 0.000259
# Epoch 2840, Train Loss: 0.000242, Validation Loss: 0.000363
# Epoch 2841, Train Loss: 0.000222, Validation Loss: 0.000214
# Epoch 2842, Train Loss: 0.000200, Validation Loss: 0.000196
# Epoch 2843, Train Loss: 0.000170, Validation Loss: 0.000187
# Epoch 2844, Train Loss: 0.000165, Validation Loss: 0.000190
# Epoch 2845, Train Loss: 0.000166, Validation Loss: 0.000208
# Epoch 2846, Train Loss: 0.000182, Validation Loss: 0.000190
# Epoch 2847, Train Loss: 0.000171, Validation Loss: 0.000210
# Epoch 2848, Train Loss: 0.000178, Validation Loss: 0.000189
# Epoch 2849, Train Loss: 0.000180, Validation Loss: 0.000207
# Epoch 2850, Train Loss: 0.000172, Validation Loss: 0.000192
# Epoch 2851, Train Loss: 0.000182, Validation Loss: 0.000202
# Epoch 2852, Train Loss: 0.000184, Validation Loss: 0.000199
# Epoch 2853, Train Loss: 0.000193, Validation Loss: 0.000217
# Epoch 2854, Train Loss: 0.000181, Validation Loss: 0.000191
# Epoch 2855, Train Loss: 0.000186, Validation Loss: 0.000256
# Epoch 2856, Train Loss: 0.000209, Validation Loss: 0.000256
# Epoch 2857, Train Loss: 0.000196, Validation Loss: 0.000259
# Epoch 2858, Train Loss: 0.000200, Validation Loss: 0.000269
# Epoch 2859, Train Loss: 0.000429, Validation Loss: 0.000433
# Epoch 2860, Train Loss: 0.000481, Validation Loss: 0.000711
# Epoch 2861, Train Loss: 0.000396, Validation Loss: 0.000600
# Epoch 2862, Train Loss: 0.000392, Validation Loss: 0.000246
# Epoch 2863, Train Loss: 0.000260, Validation Loss: 0.000318
# Epoch 2864, Train Loss: 0.000284, Validation Loss: 0.000297
# Epoch 2865, Train Loss: 0.000252, Validation Loss: 0.000271
# Epoch 2866, Train Loss: 0.000252, Validation Loss: 0.000218
# Epoch 2867, Train Loss: 0.000187, Validation Loss: 0.000184
# Epoch 2868, Train Loss: 0.000168, Validation Loss: 0.000266
# Epoch 2869, Train Loss: 0.000224, Validation Loss: 0.000262
# Epoch 2870, Train Loss: 0.000272, Validation Loss: 0.000315
# Epoch 2871, Train Loss: 0.000233, Validation Loss: 0.000275
# Epoch 2872, Train Loss: 0.000207, Validation Loss: 0.000209
# Epoch 2873, Train Loss: 0.000215, Validation Loss: 0.000276
# Epoch 2874, Train Loss: 0.000222, Validation Loss: 0.000201
# Epoch 2875, Train Loss: 0.000238, Validation Loss: 0.000796
# Epoch 2876, Train Loss: 0.000319, Validation Loss: 0.000307
# Epoch 2877, Train Loss: 0.000306, Validation Loss: 0.000253
# Epoch 2878, Train Loss: 0.000193, Validation Loss: 0.000298
# Epoch 2879, Train Loss: 0.000212, Validation Loss: 0.000200
# Epoch 2880, Train Loss: 0.000203, Validation Loss: 0.000255
# Epoch 2881, Train Loss: 0.000293, Validation Loss: 0.000467
# Epoch 2882, Train Loss: 0.000424, Validation Loss: 0.000500
# Epoch 2883, Train Loss: 0.000418, Validation Loss: 0.000309
# Epoch 2884, Train Loss: 0.000216, Validation Loss: 0.000364
# Epoch 2885, Train Loss: 0.000259, Validation Loss: 0.000237
# Epoch 2886, Train Loss: 0.000208, Validation Loss: 0.000260
# Epoch 2887, Train Loss: 0.000321, Validation Loss: 0.000274
# Epoch 2888, Train Loss: 0.000397, Validation Loss: 0.000572
# Epoch 2889, Train Loss: 0.000319, Validation Loss: 0.000190
# Epoch 2890, Train Loss: 0.000314, Validation Loss: 0.000231
# Epoch 2891, Train Loss: 0.000282, Validation Loss: 0.000305
# Epoch 2892, Train Loss: 0.000216, Validation Loss: 0.000226
# Epoch 2893, Train Loss: 0.000181, Validation Loss: 0.000182
# Epoch 2894, Train Loss: 0.000176, Validation Loss: 0.000197
# Epoch 2895, Train Loss: 0.000184, Validation Loss: 0.000199
# Epoch 2896, Train Loss: 0.000177, Validation Loss: 0.000191
# Epoch 2897, Train Loss: 0.000172, Validation Loss: 0.000204
# Epoch 2898, Train Loss: 0.000173, Validation Loss: 0.000194
# Epoch 2899, Train Loss: 0.000170, Validation Loss: 0.000191
# Epoch 2900, Train Loss: 0.000178, Validation Loss: 0.000218
# Epoch 2901, Train Loss: 0.000196, Validation Loss: 0.000207
# Epoch 2902, Train Loss: 0.000189, Validation Loss: 0.000204
# Epoch 2903, Train Loss: 0.000194, Validation Loss: 0.000200
# Epoch 2904, Train Loss: 0.000204, Validation Loss: 0.000196
# Epoch 2905, Train Loss: 0.000204, Validation Loss: 0.000182
# Epoch 2906, Train Loss: 0.000194, Validation Loss: 0.000195
# Epoch 2907, Train Loss: 0.000180, Validation Loss: 0.000190
# Epoch 2908, Train Loss: 0.000189, Validation Loss: 0.000363
# Epoch 2909, Train Loss: 0.000237, Validation Loss: 0.000215
# Epoch 2910, Train Loss: 0.000237, Validation Loss: 0.000233
# Epoch 2911, Train Loss: 0.000201, Validation Loss: 0.000325
# Epoch 2912, Train Loss: 0.000238, Validation Loss: 0.000248
# Epoch 2913, Train Loss: 0.000302, Validation Loss: 0.000242
# Epoch 2914, Train Loss: 0.000320, Validation Loss: 0.000244
# Epoch 2915, Train Loss: 0.000227, Validation Loss: 0.000216
# Epoch 2916, Train Loss: 0.000222, Validation Loss: 0.000286
# Epoch 2917, Train Loss: 0.000212, Validation Loss: 0.000242
# Epoch 2918, Train Loss: 0.000187, Validation Loss: 0.000200
# Epoch 2919, Train Loss: 0.000184, Validation Loss: 0.000193
# Epoch 2920, Train Loss: 0.000169, Validation Loss: 0.000209
# Epoch 2921, Train Loss: 0.000178, Validation Loss: 0.000183
# Epoch 2922, Train Loss: 0.000176, Validation Loss: 0.000196
# Epoch 2923, Train Loss: 0.000170, Validation Loss: 0.000203
# Epoch 2924, Train Loss: 0.000194, Validation Loss: 0.000187
# Epoch 2925, Train Loss: 0.000194, Validation Loss: 0.000356
# Epoch 2926, Train Loss: 0.000228, Validation Loss: 0.000195
# Epoch 2927, Train Loss: 0.000176, Validation Loss: 0.000221
# Epoch 2928, Train Loss: 0.000221, Validation Loss: 0.000307
# Epoch 2929, Train Loss: 0.000199, Validation Loss: 0.000195
# Epoch 2930, Train Loss: 0.000182, Validation Loss: 0.000188
# Epoch 2931, Train Loss: 0.000187, Validation Loss: 0.000275
# Epoch 2932, Train Loss: 0.000200, Validation Loss: 0.000237
# Epoch 2933, Train Loss: 0.000226, Validation Loss: 0.000395
# Epoch 2934, Train Loss: 0.000250, Validation Loss: 0.000206
# Epoch 2935, Train Loss: 0.000200, Validation Loss: 0.000363
# Epoch 2936, Train Loss: 0.000217, Validation Loss: 0.000205
# Epoch 2937, Train Loss: 0.000187, Validation Loss: 0.000188
# Epoch 2938, Train Loss: 0.000179, Validation Loss: 0.000230
# Epoch 2939, Train Loss: 0.000194, Validation Loss: 0.000203
# Epoch 2940, Train Loss: 0.000206, Validation Loss: 0.000248
# Epoch 2941, Train Loss: 0.000250, Validation Loss: 0.000268
# Epoch 2942, Train Loss: 0.000205, Validation Loss: 0.000234
# Epoch 2943, Train Loss: 0.000259, Validation Loss: 0.000262
# Epoch 2944, Train Loss: 0.000235, Validation Loss: 0.000410
# Epoch 2945, Train Loss: 0.000260, Validation Loss: 0.000262
# Epoch 2946, Train Loss: 0.000278, Validation Loss: 0.000381
# Epoch 2947, Train Loss: 0.000477, Validation Loss: 0.000583
# Epoch 2948, Train Loss: 0.000403, Validation Loss: 0.000239
# Epoch 2949, Train Loss: 0.000240, Validation Loss: 0.000253
# Epoch 2950, Train Loss: 0.000201, Validation Loss: 0.000245
# Epoch 2951, Train Loss: 0.000200, Validation Loss: 0.000225
# Epoch 2952, Train Loss: 0.000193, Validation Loss: 0.000252
# Epoch 2953, Train Loss: 0.000207, Validation Loss: 0.000192
# Epoch 2954, Train Loss: 0.000185, Validation Loss: 0.000210
# Epoch 2955, Train Loss: 0.000197, Validation Loss: 0.000205
# Epoch 2956, Train Loss: 0.000175, Validation Loss: 0.000189
# Epoch 2957, Train Loss: 0.000187, Validation Loss: 0.000214
# Epoch 2958, Train Loss: 0.000173, Validation Loss: 0.000195
# Epoch 2959, Train Loss: 0.000196, Validation Loss: 0.000229
# Epoch 2960, Train Loss: 0.000296, Validation Loss: 0.000426
# Epoch 2961, Train Loss: 0.000279, Validation Loss: 0.000239
# Epoch 2962, Train Loss: 0.000267, Validation Loss: 0.000234
# Epoch 2963, Train Loss: 0.000229, Validation Loss: 0.000256
# Epoch 2964, Train Loss: 0.000235, Validation Loss: 0.000266
# Epoch 2965, Train Loss: 0.000192, Validation Loss: 0.000237
# Epoch 2966, Train Loss: 0.000223, Validation Loss: 0.000191
# Epoch 2967, Train Loss: 0.000297, Validation Loss: 0.000394
# Epoch 2968, Train Loss: 0.000268, Validation Loss: 0.000279
# Epoch 2969, Train Loss: 0.000237, Validation Loss: 0.000226
# Epoch 2970, Train Loss: 0.000177, Validation Loss: 0.000232
# Epoch 2971, Train Loss: 0.000205, Validation Loss: 0.000238
# Epoch 2972, Train Loss: 0.000365, Validation Loss: 0.000540
# Epoch 2973, Train Loss: 0.000411, Validation Loss: 0.000469
# Epoch 2974, Train Loss: 0.000293, Validation Loss: 0.000231
# Epoch 2975, Train Loss: 0.000241, Validation Loss: 0.000236
# Epoch 2976, Train Loss: 0.000231, Validation Loss: 0.000195
# Epoch 2977, Train Loss: 0.000172, Validation Loss: 0.000187
# Epoch 2978, Train Loss: 0.000193, Validation Loss: 0.000241
# Epoch 2979, Train Loss: 0.000200, Validation Loss: 0.000286
# Epoch 2980, Train Loss: 0.000240, Validation Loss: 0.000292
# Epoch 2981, Train Loss: 0.000195, Validation Loss: 0.000273
# Epoch 2982, Train Loss: 0.000223, Validation Loss: 0.000211
# Epoch 2983, Train Loss: 0.000208, Validation Loss: 0.000229
# Epoch 2984, Train Loss: 0.000197, Validation Loss: 0.000353
# Epoch 2985, Train Loss: 0.000266, Validation Loss: 0.000221
# Epoch 2986, Train Loss: 0.000247, Validation Loss: 0.000581
# Epoch 2987, Train Loss: 0.000355, Validation Loss: 0.000575
# Epoch 2988, Train Loss: 0.000295, Validation Loss: 0.000233
# Epoch 2989, Train Loss: 0.000227, Validation Loss: 0.000233
# Epoch 2990, Train Loss: 0.000193, Validation Loss: 0.000215
# Epoch 2991, Train Loss: 0.000195, Validation Loss: 0.000266
# Epoch 2992, Train Loss: 0.000297, Validation Loss: 0.000231
# Epoch 2993, Train Loss: 0.000277, Validation Loss: 0.000290
# Epoch 2994, Train Loss: 0.000256, Validation Loss: 0.000261
# Epoch 2995, Train Loss: 0.000213, Validation Loss: 0.000223
# Epoch 2996, Train Loss: 0.000223, Validation Loss: 0.000395
# Epoch 2997, Train Loss: 0.000283, Validation Loss: 0.000294
# Epoch 2998, Train Loss: 0.000230, Validation Loss: 0.000251
# Epoch 2999, Train Loss: 0.000229, Validation Loss: 0.000262
# Epoch 3000, Train Loss: 0.000241, Validation Loss: 0.000190
# Training complete. Best model saved at ./Model/linspace_n_init2/128/CH467160_Buck_n_init2.pt.
# C:\Users\USER\AppData\Local\Temp\ipykernel_58288\746399810.py:176: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_save_path))  # 載入最佳模型
