# %% [markdown]
# # Part 1: Network Training

# %% [markdown]
# ## Step0: Import Package & Hyperparameter Configuration

# %%
"""
2025/02/03: 1.新增normDict計算 #!注意normDict是有先經過資料前處理計算的
            2.資料集中任意取n筆去訓練(n:自填數) 
            
"""
# Out:
# '\n2025/02/03: 1.新增normDict計算 #!注意normDict是有先經過資料前處理計算的\n            2.資料集中任意取n筆去訓練(n:自填數) \n            \n'

# %% [markdown]
# ### Package

# %%
# %reset -f

import os
import torch
import numpy as np
import random
import torch.nn as nn
from torch.autograd import Variable
from torch.utils.data import DataLoader, TensorDataset
import matplotlib.pyplot as plt

# %% [markdown]
# ### Hyperparameter Config

# %%
# %%
# Unified Hyperparameter Configuration
class Config:
    SEED = 1
    NUM_EPOCHS = 3000
    BATCH_SIZE = 128
    LEARNING_RATE = 0.002  #論文提供
    LR_SCHEDULER_GAMMA = 0.99  #論文提供
    DECAY_EPOCH = 200
    DECAY_RATIO = 0.5
    EARLY_STOPPING_PATIENCE = 500
    HIDDEN_SIZE = 30
    OPERATOR_SIZE = 30


# Reproducibility
random.seed(Config.SEED)
np.random.seed(Config.SEED)
torch.manual_seed(Config.SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %% [markdown]
# ### Material & Number of Data

# %%
material = "N87"
data_number = 5000

# 定義保存模型的路徑
model_save_dir = "./Model/"
os.makedirs(model_save_dir, exist_ok=True)  # 如果路徑不存在，創建路徑

# 定義模型保存檔名
model_save_path = os.path.join(model_save_dir, f"{material}.pt")

# Select device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Step1: Data processing and data loader generate

# %%
# %% Preprocess data into a data loader
def get_dataloader(data_B, data_F, data_T, data_H, data_Pcv, n_init=16):
    """ #*(Date:250105)
    Process data and return DataLoader for training, validation, and testing.

    Parameters
    ----------
    data_B : np.array
        Magnetic flux density data.
    data_F : np.array
        Frequency data.
    data_T : np.array
        Temperature data.
    data_H : np.array
        Magnetic field strength data.
    data_Pcv : np.array
        Core loss data.
    norm : list
        Normalization parameters for the features.
    n_init : int
        Number of initial data points for magnetization.

    Returns
    -------
    train_loader, valid_loader, test_loader : DataLoader
        Dataloaders for training, validation, and testing sets.
    """

    # Data pre-process
    # 1. Down-sample to 128 points
    seq_length = 128
    cols = range(0, 1024, int(1024 / seq_length))  #range(start, stop, step)
    data_B = data_B[:, cols]
    data_H = data_H[:, cols]  #*  Add H Down-sample to 128 points (Date:241213)

    # 2. Add extra points for initial magnetization calculation
    data_length = seq_length + n_init
    data_B = np.hstack((data_B, data_B[:, :n_init]))
    data_H = np.hstack(
        (data_H, data_H[:, :n_init]))  #*(Date:241216) MMINN output似乎是128點
    #*(Date:250130) 原始MMINN H有包含n_init

    # 3. Format data into tensors  #*(Date:241216) seq_length=128, data_length=144
    B = torch.from_numpy(data_B).view(-1, data_length, 1).float()
    H = torch.from_numpy(data_H).view(-1, data_length, 1).float()
    F = torch.log10(torch.from_numpy(data_F).view(-1, 1).float())
    T = torch.from_numpy(data_T).view(-1, 1).float()
    Pcv = torch.log10(torch.from_numpy(data_Pcv).view(-1, 1).float())

    # 原本在6. 因要先計算標準化故移至這
    dB = torch.diff(B, dim=1)
    dB = torch.cat((dB[:, 0:1], dB), dim=1)
    dB_dt = dB * (seq_length * F.view(-1, 1, 1))

    # 4. Compute normalization parameters (均值 & 標準差)**
    norm = [
        [torch.mean(B).item(), torch.std(B).item()],  # 1. B (磁通密度)
        [torch.mean(H).item(), torch.std(H).item()],  # 2. H (磁場強度)
        [torch.mean(F).item(), torch.std(F).item()],  # 3. F (頻率，取 log10)
        [torch.mean(T).item(), torch.std(T).item()],  # 4. T (溫度)
        [torch.mean(dB_dt).item(),
         torch.std(dB_dt).item()],  # 5. dB/dt
        [torch.mean(Pcv).item(), torch.std(Pcv).item()]  # 6. Pv (核心損耗，取 log10)
    ]

    material_name = f"{material}"  # 可以改成你想要的材料名稱
    print(f'"{material_name}": [')
    for param in norm:
        print(f"    {param},")
    print("]")

    # 5. Data Normalization
    in_B = (B - norm[0][0]) / norm[0][1]
    out_H = (H - norm[1][0]) / norm[1][1]
    in_T = (T - norm[3][0]) / norm[3][1]
    in_F = (F - norm[2][0]) / norm[2][1]
    in_Pcv = (Pcv - norm[5][0]) / norm[5][1]

    # 6. Extra features

    in_dB = torch.diff(B, dim=1)
    in_dB = torch.cat((in_dB[:, 0:1], in_dB), dim=1)

    in_dB_dt = (dB_dt - norm[4][0]) / norm[4][1]

    max_B, _ = torch.max(in_B, dim=1)
    min_B, _ = torch.min(in_B, dim=1)

    s0 = get_operator_init(in_B[:, 0] - in_dB[:, 0], in_dB, max_B, min_B)

    # 7. Create dataloader to speed up data processing
    full_dataset = torch.utils.data.TensorDataset(
        torch.cat((in_B, in_dB, in_dB_dt), dim=2),  # B 部分（144 點）
        torch.cat((in_F, in_T, in_Pcv), dim=1),  # 輔助變量
        s0,  # 初始狀態
        out_H)

    # Split dataset into train, validation, and test sets (60:20:20)
    train_size = int(0.8 * len(full_dataset))
    valid_size = len(full_dataset) - train_size

    train_dataset, valid_dataset = torch.utils.data.random_split(
        full_dataset, [train_size, valid_size],
        generator=torch.Generator().manual_seed(Config.SEED))

    train_loader = torch.utils.data.DataLoader(train_dataset,
                                               batch_size=Config.BATCH_SIZE,
                                               shuffle=True,
                                               num_workers=0,
                                               collate_fn=filter_input)

    valid_loader = torch.utils.data.DataLoader(valid_dataset,
                                               batch_size=Config.BATCH_SIZE,
                                               shuffle=False,
                                               num_workers=0,
                                               collate_fn=filter_input)

    return train_loader, valid_loader, norm


# %% Predict the operator state at t0
def get_operator_init(B1,
                      dB,
                      Bmax,
                      Bmin,
                      max_out_H=5,
                      operator_size=Config.OPERATOR_SIZE):
    """Compute the initial state of hysteresis operators"""
    s0 = torch.zeros((dB.shape[0], operator_size))
    operator_thre = torch.from_numpy(
        np.linspace(max_out_H / operator_size, max_out_H,
                    operator_size)).view(1, -1)

    for i in range(dB.shape[0]):
        for j in range(operator_size):
            r = operator_thre[0, j]
            if (Bmax[i] >= r) or (Bmin[i] <= -r):
                if dB[i, 0] >= 0:
                    if B1[i] > Bmin[i] + 2 * r:
                        s0[i, j] = r
                    else:
                        s0[i, j] = B1[i] - (r + Bmin[i])
                else:
                    if B1[i] < Bmax[i] - 2 * r:
                        s0[i, j] = -r
                    else:
                        s0[i, j] = B1[i] + (r - Bmax[i])
    return s0


def filter_input(batch):
    inputs, features, s0, target_H = zip(*batch)

    # 如果 inputs 是 tuple，先堆疊成張量
    inputs = torch.stack(inputs)  # B 的所有輸入部分（144 點）

    # 保留 in_B, in_dB, in_dB_dt 作為模型輸入
    inputs = inputs[:, :, :3]

    # 保留 features（包括 in_F 和 in_T）
    features = torch.stack(features)[:, :2]

    # 保留目標值 H
    target_H = torch.stack(target_H)[:, -128:, :]  # 只取最後 128 點

    s0 = torch.stack(s0)  # 初始狀態

    return inputs, features, s0, target_H

# %% [markdown]
# ## Step2: Define Network Structure

# %%
# %% Magnetization mechansim-determined neural network
"""
    Parameters:
    - hidden_size: number of eddy current slices (RNN neuron)
    - operator_size: number of operators
    - input_size: number of inputs (1.B 2.dB 3.dB/dt)
    - var_size: number of supplenmentary variables (1.F 2.T)        
    - output_size: number of outputs (1.H)
"""


class MMINet(nn.Module):
    def __init__(
            self,
            norm,  #*這裡改成從外部傳入 norm(250203)
            hidden_size=Config.HIDDEN_SIZE,
            operator_size=Config.OPERATOR_SIZE,
            input_size=3,
            var_size=2,
            output_size=1):
        super().__init__()
        self.input_size = input_size
        self.var_size = var_size
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.operator_size = operator_size
        self.norm = norm  #*這裡改成從外部傳入 norm(250203)

        self.rnn1 = StopOperatorCell(self.operator_size)
        self.dnn1 = nn.Linear(self.operator_size + 2, 1)
        self.rnn2 = EddyCell(4, self.hidden_size, output_size)
        self.dnn2 = nn.Linear(self.hidden_size, 1)

        self.rnn2_hx = None

    def forward(self, x, var, s0, n_init=16):
        """
         Parameters: 
          - x(batch,seq,input_size): Input features (1.B, 2.dB, 3.dB/dt)  
          - var(batch,var_size): Supplementary inputs (1.F 2.T)
          - s0(batch,1): Operator inital states
        """
        batch_size = x.size(0)  # Batch size
        seq_size = x.size(1)  # Ser
        self.rnn1_hx = s0

        # Initialize DNN2 input (1.B 2.dB/dt)
        x2 = torch.cat((x[:, :, 0:1], x[:, :, 2:3]), dim=2)

        for t in range(seq_size):
            # RNN1 input (dB,state)
            self.rnn1_hx = self.rnn1(x[:, t, 1:2], self.rnn1_hx)

            # DNN1 input (rnn1_hx,F,T)
            dnn1_in = torch.cat((self.rnn1_hx, var), dim=1)

            # H hysteresis prediction
            H_hyst_pred = self.dnn1(dnn1_in)

            # DNN2 input (B,dB/dt,T,F)
            rnn2_in = torch.cat((x2[:, t, :], var), dim=1)

            # Initialize second rnn state
            if t == 0:
                H_eddy_init = x[:, t, 0:1] - H_hyst_pred
                buffer = x.new_ones(x.size(0), self.hidden_size)
                self.rnn2_hx = Variable(
                    (buffer / torch.sum(self.dnn2.weight, dim=1)) *
                    H_eddy_init)

            #rnn2_in = torch.cat((rnn2_in,H_hyst_pred),dim=1)
            self.rnn2_hx = self.rnn2(rnn2_in, self.rnn2_hx)

            # H eddy prediction
            H_eddy = self.dnn2(self.rnn2_hx)

            # H total
            H_total = (H_hyst_pred + H_eddy).view(batch_size, 1,
                                                  self.output_size)
            if t == 0:
                output = H_total
            else:
                output = torch.cat((output, H_total), dim=1)

        H = (output[:, n_init:, :])

        return H


class StopOperatorCell():
    def __init__(self, operator_size):
        self.operator_thre = torch.from_numpy(
            np.linspace(5 / operator_size, 5, operator_size)).view(1, -1)

    def sslu(self, X):
        a = torch.ones_like(X)
        return torch.max(-a, torch.min(a, X))

    def __call__(self, dB, state):
        r = self.operator_thre.to(dB.device)
        output = self.sslu((dB + state) / r) * r
        return output.float()


class EddyCell(nn.Module):
    def __init__(self, input_size, hidden_size, output_size=1):
        super().__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.output_size = output_size

        self.x2h = nn.Linear(input_size, hidden_size, bias=False)
        self.h2h = nn.Linear(hidden_size, hidden_size, bias=False)

    def forward(self, x, hidden=None):
        hidden = self.x2h(x) + self.h2h(hidden)
        hidden = torch.sigmoid(hidden)
        return hidden

# %% [markdown]
# ## Step3: Training the Model

# %% [markdown]
# ### Load Dataset

# %%
# %%
def load_dataset(material, base_path="./Data/"):

    in_file1 = f"{base_path}{material}/B_Field.csv"
    in_file2 = f"{base_path}{material}/Frequency.csv"
    in_file3 = f"{base_path}{material}/Temperature.csv"
    in_file4 = f"{base_path}{material}/H_Field.csv"
    in_file5 = f"{base_path}{material}/Volumetric_Loss.csv"

    data_B = np.genfromtxt(in_file1, delimiter=',')  # N by 1024
    data_F = np.genfromtxt(in_file2, delimiter=',')  # N by 1
    data_T = np.genfromtxt(in_file3, delimiter=',')  # N by 1
    data_H = np.genfromtxt(in_file4, delimiter=',')  # N by 1024
    data_Pcv = np.genfromtxt(in_file5, delimiter=',')  # N by 1

    # 隨機選取 1000 筆資料
    data_size = len(data_B)
    np.random.seed(Config.SEED)  # 設定隨機種子確保可復現
    indices = np.random.choice(data_size, data_number,
                               replace=False)  # 隨機選取 1000 筆

    data_B = data_B[indices]
    data_F = data_F[indices]
    data_T = data_T[indices]
    data_H = data_H[indices]
    data_Pcv = data_Pcv[indices]

    return data_B, data_F, data_T, data_H, data_Pcv

# %% [markdown]
# ### Train Code

# %%
# %%
def train_model(norm, train_loader, valid_loader):

    model = MMINet(norm=norm).to(device)
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=Config.LEARNING_RATE)

    best_val_loss = float('inf')
    patience_counter = 0

    # 定義保存路徑
    model_save_path = os.path.join("./Model/", f"{material}.pt")

    # **新增 Loss 記錄**
    train_losses = []
    val_losses = []

    for epoch in range(Config.NUM_EPOCHS):
        model.train()
        train_loss = 0

        for inputs, features, s0, target_H in train_loader:
            inputs, features, s0, target_H = inputs.to(device), features.to(
                device), s0.to(device), target_H.to(device)

            optimizer.zero_grad()
            outputs = model(inputs, features, s0)  # 模型的輸出
            loss = criterion(outputs, target_H)  # 使用真實的 H(t) 計算損失
            loss.backward()
            optimizer.step()
            train_loss += loss.item()

        train_loss /= len(train_loader)
        train_losses.append(train_loss)  # **記錄 Train Loss**

        model.eval()
        val_loss = 0

        with torch.no_grad():
            for inputs, features, s0, target_H in valid_loader:
                inputs, features, s0, target_H = inputs.to(
                    device), features.to(device), s0.to(device), target_H.to(
                        device)
                outputs = model(inputs, features, s0)
                loss = criterion(outputs, target_H)
                val_loss += loss.item()

        val_loss /= len(valid_loader)
        val_losses.append(val_loss)  # **記錄 Validation Loss**

        print(
            f"Epoch {epoch+1}, Train Loss: {train_loss:.6f}, Validation Loss: {val_loss:.6f}"
        )

        # ======================================================繪製訓練情況======================================================
        plot_interval = 500
        if (epoch + 1) % plot_interval == 0:
            outputs = outputs[:3].detach().cpu().numpy()
            targets = target_H[:3].detach().cpu().numpy()

            # 設定圖表
            plt.figure(figsize=(12, 6))

            for i in range(outputs.shape[0]):  # 每一批數據繪製一個圖表
                plt.plot(outputs[i, :, 0],
                         label=f"Pred: Sample {i+1}",
                         linestyle='--',
                         marker='o')
                plt.plot(targets[i, :, 0],
                         label=f"Target: Sample {i+1}",
                         linestyle='-',
                         marker='x')

            # 添加標題和標籤
            plt.title(f"Compare - Epoch {epoch + 1}", fontsize=16)
            plt.xlabel("Index", fontsize=14)
            plt.ylabel("Value", fontsize=14)
            plt.legend(loc="upper right", fontsize=12)
            plt.grid(alpha=0.5)

            # 顯示圖表
            plt.show()
        # ======================================================繪製訓練情況= END ======================================================

        # ======================================================Early stop======================================================
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            torch.save(model.state_dict(), model_save_path)  # 保存最佳模型
            print(
                f"Saving model at epoch {epoch+1} with validation loss {val_loss:.6f}..."
            )
            patience_counter = 0
        else:
            patience_counter += 1

        if patience_counter >= Config.EARLY_STOPPING_PATIENCE:
            print("Early stopping triggered.")
            break

        # ======================================================Early stop======================================================

    print(f"Training complete. Best model saved at {model_save_path}.")

    # ==============================繪製 Train Loss 與 Validation Loss 圖==============================
    plt.figure(figsize=(10, 5))
    plt.plot(
        range(1,
              len(train_losses) + 1),
        train_losses,
        label="Train Loss",
    )
    plt.plot(range(1,
                   len(val_losses) + 1),
             val_losses,
             label="Validation Loss")

    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.title("Training & Validation Loss Curve")
    plt.legend()
    plt.grid(alpha=0.5)
    plt.show()
    # ==============================繪製 Train Loss 與 Validation Loss 圖 END==============================

    # ===================================使用最佳模型來產生驗證結果=============================
    model.load_state_dict(torch.load(model_save_path))  # 載入最佳模型
    model.eval()

    with torch.no_grad():
        for inputs, features, s0, target_H in valid_loader:
            inputs, features, s0, target_H = inputs.to(device), features.to(
                device), s0.to(device), target_H.to(device)

            outputs = model(inputs, features, s0)  # 使用最佳模型產生預測值
            outputs = outputs[:3].detach().cpu().numpy()
            targets = target_H[:3].detach().cpu().numpy()
            break  # 只使用一批驗證數據進行可視化

    # **繪製最佳模型的輸出與 Ground Truth 比較**
    plt.figure(figsize=(12, 6))

    for i in range(outputs.shape[0]):  # 每一批數據繪製一個圖表
        plt.plot(outputs[i, :, 0],
                 label=f"Pred: Sample {i+1}",
                 linestyle='--',
                 marker='o')
        plt.plot(targets[i, :, 0],
                 label=f"Target: Sample {i+1}",
                 linestyle='-',
                 marker='x')

    plt.title(f"Best Model - Predicted vs Target", fontsize=16)
    plt.xlabel("Index", fontsize=14)
    plt.ylabel("Value", fontsize=14)
    plt.legend(loc="upper right", fontsize=12)
    plt.grid(alpha=0.5)
    plt.show()

    # ===================================使用最佳模型來產生驗證結果 END=============================

# %%
# 驗證輸入shape
# net = MMINet(Material=material).to(device)
# for inputs, features, s0 in train_loader:
#     print(f"inputs shape: {inputs.shape}")  # 包括 in_B, in_dB, in_dB_dt
#     print(f"features shape: {features.shape}")  # 包括 in_F, in_T
#     print(f"s0 shape: {s0.shape}")  # 初始化狀態向量
#     break

# 驗證輸出shape
# net = MMINet(Material=material).to(device)
# for inputs, features, s0 in train_loader:
#     # 提取輸入數據
#     inputs = inputs.to(device)  # in_B, in_dB, in_dB_dt
#     features = features.to(device)  # in_F, in_T
#     s0 = s0.to(device)  # 初始狀態向量

#     # 將數據傳入模型
#     outputs = net(inputs, features, s0)

#     # 打印輸出形狀與樣本數據
#     print(f"outputs shape: {outputs.shape}")
#     print(f"outputs data: {outputs[0]}")  # 打印第一個樣本的輸出波形數據
#     break

# %% [markdown]
# ### Start Train!!!

# %%
if __name__ == "__main__":

    data_B, data_F, data_T, data_H, data_Pcv = load_dataset(material)
    # norm_values = calculate_norm(data_B, data_H, data_F, data_T, data_Pcv)
    # print(norm_values)  # 輸出該材料的 (均值, 標準差)

    train_loader, valid_loader, norm = get_dataloader(data_B, data_F, data_T,
                                                      data_H, data_Pcv)

    train_model(norm, train_loader, valid_loader)
# Out:
# "N87": [
#     [-0.0039005703292787075, 0.060377106070518494],
#     [-0.5195177793502808, 11.593074798583984],
#     [5.180987358093262, 0.2678092122077942],
#     [58.85100173950195, 24.114748001098633],
#     [0.24289657175540924, 2.2880825996398926],
#     [4.625202178955078, 0.8005720973014832],
# ]
# Epoch 1, Train Loss: 0.849474, Validation Loss: 0.601206
# Saving model at epoch 1 with validation loss 0.601206...
# Epoch 2, Train Loss: 0.374956, Validation Loss: 0.134751
# Saving model at epoch 2 with validation loss 0.134751...
# Epoch 3, Train Loss: 0.098620, Validation Loss: 0.076957
# Saving model at epoch 3 with validation loss 0.076957...
# Epoch 4, Train Loss: 0.069072, Validation Loss: 0.058458
# Saving model at epoch 4 with validation loss 0.058458...
# Epoch 5, Train Loss: 0.054430, Validation Loss: 0.048371
# Saving model at epoch 5 with validation loss 0.048371...
# Epoch 6, Train Loss: 0.046155, Validation Loss: 0.041795
# Saving model at epoch 6 with validation loss 0.041795...
# Epoch 7, Train Loss: 0.041079, Validation Loss: 0.037751
# Saving model at epoch 7 with validation loss 0.037751...
# Epoch 8, Train Loss: 0.036752, Validation Loss: 0.035390
# Saving model at epoch 8 with validation loss 0.035390...
# Epoch 9, Train Loss: 0.034734, Validation Loss: 0.032842
# Saving model at epoch 9 with validation loss 0.032842...
# Epoch 10, Train Loss: 0.032411, Validation Loss: 0.031150
# Saving model at epoch 10 with validation loss 0.031150...
# Epoch 11, Train Loss: 0.031841, Validation Loss: 0.029871
# Saving model at epoch 11 with validation loss 0.029871...
# Epoch 12, Train Loss: 0.029897, Validation Loss: 0.029111
# Saving model at epoch 12 with validation loss 0.029111...
# Epoch 13, Train Loss: 0.029393, Validation Loss: 0.028075
# Saving model at epoch 13 with validation loss 0.028075...
# Epoch 14, Train Loss: 0.029015, Validation Loss: 0.027363
# Saving model at epoch 14 with validation loss 0.027363...
# Epoch 15, Train Loss: 0.027488, Validation Loss: 0.026894
# Saving model at epoch 15 with validation loss 0.026894...
# Epoch 16, Train Loss: 0.026936, Validation Loss: 0.026267
# Saving model at epoch 16 with validation loss 0.026267...
# Epoch 17, Train Loss: 0.026300, Validation Loss: 0.026103
# Saving model at epoch 17 with validation loss 0.026103...
# Epoch 18, Train Loss: 0.025950, Validation Loss: 0.025595
# Saving model at epoch 18 with validation loss 0.025595...
# Epoch 19, Train Loss: 0.025936, Validation Loss: 0.025153
# Saving model at epoch 19 with validation loss 0.025153...
# Epoch 20, Train Loss: 0.025179, Validation Loss: 0.025005
# Saving model at epoch 20 with validation loss 0.025005...
# Epoch 21, Train Loss: 0.024870, Validation Loss: 0.024614
# Saving model at epoch 21 with validation loss 0.024614...
# Epoch 22, Train Loss: 0.024900, Validation Loss: 0.024990
# Epoch 23, Train Loss: 0.024631, Validation Loss: 0.024065
# Saving model at epoch 23 with validation loss 0.024065...
# Epoch 24, Train Loss: 0.023914, Validation Loss: 0.023811
# Saving model at epoch 24 with validation loss 0.023811...
# Epoch 25, Train Loss: 0.023820, Validation Loss: 0.024168
# Epoch 26, Train Loss: 0.023481, Validation Loss: 0.023565
# Saving model at epoch 26 with validation loss 0.023565...
# Epoch 27, Train Loss: 0.023774, Validation Loss: 0.023142
# Saving model at epoch 27 with validation loss 0.023142...
# Epoch 28, Train Loss: 0.023576, Validation Loss: 0.022851
# Saving model at epoch 28 with validation loss 0.022851...
# Epoch 29, Train Loss: 0.022657, Validation Loss: 0.022654
# Saving model at epoch 29 with validation loss 0.022654...
# Epoch 30, Train Loss: 0.022391, Validation Loss: 0.022374
# Saving model at epoch 30 with validation loss 0.022374...
# Epoch 31, Train Loss: 0.021972, Validation Loss: 0.022249
# Saving model at epoch 31 with validation loss 0.022249...
# Epoch 32, Train Loss: 0.021711, Validation Loss: 0.022085
# Saving model at epoch 32 with validation loss 0.022085...
# Epoch 33, Train Loss: 0.021319, Validation Loss: 0.021878
# Saving model at epoch 33 with validation loss 0.021878...
# Epoch 34, Train Loss: 0.020957, Validation Loss: 0.021650
# Saving model at epoch 34 with validation loss 0.021650...
# Epoch 35, Train Loss: 0.021186, Validation Loss: 0.021432
# Saving model at epoch 35 with validation loss 0.021432...
# Epoch 36, Train Loss: 0.020739, Validation Loss: 0.021222
# Saving model at epoch 36 with validation loss 0.021222...
# Epoch 37, Train Loss: 0.020527, Validation Loss: 0.020970
# Saving model at epoch 37 with validation loss 0.020970...
# Epoch 38, Train Loss: 0.020549, Validation Loss: 0.020702
# Saving model at epoch 38 with validation loss 0.020702...
# Epoch 39, Train Loss: 0.019917, Validation Loss: 0.020544
# Saving model at epoch 39 with validation loss 0.020544...
# Epoch 40, Train Loss: 0.019640, Validation Loss: 0.020232
# Saving model at epoch 40 with validation loss 0.020232...
# Epoch 41, Train Loss: 0.019267, Validation Loss: 0.019911
# Saving model at epoch 41 with validation loss 0.019911...
# Epoch 42, Train Loss: 0.018858, Validation Loss: 0.019706
# Saving model at epoch 42 with validation loss 0.019706...
# Epoch 43, Train Loss: 0.018907, Validation Loss: 0.019837
# Epoch 44, Train Loss: 0.018431, Validation Loss: 0.019845
# Epoch 45, Train Loss: 0.018514, Validation Loss: 0.019619
# Saving model at epoch 45 with validation loss 0.019619...
# Epoch 46, Train Loss: 0.018309, Validation Loss: 0.019023
# Saving model at epoch 46 with validation loss 0.019023...
# Epoch 47, Train Loss: 0.017641, Validation Loss: 0.018599
# Saving model at epoch 47 with validation loss 0.018599...
# Epoch 48, Train Loss: 0.017520, Validation Loss: 0.018616
# Epoch 49, Train Loss: 0.017264, Validation Loss: 0.018817
# Epoch 50, Train Loss: 0.017077, Validation Loss: 0.018300
# Saving model at epoch 50 with validation loss 0.018300...
# Epoch 51, Train Loss: 0.016883, Validation Loss: 0.018346
# Epoch 52, Train Loss: 0.016946, Validation Loss: 0.018377
# Epoch 53, Train Loss: 0.016937, Validation Loss: 0.017977
# Saving model at epoch 53 with validation loss 0.017977...
# Epoch 54, Train Loss: 0.016679, Validation Loss: 0.017858
# Saving model at epoch 54 with validation loss 0.017858...
# Epoch 55, Train Loss: 0.016434, Validation Loss: 0.017823
# Saving model at epoch 55 with validation loss 0.017823...
# Epoch 56, Train Loss: 0.016076, Validation Loss: 0.018118
# Epoch 57, Train Loss: 0.016094, Validation Loss: 0.018516
# Epoch 58, Train Loss: 0.015856, Validation Loss: 0.017288
# Saving model at epoch 58 with validation loss 0.017288...
# Epoch 59, Train Loss: 0.016008, Validation Loss: 0.017195
# Saving model at epoch 59 with validation loss 0.017195...
# Epoch 60, Train Loss: 0.015709, Validation Loss: 0.017279
# Epoch 61, Train Loss: 0.015671, Validation Loss: 0.016939
# Saving model at epoch 61 with validation loss 0.016939...
# Epoch 62, Train Loss: 0.015488, Validation Loss: 0.017024
# Epoch 63, Train Loss: 0.015251, Validation Loss: 0.016774
# Saving model at epoch 63 with validation loss 0.016774...
# Epoch 64, Train Loss: 0.015027, Validation Loss: 0.017003
# Epoch 65, Train Loss: 0.015364, Validation Loss: 0.016530
# Saving model at epoch 65 with validation loss 0.016530...
# Epoch 66, Train Loss: 0.014642, Validation Loss: 0.016704
# Epoch 67, Train Loss: 0.014605, Validation Loss: 0.016910
# Epoch 68, Train Loss: 0.014621, Validation Loss: 0.017258
# Epoch 69, Train Loss: 0.014876, Validation Loss: 0.016723
# Epoch 70, Train Loss: 0.015110, Validation Loss: 0.016676
# Epoch 71, Train Loss: 0.014260, Validation Loss: 0.016221
# Saving model at epoch 71 with validation loss 0.016221...
# Epoch 72, Train Loss: 0.014022, Validation Loss: 0.016120
# Saving model at epoch 72 with validation loss 0.016120...
# Epoch 73, Train Loss: 0.014167, Validation Loss: 0.015756
# Saving model at epoch 73 with validation loss 0.015756...
# Epoch 74, Train Loss: 0.014246, Validation Loss: 0.015793
# Epoch 75, Train Loss: 0.013919, Validation Loss: 0.016038
# Epoch 76, Train Loss: 0.013749, Validation Loss: 0.015739
# Saving model at epoch 76 with validation loss 0.015739...
# Epoch 77, Train Loss: 0.013995, Validation Loss: 0.017746
# Epoch 78, Train Loss: 0.014235, Validation Loss: 0.015441
# Saving model at epoch 78 with validation loss 0.015441...
# Epoch 79, Train Loss: 0.013287, Validation Loss: 0.015440
# Saving model at epoch 79 with validation loss 0.015440...
# Epoch 80, Train Loss: 0.013246, Validation Loss: 0.015897
# Epoch 81, Train Loss: 0.013330, Validation Loss: 0.015460
# Epoch 82, Train Loss: 0.013306, Validation Loss: 0.017972
# Epoch 83, Train Loss: 0.013943, Validation Loss: 0.016737
# Epoch 84, Train Loss: 0.013528, Validation Loss: 0.015023
# Saving model at epoch 84 with validation loss 0.015023...
# Epoch 85, Train Loss: 0.012882, Validation Loss: 0.014772
# Saving model at epoch 85 with validation loss 0.014772...
# Epoch 86, Train Loss: 0.012678, Validation Loss: 0.014661
# Saving model at epoch 86 with validation loss 0.014661...
# Epoch 87, Train Loss: 0.012869, Validation Loss: 0.015421
# Epoch 88, Train Loss: 0.012692, Validation Loss: 0.015243
# Epoch 89, Train Loss: 0.012261, Validation Loss: 0.014736
# Epoch 90, Train Loss: 0.012248, Validation Loss: 0.014419
# Saving model at epoch 90 with validation loss 0.014419...
# Epoch 91, Train Loss: 0.011973, Validation Loss: 0.016457
# Epoch 92, Train Loss: 0.012524, Validation Loss: 0.015291
# Epoch 93, Train Loss: 0.014018, Validation Loss: 0.014440
# Epoch 94, Train Loss: 0.011721, Validation Loss: 0.014515
# Epoch 95, Train Loss: 0.011735, Validation Loss: 0.015726
# Epoch 96, Train Loss: 0.011744, Validation Loss: 0.014296
# Saving model at epoch 96 with validation loss 0.014296...
# Epoch 97, Train Loss: 0.011726, Validation Loss: 0.014757
# Epoch 98, Train Loss: 0.011732, Validation Loss: 0.019352
# Epoch 99, Train Loss: 0.012483, Validation Loss: 0.014975
# Epoch 100, Train Loss: 0.011670, Validation Loss: 0.015559
# Epoch 101, Train Loss: 0.011493, Validation Loss: 0.014531
# Epoch 102, Train Loss: 0.011308, Validation Loss: 0.013968
# Saving model at epoch 102 with validation loss 0.013968...
# Epoch 103, Train Loss: 0.011155, Validation Loss: 0.020749
# Epoch 104, Train Loss: 0.013649, Validation Loss: 0.014296
# Epoch 105, Train Loss: 0.011035, Validation Loss: 0.013843
# Saving model at epoch 105 with validation loss 0.013843...
# Epoch 106, Train Loss: 0.010927, Validation Loss: 0.014606
# Epoch 107, Train Loss: 0.010963, Validation Loss: 0.015488
# Epoch 108, Train Loss: 0.011761, Validation Loss: 0.013866
# Epoch 109, Train Loss: 0.010735, Validation Loss: 0.014417
# Epoch 110, Train Loss: 0.010840, Validation Loss: 0.013831
# Saving model at epoch 110 with validation loss 0.013831...
# Epoch 111, Train Loss: 0.010995, Validation Loss: 0.015259
# Epoch 112, Train Loss: 0.011676, Validation Loss: 0.013636
# Saving model at epoch 112 with validation loss 0.013636...
# Epoch 113, Train Loss: 0.010578, Validation Loss: 0.013966
# Epoch 114, Train Loss: 0.010605, Validation Loss: 0.014276
# Epoch 115, Train Loss: 0.010813, Validation Loss: 0.013695
# Epoch 116, Train Loss: 0.010794, Validation Loss: 0.013662
# Epoch 117, Train Loss: 0.010440, Validation Loss: 0.014199
# Epoch 118, Train Loss: 0.010950, Validation Loss: 0.014442
# Epoch 119, Train Loss: 0.010626, Validation Loss: 0.015454
# Epoch 120, Train Loss: 0.010621, Validation Loss: 0.014824
# Epoch 121, Train Loss: 0.010631, Validation Loss: 0.013553
# Saving model at epoch 121 with validation loss 0.013553...
# Epoch 122, Train Loss: 0.010679, Validation Loss: 0.015227
# Epoch 123, Train Loss: 0.011092, Validation Loss: 0.013668
# Epoch 124, Train Loss: 0.010117, Validation Loss: 0.013633
# Epoch 125, Train Loss: 0.010151, Validation Loss: 0.013479
# Saving model at epoch 125 with validation loss 0.013479...
# Epoch 126, Train Loss: 0.010128, Validation Loss: 0.013164
# Saving model at epoch 126 with validation loss 0.013164...
# Epoch 127, Train Loss: 0.010169, Validation Loss: 0.013778
# Epoch 128, Train Loss: 0.010779, Validation Loss: 0.015513
# Epoch 129, Train Loss: 0.010067, Validation Loss: 0.014303
# Epoch 130, Train Loss: 0.009915, Validation Loss: 0.014774
# Epoch 131, Train Loss: 0.010254, Validation Loss: 0.013209
# Epoch 132, Train Loss: 0.010078, Validation Loss: 0.014610
# Epoch 133, Train Loss: 0.010503, Validation Loss: 0.015411
# Epoch 134, Train Loss: 0.010236, Validation Loss: 0.013524
# Epoch 135, Train Loss: 0.010277, Validation Loss: 0.016197
# Epoch 136, Train Loss: 0.010646, Validation Loss: 0.014693
# Epoch 137, Train Loss: 0.009738, Validation Loss: 0.015003
# Epoch 138, Train Loss: 0.009920, Validation Loss: 0.014982
# Epoch 139, Train Loss: 0.009888, Validation Loss: 0.014367
# Epoch 140, Train Loss: 0.010622, Validation Loss: 0.014750
# Epoch 141, Train Loss: 0.009935, Validation Loss: 0.013317
# Epoch 142, Train Loss: 0.009529, Validation Loss: 0.013655
# Epoch 143, Train Loss: 0.009893, Validation Loss: 0.014511
# Epoch 144, Train Loss: 0.009554, Validation Loss: 0.013552
# Epoch 145, Train Loss: 0.009375, Validation Loss: 0.014022
# Epoch 146, Train Loss: 0.009468, Validation Loss: 0.013672
# Epoch 147, Train Loss: 0.009490, Validation Loss: 0.013377
# Epoch 148, Train Loss: 0.009366, Validation Loss: 0.014275
# Epoch 149, Train Loss: 0.010354, Validation Loss: 0.013627
# Epoch 150, Train Loss: 0.009490, Validation Loss: 0.014094
# Epoch 151, Train Loss: 0.009170, Validation Loss: 0.013912
# Epoch 152, Train Loss: 0.009207, Validation Loss: 0.013405
# Epoch 153, Train Loss: 0.009912, Validation Loss: 0.013506
# Epoch 154, Train Loss: 0.009655, Validation Loss: 0.013724
# Epoch 155, Train Loss: 0.009116, Validation Loss: 0.013180
# Epoch 156, Train Loss: 0.009186, Validation Loss: 0.013573
# Epoch 157, Train Loss: 0.009003, Validation Loss: 0.013423
# Epoch 158, Train Loss: 0.009581, Validation Loss: 0.018034
# Epoch 159, Train Loss: 0.010233, Validation Loss: 0.014078
# Epoch 160, Train Loss: 0.008956, Validation Loss: 0.014048
# Epoch 161, Train Loss: 0.009601, Validation Loss: 0.014577
# Epoch 162, Train Loss: 0.008850, Validation Loss: 0.013172
# Epoch 163, Train Loss: 0.009133, Validation Loss: 0.013312
# Epoch 164, Train Loss: 0.009102, Validation Loss: 0.013422
# Epoch 165, Train Loss: 0.009378, Validation Loss: 0.013488
# Epoch 166, Train Loss: 0.008877, Validation Loss: 0.013836
# Epoch 167, Train Loss: 0.008987, Validation Loss: 0.015386
# Epoch 168, Train Loss: 0.009835, Validation Loss: 0.013178
# Epoch 169, Train Loss: 0.008655, Validation Loss: 0.013531
# Epoch 170, Train Loss: 0.008547, Validation Loss: 0.013583
# Epoch 171, Train Loss: 0.008841, Validation Loss: 0.013149
# Saving model at epoch 171 with validation loss 0.013149...
# Epoch 172, Train Loss: 0.008889, Validation Loss: 0.017243
# Epoch 173, Train Loss: 0.011511, Validation Loss: 0.013703
# Epoch 174, Train Loss: 0.008886, Validation Loss: 0.013158
# Epoch 175, Train Loss: 0.008557, Validation Loss: 0.013251
# Epoch 176, Train Loss: 0.008434, Validation Loss: 0.013022
# Saving model at epoch 176 with validation loss 0.013022...
# Epoch 177, Train Loss: 0.008607, Validation Loss: 0.014189
# Epoch 178, Train Loss: 0.008756, Validation Loss: 0.013399
# Epoch 179, Train Loss: 0.009019, Validation Loss: 0.013625
# Epoch 180, Train Loss: 0.008344, Validation Loss: 0.013430
# Epoch 181, Train Loss: 0.008265, Validation Loss: 0.014293
# Epoch 182, Train Loss: 0.008351, Validation Loss: 0.012986
# Saving model at epoch 182 with validation loss 0.012986...
# Epoch 183, Train Loss: 0.008165, Validation Loss: 0.013503
# Epoch 184, Train Loss: 0.008744, Validation Loss: 0.013103
# Epoch 185, Train Loss: 0.008365, Validation Loss: 0.013751
# Epoch 186, Train Loss: 0.008926, Validation Loss: 0.013827
# Epoch 187, Train Loss: 0.008431, Validation Loss: 0.013468
# Epoch 188, Train Loss: 0.008562, Validation Loss: 0.013099
# Epoch 189, Train Loss: 0.008271, Validation Loss: 0.014752
# Epoch 190, Train Loss: 0.008406, Validation Loss: 0.013755
# Epoch 191, Train Loss: 0.009311, Validation Loss: 0.013594
# Epoch 192, Train Loss: 0.008285, Validation Loss: 0.014520
# Epoch 193, Train Loss: 0.009227, Validation Loss: 0.013274
# Epoch 194, Train Loss: 0.008060, Validation Loss: 0.013244
# Epoch 195, Train Loss: 0.008557, Validation Loss: 0.014527
# Epoch 196, Train Loss: 0.008804, Validation Loss: 0.013057
# Epoch 197, Train Loss: 0.008647, Validation Loss: 0.013093
# Epoch 198, Train Loss: 0.008363, Validation Loss: 0.013239
# Epoch 199, Train Loss: 0.008319, Validation Loss: 0.013835
# Epoch 200, Train Loss: 0.008216, Validation Loss: 0.014782
# Epoch 201, Train Loss: 0.008414, Validation Loss: 0.013488
# Epoch 202, Train Loss: 0.008142, Validation Loss: 0.013049
# Epoch 203, Train Loss: 0.008034, Validation Loss: 0.012944
# Saving model at epoch 203 with validation loss 0.012944...
# Epoch 204, Train Loss: 0.007992, Validation Loss: 0.013063
# Epoch 205, Train Loss: 0.008219, Validation Loss: 0.013110
# Epoch 206, Train Loss: 0.007924, Validation Loss: 0.013403
# Epoch 207, Train Loss: 0.008317, Validation Loss: 0.013089
# Epoch 208, Train Loss: 0.008017, Validation Loss: 0.014103
# Epoch 209, Train Loss: 0.008012, Validation Loss: 0.013131
# Epoch 210, Train Loss: 0.008276, Validation Loss: 0.015860
# Epoch 211, Train Loss: 0.009795, Validation Loss: 0.015161
# Epoch 212, Train Loss: 0.008471, Validation Loss: 0.013705
# Epoch 213, Train Loss: 0.008254, Validation Loss: 0.012956
# Epoch 214, Train Loss: 0.007797, Validation Loss: 0.013123
# Epoch 215, Train Loss: 0.007963, Validation Loss: 0.013470
# Epoch 216, Train Loss: 0.008898, Validation Loss: 0.013716
# Epoch 217, Train Loss: 0.007796, Validation Loss: 0.012947
# Epoch 218, Train Loss: 0.008101, Validation Loss: 0.013106
# Epoch 219, Train Loss: 0.008216, Validation Loss: 0.013231
# Epoch 220, Train Loss: 0.008198, Validation Loss: 0.015544
# Epoch 221, Train Loss: 0.008365, Validation Loss: 0.013086
# Epoch 222, Train Loss: 0.007557, Validation Loss: 0.012896
# Saving model at epoch 222 with validation loss 0.012896...
# Epoch 223, Train Loss: 0.008093, Validation Loss: 0.012998
# Epoch 224, Train Loss: 0.007743, Validation Loss: 0.013055
# Epoch 225, Train Loss: 0.008063, Validation Loss: 0.014587
# Epoch 226, Train Loss: 0.008525, Validation Loss: 0.013343
# Epoch 227, Train Loss: 0.007891, Validation Loss: 0.012769
# Saving model at epoch 227 with validation loss 0.012769...
# Epoch 228, Train Loss: 0.007735, Validation Loss: 0.013886
# Epoch 229, Train Loss: 0.008621, Validation Loss: 0.013634
# Epoch 230, Train Loss: 0.007724, Validation Loss: 0.013361
# Epoch 231, Train Loss: 0.008206, Validation Loss: 0.013051
# Epoch 232, Train Loss: 0.008308, Validation Loss: 0.013110
# Epoch 233, Train Loss: 0.007767, Validation Loss: 0.013355
# Epoch 234, Train Loss: 0.007958, Validation Loss: 0.013383
# Epoch 235, Train Loss: 0.008016, Validation Loss: 0.013375
# Epoch 236, Train Loss: 0.007576, Validation Loss: 0.012869
# Epoch 237, Train Loss: 0.007533, Validation Loss: 0.013479
# Epoch 238, Train Loss: 0.007973, Validation Loss: 0.012853
# Epoch 239, Train Loss: 0.007858, Validation Loss: 0.012843
# Epoch 240, Train Loss: 0.007769, Validation Loss: 0.013608
# Epoch 241, Train Loss: 0.008253, Validation Loss: 0.015727
# Epoch 242, Train Loss: 0.009074, Validation Loss: 0.013374
# Epoch 243, Train Loss: 0.008637, Validation Loss: 0.013213
# Epoch 244, Train Loss: 0.007572, Validation Loss: 0.012979
# Epoch 245, Train Loss: 0.007484, Validation Loss: 0.013618
# Epoch 246, Train Loss: 0.007720, Validation Loss: 0.013144
# Epoch 247, Train Loss: 0.007914, Validation Loss: 0.013190
# Epoch 248, Train Loss: 0.007710, Validation Loss: 0.013615
# Epoch 249, Train Loss: 0.007474, Validation Loss: 0.012765
# Saving model at epoch 249 with validation loss 0.012765...
# Epoch 250, Train Loss: 0.007565, Validation Loss: 0.013117
# Epoch 251, Train Loss: 0.008115, Validation Loss: 0.015556
# Epoch 252, Train Loss: 0.007755, Validation Loss: 0.013171
# Epoch 253, Train Loss: 0.007301, Validation Loss: 0.012932
# Epoch 254, Train Loss: 0.007350, Validation Loss: 0.013059
# Epoch 255, Train Loss: 0.008122, Validation Loss: 0.016655
# Epoch 256, Train Loss: 0.008684, Validation Loss: 0.014693
# Epoch 257, Train Loss: 0.007603, Validation Loss: 0.013723
# Epoch 258, Train Loss: 0.007648, Validation Loss: 0.013092
# Epoch 259, Train Loss: 0.007552, Validation Loss: 0.012878
# Epoch 260, Train Loss: 0.007384, Validation Loss: 0.013839
# Epoch 261, Train Loss: 0.008214, Validation Loss: 0.012952
# Epoch 262, Train Loss: 0.007345, Validation Loss: 0.013016
# Epoch 263, Train Loss: 0.007533, Validation Loss: 0.012930
# Epoch 264, Train Loss: 0.007536, Validation Loss: 0.013159
# Epoch 265, Train Loss: 0.007426, Validation Loss: 0.012873
# Epoch 266, Train Loss: 0.007497, Validation Loss: 0.014265
# Epoch 267, Train Loss: 0.007929, Validation Loss: 0.012942
# Epoch 268, Train Loss: 0.007740, Validation Loss: 0.013974
# Epoch 269, Train Loss: 0.007567, Validation Loss: 0.012886
# Epoch 270, Train Loss: 0.007366, Validation Loss: 0.014995
# Epoch 271, Train Loss: 0.007870, Validation Loss: 0.013959
# Epoch 272, Train Loss: 0.007782, Validation Loss: 0.013147
# Epoch 273, Train Loss: 0.007382, Validation Loss: 0.012840
# Epoch 274, Train Loss: 0.007570, Validation Loss: 0.012781
# Epoch 275, Train Loss: 0.007546, Validation Loss: 0.013104
# Epoch 276, Train Loss: 0.007378, Validation Loss: 0.012781
# Epoch 277, Train Loss: 0.007696, Validation Loss: 0.012968
# Epoch 278, Train Loss: 0.007774, Validation Loss: 0.012854
# Epoch 279, Train Loss: 0.007554, Validation Loss: 0.013395
# Epoch 280, Train Loss: 0.007265, Validation Loss: 0.013926
# Epoch 281, Train Loss: 0.007569, Validation Loss: 0.013203
# Epoch 282, Train Loss: 0.007390, Validation Loss: 0.013608
# Epoch 283, Train Loss: 0.007291, Validation Loss: 0.013563
# Epoch 284, Train Loss: 0.007896, Validation Loss: 0.012850
# Epoch 285, Train Loss: 0.007216, Validation Loss: 0.013395
# Epoch 286, Train Loss: 0.007683, Validation Loss: 0.013571
# Epoch 287, Train Loss: 0.007606, Validation Loss: 0.012724
# Saving model at epoch 287 with validation loss 0.012724...
# Epoch 288, Train Loss: 0.007284, Validation Loss: 0.013746
# Epoch 289, Train Loss: 0.007663, Validation Loss: 0.012963
# Epoch 290, Train Loss: 0.007157, Validation Loss: 0.013791
# Epoch 291, Train Loss: 0.007354, Validation Loss: 0.013191
# Epoch 292, Train Loss: 0.007778, Validation Loss: 0.013118
# Epoch 293, Train Loss: 0.007299, Validation Loss: 0.012731
# Epoch 294, Train Loss: 0.007285, Validation Loss: 0.013334
# Epoch 295, Train Loss: 0.007376, Validation Loss: 0.013507
# Epoch 296, Train Loss: 0.007362, Validation Loss: 0.013106
# Epoch 297, Train Loss: 0.008332, Validation Loss: 0.012879
# Epoch 298, Train Loss: 0.007485, Validation Loss: 0.014225
# Epoch 299, Train Loss: 0.007295, Validation Loss: 0.012776
# Epoch 300, Train Loss: 0.007333, Validation Loss: 0.012783
# Epoch 301, Train Loss: 0.007701, Validation Loss: 0.013068
# Epoch 302, Train Loss: 0.007465, Validation Loss: 0.014592
# Epoch 303, Train Loss: 0.007889, Validation Loss: 0.013583
# Epoch 304, Train Loss: 0.007329, Validation Loss: 0.013324
# Epoch 305, Train Loss: 0.007253, Validation Loss: 0.013396
# Epoch 306, Train Loss: 0.007453, Validation Loss: 0.013456
# Epoch 307, Train Loss: 0.007409, Validation Loss: 0.013317
# Epoch 308, Train Loss: 0.007527, Validation Loss: 0.013213
# Epoch 309, Train Loss: 0.007515, Validation Loss: 0.012862
# Epoch 310, Train Loss: 0.007268, Validation Loss: 0.012858
# Epoch 311, Train Loss: 0.007391, Validation Loss: 0.012609
# Saving model at epoch 311 with validation loss 0.012609...
# Epoch 312, Train Loss: 0.007286, Validation Loss: 0.013921
# Epoch 313, Train Loss: 0.007975, Validation Loss: 0.013120
# Epoch 314, Train Loss: 0.008175, Validation Loss: 0.014085
# Epoch 315, Train Loss: 0.007269, Validation Loss: 0.013070
# Epoch 316, Train Loss: 0.007108, Validation Loss: 0.012741
# Epoch 317, Train Loss: 0.007044, Validation Loss: 0.013192
# Epoch 318, Train Loss: 0.007061, Validation Loss: 0.012782
# Epoch 319, Train Loss: 0.007267, Validation Loss: 0.012506
# Saving model at epoch 319 with validation loss 0.012506...
# Epoch 320, Train Loss: 0.007337, Validation Loss: 0.013616
# Epoch 321, Train Loss: 0.007265, Validation Loss: 0.012762
# Epoch 322, Train Loss: 0.007145, Validation Loss: 0.012916
# Epoch 323, Train Loss: 0.007333, Validation Loss: 0.013325
# Epoch 324, Train Loss: 0.007596, Validation Loss: 0.012895
# Epoch 325, Train Loss: 0.007308, Validation Loss: 0.013844
# Epoch 326, Train Loss: 0.007203, Validation Loss: 0.013017
# Epoch 327, Train Loss: 0.007343, Validation Loss: 0.012776
# Epoch 328, Train Loss: 0.007071, Validation Loss: 0.012919
# Epoch 329, Train Loss: 0.007744, Validation Loss: 0.013042
# Epoch 330, Train Loss: 0.006943, Validation Loss: 0.013065
# Epoch 331, Train Loss: 0.007088, Validation Loss: 0.013466
# Epoch 332, Train Loss: 0.007298, Validation Loss: 0.013190
# Epoch 333, Train Loss: 0.007610, Validation Loss: 0.014231
# Epoch 334, Train Loss: 0.007243, Validation Loss: 0.013082
# Epoch 335, Train Loss: 0.007205, Validation Loss: 0.015924
# Epoch 336, Train Loss: 0.007993, Validation Loss: 0.014716
# Epoch 337, Train Loss: 0.007411, Validation Loss: 0.013136
# Epoch 338, Train Loss: 0.007282, Validation Loss: 0.013147
# Epoch 339, Train Loss: 0.007268, Validation Loss: 0.012859
# Epoch 340, Train Loss: 0.007601, Validation Loss: 0.012845
# Epoch 341, Train Loss: 0.007187, Validation Loss: 0.012844
# Epoch 342, Train Loss: 0.006893, Validation Loss: 0.012901
# Epoch 343, Train Loss: 0.007343, Validation Loss: 0.013159
# Epoch 344, Train Loss: 0.007275, Validation Loss: 0.012862
# Epoch 345, Train Loss: 0.007045, Validation Loss: 0.014174
# Epoch 346, Train Loss: 0.007088, Validation Loss: 0.013168
# Epoch 347, Train Loss: 0.007124, Validation Loss: 0.014666
# Epoch 348, Train Loss: 0.007325, Validation Loss: 0.012815
# Epoch 349, Train Loss: 0.007120, Validation Loss: 0.013079
# Epoch 350, Train Loss: 0.007069, Validation Loss: 0.013740
# Epoch 351, Train Loss: 0.007278, Validation Loss: 0.012826
# Epoch 352, Train Loss: 0.007106, Validation Loss: 0.013293
# Epoch 353, Train Loss: 0.007537, Validation Loss: 0.012887
# Epoch 354, Train Loss: 0.007244, Validation Loss: 0.012726
# Epoch 355, Train Loss: 0.007976, Validation Loss: 0.012864
# Epoch 356, Train Loss: 0.007330, Validation Loss: 0.012661
# Epoch 357, Train Loss: 0.006808, Validation Loss: 0.013004
# Epoch 358, Train Loss: 0.007156, Validation Loss: 0.012731
# Epoch 359, Train Loss: 0.007076, Validation Loss: 0.012591
# Epoch 360, Train Loss: 0.007129, Validation Loss: 0.012907
# Epoch 361, Train Loss: 0.007193, Validation Loss: 0.013008
# Epoch 362, Train Loss: 0.007401, Validation Loss: 0.013890
# Epoch 363, Train Loss: 0.007418, Validation Loss: 0.012930
# Epoch 364, Train Loss: 0.007195, Validation Loss: 0.014846
# Epoch 365, Train Loss: 0.007638, Validation Loss: 0.012527
# Epoch 366, Train Loss: 0.006941, Validation Loss: 0.012636
# Epoch 367, Train Loss: 0.007308, Validation Loss: 0.012753
# Epoch 368, Train Loss: 0.006949, Validation Loss: 0.012720
# Epoch 369, Train Loss: 0.006990, Validation Loss: 0.013007
# Epoch 370, Train Loss: 0.006860, Validation Loss: 0.013255
# Epoch 371, Train Loss: 0.006895, Validation Loss: 0.012756
# Epoch 372, Train Loss: 0.007351, Validation Loss: 0.012678
# Epoch 373, Train Loss: 0.007101, Validation Loss: 0.012754
# Epoch 374, Train Loss: 0.007305, Validation Loss: 0.013021
# Epoch 375, Train Loss: 0.007106, Validation Loss: 0.012357
# Saving model at epoch 375 with validation loss 0.012357...
# Epoch 376, Train Loss: 0.007009, Validation Loss: 0.012452
# Epoch 377, Train Loss: 0.007154, Validation Loss: 0.013238
# Epoch 378, Train Loss: 0.007894, Validation Loss: 0.013087
# Epoch 379, Train Loss: 0.007125, Validation Loss: 0.013491
# Epoch 380, Train Loss: 0.007074, Validation Loss: 0.012701
# Epoch 381, Train Loss: 0.006843, Validation Loss: 0.013770
# Epoch 382, Train Loss: 0.007475, Validation Loss: 0.012634
# Epoch 383, Train Loss: 0.007242, Validation Loss: 0.013414
# Epoch 384, Train Loss: 0.007137, Validation Loss: 0.012815
# Epoch 385, Train Loss: 0.007095, Validation Loss: 0.012694
# Epoch 386, Train Loss: 0.007384, Validation Loss: 0.012813
# Epoch 387, Train Loss: 0.006941, Validation Loss: 0.012852
# Epoch 388, Train Loss: 0.007455, Validation Loss: 0.012519
# Epoch 389, Train Loss: 0.007070, Validation Loss: 0.012807
# Epoch 390, Train Loss: 0.007205, Validation Loss: 0.012818
# Epoch 391, Train Loss: 0.006939, Validation Loss: 0.013799
# Epoch 392, Train Loss: 0.007069, Validation Loss: 0.012574
# Epoch 393, Train Loss: 0.007132, Validation Loss: 0.012657
# Epoch 394, Train Loss: 0.006865, Validation Loss: 0.012797
# Epoch 395, Train Loss: 0.006974, Validation Loss: 0.013000
# Epoch 396, Train Loss: 0.007189, Validation Loss: 0.012868
# Epoch 397, Train Loss: 0.007037, Validation Loss: 0.012835
# Epoch 398, Train Loss: 0.006869, Validation Loss: 0.012943
# Epoch 399, Train Loss: 0.007034, Validation Loss: 0.013897
# Epoch 400, Train Loss: 0.007418, Validation Loss: 0.012801
# Epoch 401, Train Loss: 0.006882, Validation Loss: 0.012846
# Epoch 402, Train Loss: 0.007220, Validation Loss: 0.012971
# Epoch 403, Train Loss: 0.007061, Validation Loss: 0.012488
# Epoch 404, Train Loss: 0.006930, Validation Loss: 0.012506
# Epoch 405, Train Loss: 0.007643, Validation Loss: 0.014429
# Epoch 406, Train Loss: 0.007332, Validation Loss: 0.012788
# Epoch 407, Train Loss: 0.006896, Validation Loss: 0.012402
# Epoch 408, Train Loss: 0.007042, Validation Loss: 0.012596
# Epoch 409, Train Loss: 0.006851, Validation Loss: 0.012489
# Epoch 410, Train Loss: 0.007276, Validation Loss: 0.012248
# Saving model at epoch 410 with validation loss 0.012248...
# Epoch 411, Train Loss: 0.007127, Validation Loss: 0.012607
# Epoch 412, Train Loss: 0.006850, Validation Loss: 0.012431
# Epoch 413, Train Loss: 0.007145, Validation Loss: 0.015641
# Epoch 414, Train Loss: 0.008100, Validation Loss: 0.014230
# Epoch 415, Train Loss: 0.007132, Validation Loss: 0.012378
# Epoch 416, Train Loss: 0.006784, Validation Loss: 0.012466
# Epoch 417, Train Loss: 0.006965, Validation Loss: 0.012394
# Epoch 418, Train Loss: 0.007073, Validation Loss: 0.013484
# Epoch 419, Train Loss: 0.007464, Validation Loss: 0.012437
# Epoch 420, Train Loss: 0.006868, Validation Loss: 0.012476
# Epoch 421, Train Loss: 0.006834, Validation Loss: 0.012454
# Epoch 422, Train Loss: 0.007323, Validation Loss: 0.012616
# Epoch 423, Train Loss: 0.006724, Validation Loss: 0.012948
# Epoch 424, Train Loss: 0.006868, Validation Loss: 0.012255
# Epoch 425, Train Loss: 0.006946, Validation Loss: 0.013510
# Epoch 426, Train Loss: 0.007040, Validation Loss: 0.012959
# Epoch 427, Train Loss: 0.007128, Validation Loss: 0.012420
# Epoch 428, Train Loss: 0.006976, Validation Loss: 0.012892
# Epoch 429, Train Loss: 0.007331, Validation Loss: 0.013034
# Epoch 430, Train Loss: 0.007090, Validation Loss: 0.012592
# Epoch 431, Train Loss: 0.007584, Validation Loss: 0.013444
# Epoch 432, Train Loss: 0.006882, Validation Loss: 0.012399
# Epoch 433, Train Loss: 0.006731, Validation Loss: 0.012216
# Saving model at epoch 433 with validation loss 0.012216...
# Epoch 434, Train Loss: 0.006718, Validation Loss: 0.012733
# Epoch 435, Train Loss: 0.006640, Validation Loss: 0.012369
# Epoch 436, Train Loss: 0.007036, Validation Loss: 0.012768
# Epoch 437, Train Loss: 0.007457, Validation Loss: 0.012367
# Epoch 438, Train Loss: 0.006989, Validation Loss: 0.013567
# Epoch 439, Train Loss: 0.006944, Validation Loss: 0.014371
# Epoch 440, Train Loss: 0.007020, Validation Loss: 0.012403
# Epoch 441, Train Loss: 0.006752, Validation Loss: 0.012401
# Epoch 442, Train Loss: 0.006948, Validation Loss: 0.013622
# Epoch 443, Train Loss: 0.007296, Validation Loss: 0.012748
# Epoch 444, Train Loss: 0.006989, Validation Loss: 0.012198
# Saving model at epoch 444 with validation loss 0.012198...
# Epoch 445, Train Loss: 0.006840, Validation Loss: 0.012452
# Epoch 446, Train Loss: 0.007020, Validation Loss: 0.012475
# Epoch 447, Train Loss: 0.006961, Validation Loss: 0.012657
# Epoch 448, Train Loss: 0.006783, Validation Loss: 0.012575
# Epoch 449, Train Loss: 0.006757, Validation Loss: 0.012433
# Epoch 450, Train Loss: 0.006868, Validation Loss: 0.012708
# Epoch 451, Train Loss: 0.006787, Validation Loss: 0.012125
# Saving model at epoch 451 with validation loss 0.012125...
# Epoch 452, Train Loss: 0.006668, Validation Loss: 0.012189
# Epoch 453, Train Loss: 0.007363, Validation Loss: 0.013069
# Epoch 454, Train Loss: 0.006788, Validation Loss: 0.012457
# Epoch 455, Train Loss: 0.007203, Validation Loss: 0.012856
# Epoch 456, Train Loss: 0.006938, Validation Loss: 0.012585
# Epoch 457, Train Loss: 0.007104, Validation Loss: 0.012817
# Epoch 458, Train Loss: 0.006986, Validation Loss: 0.014174
# Epoch 459, Train Loss: 0.008444, Validation Loss: 0.012867
# Epoch 460, Train Loss: 0.007498, Validation Loss: 0.013052
# Epoch 461, Train Loss: 0.006790, Validation Loss: 0.012080
# Saving model at epoch 461 with validation loss 0.012080...
# Epoch 462, Train Loss: 0.006766, Validation Loss: 0.012018
# Saving model at epoch 462 with validation loss 0.012018...
# Epoch 463, Train Loss: 0.006711, Validation Loss: 0.012216
# Epoch 464, Train Loss: 0.007222, Validation Loss: 0.013018
# Epoch 465, Train Loss: 0.006978, Validation Loss: 0.012397
# Epoch 466, Train Loss: 0.006564, Validation Loss: 0.011964
# Saving model at epoch 466 with validation loss 0.011964...
# Epoch 467, Train Loss: 0.006586, Validation Loss: 0.012036
# Epoch 468, Train Loss: 0.006862, Validation Loss: 0.011923
# Saving model at epoch 468 with validation loss 0.011923...
# Epoch 469, Train Loss: 0.007046, Validation Loss: 0.013815
# Epoch 470, Train Loss: 0.007133, Validation Loss: 0.012265
# Epoch 471, Train Loss: 0.006817, Validation Loss: 0.012442
# Epoch 472, Train Loss: 0.007240, Validation Loss: 0.012332
# Epoch 473, Train Loss: 0.007214, Validation Loss: 0.011964
# Epoch 474, Train Loss: 0.006852, Validation Loss: 0.012183
# Epoch 475, Train Loss: 0.006587, Validation Loss: 0.012145
# Epoch 476, Train Loss: 0.006681, Validation Loss: 0.012050
# Epoch 477, Train Loss: 0.007616, Validation Loss: 0.013019
# Epoch 478, Train Loss: 0.006735, Validation Loss: 0.012206
# Epoch 479, Train Loss: 0.006779, Validation Loss: 0.011798
# Saving model at epoch 479 with validation loss 0.011798...
# Epoch 480, Train Loss: 0.006648, Validation Loss: 0.012102
# Epoch 481, Train Loss: 0.006949, Validation Loss: 0.014394
# Epoch 482, Train Loss: 0.007135, Validation Loss: 0.014622
# Epoch 483, Train Loss: 0.007685, Validation Loss: 0.012198
# Epoch 484, Train Loss: 0.006685, Validation Loss: 0.012225
# Epoch 485, Train Loss: 0.006625, Validation Loss: 0.011985
# Epoch 486, Train Loss: 0.006778, Validation Loss: 0.012761
# Epoch 487, Train Loss: 0.006792, Validation Loss: 0.012151
# Epoch 488, Train Loss: 0.006620, Validation Loss: 0.012167
# Epoch 489, Train Loss: 0.006961, Validation Loss: 0.013055
# Epoch 490, Train Loss: 0.006910, Validation Loss: 0.013013
# Epoch 491, Train Loss: 0.007039, Validation Loss: 0.012102
# Epoch 492, Train Loss: 0.006658, Validation Loss: 0.012093
# Epoch 493, Train Loss: 0.006788, Validation Loss: 0.014950
# Epoch 494, Train Loss: 0.007011, Validation Loss: 0.012119
# Epoch 495, Train Loss: 0.006670, Validation Loss: 0.012254
# Epoch 496, Train Loss: 0.007378, Validation Loss: 0.012224
# Epoch 497, Train Loss: 0.006893, Validation Loss: 0.011867
# Epoch 498, Train Loss: 0.006683, Validation Loss: 0.013174
# Epoch 499, Train Loss: 0.007139, Validation Loss: 0.012507
# Epoch 500, Train Loss: 0.007158, Validation Loss: 0.012096
# Epoch 501, Train Loss: 0.006558, Validation Loss: 0.013001
# Epoch 502, Train Loss: 0.007185, Validation Loss: 0.012103
# Epoch 503, Train Loss: 0.006608, Validation Loss: 0.011923
# Epoch 504, Train Loss: 0.006567, Validation Loss: 0.012019
# Epoch 505, Train Loss: 0.006799, Validation Loss: 0.011992
# Epoch 506, Train Loss: 0.006877, Validation Loss: 0.012619
# Epoch 507, Train Loss: 0.007296, Validation Loss: 0.012833
# Epoch 508, Train Loss: 0.006950, Validation Loss: 0.011891
# Epoch 509, Train Loss: 0.006690, Validation Loss: 0.013235
# Epoch 510, Train Loss: 0.007201, Validation Loss: 0.012956
# Epoch 511, Train Loss: 0.006617, Validation Loss: 0.012519
# Epoch 512, Train Loss: 0.006731, Validation Loss: 0.011946
# Epoch 513, Train Loss: 0.006813, Validation Loss: 0.012348
# Epoch 514, Train Loss: 0.006839, Validation Loss: 0.012830
# Epoch 515, Train Loss: 0.006910, Validation Loss: 0.012257
# Epoch 516, Train Loss: 0.006577, Validation Loss: 0.012103
# Epoch 517, Train Loss: 0.006865, Validation Loss: 0.012447
# Epoch 518, Train Loss: 0.007047, Validation Loss: 0.012390
# Epoch 519, Train Loss: 0.006883, Validation Loss: 0.011990
# Epoch 520, Train Loss: 0.006749, Validation Loss: 0.012213
# Epoch 521, Train Loss: 0.006597, Validation Loss: 0.012220
# Epoch 522, Train Loss: 0.006874, Validation Loss: 0.012437
# Epoch 523, Train Loss: 0.006808, Validation Loss: 0.012361
# Epoch 524, Train Loss: 0.006606, Validation Loss: 0.012537
# Epoch 525, Train Loss: 0.006764, Validation Loss: 0.012346
# Epoch 526, Train Loss: 0.006538, Validation Loss: 0.011981
# Epoch 527, Train Loss: 0.006947, Validation Loss: 0.012507
# Epoch 528, Train Loss: 0.007086, Validation Loss: 0.013397
# Epoch 529, Train Loss: 0.007357, Validation Loss: 0.013790
# Epoch 530, Train Loss: 0.006802, Validation Loss: 0.012238
# Epoch 531, Train Loss: 0.006662, Validation Loss: 0.012137
# Epoch 532, Train Loss: 0.006491, Validation Loss: 0.012322
# Epoch 533, Train Loss: 0.006434, Validation Loss: 0.012083
# Epoch 534, Train Loss: 0.006520, Validation Loss: 0.011579
# Saving model at epoch 534 with validation loss 0.011579...
# Epoch 535, Train Loss: 0.006975, Validation Loss: 0.011951
# Epoch 536, Train Loss: 0.006768, Validation Loss: 0.012715
# Epoch 537, Train Loss: 0.006835, Validation Loss: 0.012880
# Epoch 538, Train Loss: 0.006630, Validation Loss: 0.011485
# Saving model at epoch 538 with validation loss 0.011485...
# Epoch 539, Train Loss: 0.006569, Validation Loss: 0.012088
# Epoch 540, Train Loss: 0.006806, Validation Loss: 0.011698
# Epoch 541, Train Loss: 0.006642, Validation Loss: 0.011803
# Epoch 542, Train Loss: 0.006428, Validation Loss: 0.011683
# Epoch 543, Train Loss: 0.006602, Validation Loss: 0.011891
# Epoch 544, Train Loss: 0.006942, Validation Loss: 0.014803
# Epoch 545, Train Loss: 0.007246, Validation Loss: 0.012749
# Epoch 546, Train Loss: 0.006757, Validation Loss: 0.012108
# Epoch 547, Train Loss: 0.007456, Validation Loss: 0.013428
# Epoch 548, Train Loss: 0.006802, Validation Loss: 0.012195
# Epoch 549, Train Loss: 0.006521, Validation Loss: 0.012104
# Epoch 550, Train Loss: 0.006542, Validation Loss: 0.012510
# Epoch 551, Train Loss: 0.006604, Validation Loss: 0.011947
# Epoch 552, Train Loss: 0.006724, Validation Loss: 0.012121
# Epoch 553, Train Loss: 0.007134, Validation Loss: 0.013014
# Epoch 554, Train Loss: 0.006897, Validation Loss: 0.012499
# Epoch 555, Train Loss: 0.006606, Validation Loss: 0.012804
# Epoch 556, Train Loss: 0.007458, Validation Loss: 0.012182
# Epoch 557, Train Loss: 0.006629, Validation Loss: 0.011980
# Epoch 558, Train Loss: 0.006583, Validation Loss: 0.013006
# Epoch 559, Train Loss: 0.006999, Validation Loss: 0.011808
# Epoch 560, Train Loss: 0.006661, Validation Loss: 0.012781
# Epoch 561, Train Loss: 0.006703, Validation Loss: 0.014089
# Epoch 562, Train Loss: 0.006913, Validation Loss: 0.011747
# Epoch 563, Train Loss: 0.006426, Validation Loss: 0.011852
# Epoch 564, Train Loss: 0.006652, Validation Loss: 0.012082
# Epoch 565, Train Loss: 0.006679, Validation Loss: 0.012714
# Epoch 566, Train Loss: 0.006762, Validation Loss: 0.012116
# Epoch 567, Train Loss: 0.007152, Validation Loss: 0.012992
# Epoch 568, Train Loss: 0.006597, Validation Loss: 0.011708
# Epoch 569, Train Loss: 0.006761, Validation Loss: 0.012406
# Epoch 570, Train Loss: 0.006697, Validation Loss: 0.011596
# Epoch 571, Train Loss: 0.006531, Validation Loss: 0.011934
# Epoch 572, Train Loss: 0.006672, Validation Loss: 0.012023
# Epoch 573, Train Loss: 0.006644, Validation Loss: 0.013115
# Epoch 574, Train Loss: 0.007174, Validation Loss: 0.014409
# Epoch 575, Train Loss: 0.007382, Validation Loss: 0.011909
# Epoch 576, Train Loss: 0.006444, Validation Loss: 0.011835
# Epoch 577, Train Loss: 0.006536, Validation Loss: 0.013397
# Epoch 578, Train Loss: 0.006754, Validation Loss: 0.012561
# Epoch 579, Train Loss: 0.006415, Validation Loss: 0.011611
# Epoch 580, Train Loss: 0.006506, Validation Loss: 0.011879
# Epoch 581, Train Loss: 0.006772, Validation Loss: 0.012769
# Epoch 582, Train Loss: 0.006862, Validation Loss: 0.011807
# Epoch 583, Train Loss: 0.006574, Validation Loss: 0.011469
# Saving model at epoch 583 with validation loss 0.011469...
# Epoch 584, Train Loss: 0.006584, Validation Loss: 0.012574
# Epoch 585, Train Loss: 0.006760, Validation Loss: 0.011927
# Epoch 586, Train Loss: 0.006845, Validation Loss: 0.012022
# Epoch 587, Train Loss: 0.006882, Validation Loss: 0.013742
# Epoch 588, Train Loss: 0.006879, Validation Loss: 0.012229
# Epoch 589, Train Loss: 0.006501, Validation Loss: 0.011458
# Saving model at epoch 589 with validation loss 0.011458...
# Epoch 590, Train Loss: 0.006477, Validation Loss: 0.011774
# Epoch 591, Train Loss: 0.006547, Validation Loss: 0.012359
# Epoch 592, Train Loss: 0.006534, Validation Loss: 0.011973
# Epoch 593, Train Loss: 0.006504, Validation Loss: 0.012055
# Epoch 594, Train Loss: 0.006643, Validation Loss: 0.012032
# Epoch 595, Train Loss: 0.006806, Validation Loss: 0.011583
# Epoch 596, Train Loss: 0.006572, Validation Loss: 0.011845
# Epoch 597, Train Loss: 0.006869, Validation Loss: 0.011842
# Epoch 598, Train Loss: 0.006781, Validation Loss: 0.011473
# Epoch 599, Train Loss: 0.006407, Validation Loss: 0.011652
# Epoch 600, Train Loss: 0.006429, Validation Loss: 0.012321
# Epoch 601, Train Loss: 0.007354, Validation Loss: 0.011602
# Epoch 602, Train Loss: 0.006561, Validation Loss: 0.011717
# Epoch 603, Train Loss: 0.006659, Validation Loss: 0.012100
# Epoch 604, Train Loss: 0.007369, Validation Loss: 0.011909
# Epoch 605, Train Loss: 0.006610, Validation Loss: 0.011558
# Epoch 606, Train Loss: 0.006748, Validation Loss: 0.011437
# Saving model at epoch 606 with validation loss 0.011437...
# Epoch 607, Train Loss: 0.006673, Validation Loss: 0.011869
# Epoch 608, Train Loss: 0.006495, Validation Loss: 0.011723
# Epoch 609, Train Loss: 0.006469, Validation Loss: 0.011804
# Epoch 610, Train Loss: 0.006433, Validation Loss: 0.012101
# Epoch 611, Train Loss: 0.006766, Validation Loss: 0.013270
# Epoch 612, Train Loss: 0.006666, Validation Loss: 0.011797
# Epoch 613, Train Loss: 0.006923, Validation Loss: 0.012009
# Epoch 614, Train Loss: 0.006678, Validation Loss: 0.012021
# Epoch 615, Train Loss: 0.006606, Validation Loss: 0.011880
# Epoch 616, Train Loss: 0.006460, Validation Loss: 0.011486
# Epoch 617, Train Loss: 0.007247, Validation Loss: 0.013168
# Epoch 618, Train Loss: 0.006795, Validation Loss: 0.011711
# Epoch 619, Train Loss: 0.006691, Validation Loss: 0.013080
# Epoch 620, Train Loss: 0.006991, Validation Loss: 0.012284
# Epoch 621, Train Loss: 0.006517, Validation Loss: 0.011557
# Epoch 622, Train Loss: 0.006560, Validation Loss: 0.011318
# Saving model at epoch 622 with validation loss 0.011318...
# Epoch 623, Train Loss: 0.006528, Validation Loss: 0.011810
# Epoch 624, Train Loss: 0.006685, Validation Loss: 0.011448
# Epoch 625, Train Loss: 0.006694, Validation Loss: 0.011723
# Epoch 626, Train Loss: 0.006496, Validation Loss: 0.011518
# Epoch 627, Train Loss: 0.006429, Validation Loss: 0.011589
# Epoch 628, Train Loss: 0.007012, Validation Loss: 0.012476
# Epoch 629, Train Loss: 0.006414, Validation Loss: 0.011369
# Epoch 630, Train Loss: 0.006528, Validation Loss: 0.011911
# Epoch 631, Train Loss: 0.006521, Validation Loss: 0.011569
# Epoch 632, Train Loss: 0.006805, Validation Loss: 0.011623
# Epoch 633, Train Loss: 0.006364, Validation Loss: 0.012633
# Epoch 634, Train Loss: 0.006562, Validation Loss: 0.011745
# Epoch 635, Train Loss: 0.006778, Validation Loss: 0.012220
# Epoch 636, Train Loss: 0.006861, Validation Loss: 0.011386
# Epoch 637, Train Loss: 0.006503, Validation Loss: 0.011548
# Epoch 638, Train Loss: 0.006728, Validation Loss: 0.011804
# Epoch 639, Train Loss: 0.006595, Validation Loss: 0.011360
# Epoch 640, Train Loss: 0.006437, Validation Loss: 0.011619
# Epoch 641, Train Loss: 0.006492, Validation Loss: 0.013329
# Epoch 642, Train Loss: 0.006882, Validation Loss: 0.011584
# Epoch 643, Train Loss: 0.006262, Validation Loss: 0.011433
# Epoch 644, Train Loss: 0.006568, Validation Loss: 0.012513
# Epoch 645, Train Loss: 0.006484, Validation Loss: 0.011397
# Epoch 646, Train Loss: 0.006312, Validation Loss: 0.011616
# Epoch 647, Train Loss: 0.006439, Validation Loss: 0.012198
# Epoch 648, Train Loss: 0.007286, Validation Loss: 0.011505
# Epoch 649, Train Loss: 0.007057, Validation Loss: 0.011752
# Epoch 650, Train Loss: 0.006481, Validation Loss: 0.011764
# Epoch 651, Train Loss: 0.006585, Validation Loss: 0.011720
# Epoch 652, Train Loss: 0.006418, Validation Loss: 0.011829
# Epoch 653, Train Loss: 0.006492, Validation Loss: 0.012179
# Epoch 654, Train Loss: 0.006361, Validation Loss: 0.011487
# Epoch 655, Train Loss: 0.006475, Validation Loss: 0.011980
# Epoch 656, Train Loss: 0.006529, Validation Loss: 0.013010
# Epoch 657, Train Loss: 0.006532, Validation Loss: 0.011831
# Epoch 658, Train Loss: 0.006759, Validation Loss: 0.012269
# Epoch 659, Train Loss: 0.006468, Validation Loss: 0.012398
# Epoch 660, Train Loss: 0.006492, Validation Loss: 0.011588
# Epoch 661, Train Loss: 0.006662, Validation Loss: 0.012550
# Epoch 662, Train Loss: 0.006485, Validation Loss: 0.011777
# Epoch 663, Train Loss: 0.006366, Validation Loss: 0.011525
# Epoch 664, Train Loss: 0.006696, Validation Loss: 0.011815
# Epoch 665, Train Loss: 0.006610, Validation Loss: 0.012259
# Epoch 666, Train Loss: 0.006562, Validation Loss: 0.012436
# Epoch 667, Train Loss: 0.007088, Validation Loss: 0.011819
# Epoch 668, Train Loss: 0.006545, Validation Loss: 0.011630
# Epoch 669, Train Loss: 0.006785, Validation Loss: 0.011676
# Epoch 670, Train Loss: 0.006419, Validation Loss: 0.012803
# Epoch 671, Train Loss: 0.006499, Validation Loss: 0.012112
# Epoch 672, Train Loss: 0.006515, Validation Loss: 0.011430
# Epoch 673, Train Loss: 0.006323, Validation Loss: 0.011980
# Epoch 674, Train Loss: 0.006359, Validation Loss: 0.011437
# Epoch 675, Train Loss: 0.006491, Validation Loss: 0.011884
# Epoch 676, Train Loss: 0.006470, Validation Loss: 0.011676
# Epoch 677, Train Loss: 0.006553, Validation Loss: 0.012797
# Epoch 678, Train Loss: 0.006548, Validation Loss: 0.011695
# Epoch 679, Train Loss: 0.006352, Validation Loss: 0.011790
# Epoch 680, Train Loss: 0.006408, Validation Loss: 0.011936
# Epoch 681, Train Loss: 0.006626, Validation Loss: 0.011998
# Epoch 682, Train Loss: 0.006475, Validation Loss: 0.011608
# Epoch 683, Train Loss: 0.006489, Validation Loss: 0.011624
# Epoch 684, Train Loss: 0.006673, Validation Loss: 0.011533
# Epoch 685, Train Loss: 0.006486, Validation Loss: 0.013253
# Epoch 686, Train Loss: 0.007114, Validation Loss: 0.011645
# Epoch 687, Train Loss: 0.006632, Validation Loss: 0.011702
# Epoch 688, Train Loss: 0.006369, Validation Loss: 0.011766
# Epoch 689, Train Loss: 0.006590, Validation Loss: 0.011597
# Epoch 690, Train Loss: 0.006407, Validation Loss: 0.012642
# Epoch 691, Train Loss: 0.006674, Validation Loss: 0.012579
# Epoch 692, Train Loss: 0.006426, Validation Loss: 0.011691
# Epoch 693, Train Loss: 0.006890, Validation Loss: 0.011379
# Epoch 694, Train Loss: 0.006403, Validation Loss: 0.012219
# Epoch 695, Train Loss: 0.006523, Validation Loss: 0.011033
# Saving model at epoch 695 with validation loss 0.011033...
# Epoch 696, Train Loss: 0.006306, Validation Loss: 0.012035
# Epoch 697, Train Loss: 0.006700, Validation Loss: 0.011456
# Epoch 698, Train Loss: 0.006768, Validation Loss: 0.011324
# Epoch 699, Train Loss: 0.006411, Validation Loss: 0.011638
# Epoch 700, Train Loss: 0.006316, Validation Loss: 0.011453
# Epoch 701, Train Loss: 0.006316, Validation Loss: 0.011511
# Epoch 702, Train Loss: 0.006719, Validation Loss: 0.013097
# Epoch 703, Train Loss: 0.006960, Validation Loss: 0.011710
# Epoch 704, Train Loss: 0.006357, Validation Loss: 0.011768
# Epoch 705, Train Loss: 0.006505, Validation Loss: 0.011923
# Epoch 706, Train Loss: 0.006473, Validation Loss: 0.012407
# Epoch 707, Train Loss: 0.006582, Validation Loss: 0.011596
# Epoch 708, Train Loss: 0.006268, Validation Loss: 0.011716
# Epoch 709, Train Loss: 0.006613, Validation Loss: 0.012807
# Epoch 710, Train Loss: 0.007300, Validation Loss: 0.011780
# Epoch 711, Train Loss: 0.006521, Validation Loss: 0.011906
# Epoch 712, Train Loss: 0.006706, Validation Loss: 0.011823
# Epoch 713, Train Loss: 0.006375, Validation Loss: 0.011700
# Epoch 714, Train Loss: 0.006694, Validation Loss: 0.011252
# ...
# Epoch 947, Train Loss: 0.006592, Validation Loss: 0.012905
# Epoch 948, Train Loss: 0.006148, Validation Loss: 0.011600
# Epoch 949, Train Loss: 0.006198, Validation Loss: 0.012358
# Epoch 950, Train Loss: 0.006040, Validation Loss: 0.011747
# Epoch 951, Train Loss: 0.006178, Validation Loss: 0.012243
# Epoch 952, Train Loss: 0.006519, Validation Loss: 0.011835
# Epoch 953, Train Loss: 0.006223, Validation Loss: 0.012329
# Epoch 954, Train Loss: 0.006275, Validation Loss: 0.015011
# Epoch 955, Train Loss: 0.006366, Validation Loss: 0.012208
# Epoch 956, Train Loss: 0.006348, Validation Loss: 0.011837
# Epoch 957, Train Loss: 0.005951, Validation Loss: 0.011437
# Epoch 958, Train Loss: 0.006129, Validation Loss: 0.012002
# Epoch 959, Train Loss: 0.006249, Validation Loss: 0.011617
# Epoch 960, Train Loss: 0.005939, Validation Loss: 0.011973
# Epoch 961, Train Loss: 0.005975, Validation Loss: 0.012247
# Epoch 962, Train Loss: 0.006061, Validation Loss: 0.012875
# Epoch 963, Train Loss: 0.006269, Validation Loss: 0.014835
# Epoch 964, Train Loss: 0.006872, Validation Loss: 0.011654
# Epoch 965, Train Loss: 0.006089, Validation Loss: 0.012331
# Epoch 966, Train Loss: 0.006174, Validation Loss: 0.012095
# Epoch 967, Train Loss: 0.006150, Validation Loss: 0.011771
# Epoch 968, Train Loss: 0.006051, Validation Loss: 0.011852
# Epoch 969, Train Loss: 0.006195, Validation Loss: 0.011777
# Epoch 970, Train Loss: 0.006113, Validation Loss: 0.011699
# Epoch 971, Train Loss: 0.006051, Validation Loss: 0.012854
# Epoch 972, Train Loss: 0.006410, Validation Loss: 0.011623
# Epoch 973, Train Loss: 0.006099, Validation Loss: 0.011454
# Epoch 974, Train Loss: 0.006345, Validation Loss: 0.011754
# Epoch 975, Train Loss: 0.006141, Validation Loss: 0.011575
# Epoch 976, Train Loss: 0.005972, Validation Loss: 0.012184
# Epoch 977, Train Loss: 0.005990, Validation Loss: 0.011844
# Epoch 978, Train Loss: 0.006249, Validation Loss: 0.011648
# Epoch 979, Train Loss: 0.006291, Validation Loss: 0.011882
# Epoch 980, Train Loss: 0.006033, Validation Loss: 0.011498
# Epoch 981, Train Loss: 0.006184, Validation Loss: 0.012325
# Epoch 982, Train Loss: 0.006032, Validation Loss: 0.011747
# Epoch 983, Train Loss: 0.006024, Validation Loss: 0.011751
# Epoch 984, Train Loss: 0.006273, Validation Loss: 0.011891
# Epoch 985, Train Loss: 0.005878, Validation Loss: 0.012903
# Epoch 986, Train Loss: 0.006007, Validation Loss: 0.011578
# Epoch 987, Train Loss: 0.006212, Validation Loss: 0.012128
# Epoch 988, Train Loss: 0.006087, Validation Loss: 0.011626
# Epoch 989, Train Loss: 0.005952, Validation Loss: 0.011877
# Epoch 990, Train Loss: 0.006072, Validation Loss: 0.012112
# Epoch 991, Train Loss: 0.006483, Validation Loss: 0.011865
# Epoch 992, Train Loss: 0.006183, Validation Loss: 0.012206
# Epoch 993, Train Loss: 0.006274, Validation Loss: 0.011962
# Epoch 994, Train Loss: 0.006212, Validation Loss: 0.011747
# Epoch 995, Train Loss: 0.006288, Validation Loss: 0.012090
# Epoch 996, Train Loss: 0.006283, Validation Loss: 0.011881
# Epoch 997, Train Loss: 0.006511, Validation Loss: 0.011905
# Epoch 998, Train Loss: 0.005951, Validation Loss: 0.011711
# Epoch 999, Train Loss: 0.006122, Validation Loss: 0.012534
# Epoch 1000, Train Loss: 0.006935, Validation Loss: 0.013453
# Epoch 1001, Train Loss: 0.006159, Validation Loss: 0.011830
# Epoch 1002, Train Loss: 0.006210, Validation Loss: 0.012065
# Epoch 1003, Train Loss: 0.006172, Validation Loss: 0.012594
# Epoch 1004, Train Loss: 0.006356, Validation Loss: 0.012080
# Epoch 1005, Train Loss: 0.006241, Validation Loss: 0.011610
# Epoch 1006, Train Loss: 0.006091, Validation Loss: 0.011860
# Epoch 1007, Train Loss: 0.006119, Validation Loss: 0.011513
# Epoch 1008, Train Loss: 0.005969, Validation Loss: 0.011452
# Epoch 1009, Train Loss: 0.006115, Validation Loss: 0.011787
# Epoch 1010, Train Loss: 0.006343, Validation Loss: 0.012582
# Epoch 1011, Train Loss: 0.006247, Validation Loss: 0.012446
# Epoch 1012, Train Loss: 0.006155, Validation Loss: 0.011625
# Epoch 1013, Train Loss: 0.005901, Validation Loss: 0.011531
# Epoch 1014, Train Loss: 0.006099, Validation Loss: 0.012047
# Epoch 1015, Train Loss: 0.006030, Validation Loss: 0.012195
# Epoch 1016, Train Loss: 0.006184, Validation Loss: 0.011638
# Epoch 1017, Train Loss: 0.006063, Validation Loss: 0.012914
# Epoch 1018, Train Loss: 0.006473, Validation Loss: 0.011937
# Epoch 1019, Train Loss: 0.006152, Validation Loss: 0.012187
# Epoch 1020, Train Loss: 0.006317, Validation Loss: 0.012386
# Epoch 1021, Train Loss: 0.006092, Validation Loss: 0.011898
# Epoch 1022, Train Loss: 0.006204, Validation Loss: 0.012446
# Epoch 1023, Train Loss: 0.006207, Validation Loss: 0.011884
# Epoch 1024, Train Loss: 0.005985, Validation Loss: 0.012037
# Epoch 1025, Train Loss: 0.006180, Validation Loss: 0.011446
# Epoch 1026, Train Loss: 0.005968, Validation Loss: 0.011867
# Epoch 1027, Train Loss: 0.006152, Validation Loss: 0.012064
# Epoch 1028, Train Loss: 0.006090, Validation Loss: 0.011670
# Epoch 1029, Train Loss: 0.006092, Validation Loss: 0.011381
# Epoch 1030, Train Loss: 0.005959, Validation Loss: 0.011923
# Epoch 1031, Train Loss: 0.005888, Validation Loss: 0.011877
# Epoch 1032, Train Loss: 0.005987, Validation Loss: 0.012238
# Epoch 1033, Train Loss: 0.006123, Validation Loss: 0.011565
# Epoch 1034, Train Loss: 0.006074, Validation Loss: 0.012264
# Epoch 1035, Train Loss: 0.006324, Validation Loss: 0.012340
# Epoch 1036, Train Loss: 0.006577, Validation Loss: 0.014179
# Epoch 1037, Train Loss: 0.006915, Validation Loss: 0.012261
# Epoch 1038, Train Loss: 0.006042, Validation Loss: 0.012010
# Epoch 1039, Train Loss: 0.005939, Validation Loss: 0.011722
# Epoch 1040, Train Loss: 0.005985, Validation Loss: 0.013035
# Epoch 1041, Train Loss: 0.006036, Validation Loss: 0.011617
# Epoch 1042, Train Loss: 0.006355, Validation Loss: 0.013646
# Epoch 1043, Train Loss: 0.006598, Validation Loss: 0.012490
# Epoch 1044, Train Loss: 0.006345, Validation Loss: 0.011582
# Epoch 1045, Train Loss: 0.006334, Validation Loss: 0.012536
# Epoch 1046, Train Loss: 0.006217, Validation Loss: 0.012354
# Epoch 1047, Train Loss: 0.006087, Validation Loss: 0.011586
# Epoch 1048, Train Loss: 0.005946, Validation Loss: 0.011650
# Epoch 1049, Train Loss: 0.006112, Validation Loss: 0.011858
# Epoch 1050, Train Loss: 0.006179, Validation Loss: 0.011756
# Epoch 1051, Train Loss: 0.006147, Validation Loss: 0.012404
# Epoch 1052, Train Loss: 0.006372, Validation Loss: 0.012802
# Epoch 1053, Train Loss: 0.005948, Validation Loss: 0.011845
# Epoch 1054, Train Loss: 0.006017, Validation Loss: 0.011521
# Epoch 1055, Train Loss: 0.006220, Validation Loss: 0.012170
# Epoch 1056, Train Loss: 0.005992, Validation Loss: 0.011561
# Epoch 1057, Train Loss: 0.006089, Validation Loss: 0.011799
# Epoch 1058, Train Loss: 0.006183, Validation Loss: 0.012302
# Epoch 1059, Train Loss: 0.006023, Validation Loss: 0.012093
# Epoch 1060, Train Loss: 0.006019, Validation Loss: 0.011797
# Epoch 1061, Train Loss: 0.005999, Validation Loss: 0.012112
# Epoch 1062, Train Loss: 0.005999, Validation Loss: 0.011979
# Epoch 1063, Train Loss: 0.006006, Validation Loss: 0.012191
# Epoch 1064, Train Loss: 0.005877, Validation Loss: 0.011853
# Epoch 1065, Train Loss: 0.005883, Validation Loss: 0.012218
# Epoch 1066, Train Loss: 0.006382, Validation Loss: 0.011936
# Epoch 1067, Train Loss: 0.006178, Validation Loss: 0.011825
# Epoch 1068, Train Loss: 0.006199, Validation Loss: 0.012219
# Epoch 1069, Train Loss: 0.006270, Validation Loss: 0.012018
# Epoch 1070, Train Loss: 0.006458, Validation Loss: 0.012867
# Epoch 1071, Train Loss: 0.006451, Validation Loss: 0.012038
# Epoch 1072, Train Loss: 0.006064, Validation Loss: 0.012097
# Epoch 1073, Train Loss: 0.005853, Validation Loss: 0.011523
# Epoch 1074, Train Loss: 0.006000, Validation Loss: 0.011703
# Epoch 1075, Train Loss: 0.005931, Validation Loss: 0.011698
# Epoch 1076, Train Loss: 0.006170, Validation Loss: 0.012372
# Epoch 1077, Train Loss: 0.005973, Validation Loss: 0.012904
# Epoch 1078, Train Loss: 0.006117, Validation Loss: 0.011943
# Epoch 1079, Train Loss: 0.006019, Validation Loss: 0.011682
# Epoch 1080, Train Loss: 0.006084, Validation Loss: 0.011880
# Epoch 1081, Train Loss: 0.006001, Validation Loss: 0.012687
# Epoch 1082, Train Loss: 0.006225, Validation Loss: 0.011519
# Epoch 1083, Train Loss: 0.006025, Validation Loss: 0.012228
# Epoch 1084, Train Loss: 0.006314, Validation Loss: 0.012256
# Epoch 1085, Train Loss: 0.005957, Validation Loss: 0.011533
# Epoch 1086, Train Loss: 0.006262, Validation Loss: 0.012745
# Epoch 1087, Train Loss: 0.006010, Validation Loss: 0.011708
# Epoch 1088, Train Loss: 0.005921, Validation Loss: 0.012140
# Epoch 1089, Train Loss: 0.006052, Validation Loss: 0.012286
# Epoch 1090, Train Loss: 0.006235, Validation Loss: 0.012216
# Epoch 1091, Train Loss: 0.006300, Validation Loss: 0.011721
# Epoch 1092, Train Loss: 0.005885, Validation Loss: 0.011909
# Epoch 1093, Train Loss: 0.005958, Validation Loss: 0.012485
# Epoch 1094, Train Loss: 0.006154, Validation Loss: 0.011563
# Epoch 1095, Train Loss: 0.005875, Validation Loss: 0.011950
# Epoch 1096, Train Loss: 0.005818, Validation Loss: 0.012286
# Epoch 1097, Train Loss: 0.006022, Validation Loss: 0.011868
# Epoch 1098, Train Loss: 0.005856, Validation Loss: 0.011780
# Epoch 1099, Train Loss: 0.006421, Validation Loss: 0.014172
# Epoch 1100, Train Loss: 0.006318, Validation Loss: 0.011789
# Epoch 1101, Train Loss: 0.005958, Validation Loss: 0.012510
# Epoch 1102, Train Loss: 0.006379, Validation Loss: 0.013864
# Epoch 1103, Train Loss: 0.006064, Validation Loss: 0.011639
# Epoch 1104, Train Loss: 0.005961, Validation Loss: 0.011828
# Epoch 1105, Train Loss: 0.005980, Validation Loss: 0.011674
# Epoch 1106, Train Loss: 0.005940, Validation Loss: 0.012163
# Epoch 1107, Train Loss: 0.006095, Validation Loss: 0.011569
# Epoch 1108, Train Loss: 0.006082, Validation Loss: 0.012623
# Epoch 1109, Train Loss: 0.006355, Validation Loss: 0.011968
# Epoch 1110, Train Loss: 0.006246, Validation Loss: 0.011920
# Epoch 1111, Train Loss: 0.005991, Validation Loss: 0.011997
# Epoch 1112, Train Loss: 0.005890, Validation Loss: 0.012364
# Epoch 1113, Train Loss: 0.006358, Validation Loss: 0.012026
# Epoch 1114, Train Loss: 0.005893, Validation Loss: 0.011510
# Epoch 1115, Train Loss: 0.005883, Validation Loss: 0.012301
# Epoch 1116, Train Loss: 0.005927, Validation Loss: 0.011846
# Epoch 1117, Train Loss: 0.006117, Validation Loss: 0.012237
# Epoch 1118, Train Loss: 0.005919, Validation Loss: 0.011847
# Epoch 1119, Train Loss: 0.005840, Validation Loss: 0.012194
# Epoch 1120, Train Loss: 0.005994, Validation Loss: 0.012106
# Epoch 1121, Train Loss: 0.005990, Validation Loss: 0.012719
# Epoch 1122, Train Loss: 0.006032, Validation Loss: 0.011880
# Epoch 1123, Train Loss: 0.006410, Validation Loss: 0.012228
# Epoch 1124, Train Loss: 0.005978, Validation Loss: 0.011988
# Epoch 1125, Train Loss: 0.005870, Validation Loss: 0.011833
# Epoch 1126, Train Loss: 0.005891, Validation Loss: 0.011709
# Epoch 1127, Train Loss: 0.005933, Validation Loss: 0.011728
# Epoch 1128, Train Loss: 0.005942, Validation Loss: 0.012640
# Epoch 1129, Train Loss: 0.006048, Validation Loss: 0.012812
# Epoch 1130, Train Loss: 0.005931, Validation Loss: 0.013178
# Epoch 1131, Train Loss: 0.006393, Validation Loss: 0.011868
# Epoch 1132, Train Loss: 0.005942, Validation Loss: 0.012106
# Epoch 1133, Train Loss: 0.005881, Validation Loss: 0.011693
# Epoch 1134, Train Loss: 0.005845, Validation Loss: 0.012161
# Epoch 1135, Train Loss: 0.006054, Validation Loss: 0.012545
# Epoch 1136, Train Loss: 0.005889, Validation Loss: 0.011836
# Epoch 1137, Train Loss: 0.006075, Validation Loss: 0.012059
# Epoch 1138, Train Loss: 0.006261, Validation Loss: 0.012098
# Epoch 1139, Train Loss: 0.005973, Validation Loss: 0.011674
# Epoch 1140, Train Loss: 0.005800, Validation Loss: 0.011871
# Epoch 1141, Train Loss: 0.005806, Validation Loss: 0.011928
# Epoch 1142, Train Loss: 0.006099, Validation Loss: 0.013105
# Epoch 1143, Train Loss: 0.006023, Validation Loss: 0.011805
# Epoch 1144, Train Loss: 0.005830, Validation Loss: 0.011716
# Epoch 1145, Train Loss: 0.005925, Validation Loss: 0.012315
# Epoch 1146, Train Loss: 0.006083, Validation Loss: 0.012569
# Epoch 1147, Train Loss: 0.005949, Validation Loss: 0.011718
# Epoch 1148, Train Loss: 0.006084, Validation Loss: 0.012631
# Epoch 1149, Train Loss: 0.006250, Validation Loss: 0.011756
# Epoch 1150, Train Loss: 0.006018, Validation Loss: 0.011932
# Epoch 1151, Train Loss: 0.006055, Validation Loss: 0.012256
# Epoch 1152, Train Loss: 0.005906, Validation Loss: 0.012596
# Epoch 1153, Train Loss: 0.005864, Validation Loss: 0.012253
# Epoch 1154, Train Loss: 0.006041, Validation Loss: 0.012064
# Epoch 1155, Train Loss: 0.005973, Validation Loss: 0.011911
# Epoch 1156, Train Loss: 0.005881, Validation Loss: 0.012687
# Epoch 1157, Train Loss: 0.005836, Validation Loss: 0.011520
# Epoch 1158, Train Loss: 0.005807, Validation Loss: 0.011885
# Epoch 1159, Train Loss: 0.005821, Validation Loss: 0.011725
# Epoch 1160, Train Loss: 0.006017, Validation Loss: 0.012249
# Epoch 1161, Train Loss: 0.006555, Validation Loss: 0.013096
# Epoch 1162, Train Loss: 0.006277, Validation Loss: 0.011981
# Epoch 1163, Train Loss: 0.005884, Validation Loss: 0.012021
# Epoch 1164, Train Loss: 0.005940, Validation Loss: 0.011631
# Epoch 1165, Train Loss: 0.005984, Validation Loss: 0.012011
# Epoch 1166, Train Loss: 0.005842, Validation Loss: 0.012358
# Epoch 1167, Train Loss: 0.006181, Validation Loss: 0.012606
# Epoch 1168, Train Loss: 0.006098, Validation Loss: 0.011963
# Epoch 1169, Train Loss: 0.005901, Validation Loss: 0.012126
# Epoch 1170, Train Loss: 0.006001, Validation Loss: 0.013143
# Epoch 1171, Train Loss: 0.006020, Validation Loss: 0.011967
# Epoch 1172, Train Loss: 0.006025, Validation Loss: 0.012031
# Epoch 1173, Train Loss: 0.006230, Validation Loss: 0.012964
# Epoch 1174, Train Loss: 0.006049, Validation Loss: 0.011843
# Epoch 1175, Train Loss: 0.005855, Validation Loss: 0.011663
# Epoch 1176, Train Loss: 0.005901, Validation Loss: 0.012347
# Epoch 1177, Train Loss: 0.006228, Validation Loss: 0.012173
# Epoch 1178, Train Loss: 0.005951, Validation Loss: 0.012978
# Epoch 1179, Train Loss: 0.005982, Validation Loss: 0.011711
# Epoch 1180, Train Loss: 0.005717, Validation Loss: 0.012581
# Epoch 1181, Train Loss: 0.006005, Validation Loss: 0.012052
# Epoch 1182, Train Loss: 0.006049, Validation Loss: 0.012208
# Epoch 1183, Train Loss: 0.005897, Validation Loss: 0.011399
# Epoch 1184, Train Loss: 0.005780, Validation Loss: 0.011969
# Epoch 1185, Train Loss: 0.005997, Validation Loss: 0.013187
# Epoch 1186, Train Loss: 0.006356, Validation Loss: 0.011816
# Epoch 1187, Train Loss: 0.005906, Validation Loss: 0.011911
# Epoch 1188, Train Loss: 0.006034, Validation Loss: 0.012141
# Epoch 1189, Train Loss: 0.005993, Validation Loss: 0.012022
# Epoch 1190, Train Loss: 0.005805, Validation Loss: 0.011974
# Epoch 1191, Train Loss: 0.006027, Validation Loss: 0.012037
# Epoch 1192, Train Loss: 0.005947, Validation Loss: 0.012374
# Epoch 1193, Train Loss: 0.005752, Validation Loss: 0.012225
# Epoch 1194, Train Loss: 0.005707, Validation Loss: 0.012839
# Epoch 1195, Train Loss: 0.006424, Validation Loss: 0.012007
# Early stopping triggered.
# Training complete. Best model saved at ./Model/N87.pt.
# C:\Users\USER\AppData\Local\Temp\ipykernel_7548\1888580014.py:126: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_save_path))  # 載入最佳模型
