# %% [markdown]
# # Part 1: Network Training

# %% [markdown]
# ## Step0: Import Package & Hyperparameter Configuration

# %%
# # 清空所有變數
# %reset -f
# # 強制 Python 回收記憶體
# import gc
# gc.collect()

# %% [markdown]
# ### Package

# %%
import os
import torch
import numpy as np
import random
import torch.nn as nn
from torch.autograd import Variable
import matplotlib.pyplot as plt
import time
from datetime import datetime

# %% [markdown]
# ### Hyperparameter Config

# %%
# %%
# Unified Hyperparameter Configuration
class Config:
    SEED = 1
    NUM_EPOCHS = 3000
    BATCH_SIZE = 256
    LEARNING_RATE = 0.002  #論文提供
    LR_SCHEDULER_GAMMA = 0.99  #論文提供
    DECAY_EPOCH = 200
    DECAY_RATIO = 0.5
    EARLY_STOPPING_PATIENCE = 500
    HIDDEN_SIZE = 30
    OPERATOR_SIZE = 30


# Reproducibility
random.seed(Config.SEED)
np.random.seed(Config.SEED)
torch.manual_seed(Config.SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %% [markdown]
# ### Material & Number of Data

# %%
material = "CH467160_Buck"
fix_way = "perChannelScaling_MLP"
note = "n_init2"
downsample = 1024
save_figure = True
timestamp = datetime.now().strftime("%Y%m%d")

# 訓練情況況
plot_interval = 150
train_show_sample = 1

# 定義保存模型的路徑
model_save_dir = f"./Model/{fix_way}/{downsample}/"
os.makedirs(model_save_dir, exist_ok=True)  # 如果路徑不存在，創建路徑
model_save_path = os.path.join(model_save_dir,
                               f"{material}_{note}_{timestamp}.pt")  # 定義模型保存檔名

figure_save_base_path = f"./figure/{fix_way}/{downsample}/"
os.makedirs(figure_save_base_path, exist_ok=True)  # 如果路徑不存在，創建路徑

# Select device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Step1: Data processing and data loader generate

# %%
# %% Preprocess data into a data loader
def get_dataloader(data_B,
                   data_F,
                   data_T,
                   data_H,
                   data_N,
                   data_Hdc,
                   data_Pcv,
                   n_init=16):

    # Data pre-process

    # ── 0. 全域設定/降階設定 ──────────────────────────────
    eps = 1e-8  # 防止除以 0
    if downsample == 1024:
        seq_length = 1024  # 單筆波形點數 (不再 down-sample)
    else:
        seq_length = downsample
        cols = np.linspace(0, 1023, seq_length, dtype=int)
        data_B = data_B[:, cols]
        data_H = data_H[:, cols]

    # ── 1. 波形拼接 (補 n_init 點作初始磁化) ────
    data_length = seq_length + n_init
    data_B = np.hstack((data_B[:, -n_init:], data_B))  # (batch, data_length)
    data_H = np.hstack((data_H[:, -n_init:], data_H))

    # ── 2. 轉成 Tensor ───────────────────────────
    B = torch.from_numpy(data_B).view(-1, data_length, 1).float()  # (B,N,1)
    H = torch.from_numpy(data_H).view(-1, data_length, 1).float()
    F = torch.log10(torch.from_numpy(data_F).view(-1, 1).float())  # 純量
    T = torch.from_numpy(data_T).view(-1, 1).float()
    Hdc = torch.from_numpy(data_Hdc).view(-1, 1).float()
    N = torch.from_numpy(data_N).view(-1, 1).float()
    Pcv = torch.log10(torch.from_numpy(data_Pcv).view(-1, 1).float())

    # ── 3. 每筆樣本各自找最大幅值 (per-profile scale) ─
    scale_B = torch.max(torch.abs(B), dim=1,
                        keepdim=True).values + eps  # (B,1,1)
    scale_H = torch.max(torch.abs(H), dim=1, keepdim=True).values + eps

    # ── 4. 先計算導數，再除以 scale_B ─────────────
    dB = torch.diff(B, dim=1, prepend=B[:, :1])
    dB_dt = dB * (seq_length * F.view(-1, 1, 1))  # 真實斜率
    d2B = torch.diff(dB, dim=1, prepend=dB[:, :1])
    d2B_dt = d2B * (seq_length * F.view(-1, 1, 1))

    # ── 5. 形成模型輸入 (已經縮放到 [-1,1]) ────────
    in_B = B / scale_B
    out_H = H / scale_H  # 預測目標
    in_dB_dt = dB_dt / scale_B
    in_d2B_dt = d2B_dt / scale_B

    # ── 6. 純量特徵：計算 z-score 參數 ─────────────
    def safe_mean_std(tensor, eps=1e-8):
        m = torch.mean(tensor).item()
        s = torch.std(tensor).item()
        return [m, 1.0 if s < eps else s]

    #  Compute normalization parameters (均值 & 標準差)**
    norm = [
        safe_mean_std(F),
        safe_mean_std(T),
        safe_mean_std(Hdc),
        safe_mean_std(N),
        safe_mean_std(Pcv)
    ]

    # 用來做test固定標準化參數的
    print("0.F, 1.T, 2.Hdc, 3.N, 4.Pcv")
    material_name = f"{material}"
    print(f'"{material_name}": [')
    for param in norm:
        print(f"    {param},")
    print("]")

    # Data Normalization
    in_F = (F - norm[0][0]) / norm[0][1]  # F
    in_T = (T - norm[1][0]) / norm[1][1]  # T
    in_Hdc = (Hdc - norm[2][0]) / norm[2][1]  # Hdc
    in_N = (N - norm[3][0]) / norm[3][1]  # N
    in_Pcv = (Pcv - norm[4][0]) / norm[4][1]  # Pcv

    #   → 方便推論復原，保留 scale_B, scale_H 當作額外純量
    aux_features = torch.cat(
        (in_F, in_T, in_Hdc, in_N, in_Pcv, scale_B.squeeze(-1),
         scale_H.squeeze(-1)),  # (batch, 7)
        dim=1)

    # ── 7. 產生初始 Preisach operator 狀態 s0 ──────
    max_B, _ = torch.max(in_B, dim=1)
    min_B, _ = torch.min(in_B, dim=1)
    s0 = get_operator_init(in_B[:, 0] - dB[:, 0] / scale_B.squeeze(-1),
                           dB / scale_B, max_B, min_B)

    # ── 8. 組合 Dataset ───────────────────────────
    wave_inputs = torch.cat(
        (
            in_B,  # ① B
            dB / scale_B,  # ② ΔB
            in_dB_dt,  # ③ dB/dt
            in_d2B_dt),
        dim=2)  # ④ d²B/dt²   → (B,L,4)

    aux_features = torch.cat((in_F, in_T, in_Hdc, in_N), dim=1)  # (B,4)
    amps = torch.cat((scale_B.squeeze(-1), scale_H.squeeze(-1)),
                     dim=1)  # (B,2)

    # 這裡把 Pcv（已 z-score）單獨拿出來當另一個 label
    target_Pcv = in_Pcv  # (B,1)

    full_dataset = torch.utils.data.TensorDataset(
        wave_inputs,  # 0  → 模型序列輸入
        aux_features,  # 1  → 4 個純量
        amps,  # 2  → 幅值係數
        s0,  # 3  → Preisach 初始狀態
        out_H,  # 4  → 目標 H  (已 scale_H)
        target_Pcv)  # 5  → 目標 Pcv (已 z-score)

    # ── 9. Train / Valid split & DataLoader ───────
    train_size = int(0.8 * len(full_dataset))
    valid_size = len(full_dataset) - train_size
    train_set, valid_set = torch.utils.data.random_split(
        full_dataset, [train_size, valid_size],
        generator=torch.Generator().manual_seed(Config.SEED))

    train_loader = torch.utils.data.DataLoader(
        train_set,
        batch_size=Config.BATCH_SIZE,
        shuffle=True,
        #    num_workers=4,
        pin_memory=True,
        collate_fn=filter_input)

    valid_loader = torch.utils.data.DataLoader(
        valid_set,
        batch_size=Config.BATCH_SIZE,
        shuffle=False,
        #    num_workers=4,
        pin_memory=True,
        collate_fn=filter_input)

    return train_loader, valid_loader, norm


# %% Predict the operator state at t0
def get_operator_init(B1,
                      dB,
                      Bmax,
                      Bmin,
                      max_out_H=1,
                      operator_size=Config.OPERATOR_SIZE):
    """Compute the initial state of hysteresis operators"""
    s0 = torch.zeros((dB.shape[0], operator_size))
    operator_thre = torch.from_numpy(
        np.linspace(max_out_H / operator_size, max_out_H,
                    operator_size)).view(1, -1)

    for i in range(dB.shape[0]):
        for j in range(operator_size):
            r = operator_thre[0, j]
            if (Bmax[i] >= r) or (Bmin[i] <= -r):
                if dB[i, 0] >= 0:
                    if B1[i] > Bmin[i] + 2 * r:
                        s0[i, j] = r
                    else:
                        s0[i, j] = B1[i] - (r + Bmin[i])
                else:
                    if B1[i] < Bmax[i] - 2 * r:
                        s0[i, j] = -r
                    else:
                        s0[i, j] = B1[i] + (r - Bmax[i])
    return s0


def filter_input(batch):
    inputs, features, amps, s0, target_H, target_Pcv = zip(*batch)

    inputs = torch.stack(inputs)  # (B,L,4)
    features = torch.stack(features)  # (B,4)
    amps = torch.stack(amps)
    s0 = torch.stack(s0)
    target_H = torch.stack(target_H)[:, -downsample:, :]  # 保留全長
    target_Pcv = torch.stack(target_Pcv)  # (B,1)

    # return inputs, features, s0, target_H, target_Pcv
    return inputs, features, amps, s0, target_H, target_Pcv


# 溫度頻率不變加入微小的 epsilon
def safe_mean_std(tensor, eps=1e-8):
    m_tensor = torch.mean(tensor)  # 還是 Tensor
    s_tensor = torch.std(tensor)  # 還是 Tensor

    m_val = m_tensor.item()  # 第一次轉成 float
    s_val = s_tensor.item()
    if s_val < eps:
        s_val = 1.0
    return [m_val, s_val]  # 直接回傳 float

# %% [markdown]
# ## Step2: Define Network Structure

# %%
# %% Magnetization mechansim-determined neural network
"""
    Parameters:
    - hidden_size: number of eddy current slices (RNN neuron)
    - operator_size: number of operators
    - input_size: number of inputs (1.B 2.dB 3.dB/dt 4.d2B/dt)
    - var_size: number of supplenmentary variables (1.F 2.T 3.Hdc 4.N)        
    - output_size: number of outputs (1.H)
    
    只先把d2B/dt考量在EddyCell裡面
"""


class MMINet(nn.Module):

    def __init__(
            self,
            norm,
            hidden_size=Config.HIDDEN_SIZE,
            operator_size=Config.OPERATOR_SIZE,
            input_size=4,  #!新增d2B(250203)
            var_size=4,
            output_size=1):
        super().__init__()
        self.input_size = input_size
        self.var_size = var_size
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.operator_size = operator_size
        self.norm = norm  #*這裡改成從外部傳入 norm(250203)

        self.rnn1 = StopOperatorCell(self.operator_size)
        self.dnn1 = nn.Linear(self.operator_size + self.var_size, 1)
        #!250520更新：5 (F, T, B, dB/dt, d2B/dt ) + 2 (Hdc, N)
        self.rnn2 = EddyCell(7, self.hidden_size, output_size)
        self.dnn2 = nn.Linear(self.hidden_size, 1)
        self.rnn2_hx = None

        self.loss_mlp = nn.Sequential(
            nn.Linear(self.var_size + 1,
                      64),  # var_size=4: F, T, Hdc, N + 1 for P_prelim
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(32, 1))

    def forward(self, x, var, amps, s0, n_init=16):
        """
         Parameters: 
          - x(batch,seq,input_size): Input features (1.B, 2.dB, 3.dB/dt)  
# !       - var(batch,var_size): Supplementary inputs (1.F 2.T 3.Hdc 4.N) 
          - s0(batch,1): Operator inital states
        """
        batch_size = x.size(0)  # Batch size
        seq_size = x.size(1)  # Ser
        self.rnn1_hx = s0

        # !Initialize DNN2 input (1.B 2.dB/dt 3.d2B)
        # x2 = torch.cat((x[:, :, 0:1], x[:, :, 2:3]), dim=2)
        # !選取 B, dB/dt, d2B/dt
        x2 = torch.cat((x[:, :, 0:1], x[:, :, 2:4]), dim=2)

        for t in range(seq_size):
            # RNN1 input (dB,state)
            self.rnn1_hx = self.rnn1(x[:, t, 1:2], self.rnn1_hx)

            # DNN1 input (rnn1_hx,F,T,Hdc,N)
            dnn1_in = torch.cat((self.rnn1_hx, var), dim=1)

            # H hysteresis prediction
            H_hyst_pred = self.dnn1(dnn1_in)

            # DNN2 input (B,dB/dt,T,F)
            rnn2_in = torch.cat((x2[:, t, :], var), dim=1)

            # Initialize second rnn state
            if t == 0:
                H_eddy_init = x[:, t, 0:1] - H_hyst_pred
                buffer = x.new_ones(x.size(0), self.hidden_size)
                self.rnn2_hx = Variable(
                    (buffer / torch.sum(self.dnn2.weight, dim=1)) *
                    H_eddy_init)

            #rnn2_in = torch.cat((rnn2_in,H_hyst_pred),dim=1)
            self.rnn2_hx = self.rnn2(rnn2_in, self.rnn2_hx)

            # H eddy prediction
            H_eddy = self.dnn2(self.rnn2_hx)

            # H total
            H_total = (H_hyst_pred + H_eddy).view(batch_size, 1,
                                                  self.output_size)
            if t == 0:
                output = H_total
            else:
                output = torch.cat((output, H_total), dim=1)

        H = (output[:, n_init:, :])

        amp_B = amps[:, 0:1]  # (batch,1)
        amp_H = amps[:, 1:2]  # (batch,1)
        B_amp = x[:, n_init:, 0:1] * amp_B.unsqueeze(1)
        H_amp = output[:, n_init:, :] * amp_H.unsqueeze(1)
        P_prelim = torch.trapz(H_amp, B_amp, axis=1) * (10**(
            var[:, 0:1] * self.norm[0][1] + self.norm[0][0]))
        Pcv_log = torch.log10(P_prelim.clamp(min=1e-12))
        Pcv = (Pcv_log - self.norm[4][0]) / self.norm[4][1]
        mlp_input = torch.cat((var, Pcv), dim=1)  # (batch, 5)
        s = self.loss_mlp(mlp_input)
        Pcv_mlp = Pcv + s

        return H, Pcv_mlp


class StopOperatorCell():

    def __init__(self, operator_size):
        self.operator_thre = torch.from_numpy(
            np.linspace(5 / operator_size, 5, operator_size)).view(1, -1)

    def sslu(self, X):
        a = torch.ones_like(X)
        return torch.max(-a, torch.min(a, X))

    def __call__(self, dB, state):
        r = self.operator_thre.to(dB.device)
        output = self.sslu((dB + state) / r) * r
        return output.float()


class EddyCell(nn.Module):

    def __init__(self, input_size, hidden_size, output_size=1):
        super().__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.output_size = output_size

        self.x2h = nn.Linear(input_size, hidden_size, bias=False)
        self.h2h = nn.Linear(hidden_size, hidden_size, bias=False)

    def forward(self, x, hidden=None):
        hidden = self.x2h(x) + self.h2h(hidden)
        hidden = torch.sigmoid(hidden)
        return hidden


def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# ## Step3: Training the Model

# %% [markdown]
# ### Load Dataset

# %%
# %%
def load_dataset(material, base_path="./Data/"):

    in_file1 = f"{base_path}{material}/train/B_Field.csv"
    in_file2 = f"{base_path}{material}/train/Frequency.csv"
    in_file3 = f"{base_path}{material}/train/Temperature.csv"
    in_file4 = f"{base_path}{material}/train/H_Field.csv"
    in_file5 = f"{base_path}{material}/train/Volumetric_Loss.csv"
    in_file6 = f"{base_path}{material}/train/Hdc.csv"  # *250317新增：直流偏置磁場
    in_file7 = f"{base_path}{material}/train/Turns.csv"  # *250317新增：匝數

    data_B = np.genfromtxt(in_file1, delimiter=',')  # N x 1024
    data_F = np.genfromtxt(in_file2, delimiter=',')  # N x 1
    data_T = np.genfromtxt(in_file3, delimiter=',')  # N x 1
    data_H = np.genfromtxt(in_file4, delimiter=',')  # N x 1024
    data_Pcv = np.genfromtxt(in_file5, delimiter=',')  # N x 1
    data_Hdc = np.genfromtxt(in_file6, delimiter=',')  # N x 1
    data_N = np.genfromtxt(in_file7, delimiter=',')  # N x 1

    return data_B, data_F, data_T, data_H, data_Pcv, data_Hdc, data_N

# %% [markdown]
# ### Train Code

# %%
def train_model(norm, train_loader, valid_loader):

    start_time = time.perf_counter()
    model = MMINet(norm=norm).to(device)
    print("=== Start Train  ===")
    print(r"""
    (\_/)
    ( •_•)
    / > 拜託順利阿
    """)
    print("Number of parameters: ", count_parameters(model))

    criterion_H = nn.MSELoss()
    criterion_Pcv = nn.MSELoss()

    optimizer = torch.optim.Adam(model.parameters(), lr=Config.LEARNING_RATE)

    # Loss 記錄
    best_val_loss = float('inf')
    patience_counter = 0
    train_losses = []
    val_losses = []
    fixed_idx = None
    epoch_times = []  # ← 用來保存每個 epoch 的時間

    for epoch in range(Config.NUM_EPOCHS):
        t0 = time.perf_counter()

        model.train()
        train_loss = 0

        for inputs, features, amps, s0, target_H, target_Pcv in train_loader:
            inputs, features, amps, s0, target_H, target_Pcv = inputs.to(
                device), features.to(device), amps.to(device), s0.to(
                    device), target_H.to(device), target_Pcv.to(device)

            optimizer.zero_grad()

            with torch.autocast(device_type="cuda"):
                outputs_H, outputs_Pcv = model(inputs, features, amps,
                                               s0)  # 模型的輸出
                loss_H = criterion_H(outputs_H, target_H)  # 使用真實的 H(t) 計算損失
                loss_Pcv = criterion_Pcv(outputs_Pcv, target_Pcv)
                # if epoch < 1000:
                #     loss = loss_H
                # else:
                #     alpha = (epoch + 1) / Config.NUM_EPOCHS
                #     loss = (1 - alpha) * loss_H + alpha * loss_Pcv
                alpha = 0.5
                # alpha = (epoch + 1) / Config.NUM_EPOCHS
                loss = (1 - alpha) * loss_H + alpha * loss_Pcv

            loss.backward()
            optimizer.step()
            train_loss += loss.item()

        train_loss /= len(train_loader)
        train_losses.append(train_loss)  # **記錄 Train Loss**

        model.eval()
        val_loss = 0

        with torch.no_grad():
            for inputs, features, amps, s0, target_H, target_Pcv in valid_loader:
                inputs, features, amps, s0, target_H, target_Pcv = inputs.to(
                    device), features.to(device), amps.to(device), s0.to(
                        device), target_H.to(device), target_Pcv.to(device)

                outputs_H, outputs_Pcv = model(inputs, features, amps,
                                               s0)  # 模型的輸出
                loss_H = criterion_H(outputs_H, target_H)  # 使用真實的 H(t) 計算損失
                loss_Pcv = criterion_Pcv(outputs_Pcv, target_Pcv)
                # if epoch < 1000:
                #     loss = loss_H
                # else:
                #     alpha = (epoch + 1) / Config.NUM_EPOCHS
                #     loss = (1 - alpha) * loss_H + alpha * loss_Pcv

                # alpha = (epoch + 1) / Config.NUM_EPOCHS
                alpha = 0.5
                loss = (1 - alpha) * loss_H + alpha * loss_Pcv

                val_loss += loss.item()

        val_loss /= len(valid_loader)
        val_losses.append(val_loss)  # **記錄 Validation Loss**

        # ─── 計算並輸出這個 epoch 的耗時 ───────────
        te = time.perf_counter() - t0
        epoch_times.append(te)
        print(
            f"Epoch {epoch+1}, loss_H: {loss_H.item():.6f}, loss_Pcv: {loss_Pcv.item():.6f}"
        )
        print(
            f"Epoch {epoch+1} | Train Loss: {train_loss:.6f} | Val Loss: {val_loss:.6f} | Time: {te:.2f}s"
        )

        # ======================================================繪製訓練情況======================================================

        if (epoch + 1) % plot_interval == 0:

            # 第一次產生固定的隨機索引
            if fixed_idx is None:
                batch_size_fix = 3
                fixed_idx = torch.randperm(batch_size_fix)[:train_show_sample]

            # # -------------------------設定圖表H(t)比較---------------------------------------

            # outputs = [fixed_idx, :downsample,
            #  0].detach().cpu().numpy()
            # targets_np = target_H[fixed_idx, :downsample,
            #                       0].detach().cpu().numpy()

            # plt.figure(figsize=(12, 6))

            # for i in range(outputs.shape[0]):  # 每一批數據繪製一個圖表
            #     plt.plot(outputs[i, :, 0],
            #              label=f"Pred: Sample {i+1}",
            #              linestyle='--',
            #              marker='o')
            #     plt.plot(targets[i, :, 0],
            #              label=f"Target: Sample {i+1}",
            #              linestyle='-',
            #              marker='x')

            # # 添加標題和標籤
            # plt.title(f"Compare - Epoch {epoch + 1}", fontsize=16)
            # plt.xlabel("Index", fontsize=14)
            # plt.ylabel("Value", fontsize=14)
            # plt.legend(loc="upper right", fontsize=12)
            # plt.grid(alpha=0.5)

            # # 顯示圖表
            # plt.show()
            # # -------------------------設定圖表H(t)比較 結束---------------------------------------

            # # -------------------------設定圖表B-H比較---------------------------------------
            # 取對應 sample
            outputs_np = outputs_H[fixed_idx, -downsample:,
                                   0].detach().cpu().numpy()
            targets_np = target_H[fixed_idx, -downsample:,
                                  0].detach().cpu().numpy()
            B_seq_np = inputs[fixed_idx, -downsample:,
                              0].detach().cpu().numpy()

            # 設定圖表
            plt.figure()

            for i in range(train_show_sample):  # 每一批數據繪製一個圖表
                plt.plot(outputs_np[i],
                         B_seq_np[i],
                         label=f"Pred: Sample {i+1}",
                         markersize=1)

                plt.plot(targets_np[i],
                         B_seq_np[i],
                         label=f"Target: Sample {i+1}",
                         alpha=0.5)

            # 添加標題和標籤
            plt.title(f"Compare - Epoch {epoch + 1}")
            plt.xlabel("Index")
            plt.ylabel("Value")
            plt.grid(alpha=0.5)
            plt.legend()
            if save_figure == True:
                figure_save_path1 = os.path.join(
                    figure_save_base_path,
                    f"Compare_Epoch {epoch + 1}.svg")  # 定義模型保存檔名
                plt.savefig(figure_save_path1)
            plt.show()
            # # -------------------------設定圖表B-H比較 END---------------------------------------
        # ======================================================繪製訓練情況  END ======================================================

        # ======================================================Early stop======================================================
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            torch.save(model.state_dict(), model_save_path)  # 保存最佳模型
            print(
                f"Saving model at epoch {epoch+1} with validation loss {val_loss:.6f}..."
            )
            patience_counter = 0
        else:
            patience_counter += 1

        if patience_counter >= Config.EARLY_STOPPING_PATIENCE:
            print("Early stopping triggered.")
            break

        # ======================================================Early stop======================================================

    print(f"Training complete. Best model saved at {model_save_path}.")
    elapsed = time.perf_counter() - start_time  # ← 訓練結束，計算耗時
    hrs = int(elapsed // 3600)
    mins = int((elapsed % 3600) // 60)
    secs = elapsed % 60
    print(f"訓練總耗時：{hrs} 小時 {mins} 分 {secs:.2f} 秒")

    # ==============================繪製 Train Loss 與 Validation Loss 圖==============================
    plt.figure(figsize=(10, 5))
    plt.plot(
        range(1,
              len(train_losses) + 1),
        train_losses,
        label="Train Loss",
    )
    plt.plot(range(1,
                   len(val_losses) + 1),
             val_losses,
             label="Validation Loss")

    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.title("Training & Validation Loss Curve")
    plt.legend()
    plt.grid(alpha=0.5)
    if save_figure == True:
        # 將圖表保存為 SVG 格式
        figure_save_path2 = os.path.join(figure_save_base_path,
                                         "Training_Validation_Loss_Curve.svg")
        plt.savefig(figure_save_path2)
    plt.show()
    # ==============================繪製 Train Loss 與 Validation Loss 圖 END==============================

    # ===================================使用最佳模型來產生驗證結果=============================
    model.load_state_dict(torch.load(model_save_path))  # 載入最佳模型
    model.eval()

    with torch.no_grad():
        for inputs, features, amps, s0, target_H, target_Pcv in valid_loader:
            inputs, features, amps, s0, target_H, target_Pcv = inputs.to(
                device), features.to(device), amps.to(device), s0.to(
                    device), target_H.to(device), target_Pcv.to(device)

            outputs_H, outputs_Pcv = model(inputs, features, amps, s0)
            break  # 只使用一批驗證數據進行可視化

    # 選取對應資料（index tensor 要先轉 list 才能 index numpy）
    outputs_np = outputs_H[fixed_idx, -downsample:, 0].detach().cpu().numpy()
    targets_np = target_H[fixed_idx, -downsample:, 0].detach().cpu().numpy()
    B_seq_np = inputs[fixed_idx, -downsample:, 0].detach().cpu().numpy()

    # 設定圖表
    plt.figure()

    for i in range(train_show_sample):  # 每一批數據繪製一個圖表
        plt.plot(outputs_np[i], B_seq_np[i], label=f"Pred: Sample {i+1}")

        plt.plot(targets_np[i],
                 B_seq_np[i],
                 label=f"Target: Sample {i+1}",
                 alpha=0.7)

    # 添加標題和標籤
    plt.title(f"Best Model - Predicted vs Target")
    plt.xlabel("Index")
    plt.ylabel("Value")
    plt.grid(alpha=0.5)
    plt.legend()
    if save_figure == True:
        figure_save_path3 = os.path.join(
            figure_save_base_path,
            "Best Model_Predicted vs Target.svg")  # 定義模型保存檔名
        plt.savefig(figure_save_path3)

    # ===================================使用最佳模型來產生驗證結果 END=============================

# %% [markdown]
# ### Start Train!!!

# %%
def main():
    # # 這段放在檔案最前面（import 之後）
    # BASE_DIR = Path(__file__).resolve().parent
    # os.chdir(BASE_DIR)
    # print("👉 Switch CWD to script folder:", os.getcwd())

    data_B, data_F, data_T, data_H, data_Pcv, data_Hdc, data_N = load_dataset(
        material)

    train_loader, valid_loader, norm = get_dataloader(data_B, data_F, data_T,
                                                      data_H, data_N, data_Hdc,
                                                      data_Pcv)

    # ---- 印第一個 batch 檢查 ----
    # inputs, features, s0, target_H, target_Pcv = next(iter(train_loader))
    inputs, features, amps, s0, target_H, target_Pcv = next(iter(train_loader))

    print("=== Batch shape check ===")
    print(f"inputs      : {inputs.shape}")  # (batch, seq_len, 4)
    print(f"features    : {features.shape}")  # (batch, 4)
    print(f"s0          : {s0.shape}")  # (batch, operator_size)
    print(f"target_H    : {target_H.shape}")  # (batch, seq_len, 1)
    # print(f"target_Pcv  : {target_Pcv.shape}")  # (batch, 1)
    print()

    # 選一筆樣本看看數值範圍
    idx = 0
    print("範例 inputs[0] (前 3 個時間點):")
    print(inputs[idx, :3, :])  # B, ΔB, dB/dt, d²B/dt² (已歸一化到 ~[-1,1])
    print("範例 features[0]:", features[idx])  # F, T, Hdc, N (已 z-score)
    print("範例 s0[0]:", s0[idx, :5])  # 前 5 個 Preisach operator 狀態
    print("範例 target_H[0] (前 3 點):", target_H[idx, :3, 0])
    # print("範例 target_Pcv[0]:", target_Pcv[idx, 0])

    train_model(norm, train_loader, valid_loader)

# %%
if __name__ == "__main__":
    main()
# Out:
# 0.F, 1.T, 2.Hdc, 3.N, 4.Pcv
# "CH467160_Buck": [
#     [2.0, 1.0],
#     [25.0, 1.0],
#     [1245.2510986328125, 698.5667114257812],
#     [14.20181941986084, 4.4452033042907715],
#     [1.6664491891860962, 0.7449064254760742],
# ]
# === Batch shape check ===
# inputs      : torch.Size([256, 1040, 4])
# features    : torch.Size([256, 4])
# s0          : torch.Size([256, 30])
# target_H    : torch.Size([256, 1024, 1])
#
# 範例 inputs[0] (前 3 個時間點):
# tensor([[-8.2046e-02,  0.0000e+00,  0.0000e+00,  0.0000e+00],
#         [-7.8059e-02,  3.9872e-03,  8.1659e+00,  8.1659e+00],
#         [-7.4073e-02,  3.9859e-03,  8.1631e+00, -2.7768e-03]])
# 範例 features[0]: tensor([ 0.0000,  0.0000, -0.6377, -0.9452])
# 範例 s0[0]: tensor([0.0333, 0.0667, 0.1000, 0.1333, 0.1667])
# 範例 target_H[0] (前 3 點): tensor([0.0015, 0.0055, 0.0094])
# === Start Train  ===
#
#     (\_/)
#     ( •_•)
#     / > 拜託順利阿
#
# Number of parameters:  3673
# Epoch 1, loss_H: 0.057168, loss_Pcv: 52.483227
# Epoch 1 | Train Loss: 106.279563 | Val Loss: 24.400170 | Time: 5.39s
# Saving model at epoch 1 with validation loss 24.400170...
# Epoch 2, loss_H: 0.040179, loss_Pcv: 1.296697
# Epoch 2 | Train Loss: 5.242258 | Val Loss: 0.652289 | Time: 5.19s
# Saving model at epoch 2 with validation loss 0.652289...
# Epoch 3, loss_H: 0.056956, loss_Pcv: 1.053427
# Epoch 3 | Train Loss: 0.608470 | Val Loss: 0.526812 | Time: 5.59s
# Saving model at epoch 3 with validation loss 0.526812...
# Epoch 4, loss_H: 0.060127, loss_Pcv: 0.573369
# Epoch 4 | Train Loss: 0.393712 | Val Loss: 0.288670 | Time: 5.56s
# Saving model at epoch 4 with validation loss 0.288670...
# Epoch 5, loss_H: 0.056932, loss_Pcv: 0.415005
# Epoch 5 | Train Loss: 0.238083 | Val Loss: 0.221668 | Time: 5.45s
# Saving model at epoch 5 with validation loss 0.221668...
# Epoch 6, loss_H: 0.055950, loss_Pcv: 0.285470
# Epoch 6 | Train Loss: 0.213056 | Val Loss: 0.156216 | Time: 5.36s
# Saving model at epoch 6 with validation loss 0.156216...
# Epoch 7, loss_H: 0.055022, loss_Pcv: 0.218201
# Epoch 7 | Train Loss: 0.150030 | Val Loss: 0.121498 | Time: 5.18s
# Saving model at epoch 7 with validation loss 0.121498...
# Epoch 8, loss_H: 0.052939, loss_Pcv: 0.158793
# Epoch 8 | Train Loss: 0.129421 | Val Loss: 0.094242 | Time: 5.25s
# Saving model at epoch 8 with validation loss 0.094242...
# Epoch 9, loss_H: 0.050825, loss_Pcv: 0.110397
# Epoch 9 | Train Loss: 0.101614 | Val Loss: 0.072833 | Time: 5.36s
# Saving model at epoch 9 with validation loss 0.072833...
# Epoch 10, loss_H: 0.049001, loss_Pcv: 0.089669
# Epoch 10 | Train Loss: 0.094730 | Val Loss: 0.062742 | Time: 5.19s
# Saving model at epoch 10 with validation loss 0.062742...
# Epoch 11, loss_H: 0.047215, loss_Pcv: 0.081148
# Epoch 11 | Train Loss: 0.089062 | Val Loss: 0.057749 | Time: 5.11s
# Saving model at epoch 11 with validation loss 0.057749...
# Epoch 12, loss_H: 0.045465, loss_Pcv: 0.073664
# Epoch 12 | Train Loss: 0.084439 | Val Loss: 0.053525 | Time: 5.12s
# Saving model at epoch 12 with validation loss 0.053525...
# Epoch 13, loss_H: 0.043830, loss_Pcv: 0.069302
# Epoch 13 | Train Loss: 0.079804 | Val Loss: 0.050717 | Time: 5.18s
# Saving model at epoch 13 with validation loss 0.050717...
# Epoch 14, loss_H: 0.042327, loss_Pcv: 0.068701
# Epoch 14 | Train Loss: 0.078826 | Val Loss: 0.049558 | Time: 5.27s
# Saving model at epoch 14 with validation loss 0.049558...
# Epoch 15, loss_H: 0.040890, loss_Pcv: 0.067435
# Epoch 15 | Train Loss: 0.076875 | Val Loss: 0.048206 | Time: 5.28s
# Saving model at epoch 15 with validation loss 0.048206...
# Epoch 16, loss_H: 0.039535, loss_Pcv: 0.066219
# Epoch 16 | Train Loss: 0.074408 | Val Loss: 0.046926 | Time: 5.43s
# Saving model at epoch 16 with validation loss 0.046926...
# Epoch 17, loss_H: 0.038277, loss_Pcv: 0.065503
# Epoch 17 | Train Loss: 0.077844 | Val Loss: 0.045897 | Time: 5.40s
# Saving model at epoch 17 with validation loss 0.045897...
# Epoch 18, loss_H: 0.037093, loss_Pcv: 0.063947
# Epoch 18 | Train Loss: 0.073385 | Val Loss: 0.044569 | Time: 5.21s
# Saving model at epoch 18 with validation loss 0.044569...
# Epoch 19, loss_H: 0.035983, loss_Pcv: 0.063974
# Epoch 19 | Train Loss: 0.068719 | Val Loss: 0.043902 | Time: 5.47s
# Saving model at epoch 19 with validation loss 0.043902...
# Epoch 20, loss_H: 0.034974, loss_Pcv: 0.065218
# Epoch 20 | Train Loss: 0.070495 | Val Loss: 0.043806 | Time: 5.17s
# Saving model at epoch 20 with validation loss 0.043806...
# Epoch 21, loss_H: 0.033980, loss_Pcv: 0.063185
# Epoch 21 | Train Loss: 0.068871 | Val Loss: 0.042392 | Time: 5.32s
# Saving model at epoch 21 with validation loss 0.042392...
# Epoch 22, loss_H: 0.033057, loss_Pcv: 0.062735
# Epoch 22 | Train Loss: 0.070064 | Val Loss: 0.041677 | Time: 5.39s
# Saving model at epoch 22 with validation loss 0.041677...
# Epoch 23, loss_H: 0.032201, loss_Pcv: 0.063232
# Epoch 23 | Train Loss: 0.066852 | Val Loss: 0.041391 | Time: 5.12s
# Saving model at epoch 23 with validation loss 0.041391...
# Epoch 24, loss_H: 0.031370, loss_Pcv: 0.061551
# Epoch 24 | Train Loss: 0.065861 | Val Loss: 0.040241 | Time: 5.20s
# Saving model at epoch 24 with validation loss 0.040241...
# Epoch 25, loss_H: 0.030592, loss_Pcv: 0.060659
# Epoch 25 | Train Loss: 0.064827 | Val Loss: 0.039491 | Time: 5.42s
# Saving model at epoch 25 with validation loss 0.039491...
# Epoch 26, loss_H: 0.029879, loss_Pcv: 0.061570
# Epoch 26 | Train Loss: 0.061630 | Val Loss: 0.039495 | Time: 5.43s
# Epoch 27, loss_H: 0.029178, loss_Pcv: 0.062066
# Epoch 27 | Train Loss: 0.060345 | Val Loss: 0.039263 | Time: 5.57s
# Saving model at epoch 27 with validation loss 0.039263...
# Epoch 28, loss_H: 0.028493, loss_Pcv: 0.060448
# Epoch 28 | Train Loss: 0.059405 | Val Loss: 0.038186 | Time: 5.30s
# Saving model at epoch 28 with validation loss 0.038186...
# Epoch 29, loss_H: 0.027851, loss_Pcv: 0.059189
# Epoch 29 | Train Loss: 0.061910 | Val Loss: 0.037358 | Time: 5.24s
# Saving model at epoch 29 with validation loss 0.037358...
# Epoch 30, loss_H: 0.027261, loss_Pcv: 0.060072
# Epoch 30 | Train Loss: 0.056830 | Val Loss: 0.037394 | Time: 5.47s
# Epoch 31, loss_H: 0.026649, loss_Pcv: 0.057968
# Epoch 31 | Train Loss: 0.055186 | Val Loss: 0.036236 | Time: 5.26s
# Saving model at epoch 31 with validation loss 0.036236...
# Epoch 32, loss_H: 0.026106, loss_Pcv: 0.059069
# Epoch 32 | Train Loss: 0.055203 | Val Loss: 0.036405 | Time: 5.10s
# Epoch 33, loss_H: 0.025537, loss_Pcv: 0.058006
# Epoch 33 | Train Loss: 0.054702 | Val Loss: 0.035670 | Time: 5.31s
# Saving model at epoch 33 with validation loss 0.035670...
# Epoch 34, loss_H: 0.024988, loss_Pcv: 0.057502
# Epoch 34 | Train Loss: 0.054927 | Val Loss: 0.035141 | Time: 5.11s
# Saving model at epoch 34 with validation loss 0.035141...
# Epoch 35, loss_H: 0.024460, loss_Pcv: 0.057025
# Epoch 35 | Train Loss: 0.051982 | Val Loss: 0.034666 | Time: 5.20s
# Saving model at epoch 35 with validation loss 0.034666...
# Epoch 36, loss_H: 0.023973, loss_Pcv: 0.057632
# Epoch 36 | Train Loss: 0.052354 | Val Loss: 0.034688 | Time: 5.18s
# Epoch 37, loss_H: 0.023464, loss_Pcv: 0.056125
# Epoch 37 | Train Loss: 0.054013 | Val Loss: 0.033734 | Time: 5.24s
# Saving model at epoch 37 with validation loss 0.033734...
# Epoch 38, loss_H: 0.022978, loss_Pcv: 0.056610
# Epoch 38 | Train Loss: 0.052924 | Val Loss: 0.033645 | Time: 5.46s
# Saving model at epoch 38 with validation loss 0.033645...
# Epoch 39, loss_H: 0.022502, loss_Pcv: 0.056418
# Epoch 39 | Train Loss: 0.050868 | Val Loss: 0.033298 | Time: 5.26s
# Saving model at epoch 39 with validation loss 0.033298...
# Epoch 40, loss_H: 0.022008, loss_Pcv: 0.054833
# Epoch 40 | Train Loss: 0.050225 | Val Loss: 0.032433 | Time: 5.40s
# Saving model at epoch 40 with validation loss 0.032433...
# Epoch 41, loss_H: 0.021591, loss_Pcv: 0.055088
# Epoch 41 | Train Loss: 0.048865 | Val Loss: 0.032300 | Time: 5.44s
# Saving model at epoch 41 with validation loss 0.032300...
# Epoch 42, loss_H: 0.021133, loss_Pcv: 0.054377
# Epoch 42 | Train Loss: 0.050938 | Val Loss: 0.031719 | Time: 5.33s
# Saving model at epoch 42 with validation loss 0.031719...
# Epoch 43, loss_H: 0.020671, loss_Pcv: 0.053381
# Epoch 43 | Train Loss: 0.047869 | Val Loss: 0.031046 | Time: 5.38s
# Saving model at epoch 43 with validation loss 0.031046...
# Epoch 44, loss_H: 0.020230, loss_Pcv: 0.052406
# Epoch 44 | Train Loss: 0.048117 | Val Loss: 0.030473 | Time: 5.23s
# Saving model at epoch 44 with validation loss 0.030473...
# Epoch 45, loss_H: 0.019805, loss_Pcv: 0.051855
# Epoch 45 | Train Loss: 0.047304 | Val Loss: 0.030055 | Time: 5.34s
# Saving model at epoch 45 with validation loss 0.030055...
# Epoch 46, loss_H: 0.019386, loss_Pcv: 0.052332
# Epoch 46 | Train Loss: 0.047643 | Val Loss: 0.029982 | Time: 5.48s
# Saving model at epoch 46 with validation loss 0.029982...
# Epoch 47, loss_H: 0.018955, loss_Pcv: 0.051893
# Epoch 47 | Train Loss: 0.044594 | Val Loss: 0.029518 | Time: 5.48s
# Saving model at epoch 47 with validation loss 0.029518...
# Epoch 48, loss_H: 0.018528, loss_Pcv: 0.050945
# Epoch 48 | Train Loss: 0.046152 | Val Loss: 0.028919 | Time: 5.52s
# Saving model at epoch 48 with validation loss 0.028919...
# Epoch 49, loss_H: 0.018153, loss_Pcv: 0.051772
# Epoch 49 | Train Loss: 0.044295 | Val Loss: 0.029027 | Time: 5.36s
# Epoch 50, loss_H: 0.017700, loss_Pcv: 0.049866
# Epoch 50 | Train Loss: 0.046259 | Val Loss: 0.028064 | Time: 5.25s
# Saving model at epoch 50 with validation loss 0.028064...
# Epoch 51, loss_H: 0.017303, loss_Pcv: 0.049753
# Epoch 51 | Train Loss: 0.043473 | Val Loss: 0.027785 | Time: 5.46s
# Saving model at epoch 51 with validation loss 0.027785...
# Epoch 52, loss_H: 0.016940, loss_Pcv: 0.050630
# Epoch 52 | Train Loss: 0.041212 | Val Loss: 0.028012 | Time: 5.23s
# Epoch 53, loss_H: 0.016520, loss_Pcv: 0.048982
# Epoch 53 | Train Loss: 0.042513 | Val Loss: 0.027081 | Time: 5.34s
# Saving model at epoch 53 with validation loss 0.027081...
# Epoch 54, loss_H: 0.016123, loss_Pcv: 0.048390
# Epoch 54 | Train Loss: 0.039310 | Val Loss: 0.026604 | Time: 5.38s
# Saving model at epoch 54 with validation loss 0.026604...
# Epoch 55, loss_H: 0.015767, loss_Pcv: 0.049068
# Epoch 55 | Train Loss: 0.040017 | Val Loss: 0.026642 | Time: 5.13s
# Epoch 56, loss_H: 0.015380, loss_Pcv: 0.047255
# Epoch 56 | Train Loss: 0.038699 | Val Loss: 0.025711 | Time: 5.66s
# Saving model at epoch 56 with validation loss 0.025711...
# Epoch 57, loss_H: 0.015007, loss_Pcv: 0.046976
# Epoch 57 | Train Loss: 0.041179 | Val Loss: 0.025358 | Time: 5.58s
# Saving model at epoch 57 with validation loss 0.025358...
# Epoch 58, loss_H: 0.014633, loss_Pcv: 0.046263
# Epoch 58 | Train Loss: 0.038242 | Val Loss: 0.024906 | Time: 5.29s
# Saving model at epoch 58 with validation loss 0.024906...
# Epoch 59, loss_H: 0.014284, loss_Pcv: 0.046279
# Epoch 59 | Train Loss: 0.035652 | Val Loss: 0.024697 | Time: 5.67s
# Saving model at epoch 59 with validation loss 0.024697...
# Epoch 60, loss_H: 0.013941, loss_Pcv: 0.046751
# Epoch 60 | Train Loss: 0.037840 | Val Loss: 0.024666 | Time: 5.20s
# Saving model at epoch 60 with validation loss 0.024666...
# Epoch 61, loss_H: 0.013588, loss_Pcv: 0.045740
# Epoch 61 | Train Loss: 0.036963 | Val Loss: 0.024054 | Time: 5.16s
# Saving model at epoch 61 with validation loss 0.024054...
# Epoch 62, loss_H: 0.013192, loss_Pcv: 0.044569
# Epoch 62 | Train Loss: 0.035981 | Val Loss: 0.023360 | Time: 5.27s
# Saving model at epoch 62 with validation loss 0.023360...
# Epoch 63, loss_H: 0.012855, loss_Pcv: 0.043970
# Epoch 63 | Train Loss: 0.035924 | Val Loss: 0.022955 | Time: 5.30s
# Saving model at epoch 63 with validation loss 0.022955...
# Epoch 64, loss_H: 0.012529, loss_Pcv: 0.044165
# Epoch 64 | Train Loss: 0.034355 | Val Loss: 0.022842 | Time: 5.34s
# Saving model at epoch 64 with validation loss 0.022842...
# Epoch 65, loss_H: 0.012172, loss_Pcv: 0.043705
# Epoch 65 | Train Loss: 0.034262 | Val Loss: 0.022394 | Time: 5.21s
# Saving model at epoch 65 with validation loss 0.022394...
# Epoch 66, loss_H: 0.011819, loss_Pcv: 0.042875
# Epoch 66 | Train Loss: 0.032397 | Val Loss: 0.021859 | Time: 4.96s
# Saving model at epoch 66 with validation loss 0.021859...
# Epoch 67, loss_H: 0.011492, loss_Pcv: 0.042093
# Epoch 67 | Train Loss: 0.033054 | Val Loss: 0.021399 | Time: 5.31s
# Saving model at epoch 67 with validation loss 0.021399...
# Epoch 68, loss_H: 0.011187, loss_Pcv: 0.042078
# Epoch 68 | Train Loss: 0.033974 | Val Loss: 0.021193 | Time: 5.40s
# Saving model at epoch 68 with validation loss 0.021193...
# Epoch 69, loss_H: 0.010855, loss_Pcv: 0.041309
# Epoch 69 | Train Loss: 0.031870 | Val Loss: 0.020702 | Time: 5.24s
# Saving model at epoch 69 with validation loss 0.020702...
# Epoch 70, loss_H: 0.010554, loss_Pcv: 0.041025
# Epoch 70 | Train Loss: 0.032612 | Val Loss: 0.020413 | Time: 5.18s
# Saving model at epoch 70 with validation loss 0.020413...
# Epoch 71, loss_H: 0.010217, loss_Pcv: 0.039844
# Epoch 71 | Train Loss: 0.029959 | Val Loss: 0.019784 | Time: 5.01s
# Saving model at epoch 71 with validation loss 0.019784...
# Epoch 72, loss_H: 0.009892, loss_Pcv: 0.039758
# Epoch 72 | Train Loss: 0.032030 | Val Loss: 0.019497 | Time: 5.22s
# Saving model at epoch 72 with validation loss 0.019497...
# Epoch 73, loss_H: 0.009585, loss_Pcv: 0.039648
# Epoch 73 | Train Loss: 0.028640 | Val Loss: 0.019240 | Time: 5.28s
# Saving model at epoch 73 with validation loss 0.019240...
# Epoch 74, loss_H: 0.009276, loss_Pcv: 0.038720
# Epoch 74 | Train Loss: 0.028863 | Val Loss: 0.018728 | Time: 5.24s
# Saving model at epoch 74 with validation loss 0.018728...
# Epoch 75, loss_H: 0.008997, loss_Pcv: 0.038524
# Epoch 75 | Train Loss: 0.027066 | Val Loss: 0.018528 | Time: 5.16s
# Saving model at epoch 75 with validation loss 0.018528...
# Epoch 76, loss_H: 0.008711, loss_Pcv: 0.038976
# Epoch 76 | Train Loss: 0.027153 | Val Loss: 0.018470 | Time: 5.16s
# Saving model at epoch 76 with validation loss 0.018470...
# Epoch 77, loss_H: 0.008382, loss_Pcv: 0.037596
# Epoch 77 | Train Loss: 0.026859 | Val Loss: 0.017708 | Time: 5.00s
# Saving model at epoch 77 with validation loss 0.017708...
# Epoch 78, loss_H: 0.008143, loss_Pcv: 0.037593
# Epoch 78 | Train Loss: 0.025754 | Val Loss: 0.017525 | Time: 5.37s
# Saving model at epoch 78 with validation loss 0.017525...
# Epoch 79, loss_H: 0.007881, loss_Pcv: 0.036829
# Epoch 79 | Train Loss: 0.025406 | Val Loss: 0.017088 | Time: 5.41s
# Saving model at epoch 79 with validation loss 0.017088...
# Epoch 80, loss_H: 0.007610, loss_Pcv: 0.035968
# Epoch 80 | Train Loss: 0.025057 | Val Loss: 0.016610 | Time: 5.31s
# Saving model at epoch 80 with validation loss 0.016610...
# Epoch 81, loss_H: 0.007350, loss_Pcv: 0.035492
# Epoch 81 | Train Loss: 0.024181 | Val Loss: 0.016260 | Time: 5.23s
# Saving model at epoch 81 with validation loss 0.016260...
# Epoch 82, loss_H: 0.007106, loss_Pcv: 0.035298
# Epoch 82 | Train Loss: 0.022517 | Val Loss: 0.016012 | Time: 5.12s
# Saving model at epoch 82 with validation loss 0.016012...
# Epoch 83, loss_H: 0.006852, loss_Pcv: 0.034397
# Epoch 83 | Train Loss: 0.022895 | Val Loss: 0.015519 | Time: 5.38s
# Saving model at epoch 83 with validation loss 0.015519...
# Epoch 84, loss_H: 0.006614, loss_Pcv: 0.034126
# Epoch 84 | Train Loss: 0.023705 | Val Loss: 0.015252 | Time: 5.30s
# Saving model at epoch 84 with validation loss 0.015252...
# Epoch 85, loss_H: 0.006391, loss_Pcv: 0.033752
# Epoch 85 | Train Loss: 0.021566 | Val Loss: 0.014958 | Time: 5.06s
# Saving model at epoch 85 with validation loss 0.014958...
# Epoch 86, loss_H: 0.006127, loss_Pcv: 0.032833
# Epoch 86 | Train Loss: 0.021250 | Val Loss: 0.014450 | Time: 5.15s
# Saving model at epoch 86 with validation loss 0.014450...
# Epoch 87, loss_H: 0.005947, loss_Pcv: 0.033294
# Epoch 87 | Train Loss: 0.020589 | Val Loss: 0.014462 | Time: 5.08s
# Epoch 88, loss_H: 0.005726, loss_Pcv: 0.032478
# Epoch 88 | Train Loss: 0.020066 | Val Loss: 0.013994 | Time: 5.21s
# Saving model at epoch 88 with validation loss 0.013994...
# Epoch 89, loss_H: 0.005502, loss_Pcv: 0.031347
# Epoch 89 | Train Loss: 0.019876 | Val Loss: 0.013446 | Time: 5.24s
# Saving model at epoch 89 with validation loss 0.013446...
# Epoch 90, loss_H: 0.005309, loss_Pcv: 0.030979
# Epoch 90 | Train Loss: 0.019126 | Val Loss: 0.013156 | Time: 5.26s
# Saving model at epoch 90 with validation loss 0.013156...
# Epoch 91, loss_H: 0.005143, loss_Pcv: 0.030839
# Epoch 91 | Train Loss: 0.018704 | Val Loss: 0.012966 | Time: 5.37s
# Saving model at epoch 91 with validation loss 0.012966...
# Epoch 92, loss_H: 0.004955, loss_Pcv: 0.029985
# Epoch 92 | Train Loss: 0.018839 | Val Loss: 0.012531 | Time: 5.17s
# Saving model at epoch 92 with validation loss 0.012531...
# Epoch 93, loss_H: 0.004809, loss_Pcv: 0.029708
# Epoch 93 | Train Loss: 0.017615 | Val Loss: 0.012290 | Time: 5.04s
# Saving model at epoch 93 with validation loss 0.012290...
# Epoch 94, loss_H: 0.004663, loss_Pcv: 0.029371
# Epoch 94 | Train Loss: 0.016703 | Val Loss: 0.012040 | Time: 5.10s
# Saving model at epoch 94 with validation loss 0.012040...
# Epoch 95, loss_H: 0.004509, loss_Pcv: 0.028626
# Epoch 95 | Train Loss: 0.016928 | Val Loss: 0.011668 | Time: 5.28s
# Saving model at epoch 95 with validation loss 0.011668...
# Epoch 96, loss_H: 0.004376, loss_Pcv: 0.028251
# Epoch 96 | Train Loss: 0.015718 | Val Loss: 0.011420 | Time: 5.22s
# Saving model at epoch 96 with validation loss 0.011420...
# Epoch 97, loss_H: 0.004256, loss_Pcv: 0.028095
# Epoch 97 | Train Loss: 0.015084 | Val Loss: 0.011246 | Time: 5.30s
# Saving model at epoch 97 with validation loss 0.011246...
# Epoch 98, loss_H: 0.004135, loss_Pcv: 0.027661
# Epoch 98 | Train Loss: 0.014647 | Val Loss: 0.010973 | Time: 5.06s
# Saving model at epoch 98 with validation loss 0.010973...
# Epoch 99, loss_H: 0.004020, loss_Pcv: 0.027018
# Epoch 99 | Train Loss: 0.015003 | Val Loss: 0.010657 | Time: 4.97s
# Saving model at epoch 99 with validation loss 0.010657...
# Epoch 100, loss_H: 0.003940, loss_Pcv: 0.026845
# Epoch 100 | Train Loss: 0.015125 | Val Loss: 0.010497 | Time: 5.21s
# Saving model at epoch 100 with validation loss 0.010497...
# Epoch 101, loss_H: 0.003826, loss_Pcv: 0.026112
# Epoch 101 | Train Loss: 0.013965 | Val Loss: 0.010181 | Time: 5.28s
# Saving model at epoch 101 with validation loss 0.010181...
# Epoch 102, loss_H: 0.003765, loss_Pcv: 0.026387
# Epoch 102 | Train Loss: 0.015681 | Val Loss: 0.010162 | Time: 5.17s
# Saving model at epoch 102 with validation loss 0.010162...
# Epoch 103, loss_H: 0.003659, loss_Pcv: 0.025702
# Epoch 103 | Train Loss: 0.013115 | Val Loss: 0.009847 | Time: 5.41s
# Saving model at epoch 103 with validation loss 0.009847...
# Epoch 104, loss_H: 0.003600, loss_Pcv: 0.025595
# Epoch 104 | Train Loss: 0.013231 | Val Loss: 0.009718 | Time: 5.17s
# Saving model at epoch 104 with validation loss 0.009718...
# Epoch 105, loss_H: 0.003554, loss_Pcv: 0.025654
# Epoch 105 | Train Loss: 0.012443 | Val Loss: 0.009678 | Time: 5.31s
# Saving model at epoch 105 with validation loss 0.009678...
# Epoch 106, loss_H: 0.003493, loss_Pcv: 0.025136
# Epoch 106 | Train Loss: 0.012166 | Val Loss: 0.009439 | Time: 5.19s
# Saving model at epoch 106 with validation loss 0.009439...
# Epoch 107, loss_H: 0.003437, loss_Pcv: 0.024729
# Epoch 107 | Train Loss: 0.011656 | Val Loss: 0.009260 | Time: 5.22s
# Saving model at epoch 107 with validation loss 0.009260...
# Epoch 108, loss_H: 0.003403, loss_Pcv: 0.024608
# Epoch 108 | Train Loss: 0.011954 | Val Loss: 0.009174 | Time: 5.08s
# Saving model at epoch 108 with validation loss 0.009174...
# Epoch 109, loss_H: 0.003375, loss_Pcv: 0.024748
# Epoch 109 | Train Loss: 0.012952 | Val Loss: 0.009165 | Time: 5.18s
# Saving model at epoch 109 with validation loss 0.009165...
# Epoch 110, loss_H: 0.003315, loss_Pcv: 0.024349
# Epoch 110 | Train Loss: 0.011689 | Val Loss: 0.008978 | Time: 5.07s
# Saving model at epoch 110 with validation loss 0.008978...
# Epoch 111, loss_H: 0.003304, loss_Pcv: 0.024803
# Epoch 111 | Train Loss: 0.011309 | Val Loss: 0.009099 | Time: 5.42s
# Epoch 112, loss_H: 0.003276, loss_Pcv: 0.024322
# Epoch 112 | Train Loss: 0.011324 | Val Loss: 0.008895 | Time: 5.23s
# Saving model at epoch 112 with validation loss 0.008895...
# Epoch 113, loss_H: 0.003244, loss_Pcv: 0.024114
# Epoch 113 | Train Loss: 0.010852 | Val Loss: 0.008786 | Time: 5.26s
# Saving model at epoch 113 with validation loss 0.008786...
# Epoch 114, loss_H: 0.003228, loss_Pcv: 0.023781
# Epoch 114 | Train Loss: 0.010967 | Val Loss: 0.008660 | Time: 5.27s
# Saving model at epoch 114 with validation loss 0.008660...
# Epoch 115, loss_H: 0.003234, loss_Pcv: 0.024137
# Epoch 115 | Train Loss: 0.010725 | Val Loss: 0.008766 | Time: 5.07s
# Epoch 116, loss_H: 0.003196, loss_Pcv: 0.023629
# Epoch 116 | Train Loss: 0.010985 | Val Loss: 0.008559 | Time: 5.40s
# Saving model at epoch 116 with validation loss 0.008559...
# Epoch 117, loss_H: 0.003190, loss_Pcv: 0.023688
# Epoch 117 | Train Loss: 0.010569 | Val Loss: 0.008555 | Time: 5.36s
# Saving model at epoch 117 with validation loss 0.008555...
# Epoch 118, loss_H: 0.003170, loss_Pcv: 0.023655
# Epoch 118 | Train Loss: 0.010018 | Val Loss: 0.008518 | Time: 5.27s
# Saving model at epoch 118 with validation loss 0.008518...
# Epoch 119, loss_H: 0.003153, loss_Pcv: 0.023262
# Epoch 119 | Train Loss: 0.010488 | Val Loss: 0.008373 | Time: 5.18s
# Saving model at epoch 119 with validation loss 0.008373...
# Epoch 120, loss_H: 0.003159, loss_Pcv: 0.023243
# Epoch 120 | Train Loss: 0.010182 | Val Loss: 0.008361 | Time: 4.95s
# Saving model at epoch 120 with validation loss 0.008361...
# Epoch 121, loss_H: 0.003142, loss_Pcv: 0.023147
# Epoch 121 | Train Loss: 0.010119 | Val Loss: 0.008308 | Time: 5.11s
# Saving model at epoch 121 with validation loss 0.008308...
# Epoch 122, loss_H: 0.003133, loss_Pcv: 0.022870
# Epoch 122 | Train Loss: 0.010267 | Val Loss: 0.008206 | Time: 5.16s
# Saving model at epoch 122 with validation loss 0.008206...
# Epoch 123, loss_H: 0.003119, loss_Pcv: 0.022804
# Epoch 123 | Train Loss: 0.010800 | Val Loss: 0.008168 | Time: 5.19s
# Saving model at epoch 123 with validation loss 0.008168...
# Epoch 124, loss_H: 0.003102, loss_Pcv: 0.022586
# Epoch 124 | Train Loss: 0.010256 | Val Loss: 0.008077 | Time: 5.39s
# Saving model at epoch 124 with validation loss 0.008077...
# Epoch 125, loss_H: 0.003098, loss_Pcv: 0.022622
# Epoch 125 | Train Loss: 0.009827 | Val Loss: 0.008078 | Time: 5.21s
# Epoch 126, loss_H: 0.003084, loss_Pcv: 0.022454
# Epoch 126 | Train Loss: 0.010097 | Val Loss: 0.008012 | Time: 5.12s
# Saving model at epoch 126 with validation loss 0.008012...
# Epoch 127, loss_H: 0.003073, loss_Pcv: 0.022362
# Epoch 127 | Train Loss: 0.009623 | Val Loss: 0.007964 | Time: 5.31s
# Saving model at epoch 127 with validation loss 0.007964...
# Epoch 128, loss_H: 0.003074, loss_Pcv: 0.022339
# Epoch 128 | Train Loss: 0.009733 | Val Loss: 0.007947 | Time: 5.34s
# Saving model at epoch 128 with validation loss 0.007947...
# Epoch 129, loss_H: 0.003055, loss_Pcv: 0.022208
# Epoch 129 | Train Loss: 0.010358 | Val Loss: 0.007881 | Time: 5.19s
# Saving model at epoch 129 with validation loss 0.007881...
# Epoch 130, loss_H: 0.003050, loss_Pcv: 0.022122
# Epoch 130 | Train Loss: 0.009979 | Val Loss: 0.007843 | Time: 5.27s
# Saving model at epoch 130 with validation loss 0.007843...
# Epoch 131, loss_H: 0.003042, loss_Pcv: 0.022030
# Epoch 131 | Train Loss: 0.009641 | Val Loss: 0.007808 | Time: 5.03s
# Saving model at epoch 131 with validation loss 0.007808...
# Epoch 132, loss_H: 0.003045, loss_Pcv: 0.022255
# Epoch 132 | Train Loss: 0.009514 | Val Loss: 0.007877 | Time: 5.18s
# Epoch 133, loss_H: 0.003022, loss_Pcv: 0.021848
# Epoch 133 | Train Loss: 0.009532 | Val Loss: 0.007722 | Time: 5.33s
# Saving model at epoch 133 with validation loss 0.007722...
# Epoch 134, loss_H: 0.003020, loss_Pcv: 0.022033
# Epoch 134 | Train Loss: 0.009405 | Val Loss: 0.007773 | Time: 5.23s
# Epoch 135, loss_H: 0.003003, loss_Pcv: 0.021751
# Epoch 135 | Train Loss: 0.010507 | Val Loss: 0.007665 | Time: 5.33s
# Saving model at epoch 135 with validation loss 0.007665...
# Epoch 136, loss_H: 0.002996, loss_Pcv: 0.021581
# Epoch 136 | Train Loss: 0.009529 | Val Loss: 0.007606 | Time: 5.19s
# Saving model at epoch 136 with validation loss 0.007606...
# Epoch 137, loss_H: 0.002997, loss_Pcv: 0.021495
# Epoch 137 | Train Loss: 0.009164 | Val Loss: 0.007580 | Time: 5.08s
# Saving model at epoch 137 with validation loss 0.007580...
# Epoch 138, loss_H: 0.002994, loss_Pcv: 0.021556
# Epoch 138 | Train Loss: 0.009558 | Val Loss: 0.007596 | Time: 5.33s
# Epoch 139, loss_H: 0.002981, loss_Pcv: 0.021477
# Epoch 139 | Train Loss: 0.009082 | Val Loss: 0.007554 | Time: 5.19s
# Saving model at epoch 139 with validation loss 0.007554...
# Epoch 140, loss_H: 0.002967, loss_Pcv: 0.021291
# Epoch 140 | Train Loss: 0.009753 | Val Loss: 0.007484 | Time: 5.13s
# Saving model at epoch 140 with validation loss 0.007484...
# Epoch 141, loss_H: 0.002964, loss_Pcv: 0.021406
# Epoch 141 | Train Loss: 0.009459 | Val Loss: 0.007509 | Time: 5.24s
# Epoch 142, loss_H: 0.002956, loss_Pcv: 0.021280
# Epoch 142 | Train Loss: 0.009105 | Val Loss: 0.007461 | Time: 5.01s
# Saving model at epoch 142 with validation loss 0.007461...
# Epoch 143, loss_H: 0.002958, loss_Pcv: 0.021230
# Epoch 143 | Train Loss: 0.009779 | Val Loss: 0.007443 | Time: 5.07s
# Saving model at epoch 143 with validation loss 0.007443...
# Epoch 144, loss_H: 0.002945, loss_Pcv: 0.021116
# Epoch 144 | Train Loss: 0.009884 | Val Loss: 0.007394 | Time: 5.36s
# Saving model at epoch 144 with validation loss 0.007394...
# Epoch 145, loss_H: 0.002940, loss_Pcv: 0.021152
# Epoch 145 | Train Loss: 0.008842 | Val Loss: 0.007402 | Time: 5.20s
# Epoch 146, loss_H: 0.002933, loss_Pcv: 0.021003
# Epoch 146 | Train Loss: 0.008946 | Val Loss: 0.007347 | Time: 5.29s
# Saving model at epoch 146 with validation loss 0.007347...
# Epoch 147, loss_H: 0.002927, loss_Pcv: 0.020900
# Epoch 147 | Train Loss: 0.010199 | Val Loss: 0.007306 | Time: 5.34s
# Saving model at epoch 147 with validation loss 0.007306...
# Epoch 148, loss_H: 0.002928, loss_Pcv: 0.020946
# Epoch 148 | Train Loss: 0.008867 | Val Loss: 0.007327 | Time: 5.19s
# Epoch 149, loss_H: 0.002923, loss_Pcv: 0.020789
# Epoch 149 | Train Loss: 0.008789 | Val Loss: 0.007279 | Time: 5.23s
# Saving model at epoch 149 with validation loss 0.007279...
# Epoch 150, loss_H: 0.002920, loss_Pcv: 0.020942
# Epoch 150 | Train Loss: 0.008349 | Val Loss: 0.007321 | Time: 5.38s
# Epoch 151, loss_H: 0.002911, loss_Pcv: 0.020655
# Epoch 151 | Train Loss: 0.008655 | Val Loss: 0.007214 | Time: 5.21s
# Saving model at epoch 151 with validation loss 0.007214...
# Epoch 152, loss_H: 0.002911, loss_Pcv: 0.020938
# Epoch 152 | Train Loss: 0.009609 | Val Loss: 0.007307 | Time: 5.19s
# Epoch 153, loss_H: 0.002890, loss_Pcv: 0.020539
# Epoch 153 | Train Loss: 0.008646 | Val Loss: 0.007163 | Time: 5.07s
# Saving model at epoch 153 with validation loss 0.007163...
# Epoch 154, loss_H: 0.002901, loss_Pcv: 0.021004
# Epoch 154 | Train Loss: 0.008603 | Val Loss: 0.007321 | Time: 5.14s
# Epoch 155, loss_H: 0.002884, loss_Pcv: 0.020557
# Epoch 155 | Train Loss: 0.009493 | Val Loss: 0.007152 | Time: 5.60s
# Saving model at epoch 155 with validation loss 0.007152...
# Epoch 156, loss_H: 0.002888, loss_Pcv: 0.020711
# Epoch 156 | Train Loss: 0.008582 | Val Loss: 0.007211 | Time: 5.27s
# Epoch 157, loss_H: 0.002879, loss_Pcv: 0.020600
# Epoch 157 | Train Loss: 0.010117 | Val Loss: 0.007168 | Time: 5.33s
# Epoch 158, loss_H: 0.002871, loss_Pcv: 0.020469
# Epoch 158 | Train Loss: 0.008918 | Val Loss: 0.007119 | Time: 5.14s
# Saving model at epoch 158 with validation loss 0.007119...
# Epoch 159, loss_H: 0.002877, loss_Pcv: 0.020756
# Epoch 159 | Train Loss: 0.009432 | Val Loss: 0.007216 | Time: 5.22s
# Epoch 160, loss_H: 0.002859, loss_Pcv: 0.020413
# Epoch 160 | Train Loss: 0.008359 | Val Loss: 0.007092 | Time: 5.27s
# Saving model at epoch 160 with validation loss 0.007092...
# Epoch 161, loss_H: 0.002866, loss_Pcv: 0.020649
# Epoch 161 | Train Loss: 0.008625 | Val Loss: 0.007178 | Time: 5.35s
# Epoch 162, loss_H: 0.002850, loss_Pcv: 0.020321
# Epoch 162 | Train Loss: 0.008306 | Val Loss: 0.007056 | Time: 5.10s
# Saving model at epoch 162 with validation loss 0.007056...
# Epoch 163, loss_H: 0.002854, loss_Pcv: 0.020404
# Epoch 163 | Train Loss: 0.009096 | Val Loss: 0.007084 | Time: 5.23s
# Epoch 164, loss_H: 0.002843, loss_Pcv: 0.020084
# Epoch 164 | Train Loss: 0.009281 | Val Loss: 0.006984 | Time: 5.05s
# Saving model at epoch 164 with validation loss 0.006984...
# Epoch 165, loss_H: 0.002847, loss_Pcv: 0.020346
# Epoch 165 | Train Loss: 0.008835 | Val Loss: 0.007070 | Time: 5.32s
# Epoch 166, loss_H: 0.002845, loss_Pcv: 0.020178
# Epoch 166 | Train Loss: 0.008100 | Val Loss: 0.007022 | Time: 5.47s
# Epoch 167, loss_H: 0.002838, loss_Pcv: 0.020302
# Epoch 167 | Train Loss: 0.008871 | Val Loss: 0.007062 | Time: 5.29s
# Epoch 168, loss_H: 0.002836, loss_Pcv: 0.019988
# Epoch 168 | Train Loss: 0.008091 | Val Loss: 0.006960 | Time: 5.18s
# Saving model at epoch 168 with validation loss 0.006960...
# Epoch 169, loss_H: 0.002839, loss_Pcv: 0.020452
# Epoch 169 | Train Loss: 0.008258 | Val Loss: 0.007122 | Time: 5.10s
# Epoch 170, loss_H: 0.002826, loss_Pcv: 0.020066
# Epoch 170 | Train Loss: 0.008879 | Val Loss: 0.006966 | Time: 5.08s
# Epoch 171, loss_H: 0.002824, loss_Pcv: 0.020277
# Epoch 171 | Train Loss: 0.008216 | Val Loss: 0.007038 | Time: 5.42s
# Epoch 172, loss_H: 0.002820, loss_Pcv: 0.020221
# Epoch 172 | Train Loss: 0.009136 | Val Loss: 0.007015 | Time: 5.18s
# Epoch 173, loss_H: 0.002814, loss_Pcv: 0.020019
# Epoch 173 | Train Loss: 0.008222 | Val Loss: 0.006946 | Time: 5.25s
# Saving model at epoch 173 with validation loss 0.006946...
# Epoch 174, loss_H: 0.002812, loss_Pcv: 0.020083
# Epoch 174 | Train Loss: 0.008779 | Val Loss: 0.006975 | Time: 5.24s
# Epoch 175, loss_H: 0.002820, loss_Pcv: 0.020144
# Epoch 175 | Train Loss: 0.008860 | Val Loss: 0.007013 | Time: 4.94s
# Epoch 176, loss_H: 0.002807, loss_Pcv: 0.020115
# Epoch 176 | Train Loss: 0.008022 | Val Loss: 0.007000 | Time: 5.23s
# Epoch 177, loss_H: 0.002809, loss_Pcv: 0.020075
# Epoch 177 | Train Loss: 0.008185 | Val Loss: 0.006980 | Time: 5.38s
# Epoch 178, loss_H: 0.002805, loss_Pcv: 0.020135
# Epoch 178 | Train Loss: 0.008206 | Val Loss: 0.006991 | Time: 5.19s
# Epoch 179, loss_H: 0.002795, loss_Pcv: 0.019877
# Epoch 179 | Train Loss: 0.008134 | Val Loss: 0.006891 | Time: 5.02s
# Saving model at epoch 179 with validation loss 0.006891...
# Epoch 180, loss_H: 0.002794, loss_Pcv: 0.020026
# Epoch 180 | Train Loss: 0.009751 | Val Loss: 0.006936 | Time: 5.13s
# Epoch 181, loss_H: 0.002797, loss_Pcv: 0.019971
# Epoch 181 | Train Loss: 0.008173 | Val Loss: 0.006934 | Time: 5.04s
# Epoch 182, loss_H: 0.002795, loss_Pcv: 0.020035
# Epoch 182 | Train Loss: 0.009000 | Val Loss: 0.006966 | Time: 5.16s
# Epoch 183, loss_H: 0.002785, loss_Pcv: 0.019723
# Epoch 183 | Train Loss: 0.009445 | Val Loss: 0.006850 | Time: 5.11s
# Saving model at epoch 183 with validation loss 0.006850...
# Epoch 184, loss_H: 0.002794, loss_Pcv: 0.019795
# Epoch 184 | Train Loss: 0.008019 | Val Loss: 0.006878 | Time: 5.06s
# Epoch 185, loss_H: 0.002790, loss_Pcv: 0.019899
# Epoch 185 | Train Loss: 0.008257 | Val Loss: 0.006915 | Time: 5.14s
# Epoch 186, loss_H: 0.002786, loss_Pcv: 0.019844
# Epoch 186 | Train Loss: 0.007873 | Val Loss: 0.006893 | Time: 4.87s
# Epoch 187, loss_H: 0.002780, loss_Pcv: 0.020017
# Epoch 187 | Train Loss: 0.008944 | Val Loss: 0.006955 | Time: 5.22s
# Epoch 188, loss_H: 0.002780, loss_Pcv: 0.019697
# Epoch 188 | Train Loss: 0.007801 | Val Loss: 0.006837 | Time: 5.45s
# Saving model at epoch 188 with validation loss 0.006837...
# Epoch 189, loss_H: 0.002786, loss_Pcv: 0.019941
# Epoch 189 | Train Loss: 0.007829 | Val Loss: 0.006933 | Time: 5.38s
# Epoch 190, loss_H: 0.002776, loss_Pcv: 0.019673
# Epoch 190 | Train Loss: 0.008111 | Val Loss: 0.006825 | Time: 5.03s
# Saving model at epoch 190 with validation loss 0.006825...
# Epoch 191, loss_H: 0.002780, loss_Pcv: 0.019890
# Epoch 191 | Train Loss: 0.008116 | Val Loss: 0.006903 | Time: 5.21s
# Epoch 192, loss_H: 0.002770, loss_Pcv: 0.019855
# Epoch 192 | Train Loss: 0.008108 | Val Loss: 0.006877 | Time: 4.95s
# Epoch 193, loss_H: 0.002781, loss_Pcv: 0.019702
# Epoch 193 | Train Loss: 0.007868 | Val Loss: 0.006831 | Time: 5.15s
# Epoch 194, loss_H: 0.002772, loss_Pcv: 0.019921
# Epoch 194 | Train Loss: 0.007840 | Val Loss: 0.006904 | Time: 5.10s
# Epoch 195, loss_H: 0.002763, loss_Pcv: 0.019650
# Epoch 195 | Train Loss: 0.008092 | Val Loss: 0.006808 | Time: 4.99s
# Saving model at epoch 195 with validation loss 0.006808...
# Epoch 196, loss_H: 0.002771, loss_Pcv: 0.020024
# Epoch 196 | Train Loss: 0.007889 | Val Loss: 0.006946 | Time: 5.05s
# Epoch 197, loss_H: 0.002760, loss_Pcv: 0.019653
# Epoch 197 | Train Loss: 0.008567 | Val Loss: 0.006808 | Time: 5.11s
# Epoch 198, loss_H: 0.002769, loss_Pcv: 0.019834
# Epoch 198 | Train Loss: 0.007851 | Val Loss: 0.006881 | Time: 5.17s
# Epoch 199, loss_H: 0.002758, loss_Pcv: 0.019528
# Epoch 199 | Train Loss: 0.007988 | Val Loss: 0.006773 | Time: 5.37s
# Saving model at epoch 199 with validation loss 0.006773...
# Epoch 200, loss_H: 0.002766, loss_Pcv: 0.019664
# Epoch 200 | Train Loss: 0.007801 | Val Loss: 0.006825 | Time: 5.12s
# Epoch 201, loss_H: 0.002763, loss_Pcv: 0.019756
# Epoch 201 | Train Loss: 0.008594 | Val Loss: 0.006858 | Time: 5.23s
# Epoch 202, loss_H: 0.002753, loss_Pcv: 0.019539
# Epoch 202 | Train Loss: 0.007930 | Val Loss: 0.006780 | Time: 5.13s
# Epoch 203, loss_H: 0.002758, loss_Pcv: 0.019814
# Epoch 203 | Train Loss: 0.007758 | Val Loss: 0.006874 | Time: 5.10s
# Epoch 204, loss_H: 0.002750, loss_Pcv: 0.019575
# Epoch 204 | Train Loss: 0.007886 | Val Loss: 0.006787 | Time: 5.35s
# Epoch 205, loss_H: 0.002756, loss_Pcv: 0.019609
# Epoch 205 | Train Loss: 0.009377 | Val Loss: 0.006798 | Time: 5.22s
# Epoch 206, loss_H: 0.002755, loss_Pcv: 0.019664
# Epoch 206 | Train Loss: 0.007613 | Val Loss: 0.006828 | Time: 5.10s
# Epoch 207, loss_H: 0.002746, loss_Pcv: 0.019373
# Epoch 207 | Train Loss: 0.007737 | Val Loss: 0.006729 | Time: 5.05s
# Saving model at epoch 207 with validation loss 0.006729...
# Epoch 208, loss_H: 0.002760, loss_Pcv: 0.019764
# Epoch 208 | Train Loss: 0.008422 | Val Loss: 0.006863 | Time: 5.15s
# Epoch 209, loss_H: 0.002743, loss_Pcv: 0.019380
# Epoch 209 | Train Loss: 0.008577 | Val Loss: 0.006731 | Time: 5.29s
# Epoch 210, loss_H: 0.002751, loss_Pcv: 0.019481
# Epoch 210 | Train Loss: 0.007942 | Val Loss: 0.006769 | Time: 5.38s
# Epoch 211, loss_H: 0.002756, loss_Pcv: 0.019911
# Epoch 211 | Train Loss: 0.007707 | Val Loss: 0.006933 | Time: 5.19s
# Epoch 212, loss_H: 0.002746, loss_Pcv: 0.019622
# Epoch 250 | Train Loss: 0.007478 | Val Loss: 0.006737 | Time: 5.05s
# Epoch 251, loss_H: 0.002717, loss_Pcv: 0.019576
# Epoch 251 | Train Loss: 0.007526 | Val Loss: 0.006803 | Time: 5.21s
# Epoch 252, loss_H: 0.002709, loss_Pcv: 0.019104
# Epoch 252 | Train Loss: 0.007548 | Val Loss: 0.006663 | Time: 4.97s
# Epoch 253, loss_H: 0.002719, loss_Pcv: 0.019648
# Epoch 253 | Train Loss: 0.007592 | Val Loss: 0.006832 | Time: 5.30s
# Epoch 254, loss_H: 0.002711, loss_Pcv: 0.019111
# Epoch 254 | Train Loss: 0.007553 | Val Loss: 0.006647 | Time: 5.48s
# Saving model at epoch 254 with validation loss 0.006647...
# Epoch 255, loss_H: 0.002714, loss_Pcv: 0.019437
# Epoch 255 | Train Loss: 0.007417 | Val Loss: 0.006744 | Time: 5.35s
# Epoch 256, loss_H: 0.002711, loss_Pcv: 0.019334
# Epoch 256 | Train Loss: 0.008254 | Val Loss: 0.006701 | Time: 5.11s
# Epoch 257, loss_H: 0.002703, loss_Pcv: 0.019313
# Epoch 257 | Train Loss: 0.008310 | Val Loss: 0.006688 | Time: 5.28s
# Epoch 258, loss_H: 0.002723, loss_Pcv: 0.019714
# Epoch 258 | Train Loss: 0.007475 | Val Loss: 0.006840 | Time: 5.10s
# Epoch 259, loss_H: 0.002714, loss_Pcv: 0.019329
# Epoch 259 | Train Loss: 0.007479 | Val Loss: 0.006709 | Time: 5.17s
# Epoch 260, loss_H: 0.002710, loss_Pcv: 0.019530
# Epoch 260 | Train Loss: 0.007456 | Val Loss: 0.006769 | Time: 5.17s
# Epoch 261, loss_H: 0.002723, loss_Pcv: 0.019909
# Epoch 261 | Train Loss: 0.007598 | Val Loss: 0.006918 | Time: 5.01s
# Epoch 262, loss_H: 0.002703, loss_Pcv: 0.019239
# Epoch 262 | Train Loss: 0.007475 | Val Loss: 0.006667 | Time: 5.09s
# Epoch 263, loss_H: 0.002701, loss_Pcv: 0.019115
# Epoch 263 | Train Loss: 0.007555 | Val Loss: 0.006623 | Time: 5.19s
# Saving model at epoch 263 with validation loss 0.006623...
# Epoch 264, loss_H: 0.002726, loss_Pcv: 0.019676
# Epoch 264 | Train Loss: 0.008260 | Val Loss: 0.006834 | Time: 5.24s
# Epoch 265, loss_H: 0.002699, loss_Pcv: 0.019010
# Epoch 265 | Train Loss: 0.009743 | Val Loss: 0.006604 | Time: 5.37s
# Saving model at epoch 265 with validation loss 0.006604...
# Epoch 266, loss_H: 0.002734, loss_Pcv: 0.020534
# Epoch 266 | Train Loss: 0.007549 | Val Loss: 0.007207 | Time: 5.30s
# Epoch 267, loss_H: 0.002689, loss_Pcv: 0.019266
# Epoch 267 | Train Loss: 0.008270 | Val Loss: 0.006760 | Time: 5.17s
# Epoch 268, loss_H: 0.002723, loss_Pcv: 0.019839
# Epoch 268 | Train Loss: 0.008489 | Val Loss: 0.006899 | Time: 5.20s
# Epoch 288, loss_H: 0.002689, loss_Pcv: 0.019146
# Epoch 288 | Train Loss: 0.007305 | Val Loss: 0.006626 | Time: 5.27s
# Epoch 289, loss_H: 0.002702, loss_Pcv: 0.019184
# Epoch 289 | Train Loss: 0.007345 | Val Loss: 0.006644 | Time: 5.15s
# Epoch 290, loss_H: 0.002685, loss_Pcv: 0.018963
# Epoch 290 | Train Loss: 0.008103 | Val Loss: 0.006570 | Time: 5.30s
# Saving model at epoch 290 with validation loss 0.006570...
# Epoch 291, loss_H: 0.002697, loss_Pcv: 0.019413
# Epoch 291 | Train Loss: 0.008102 | Val Loss: 0.006718 | Time: 5.17s
# Epoch 292, loss_H: 0.002684, loss_Pcv: 0.019143
# Epoch 292 | Train Loss: 0.007953 | Val Loss: 0.006611 | Time: 5.17s
# Epoch 293, loss_H: 0.002682, loss_Pcv: 0.019063
# Epoch 293 | Train Loss: 0.007188 | Val Loss: 0.006596 | Time: 5.39s
# Epoch 294, loss_H: 0.002702, loss_Pcv: 0.019271
# Epoch 294 | Train Loss: 0.007375 | Val Loss: 0.006678 | Time: 5.04s
# Epoch 295, loss_H: 0.002680, loss_Pcv: 0.019080
# Epoch 295 | Train Loss: 0.008034 | Val Loss: 0.006591 | Time: 5.09s
# Epoch 296, loss_H: 0.002687, loss_Pcv: 0.019177
# Epoch 296 | Train Loss: 0.007243 | Val Loss: 0.006630 | Time: 5.00s
# Epoch 297, loss_H: 0.002691, loss_Pcv: 0.019079
# Epoch 297 | Train Loss: 0.007339 | Val Loss: 0.006602 | Time: 5.21s
# Epoch 298, loss_H: 0.002683, loss_Pcv: 0.019080
# Epoch 298 | Train Loss: 0.008124 | Val Loss: 0.006596 | Time: 5.52s
# Epoch 299, loss_H: 0.002689, loss_Pcv: 0.019335
# Epoch 299 | Train Loss: 0.007399 | Val Loss: 0.006685 | Time: 5.11s
# Epoch 300, loss_H: 0.002683, loss_Pcv: 0.019068
# Epoch 300 | Train Loss: 0.007367 | Val Loss: 0.006579 | Time: 4.98s
# Epoch 301, loss_H: 0.002673, loss_Pcv: 0.019014
# Epoch 301 | Train Loss: 0.008791 | Val Loss: 0.006570 | Time: 5.20s
# Saving model at epoch 301 with validation loss 0.006570...
# Epoch 302, loss_H: 0.002722, loss_Pcv: 0.020136
# Epoch 302 | Train Loss: 0.008419 | Val Loss: 0.007017 | Time: 5.07s
# Epoch 303, loss_H: 0.002674, loss_Pcv: 0.018991
# Epoch 303 | Train Loss: 0.007345 | Val Loss: 0.006585 | Time: 5.15s
# Epoch 304, loss_H: 0.002691, loss_Pcv: 0.019112
# Epoch 304 | Train Loss: 0.007311 | Val Loss: 0.006601 | Time: 5.35s
# Epoch 305, loss_H: 0.002700, loss_Pcv: 0.019610
# Epoch 305 | Train Loss: 0.007399 | Val Loss: 0.006783 | Time: 4.97s
# Epoch 306, loss_H: 0.002678, loss_Pcv: 0.019360
# Epoch 306 | Train Loss: 0.008008 | Val Loss: 0.006672 | Time: 5.06s
# Epoch 307, loss_H: 0.002673, loss_Pcv: 0.019078
# Epoch 307 | Train Loss: 0.007309 | Val Loss: 0.006580 | Time: 5.21s
# Epoch 308, loss_H: 0.002679, loss_Pcv: 0.019159
# Epoch 308 | Train Loss: 0.008831 | Val Loss: 0.006597 | Time: 5.17s
# Epoch 309, loss_H: 0.002675, loss_Pcv: 0.019019
# Epoch 309 | Train Loss: 0.007269 | Val Loss: 0.006554 | Time: 5.49s
# Saving model at epoch 309 with validation loss 0.006554...
# Epoch 310, loss_H: 0.002687, loss_Pcv: 0.018901
# Epoch 310 | Train Loss: 0.007185 | Val Loss: 0.006542 | Time: 5.37s
# Saving model at epoch 310 with validation loss 0.006542...
# Epoch 311, loss_H: 0.002680, loss_Pcv: 0.019103
# Epoch 311 | Train Loss: 0.007447 | Val Loss: 0.006591 | Time: 5.13s
# Epoch 312, loss_H: 0.002675, loss_Pcv: 0.019087
# Epoch 312 | Train Loss: 0.007338 | Val Loss: 0.006593 | Time: 5.19s
# Epoch 313, loss_H: 0.002684, loss_Pcv: 0.019531
# Epoch 313 | Train Loss: 0.007221 | Val Loss: 0.006773 | Time: 5.13s
# Epoch 314, loss_H: 0.002681, loss_Pcv: 0.019626
# Epoch 314 | Train Loss: 0.007429 | Val Loss: 0.006798 | Time: 5.20s
# Epoch 315, loss_H: 0.002655, loss_Pcv: 0.019070
# Epoch 315 | Train Loss: 0.007357 | Val Loss: 0.006661 | Time: 5.20s
# Epoch 316, loss_H: 0.002672, loss_Pcv: 0.019270
# Epoch 316 | Train Loss: 0.007476 | Val Loss: 0.006625 | Time: 4.98s
# Epoch 317, loss_H: 0.002675, loss_Pcv: 0.019307
# Epoch 317 | Train Loss: 0.007183 | Val Loss: 0.006636 | Time: 5.11s
# Epoch 318, loss_H: 0.002673, loss_Pcv: 0.018949
# Epoch 318 | Train Loss: 0.007927 | Val Loss: 0.006524 | Time: 5.18s
# Saving model at epoch 318 with validation loss 0.006524...
# Epoch 319, loss_H: 0.002667, loss_Pcv: 0.018971
# Epoch 319 | Train Loss: 0.008106 | Val Loss: 0.006536 | Time: 5.27s
# Epoch 320, loss_H: 0.002663, loss_Pcv: 0.018789
# Epoch 320 | Train Loss: 0.008916 | Val Loss: 0.006489 | Time: 5.59s
# Saving model at epoch 320 with validation loss 0.006489...
# Epoch 321, loss_H: 0.002681, loss_Pcv: 0.019431
# Epoch 321 | Train Loss: 0.007428 | Val Loss: 0.006720 | Time: 5.21s
# Epoch 322, loss_H: 0.002667, loss_Pcv: 0.019001
# Epoch 322 | Train Loss: 0.007439 | Val Loss: 0.006554 | Time: 5.01s
# Epoch 323, loss_H: 0.002648, loss_Pcv: 0.018963
# Epoch 323 | Train Loss: 0.007983 | Val Loss: 0.006598 | Time: 5.10s
# Epoch 324, loss_H: 0.002672, loss_Pcv: 0.019250
# Epoch 324 | Train Loss: 0.007383 | Val Loss: 0.006638 | Time: 5.15s
# Epoch 325, loss_H: 0.002661, loss_Pcv: 0.018879
# ...
